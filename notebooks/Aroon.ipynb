# %%
# !pip install yfinance
# !pip install TA-Lib
# !pip install numpy
# !pip install pandas
# !pip install vectorbt
# !pip install scipy
# %pip install scikit-optimize
# %pip install optuna

# %%
import yfinance as yf
import talib
import numpy as np
import pandas as pd
import vectorbt as vbt
import warnings
from scipy import stats
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore", message="Degrees of freedom <= 0 for slice", category=RuntimeWarning)
warnings.filterwarnings("ignore", message="invalid value encountered in scalar divide", category=RuntimeWarning)

# %%
# DOWNLOAD STOCK DATA FROM 2015 USING YFINANCE

TICKER = '3GOL.L'
START_DATE = '2010-01-01'
TRAIN_RATIO = 0.6

# Download data
stock_data = yf.download(TICKER, start=START_DATE, interval='1d')

if not stock_data.empty:
    print(f"Successfully downloaded {len(stock_data)} records for {TICKER}")
    print(f"Data range: {stock_data.index.min().date()} to {stock_data.index.max().date()}")
else:
    print(f"Failed to download {TICKER} data")

stock_data
# Out:
# C:\Users\harka\AppData\Local\Temp\ipykernel_6096\2653480815.py:8: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Successfully downloaded 3250 records for 3GOL.L
# Data range: 2012-12-20 to 2025-10-31
# Price            Close        High         Low        Open Volume
# Ticker          3GOL.L      3GOL.L      3GOL.L      3GOL.L 3GOL.L
# Date
# 2012-12-20   90.901314   90.901314   90.901314   90.901314      0
# 2012-12-21   93.247002   93.247002   93.247002   93.247002      0
# 2012-12-24   93.128700   93.128700   93.128700   93.128700      0
# 2012-12-27   93.629997   93.629997   93.629997   93.629997      0
# 2012-12-28   92.485001   92.485001   92.485001   92.485001      0
# ...                ...         ...         ...         ...    ...
# 2025-10-27  165.404999  176.309998  162.708572  175.779999  20385
# 2025-10-28  162.520004  204.710480  153.000000  158.869995  33725
# 2025-10-29  166.869995  170.710007  166.250000  167.130005  17314
# 2025-10-30  166.440002  168.539993  161.779999  161.779999   5509
# 2025-10-31  164.860001  170.770004  163.580002  169.449997   7105
#
# [3250 rows x 5 columns]

# %%
# PREPARE PRICE SERIES

def select_close_series(df, ticker):
    if isinstance(df.columns, pd.MultiIndex):
        if ('Close', ticker) in df.columns:
            s = df[('Close', ticker)]
        else:
            cols = [c for c in df.columns if 'Close' in str(c)]
            if not cols:
                raise KeyError("Close not found")
            s = df[cols[0]]
    else:
        s = df['Close']
    return s.astype(float).squeeze()

close = select_close_series(stock_data, TICKER)
close.name = 'price'

# Simple split
split_idx = int(len(close) * TRAIN_RATIO)
train_close = close.iloc[:split_idx].copy()
val_close = close.iloc[split_idx:].copy()

print(f"Data ready: train={train_close.index[0].date()} → {train_close.index[-1].date()} | val={val_close.index[0].date()} → {val_close.index[-1].date()}")
# Out:
# Data ready: train=2012-12-20 → 2020-09-08 | val=2020-09-09 → 2025-10-31

# %% [markdown]
# # Aroon Indicator Strategy
#
# This notebook optimizes an **Aroon indicator crossover strategy** for TQQQ trend following.
#
# **Strategy Logic**:
# - BUY when Aroon Up crosses above Aroon Down
# - SELL when Aroon Up crosses below Aroon Down
#
# **Aroon Indicator**:
# - Aroon Up: Measures time since highest high (0-100)
# - Aroon Down: Measures time since lowest low (0-100)
# - Length parameter: Lookback period for calculation

# %%
# Define Parameter Range for Aroon Optimization

param_bounds = {
    'aroon_length': (5, 200),  # Aroon period (lookback window)
}

print("Parameter Bounds for Optimization:")
print(f"  Aroon Length: {param_bounds['aroon_length'][0]} - {param_bounds['aroon_length'][1]} periods")
print("\n✅ Ready for optimization!")
# Out:
# Parameter Bounds for Optimization:
#   Aroon Length: 5 - 200 periods
#
# ✅ Ready for optimization!

# %%
# Core Optimization Function for Aroon Strategy

def evaluate_aroon_strategy(aroon_length, data=train_close, return_metrics=False):
    """
    Evaluate Aroon crossover strategy.
    
    Args:
        aroon_length: Aroon lookback period
        data: price data to test on
        return_metrics: if True, return full metrics dict; if False, return negative Sortino ratio
    
    Returns:
        Negative Sortino ratio (for minimization) or full metrics dict
    """
    
    try:
        # Calculate Aroon using TA-Lib
        close_array = data.values
        aroon_up, aroon_down = talib.AROON(close_array, close_array, timeperiod=aroon_length)
        
        # Convert to Series
        aroon_up_series = pd.Series(aroon_up, index=data.index)
        aroon_down_series = pd.Series(aroon_down, index=data.index)
        
        # Generate crossover signals
        # BUY: Aroon Up crosses above Aroon Down
        entries = aroon_up_series.vbt.crossed_above(aroon_down_series)
        
        # SELL: Aroon Up crosses below Aroon Down  
        exits = aroon_up_series.vbt.crossed_below(aroon_down_series)
        
        # Convert to arrays
        entries_array = pd.Series(np.asarray(entries).ravel(), index=data.index, dtype=bool)
        exits_array = pd.Series(np.asarray(exits).ravel(), index=data.index, dtype=bool)
        
        # Backtest
        portfolio = vbt.Portfolio.from_signals(
            close=data,
            entries=entries_array,
            exits=exits_array,
            init_cash=100_000,
            fees=0.0005,
            slippage=0.0005,
            freq='D'
        )
        
        # Calculate key metrics
        sharpe_ratio = float(portfolio.sharpe_ratio(freq='D'))
        sortino_ratio = float(portfolio.sortino_ratio(freq='D'))
        total_return = float(portfolio.total_return())
        max_drawdown = float(portfolio.max_drawdown())
        volatility = float(portfolio.annualized_volatility(freq='D'))
        
        # Trade metrics
        trades = portfolio.trades
        total_trades = len(trades)
        
        # Check for sufficient trading activity
        years = max((data.index[-1] - data.index[0]).days / 365.25, 1e-9)
        trades_per_year = total_trades / years
        
        if trades_per_year < 1:  # Too few trades
            if return_metrics:
                return {
                    'aroon_length': aroon_length,
                    'sharpe_ratio': np.nan,
                    'sortino_ratio': np.nan,
                    'total_return': np.nan,
                    'annualized_return': np.nan,
                    'max_drawdown': np.nan,
                    'volatility': np.nan,
                    'total_trades': total_trades,
                    'win_rate': np.nan,
                    'profit_factor': np.nan,
                    'expectancy': np.nan,
                    'trades_per_year': trades_per_year
                }
            return 999.0
        
        if return_metrics:
            # Calculate additional metrics
            win_rate_pct = np.nan
            profit_factor = np.nan
            expectancy = 0.0
            annualized_return = (1.0 + total_return) ** (1.0 / years) - 1.0 if years > 0 else np.nan
            
            if total_trades > 0:
                tr = trades.returns.values if hasattr(trades.returns, 'values') else np.array(trades.returns)
                if tr.size > 0:
                    pos = tr[tr > 0]
                    neg = tr[tr < 0]
                    win_rate_pct = (len(pos) / len(tr)) * 100.0
                    gains = pos.sum() if len(pos) else 0.0
                    losses = abs(neg.sum()) if len(neg) else 0.0
                    profit_factor = (gains / losses) if losses > 0 else np.inf
                    expectancy = float(tr.mean())
            
            return {
                'aroon_length': aroon_length,
                'sharpe_ratio': sharpe_ratio,
                'sortino_ratio': sortino_ratio,
                'total_return': total_return,
                'annualized_return': annualized_return,
                'max_drawdown': max_drawdown,
                'volatility': volatility,
                'total_trades': total_trades,
                'win_rate': win_rate_pct,
                'profit_factor': profit_factor,
                'expectancy': expectancy,
                'trades_per_year': trades_per_year
            }
        else:
            # Return negative Sortino for minimization
            return -sortino_ratio
            
    except Exception as e:
        return 999.0  # Large penalty for errors

print("✅ Core optimization function created for Aroon strategy!")
print("Function evaluates Aroon Up/Down crossover signals.")
# Out:
# ✅ Core optimization function created for Aroon strategy!
# Function evaluates Aroon Up/Down crossover signals.

# %%
# Import optimization libraries
try:
    from skopt import gp_minimize
    from skopt.space import Real
    from skopt.utils import use_named_args
    SKOPT_AVAILABLE = True
except ImportError:
    SKOPT_AVAILABLE = False

try:
    import optuna
    OPTUNA_AVAILABLE = True
except ImportError:
    OPTUNA_AVAILABLE = False

print(f"scikit-optimize: {'✅' if SKOPT_AVAILABLE else '❌'}")
print(f"Optuna: {'✅' if OPTUNA_AVAILABLE else '❌'}")
# Out:
# scikit-optimize: ✅
# Optuna: ✅

# %%
# OPTUNA OPTIMIZATION - Aroon Strategy

print("=" * 70)
print("OPTUNA OPTIMIZATION: Aroon Indicator Strategy")
print(f"Training Period: {train_close.index[0].date()} → {train_close.index[-1].date()}")
print("=" * 70)

optimization_results = []
evaluation_count = 0

def objective(trial):
    """Optuna objective function."""
    global evaluation_count
    evaluation_count += 1
    
    # Suggest parameter
    aroon_length = trial.suggest_int('aroon_length', param_bounds['aroon_length'][0], param_bounds['aroon_length'][1])
    
    # Evaluate strategy
    result = evaluate_aroon_strategy(aroon_length)
    
    # Debug output
    if result == 999.0 and evaluation_count <= 5:
        print(f"Trial {evaluation_count}: Aroon({aroon_length}) → No valid trades")
    elif evaluation_count % 10 == 0 or result != 999.0:
        print(f"Trial {evaluation_count}: Aroon({aroon_length}) → Sortino: {-result:.3f}")
    
    return result

if OPTUNA_AVAILABLE:
    # Create study
    study = optuna.create_study(
        direction='minimize',
        sampler=optuna.samplers.TPESampler(seed=42),
        pruner=optuna.pruners.MedianPruner(n_startup_trials=10, n_warmup_steps=5)
    )
    
    print("\nStarting Optuna optimization...\n")
    
    study.optimize(objective, n_trials=1000, show_progress_bar=True)
    
    # Get best parameters
    best_params = study.best_params
    best_aroon_length = best_params['aroon_length']
    best_sortino = -study.best_value
    
    # Evaluate best parameters to get full metrics
    best_result = evaluate_aroon_strategy(
        best_aroon_length, 
        return_metrics=True
    )
    
    # Create results dataframe
    results_df = pd.DataFrame([best_result])
    
    print("\n✅ Optimization complete!")
    print(f"Best Parameters: Aroon({best_aroon_length})")
    print(f"Sortino Ratio: {best_sortino:.3f}")
    
else:
    print("❌ Optuna not available")
# Out:
# [I 2025-11-01 14:36:47,281] A new study created in memory with name: no-name-f732be23-466d-48c3-b8d8-50dbc477a363
# ======================================================================
# OPTUNA OPTIMIZATION: Aroon Indicator Strategy
# Training Period: 2012-12-20 → 2020-09-08
# ======================================================================
#
# Starting Optuna optimization...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Trial 1: Aroon(78) → Sortino: 1.186
# [I 2025-11-01 14:37:00,330] Trial 0 finished with value: -1.1856798307195446 and parameters: {'aroon_length': 78}. Best is trial 0 with value: -1.1856798307195446.
# Trial 2: Aroon(191) → No valid trades
# [I 2025-11-01 14:37:00,376] Trial 1 finished with value: 999.0 and parameters: {'aroon_length': 191}. Best is trial 0 with value: -1.1856798307195446.
# Trial 3: Aroon(148) → No valid trades
# [I 2025-11-01 14:37:00,424] Trial 2 finished with value: 999.0 and parameters: {'aroon_length': 148}. Best is trial 0 with value: -1.1856798307195446.
# Trial 4: Aroon(122) → Sortino: 0.528
# [I 2025-11-01 14:37:00,471] Trial 3 finished with value: -0.5278068176842773 and parameters: {'aroon_length': 122}. Best is trial 0 with value: -1.1856798307195446.
# Trial 5: Aroon(35) → Sortino: 0.458
# [I 2025-11-01 14:37:00,523] Trial 4 finished with value: -0.45757819486488444 and parameters: {'aroon_length': 35}. Best is trial 0 with value: -1.1856798307195446.
# Trial 6: Aroon(35) → Sortino: 0.458
# [I 2025-11-01 14:37:00,564] Trial 5 finished with value: -0.45757819486488444 and parameters: {'aroon_length': 35}. Best is trial 0 with value: -1.1856798307195446.
# Trial 7: Aroon(16) → Sortino: -0.406
# [I 2025-11-01 14:37:00,606] Trial 6 finished with value: 0.40628725829769125 and parameters: {'aroon_length': 16}. Best is trial 0 with value: -1.1856798307195446.
# [I 2025-11-01 14:37:00,657] Trial 7 finished with value: 999.0 and parameters: {'aroon_length': 174}. Best is trial 0 with value: -1.1856798307195446.
# Trial 9: Aroon(122) → Sortino: 0.528
# [I 2025-11-01 14:37:00,693] Trial 8 finished with value: -0.5278068176842773 and parameters: {'aroon_length': 122}. Best is trial 0 with value: -1.1856798307195446.
# Trial 10: Aroon(143) → Sortino: -999.000
# [I 2025-11-01 14:37:00,748] Trial 9 finished with value: 999.0 and parameters: {'aroon_length': 143}. Best is trial 0 with value: -1.1856798307195446.
# Trial 11: Aroon(78) → Sortino: 1.186
# [I 2025-11-01 14:37:00,827] Trial 10 finished with value: -1.1856798307195446 and parameters: {'aroon_length': 78}. Best is trial 0 with value: -1.1856798307195446.
# Trial 12: Aroon(79) → Sortino: 1.294
# [I 2025-11-01 14:37:00,934] Trial 11 finished with value: -1.2944361556856665 and parameters: {'aroon_length': 79}. Best is trial 11 with value: -1.2944361556856665.
# Trial 13: Aroon(74) → Sortino: 1.259
# [I 2025-11-01 14:37:01,034] Trial 12 finished with value: -1.2591583158757844 and parameters: {'aroon_length': 74}. Best is trial 11 with value: -1.2944361556856665.
# Trial 14: Aroon(72) → Sortino: 1.229
# [I 2025-11-01 14:37:01,210] Trial 13 finished with value: -1.2285030868971416 and parameters: {'aroon_length': 72}. Best is trial 11 with value: -1.2944361556856665.
# Trial 15: Aroon(53) → Sortino: 0.423
# [I 2025-11-01 14:37:01,262] Trial 14 finished with value: -0.42264151486731616 and parameters: {'aroon_length': 53}. Best is trial 11 with value: -1.2944361556856665.
# Trial 16: Aroon(100) → Sortino: 1.677
# [I 2025-11-01 14:37:01,324] Trial 15 finished with value: -1.6768791727265755 and parameters: {'aroon_length': 100}. Best is trial 15 with value: -1.6768791727265755.
# Trial 17: Aroon(106) → Sortino: 1.394
# [I 2025-11-01 14:37:01,362] Trial 16 finished with value: -1.3941449759642115 and parameters: {'aroon_length': 106}. Best is trial 15 with value: -1.6768791727265755.
# Trial 18: Aroon(106) → Sortino: 1.394
# [I 2025-11-01 14:37:01,407] Trial 17 finished with value: -1.3941449759642115 and parameters: {'aroon_length': 106}. Best is trial 15 with value: -1.6768791727265755.
# Trial 19: Aroon(101) → Sortino: 1.619
# [I 2025-11-01 14:37:01,464] Trial 18 finished with value: -1.61889159817128 and parameters: {'aroon_length': 101}. Best is trial 15 with value: -1.6768791727265755.
# Trial 20: Aroon(149) → Sortino: -999.000
# [I 2025-11-01 14:37:01,520] Trial 19 finished with value: 999.0 and parameters: {'aroon_length': 149}. Best is trial 15 with value: -1.6768791727265755.
# [I 2025-11-01 14:37:01,582] Trial 20 finished with value: 999.0 and parameters: {'aroon_length': 124}. Best is trial 15 with value: -1.6768791727265755.
# Trial 22: Aroon(101) → Sortino: 1.619
# [I 2025-11-01 14:37:01,622] Trial 21 finished with value: -1.61889159817128 and parameters: {'aroon_length': 101}. Best is trial 15 with value: -1.6768791727265755.
# Trial 23: Aroon(95) → Sortino: 1.699
# [I 2025-11-01 14:37:01,666] Trial 22 finished with value: -1.699185111447561 and parameters: {'aroon_length': 95}. Best is trial 22 with value: -1.699185111447561.
# Trial 24: Aroon(99) → Sortino: 1.730
# [I 2025-11-01 14:37:01,716] Trial 23 finished with value: -1.7299848773673727 and parameters: {'aroon_length': 99}. Best is trial 23 with value: -1.7299848773673727.
# Trial 25: Aroon(56) → Sortino: 0.567
# [I 2025-11-01 14:37:01,761] Trial 24 finished with value: -0.5668116467870774 and parameters: {'aroon_length': 56}. Best is trial 23 with value: -1.7299848773673727.
# Trial 26: Aroon(89) → Sortino: 1.529
# [I 2025-11-01 14:37:01,822] Trial 25 finished with value: -1.5287301373421274 and parameters: {'aroon_length': 89}. Best is trial 23 with value: -1.7299848773673727.
# [I 2025-11-01 14:37:01,863] Trial 26 finished with value: 999.0 and parameters: {'aroon_length': 134}. Best is trial 23 with value: -1.7299848773673727.
# [I 2025-11-01 14:37:01,911] Trial 27 finished with value: 999.0 and parameters: {'aroon_length': 163}. Best is trial 23 with value: -1.7299848773673727.
# Trial 29: Aroon(57) → Sortino: 0.511
# [I 2025-11-01 14:37:01,963] Trial 28 finished with value: -0.5108250857720978 and parameters: {'aroon_length': 57}. Best is trial 23 with value: -1.7299848773673727.
# Trial 30: Aroon(92) → Sortino: 1.442
# [I 2025-11-01 14:37:02,011] Trial 29 finished with value: -1.441876538327114 and parameters: {'aroon_length': 92}. Best is trial 23 with value: -1.7299848773673727.
# Trial 31: Aroon(115) → Sortino: 1.096
# [I 2025-11-01 14:37:02,064] Trial 30 finished with value: -1.0958855432945291 and parameters: {'aroon_length': 115}. Best is trial 23 with value: -1.7299848773673727.
# Trial 32: Aroon(103) → Sortino: 1.559
# [I 2025-11-01 14:37:02,109] Trial 31 finished with value: -1.5593678170945622 and parameters: {'aroon_length': 103}. Best is trial 23 with value: -1.7299848773673727.
# Trial 33: Aroon(88) → Sortino: 1.521
# [I 2025-11-01 14:37:02,155] Trial 32 finished with value: -1.521316256183971 and parameters: {'aroon_length': 88}. Best is trial 23 with value: -1.7299848773673727.
# Trial 34: Aroon(94) → Sortino: 1.595
# [I 2025-11-01 14:37:02,206] Trial 33 finished with value: -1.5951277480474668 and parameters: {'aroon_length': 94}. Best is trial 23 with value: -1.7299848773673727.
# Trial 35: Aroon(111) → Sortino: 1.192
# [I 2025-11-01 14:37:02,252] Trial 34 finished with value: -1.1916590976916235 and parameters: {'aroon_length': 111}. Best is trial 23 with value: -1.7299848773673727.
# [I 2025-11-01 14:37:02,362] Trial 35 finished with value: 999.0 and parameters: {'aroon_length': 134}. Best is trial 23 with value: -1.7299848773673727.
# Trial 37: Aroon(64) → Sortino: 0.774
# [I 2025-11-01 14:37:02,450] Trial 36 finished with value: -0.7743408967479534 and parameters: {'aroon_length': 64}. Best is trial 23 with value: -1.7299848773673727.
# [I 2025-11-01 14:37:02,524] Trial 37 finished with value: 999.0 and parameters: {'aroon_length': 200}. Best is trial 23 with value: -1.7299848773673727.
# Trial 39: Aroon(38) → Sortino: 0.326
# [I 2025-11-01 14:37:02,574] Trial 38 finished with value: -0.32615721383931495 and parameters: {'aroon_length': 38}. Best is trial 23 with value: -1.7299848773673727.
# Trial 40: Aroon(118) → Sortino: 0.893
# [I 2025-11-01 14:37:02,617] Trial 39 finished with value: -0.8928502789600848 and parameters: {'aroon_length': 118}. Best is trial 23 with value: -1.7299848773673727.
# [I 2025-11-01 14:37:02,665] Trial 40 finished with value: 999.0 and parameters: {'aroon_length': 129}. Best is trial 23 with value: -1.7299848773673727.
# Trial 42: Aroon(94) → Sortino: 1.595
# [I 2025-11-01 14:37:02,717] Trial 41 finished with value: -1.5951277480474668 and parameters: {'aroon_length': 94}. Best is trial 23 with value: -1.7299848773673727.
# Trial 43: Aroon(98) → Sortino: 1.667
# [I 2025-11-01 14:37:02,764] Trial 42 finished with value: -1.6669716504447392 and parameters: {'aroon_length': 98}. Best is trial 23 with value: -1.7299848773673727.
# Trial 44: Aroon(85) → Sortino: 1.624
# [I 2025-11-01 14:37:02,813] Trial 43 finished with value: -1.6241139039092876 and parameters: {'aroon_length': 85}. Best is trial 23 with value: -1.7299848773673727.
# Trial 45: Aroon(83) → Sortino: 1.550
# [I 2025-11-01 14:37:02,862] Trial 44 finished with value: -1.5496976248315664 and parameters: {'aroon_length': 83}. Best is trial 23 with value: -1.7299848773673727.
# Trial 46: Aroon(67) → Sortino: 1.081
# [I 2025-11-01 14:37:02,905] Trial 45 finished with value: -1.0806364880054415 and parameters: {'aroon_length': 67}. Best is trial 23 with value: -1.7299848773673727.
# Trial 47: Aroon(82) → Sortino: 1.460
# [I 2025-11-01 14:37:02,955] Trial 46 finished with value: -1.459605179007072 and parameters: {'aroon_length': 82}. Best is trial 23 with value: -1.7299848773673727.
# Trial 48: Aroon(41) → Sortino: 0.270
# [I 2025-11-01 14:37:03,035] Trial 47 finished with value: -0.2704458676672716 and parameters: {'aroon_length': 41}. Best is trial 23 with value: -1.7299848773673727.
# Trial 49: Aroon(112) → Sortino: 1.136
# [I 2025-11-01 14:37:03,121] Trial 48 finished with value: -1.1363046752425763 and parameters: {'aroon_length': 112}. Best is trial 23 with value: -1.7299848773673727.
# Trial 50: Aroon(70) → Sortino: 1.257
# [I 2025-11-01 14:37:03,276] Trial 49 finished with value: -1.2572641536009677 and parameters: {'aroon_length': 70}. Best is trial 23 with value: -1.7299848773673727.
# Trial 51: Aroon(95) → Sortino: 1.699
# [I 2025-11-01 14:37:03,397] Trial 50 finished with value: -1.699185111447561 and parameters: {'aroon_length': 95}. Best is trial 23 with value: -1.7299848773673727.
# Trial 52: Aroon(97) → Sortino: 1.636
# [I 2025-11-01 14:37:03,506] Trial 51 finished with value: -1.6356863447067507 and parameters: {'aroon_length': 97}. Best is trial 23 with value: -1.7299848773673727.
# Trial 53: Aroon(96) → Sortino: 1.683
# [I 2025-11-01 14:37:03,547] Trial 52 finished with value: -1.6827295923742487 and parameters: {'aroon_length': 96}. Best is trial 23 with value: -1.7299848773673727.
# Trial 54: Aroon(109) → Sortino: 1.321
# [I 2025-11-01 14:37:03,612] Trial 53 finished with value: -1.3206966302260026 and parameters: {'aroon_length': 109}. Best is trial 23 with value: -1.7299848773673727.
# Trial 55: Aroon(122) → Sortino: 0.528
# [I 2025-11-01 14:37:03,654] Trial 54 finished with value: -0.5278068176842773 and parameters: {'aroon_length': 122}. Best is trial 23 with value: -1.7299848773673727.
# Trial 56: Aroon(79) → Sortino: 1.294
# [I 2025-11-01 14:37:03,705] Trial 55 finished with value: -1.2944361556856665 and parameters: {'aroon_length': 79}. Best is trial 23 with value: -1.7299848773673727.
# Trial 57: Aroon(99) → Sortino: 1.730
# [I 2025-11-01 14:37:03,758] Trial 56 finished with value: -1.7299848773673727 and parameters: {'aroon_length': 99}. Best is trial 23 with value: -1.7299848773673727.
# Trial 58: Aroon(75) → Sortino: 1.318
# [I 2025-11-01 14:37:03,799] Trial 57 finished with value: -1.3181979434548285 and parameters: {'aroon_length': 75}. Best is trial 23 with value: -1.7299848773673727.
# Trial 59: Aroon(7) → Sortino: -0.280
# [I 2025-11-01 14:37:03,853] Trial 58 finished with value: 0.2801385450013759 and parameters: {'aroon_length': 7}. Best is trial 23 with value: -1.7299848773673727.
# Trial 60: Aroon(105) → Sortino: 1.455
# [I 2025-11-01 14:37:03,900] Trial 59 finished with value: -1.4552693833113513 and parameters: {'aroon_length': 105}. Best is trial 23 with value: -1.7299848773673727.
# [I 2025-11-01 14:37:03,956] Trial 60 finished with value: 999.0 and parameters: {'aroon_length': 141}. Best is trial 23 with value: -1.7299848773673727.
# Trial 62: Aroon(100) → Sortino: 1.677
# [I 2025-11-01 14:37:03,998] Trial 61 finished with value: -1.6768791727265755 and parameters: {'aroon_length': 100}. Best is trial 23 with value: -1.7299848773673727.
# Trial 63: Aroon(88) → Sortino: 1.521
# [I 2025-11-01 14:37:04,038] Trial 62 finished with value: -1.521316256183971 and parameters: {'aroon_length': 88}. Best is trial 23 with value: -1.7299848773673727.
# Trial 64: Aroon(118) → Sortino: 0.893
# [I 2025-11-01 14:37:04,095] Trial 63 finished with value: -0.8928502789600848 and parameters: {'aroon_length': 118}. Best is trial 23 with value: -1.7299848773673727.
# Trial 65: Aroon(100) → Sortino: 1.677
# [I 2025-11-01 14:37:04,141] Trial 64 finished with value: -1.6768791727265755 and parameters: {'aroon_length': 100}. Best is trial 23 with value: -1.7299848773673727.
# Trial 66: Aroon(107) → Sortino: 1.328
# [I 2025-11-01 14:37:04,190] Trial 65 finished with value: -1.3284847137706854 and parameters: {'aroon_length': 107}. Best is trial 23 with value: -1.7299848773673727.
# [I 2025-11-01 14:37:04,243] Trial 66 finished with value: 999.0 and parameters: {'aroon_length': 127}. Best is trial 23 with value: -1.7299848773673727.
# Trial 68: Aroon(92) → Sortino: 1.442
# [I 2025-11-01 14:37:04,295] Trial 67 finished with value: -1.441876538327114 and parameters: {'aroon_length': 92}. Best is trial 23 with value: -1.7299848773673727.
# Trial 69: Aroon(99) → Sortino: 1.730
# [I 2025-11-01 14:37:04,335] Trial 68 finished with value: -1.7299848773673727 and parameters: {'aroon_length': 99}. Best is trial 23 with value: -1.7299848773673727.
# Trial 70: Aroon(61) → Sortino: 0.672
# [I 2025-11-01 14:37:04,386] Trial 69 finished with value: -0.6717550690965058 and parameters: {'aroon_length': 61}. Best is trial 23 with value: -1.7299848773673727.
# Trial 71: Aroon(115) → Sortino: 1.096
# [I 2025-11-01 14:37:04,432] Trial 70 finished with value: -1.0958855432945291 and parameters: {'aroon_length': 115}. Best is trial 23 with value: -1.7299848773673727.
# Trial 72: Aroon(100) → Sortino: 1.677
# [I 2025-11-01 14:37:04,492] Trial 71 finished with value: -1.6768791727265755 and parameters: {'aroon_length': 100}. Best is trial 23 with value: -1.7299848773673727.
# Trial 73: Aroon(87) → Sortino: 1.519
# [I 2025-11-01 14:37:04,581] Trial 72 finished with value: -1.5186831066935462 and parameters: {'aroon_length': 87}. Best is trial 23 with value: -1.7299848773673727.
# Trial 74: Aroon(95) → Sortino: 1.699
# [I 2025-11-01 14:37:04,624] Trial 73 finished with value: -1.699185111447561 and parameters: {'aroon_length': 95}. Best is trial 23 with value: -1.7299848773673727.
# Trial 75: Aroon(79) → Sortino: 1.294
# [I 2025-11-01 14:37:04,669] Trial 74 finished with value: -1.2944361556856665 and parameters: {'aroon_length': 79}. Best is trial 23 with value: -1.7299848773673727.
# Trial 76: Aroon(92) → Sortino: 1.442
# [I 2025-11-01 14:37:04,731] Trial 75 finished with value: -1.441876538327114 and parameters: {'aroon_length': 92}. Best is trial 23 with value: -1.7299848773673727.
# Trial 77: Aroon(109) → Sortino: 1.321
# [I 2025-11-01 14:37:04,783] Trial 76 finished with value: -1.3206966302260026 and parameters: {'aroon_length': 109}. Best is trial 23 with value: -1.7299848773673727.
# Trial 78: Aroon(95) → Sortino: 1.699
# [I 2025-11-01 14:37:04,833] Trial 77 finished with value: -1.699185111447561 and parameters: {'aroon_length': 95}. Best is trial 23 with value: -1.7299848773673727.
# Trial 79: Aroon(71) → Sortino: 1.217
# [I 2025-11-01 14:37:04,877] Trial 78 finished with value: -1.2174162667128856 and parameters: {'aroon_length': 71}. Best is trial 23 with value: -1.7299848773673727.
# Trial 80: Aroon(95) → Sortino: 1.699
# [I 2025-11-01 14:37:04,931] Trial 79 finished with value: -1.699185111447561 and parameters: {'aroon_length': 95}. Best is trial 23 with value: -1.7299848773673727.
# Trial 81: Aroon(82) → Sortino: 1.460
# [I 2025-11-01 14:37:04,977] Trial 80 finished with value: -1.459605179007072 and parameters: {'aroon_length': 82}. Best is trial 23 with value: -1.7299848773673727.
# Trial 82: Aroon(94) → Sortino: 1.595
# [I 2025-11-01 14:37:05,031] Trial 81 finished with value: -1.5951277480474668 and parameters: {'aroon_length': 94}. Best is trial 23 with value: -1.7299848773673727.
# Trial 83: Aroon(103) → Sortino: 1.559
# [I 2025-11-01 14:37:05,088] Trial 82 finished with value: -1.5593678170945622 and parameters: {'aroon_length': 103}. Best is trial 23 with value: -1.7299848773673727.
# Trial 84: Aroon(88) → Sortino: 1.521
# [I 2025-11-01 14:37:05,134] Trial 83 finished with value: -1.521316256183971 and parameters: {'aroon_length': 88}. Best is trial 23 with value: -1.7299848773673727.
# Trial 85: Aroon(96) → Sortino: 1.683
# [I 2025-11-01 14:37:05,252] Trial 84 finished with value: -1.6827295923742487 and parameters: {'aroon_length': 96}. Best is trial 23 with value: -1.7299848773673727.
# Trial 86: Aroon(115) → Sortino: 1.096
# [I 2025-11-01 14:37:05,396] Trial 85 finished with value: -1.0958855432945291 and parameters: {'aroon_length': 115}. Best is trial 23 with value: -1.7299848773673727.
# Trial 87: Aroon(107) → Sortino: 1.328
# [I 2025-11-01 14:37:05,542] Trial 86 finished with value: -1.3284847137706854 and parameters: {'aroon_length': 107}. Best is trial 23 with value: -1.7299848773673727.
# Trial 88: Aroon(77) → Sortino: 1.254
# [I 2025-11-01 14:37:05,600] Trial 87 finished with value: -1.253856277758802 and parameters: {'aroon_length': 77}. Best is trial 23 with value: -1.7299848773673727.
# Trial 89: Aroon(85) → Sortino: 1.624
# [I 2025-11-01 14:37:05,709] Trial 88 finished with value: -1.6241139039092876 and parameters: {'aroon_length': 85}. Best is trial 23 with value: -1.7299848773673727.
# Trial 90: Aroon(91) → Sortino: 1.495
# [I 2025-11-01 14:37:05,777] Trial 89 finished with value: -1.495039146874357 and parameters: {'aroon_length': 91}. Best is trial 23 with value: -1.7299848773673727.
# [I 2025-11-01 14:37:05,860] Trial 90 finished with value: 999.0 and parameters: {'aroon_length': 176}. Best is trial 23 with value: -1.7299848773673727.
# Trial 92: Aroon(97) → Sortino: 1.636
# [I 2025-11-01 14:37:05,948] Trial 91 finished with value: -1.6356863447067507 and parameters: {'aroon_length': 97}. Best is trial 23 with value: -1.7299848773673727.
# Trial 93: Aroon(95) → Sortino: 1.699
# [I 2025-11-01 14:37:06,013] Trial 92 finished with value: -1.699185111447561 and parameters: {'aroon_length': 95}. Best is trial 23 with value: -1.7299848773673727.
# Trial 94: Aroon(104) → Sortino: 1.451
# [I 2025-11-01 14:37:06,061] Trial 93 finished with value: -1.4514133474426052 and parameters: {'aroon_length': 104}. Best is trial 23 with value: -1.7299848773673727.
# Trial 95: Aroon(113) → Sortino: 1.108
# [I 2025-11-01 14:37:06,109] Trial 94 finished with value: -1.1079883791175935 and parameters: {'aroon_length': 113}. Best is trial 23 with value: -1.7299848773673727.
# Trial 96: Aroon(96) → Sortino: 1.683
# [I 2025-11-01 14:37:06,151] Trial 95 finished with value: -1.6827295923742487 and parameters: {'aroon_length': 96}. Best is trial 23 with value: -1.7299848773673727.
# Trial 97: Aroon(118) → Sortino: 0.893
# [I 2025-11-01 14:37:06,227] Trial 96 finished with value: -0.8928502789600848 and parameters: {'aroon_length': 118}. Best is trial 23 with value: -1.7299848773673727.
# Trial 98: Aroon(83) → Sortino: 1.550
# [I 2025-11-01 14:37:06,273] Trial 97 finished with value: -1.5496976248315664 and parameters: {'aroon_length': 83}. Best is trial 23 with value: -1.7299848773673727.
# Trial 99: Aroon(102) → Sortino: 1.648
# [I 2025-11-01 14:37:06,315] Trial 98 finished with value: -1.648020078327196 and parameters: {'aroon_length': 102}. Best is trial 23 with value: -1.7299848773673727.
# Trial 100: Aroon(110) → Sortino: 1.320
# [I 2025-11-01 14:37:06,374] Trial 99 finished with value: -1.3196792199912324 and parameters: {'aroon_length': 110}. Best is trial 23 with value: -1.7299848773673727.
# Trial 101: Aroon(91) → Sortino: 1.495
# [I 2025-11-01 14:37:06,423] Trial 100 finished with value: -1.495039146874357 and parameters: {'aroon_length': 91}. Best is trial 23 with value: -1.7299848773673727.
# Trial 102: Aroon(96) → Sortino: 1.683
# [I 2025-11-01 14:37:06,463] Trial 101 finished with value: -1.6827295923742487 and parameters: {'aroon_length': 96}. Best is trial 23 with value: -1.7299848773673727.
# Trial 103: Aroon(98) → Sortino: 1.667
# [I 2025-11-01 14:37:06,511] Trial 102 finished with value: -1.6669716504447392 and parameters: {'aroon_length': 98}. Best is trial 23 with value: -1.7299848773673727.
# Trial 104: Aroon(104) → Sortino: 1.451
# [I 2025-11-01 14:37:06,563] Trial 103 finished with value: -1.4514133474426052 and parameters: {'aroon_length': 104}. Best is trial 23 with value: -1.7299848773673727.
# Trial 105: Aroon(86) → Sortino: 1.522
# [I 2025-11-01 14:37:06,623] Trial 104 finished with value: -1.5223843016472696 and parameters: {'aroon_length': 86}. Best is trial 23 with value: -1.7299848773673727.
# Trial 106: Aroon(90) → Sortino: 1.520
# [I 2025-11-01 14:37:06,666] Trial 105 finished with value: -1.520037647181133 and parameters: {'aroon_length': 90}. Best is trial 23 with value: -1.7299848773673727.
# Trial 107: Aroon(81) → Sortino: 1.390
# [I 2025-11-01 14:37:06,712] Trial 106 finished with value: -1.390151917404163 and parameters: {'aroon_length': 81}. Best is trial 23 with value: -1.7299848773673727.
# Trial 108: Aroon(94) → Sortino: 1.595
# [I 2025-11-01 14:37:06,762] Trial 107 finished with value: -1.5951277480474668 and parameters: {'aroon_length': 94}. Best is trial 23 with value: -1.7299848773673727.
# Trial 109: Aroon(108) → Sortino: 1.381
# [I 2025-11-01 14:37:06,811] Trial 108 finished with value: -1.3808006726274185 and parameters: {'aroon_length': 108}. Best is trial 23 with value: -1.7299848773673727.
# Trial 110: Aroon(73) → Sortino: 1.237
# [I 2025-11-01 14:37:06,863] Trial 109 finished with value: -1.2366736718491902 and parameters: {'aroon_length': 73}. Best is trial 23 with value: -1.7299848773673727.
# Trial 111: Aroon(101) → Sortino: 1.619
# [I 2025-11-01 14:37:06,964] Trial 110 finished with value: -1.61889159817128 and parameters: {'aroon_length': 101}. Best is trial 23 with value: -1.7299848773673727.
# Trial 112: Aroon(97) → Sortino: 1.636
# [I 2025-11-01 14:37:07,010] Trial 111 finished with value: -1.6356863447067507 and parameters: {'aroon_length': 97}. Best is trial 23 with value: -1.7299848773673727.
# Trial 113: Aroon(94) → Sortino: 1.595
# [I 2025-11-01 14:37:07,065] Trial 112 finished with value: -1.5951277480474668 and parameters: {'aroon_length': 94}. Best is trial 23 with value: -1.7299848773673727.
# Trial 114: Aroon(89) → Sortino: 1.529
# [I 2025-11-01 14:37:07,106] Trial 113 finished with value: -1.5287301373421274 and parameters: {'aroon_length': 89}. Best is trial 23 with value: -1.7299848773673727.
# Trial 115: Aroon(105) → Sortino: 1.455
# [I 2025-11-01 14:37:07,148] Trial 114 finished with value: -1.4552693833113513 and parameters: {'aroon_length': 105}. Best is trial 23 with value: -1.7299848773673727.
# Trial 116: Aroon(98) → Sortino: 1.667
# [I 2025-11-01 14:37:07,207] Trial 115 finished with value: -1.6669716504447392 and parameters: {'aroon_length': 98}. Best is trial 23 with value: -1.7299848773673727.
# Trial 117: Aroon(77) → Sortino: 1.254
# [I 2025-11-01 14:37:07,258] Trial 116 finished with value: -1.253856277758802 and parameters: {'aroon_length': 77}. Best is trial 23 with value: -1.7299848773673727.
# Trial 118: Aroon(84) → Sortino: 1.625
# [I 2025-11-01 14:37:07,300] Trial 117 finished with value: -1.6252461657914674 and parameters: {'aroon_length': 84}. Best is trial 23 with value: -1.7299848773673727.
# Trial 119: Aroon(112) → Sortino: 1.136
# [I 2025-11-01 14:37:07,349] Trial 118 finished with value: -1.1363046752425763 and parameters: {'aroon_length': 112}. Best is trial 23 with value: -1.7299848773673727.
# Trial 120: Aroon(95) → Sortino: 1.699
# [I 2025-11-01 14:37:07,395] Trial 119 finished with value: -1.699185111447561 and parameters: {'aroon_length': 95}. Best is trial 23 with value: -1.7299848773673727.
# Trial 121: Aroon(119) → Sortino: 0.849
# [I 2025-11-01 14:37:07,445] Trial 120 finished with value: -0.8485708918125772 and parameters: {'aroon_length': 119}. Best is trial 23 with value: -1.7299848773673727.
# Trial 122: Aroon(94) → Sortino: 1.595
# [I 2025-11-01 14:37:07,514] Trial 121 finished with value: -1.5951277480474668 and parameters: {'aroon_length': 94}. Best is trial 23 with value: -1.7299848773673727.
# Trial 123: Aroon(101) → Sortino: 1.619
# [I 2025-11-01 14:37:07,564] Trial 122 finished with value: -1.61889159817128 and parameters: {'aroon_length': 101}. Best is trial 23 with value: -1.7299848773673727.
# Trial 124: Aroon(87) → Sortino: 1.519
# [I 2025-11-01 14:37:07,608] Trial 123 finished with value: -1.5186831066935462 and parameters: {'aroon_length': 87}. Best is trial 23 with value: -1.7299848773673727.
# Trial 125: Aroon(96) → Sortino: 1.683
# [I 2025-11-01 14:37:07,659] Trial 124 finished with value: -1.6827295923742487 and parameters: {'aroon_length': 96}. Best is trial 23 with value: -1.7299848773673727.
# Trial 126: Aroon(106) → Sortino: 1.394
# [I 2025-11-01 14:37:07,707] Trial 125 finished with value: -1.3941449759642115 and parameters: {'aroon_length': 106}. Best is trial 23 with value: -1.7299848773673727.
# Trial 127: Aroon(91) → Sortino: 1.495
# [I 2025-11-01 14:37:07,769] Trial 126 finished with value: -1.495039146874357 and parameters: {'aroon_length': 91}. Best is trial 23 with value: -1.7299848773673727.
# Trial 128: Aroon(101) → Sortino: 1.619
# [I 2025-11-01 14:37:07,842] Trial 127 finished with value: -1.61889159817128 and parameters: {'aroon_length': 101}. Best is trial 23 with value: -1.7299848773673727.
# Trial 129: Aroon(81) → Sortino: 1.390
# [I 2025-11-01 14:37:07,943] Trial 128 finished with value: -1.390151917404163 and parameters: {'aroon_length': 81}. Best is trial 23 with value: -1.7299848773673727.
# Trial 130: Aroon(110) → Sortino: 1.320
# [I 2025-11-01 14:37:08,094] Trial 129 finished with value: -1.3196792199912324 and parameters: {'aroon_length': 110}. Best is trial 23 with value: -1.7299848773673727.
# Trial 131: Aroon(88) → Sortino: 1.521
# [I 2025-11-01 14:37:08,143] Trial 130 finished with value: -1.521316256183971 and parameters: {'aroon_length': 88}. Best is trial 23 with value: -1.7299848773673727.
# Trial 132: Aroon(96) → Sortino: 1.683
# [I 2025-11-01 14:37:08,214] Trial 131 finished with value: -1.6827295923742487 and parameters: {'aroon_length': 96}. Best is trial 23 with value: -1.7299848773673727.
# Trial 133: Aroon(97) → Sortino: 1.636
# [I 2025-11-01 14:37:08,264] Trial 132 finished with value: -1.6356863447067507 and parameters: {'aroon_length': 97}. Best is trial 23 with value: -1.7299848773673727.
# Trial 134: Aroon(92) → Sortino: 1.442
# [I 2025-11-01 14:37:08,310] Trial 133 finished with value: -1.441876538327114 and parameters: {'aroon_length': 92}. Best is trial 23 with value: -1.7299848773673727.
# Trial 135: Aroon(104) → Sortino: 1.451
# [I 2025-11-01 14:37:08,352] Trial 134 finished with value: -1.4514133474426052 and parameters: {'aroon_length': 104}. Best is trial 23 with value: -1.7299848773673727.
# Trial 136: Aroon(26) → Sortino: -0.171
# [I 2025-11-01 14:37:08,465] Trial 135 finished with value: 0.1711670528139307 and parameters: {'aroon_length': 26}. Best is trial 23 with value: -1.7299848773673727.
# Trial 137: Aroon(100) → Sortino: 1.677
# [I 2025-11-01 14:37:08,513] Trial 136 finished with value: -1.6768791727265755 and parameters: {'aroon_length': 100}. Best is trial 23 with value: -1.7299848773673727.
# Trial 138: Aroon(86) → Sortino: 1.522
# [I 2025-11-01 14:37:08,563] Trial 137 finished with value: -1.5223843016472696 and parameters: {'aroon_length': 86}. Best is trial 23 with value: -1.7299848773673727.
# Trial 139: Aroon(95) → Sortino: 1.699
# [I 2025-11-01 14:37:08,616] Trial 138 finished with value: -1.699185111447561 and parameters: {'aroon_length': 95}. Best is trial 23 with value: -1.7299848773673727.
# Trial 140: Aroon(91) → Sortino: 1.495
# [I 2025-11-01 14:37:08,666] Trial 139 finished with value: -1.495039146874357 and parameters: {'aroon_length': 91}. Best is trial 23 with value: -1.7299848773673727.
# Trial 141: Aroon(107) → Sortino: 1.328
# [I 2025-11-01 14:37:08,741] Trial 140 finished with value: -1.3284847137706854 and parameters: {'aroon_length': 107}. Best is trial 23 with value: -1.7299848773673727.
# Trial 142: Aroon(95) → Sortino: 1.699
# [I 2025-11-01 14:37:08,799] Trial 141 finished with value: -1.699185111447561 and parameters: {'aroon_length': 95}. Best is trial 23 with value: -1.7299848773673727.
# Trial 143: Aroon(95) → Sortino: 1.699
# [I 2025-11-01 14:37:08,842] Trial 142 finished with value: -1.699185111447561 and parameters: {'aroon_length': 95}. Best is trial 23 with value: -1.7299848773673727.
# Trial 144: Aroon(103) → Sortino: 1.559
# [I 2025-11-01 14:37:08,898] Trial 143 finished with value: -1.5593678170945622 and parameters: {'aroon_length': 103}. Best is trial 23 with value: -1.7299848773673727.
# Trial 145: Aroon(92) → Sortino: 1.442
# [I 2025-11-01 14:37:08,946] Trial 144 finished with value: -1.441876538327114 and parameters: {'aroon_length': 92}. Best is trial 23 with value: -1.7299848773673727.
# Trial 146: Aroon(100) → Sortino: 1.677
# [I 2025-11-01 14:37:09,003] Trial 145 finished with value: -1.6768791727265755 and parameters: {'aroon_length': 100}. Best is trial 23 with value: -1.7299848773673727.
# Trial 147: Aroon(84) → Sortino: 1.625
# [I 2025-11-01 14:37:09,058] Trial 146 finished with value: -1.6252461657914674 and parameters: {'aroon_length': 84}. Best is trial 23 with value: -1.7299848773673727.
# Trial 148: Aroon(89) → Sortino: 1.529
# [I 2025-11-01 14:37:09,166] Trial 147 finished with value: -1.5287301373421274 and parameters: {'aroon_length': 89}. Best is trial 23 with value: -1.7299848773673727.
# Trial 149: Aroon(94) → Sortino: 1.595
# [I 2025-11-01 14:37:09,265] Trial 148 finished with value: -1.5951277480474668 and parameters: {'aroon_length': 94}. Best is trial 23 with value: -1.7299848773673727.
# Trial 150: Aroon(79) → Sortino: 1.294
# [I 2025-11-01 14:37:09,379] Trial 149 finished with value: -1.2944361556856665 and parameters: {'aroon_length': 79}. Best is trial 23 with value: -1.7299848773673727.
# Trial 151: Aroon(100) → Sortino: 1.677
# [I 2025-11-01 14:37:09,449] Trial 150 finished with value: -1.6768791727265755 and parameters: {'aroon_length': 100}. Best is trial 23 with value: -1.7299848773673727.
# Trial 152: Aroon(97) → Sortino: 1.636
# [I 2025-11-01 14:37:09,532] Trial 151 finished with value: -1.6356863447067507 and parameters: {'aroon_length': 97}. Best is trial 23 with value: -1.7299848773673727.
# Trial 153: Aroon(94) → Sortino: 1.595
# [I 2025-11-01 14:37:09,602] Trial 152 finished with value: -1.5951277480474668 and parameters: {'aroon_length': 94}. Best is trial 23 with value: -1.7299848773673727.
# Trial 154: Aroon(104) → Sortino: 1.451
# [I 2025-11-01 14:37:09,668] Trial 153 finished with value: -1.4514133474426052 and parameters: {'aroon_length': 104}. Best is trial 23 with value: -1.7299848773673727.
# Trial 155: Aroon(88) → Sortino: 1.521
# [I 2025-11-01 14:37:09,736] Trial 154 finished with value: -1.521316256183971 and parameters: {'aroon_length': 88}. Best is trial 23 with value: -1.7299848773673727.
# Trial 156: Aroon(98) → Sortino: 1.667
# [I 2025-11-01 14:37:09,803] Trial 155 finished with value: -1.6669716504447392 and parameters: {'aroon_length': 98}. Best is trial 23 with value: -1.7299848773673727.
# Trial 157: Aroon(108) → Sortino: 1.381
# [I 2025-11-01 14:37:09,936] Trial 156 finished with value: -1.3808006726274185 and parameters: {'aroon_length': 108}. Best is trial 23 with value: -1.7299848773673727.
# Trial 158: Aroon(95) → Sortino: 1.699
# [I 2025-11-01 14:37:09,998] Trial 157 finished with value: -1.699185111447561 and parameters: {'aroon_length': 95}. Best is trial 23 with value: -1.7299848773673727.
# Trial 159: Aroon(84) → Sortino: 1.625
# [I 2025-11-01 14:37:10,047] Trial 158 finished with value: -1.6252461657914674 and parameters: {'aroon_length': 84}. Best is trial 23 with value: -1.7299848773673727.
# Trial 160: Aroon(113) → Sortino: 1.108
# [I 2025-11-01 14:37:10,103] Trial 159 finished with value: -1.1079883791175935 and parameters: {'aroon_length': 113}. Best is trial 23 with value: -1.7299848773673727.
# Trial 161: Aroon(90) → Sortino: 1.520
# [I 2025-11-01 14:37:10,169] Trial 160 finished with value: -1.520037647181133 and parameters: {'aroon_length': 90}. Best is trial 23 with value: -1.7299848773673727.
# Trial 162: Aroon(95) → Sortino: 1.699
# [I 2025-11-01 14:37:10,244] Trial 161 finished with value: -1.699185111447561 and parameters: {'aroon_length': 95}. Best is trial 23 with value: -1.7299848773673727.
# Trial 163: Aroon(95) → Sortino: 1.699
# [I 2025-11-01 14:37:10,796] Trial 162 finished with value: -1.699185111447561 and parameters: {'aroon_length': 95}. Best is trial 23 with value: -1.7299848773673727.
# Trial 164: Aroon(93) → Sortino: 1.538
# [I 2025-11-01 14:37:10,857] Trial 163 finished with value: -1.538345512221517 and parameters: {'aroon_length': 93}. Best is trial 23 with value: -1.7299848773673727.
# Trial 165: Aroon(100) → Sortino: 1.677
# [I 2025-11-01 14:37:10,900] Trial 164 finished with value: -1.6768791727265755 and parameters: {'aroon_length': 100}. Best is trial 23 with value: -1.7299848773673727.
# Trial 166: Aroon(103) → Sortino: 1.559
# [I 2025-11-01 14:37:10,949] Trial 165 finished with value: -1.5593678170945622 and parameters: {'aroon_length': 103}. Best is trial 23 with value: -1.7299848773673727.
# Trial 167: Aroon(87) → Sortino: 1.519
# [I 2025-11-01 14:37:10,991] Trial 166 finished with value: -1.5186831066935462 and parameters: {'aroon_length': 87}. Best is trial 23 with value: -1.7299848773673727.
# Trial 168: Aroon(96) → Sortino: 1.683
# [I 2025-11-01 14:37:11,081] Trial 167 finished with value: -1.6827295923742487 and parameters: {'aroon_length': 96}. Best is trial 23 with value: -1.7299848773673727.
# Trial 169: Aroon(91) → Sortino: 1.495
# [I 2025-11-01 14:37:11,161] Trial 168 finished with value: -1.495039146874357 and parameters: {'aroon_length': 91}. Best is trial 23 with value: -1.7299848773673727.
# Trial 170: Aroon(106) → Sortino: 1.394
# [I 2025-11-01 14:37:11,202] Trial 169 finished with value: -1.3941449759642115 and parameters: {'aroon_length': 106}. Best is trial 23 with value: -1.7299848773673727.
# Trial 171: Aroon(100) → Sortino: 1.677
# [I 2025-11-01 14:37:11,260] Trial 170 finished with value: -1.6768791727265755 and parameters: {'aroon_length': 100}. Best is trial 23 with value: -1.7299848773673727.
# Trial 172: Aroon(96) → Sortino: 1.683
# [I 2025-11-01 14:37:11,305] Trial 171 finished with value: -1.6827295923742487 and parameters: {'aroon_length': 96}. Best is trial 23 with value: -1.7299848773673727.
# Trial 173: Aroon(93) → Sortino: 1.538
# [I 2025-11-01 14:37:11,369] Trial 172 finished with value: -1.538345512221517 and parameters: {'aroon_length': 93}. Best is trial 23 with value: -1.7299848773673727.
# Trial 174: Aroon(98) → Sortino: 1.667
# [I 2025-11-01 14:37:11,417] Trial 173 finished with value: -1.6669716504447392 and parameters: {'aroon_length': 98}. Best is trial 23 with value: -1.7299848773673727.
# Trial 175: Aroon(103) → Sortino: 1.559
# [I 2025-11-01 14:37:11,464] Trial 174 finished with value: -1.5593678170945622 and parameters: {'aroon_length': 103}. Best is trial 23 with value: -1.7299848773673727.
# Trial 176: Aroon(89) → Sortino: 1.529
# [I 2025-11-01 14:37:11,503] Trial 175 finished with value: -1.5287301373421274 and parameters: {'aroon_length': 89}. Best is trial 23 with value: -1.7299848773673727.
# Trial 177: Aroon(94) → Sortino: 1.595
# [I 2025-11-01 14:37:11,567] Trial 176 finished with value: -1.5951277480474668 and parameters: {'aroon_length': 94}. Best is trial 23 with value: -1.7299848773673727.
# Trial 178: Aroon(84) → Sortino: 1.625
# [I 2025-11-01 14:37:11,619] Trial 177 finished with value: -1.6252461657914674 and parameters: {'aroon_length': 84}. Best is trial 23 with value: -1.7299848773673727.
# Trial 179: Aroon(98) → Sortino: 1.667
# [I 2025-11-01 14:37:11,670] Trial 178 finished with value: -1.6669716504447392 and parameters: {'aroon_length': 98}. Best is trial 23 with value: -1.7299848773673727.
# Trial 180: Aroon(109) → Sortino: 1.321
# [I 2025-11-01 14:37:11,715] Trial 179 finished with value: -1.3206966302260026 and parameters: {'aroon_length': 109}. Best is trial 23 with value: -1.7299848773673727.
# Trial 181: Aroon(91) → Sortino: 1.495
# [I 2025-11-01 14:37:11,757] Trial 180 finished with value: -1.495039146874357 and parameters: {'aroon_length': 91}. Best is trial 23 with value: -1.7299848773673727.
# Trial 182: Aroon(96) → Sortino: 1.683
# [I 2025-11-01 14:37:11,807] Trial 181 finished with value: -1.6827295923742487 and parameters: {'aroon_length': 96}. Best is trial 23 with value: -1.7299848773673727.
# Trial 183: Aroon(102) → Sortino: 1.648
# [I 2025-11-01 14:37:11,880] Trial 182 finished with value: -1.648020078327196 and parameters: {'aroon_length': 102}. Best is trial 23 with value: -1.7299848773673727.
# Trial 184: Aroon(94) → Sortino: 1.595
# [I 2025-11-01 14:37:11,927] Trial 183 finished with value: -1.5951277480474668 and parameters: {'aroon_length': 94}. Best is trial 23 with value: -1.7299848773673727.
# Trial 185: Aroon(88) → Sortino: 1.521
# [I 2025-11-01 14:37:11,976] Trial 184 finished with value: -1.521316256183971 and parameters: {'aroon_length': 88}. Best is trial 23 with value: -1.7299848773673727.
# Trial 186: Aroon(99) → Sortino: 1.730
# [I 2025-11-01 14:37:12,020] Trial 185 finished with value: -1.7299848773673727 and parameters: {'aroon_length': 99}. Best is trial 23 with value: -1.7299848773673727.
# Trial 187: Aroon(100) → Sortino: 1.677
# [I 2025-11-01 14:37:12,072] Trial 186 finished with value: -1.6768791727265755 and parameters: {'aroon_length': 100}. Best is trial 23 with value: -1.7299848773673727.
# Trial 188: Aroon(106) → Sortino: 1.394
# [I 2025-11-01 14:37:12,129] Trial 187 finished with value: -1.3941449759642115 and parameters: {'aroon_length': 106}. Best is trial 23 with value: -1.7299848773673727.
# Trial 189: Aroon(93) → Sortino: 1.538
# [I 2025-11-01 14:37:12,180] Trial 188 finished with value: -1.538345512221517 and parameters: {'aroon_length': 93}. Best is trial 23 with value: -1.7299848773673727.
# Trial 190: Aroon(99) → Sortino: 1.730
# [I 2025-11-01 14:37:12,303] Trial 189 finished with value: -1.7299848773673727 and parameters: {'aroon_length': 99}. Best is trial 23 with value: -1.7299848773673727.
# Trial 191: Aroon(103) → Sortino: 1.559
# [I 2025-11-01 14:37:12,351] Trial 190 finished with value: -1.5593678170945622 and parameters: {'aroon_length': 103}. Best is trial 23 with value: -1.7299848773673727.
# Trial 192: Aroon(99) → Sortino: 1.730
# [I 2025-11-01 14:37:12,429] Trial 191 finished with value: -1.7299848773673727 and parameters: {'aroon_length': 99}. Best is trial 23 with value: -1.7299848773673727.
# Trial 193: Aroon(99) → Sortino: 1.730
# [I 2025-11-01 14:37:12,514] Trial 192 finished with value: -1.7299848773673727 and parameters: {'aroon_length': 99}. Best is trial 23 with value: -1.7299848773673727.
# Trial 194: Aroon(98) → Sortino: 1.667
# [I 2025-11-01 14:37:12,586] Trial 193 finished with value: -1.6669716504447392 and parameters: {'aroon_length': 98}. Best is trial 23 with value: -1.7299848773673727.
# Trial 195: Aroon(101) → Sortino: 1.619
# [I 2025-11-01 14:37:12,651] Trial 194 finished with value: -1.61889159817128 and parameters: {'aroon_length': 101}. Best is trial 23 with value: -1.7299848773673727.
# Trial 196: Aroon(105) → Sortino: 1.455
# [I 2025-11-01 14:37:12,701] Trial 195 finished with value: -1.4552693833113513 and parameters: {'aroon_length': 105}. Best is trial 23 with value: -1.7299848773673727.
# Trial 197: Aroon(91) → Sortino: 1.495
# [I 2025-11-01 14:37:12,791] Trial 196 finished with value: -1.495039146874357 and parameters: {'aroon_length': 91}. Best is trial 23 with value: -1.7299848773673727.
# Trial 198: Aroon(98) → Sortino: 1.667
# [I 2025-11-01 14:37:12,893] Trial 197 finished with value: -1.6669716504447392 and parameters: {'aroon_length': 98}. Best is trial 23 with value: -1.7299848773673727.
# Trial 199: Aroon(110) → Sortino: 1.320
# [I 2025-11-01 14:37:12,971] Trial 198 finished with value: -1.3196792199912324 and parameters: {'aroon_length': 110}. Best is trial 23 with value: -1.7299848773673727.
# Trial 200: Aroon(86) → Sortino: 1.522
# [I 2025-11-01 14:37:13,069] Trial 199 finished with value: -1.5223843016472696 and parameters: {'aroon_length': 86}. Best is trial 23 with value: -1.7299848773673727.
# Trial 201: Aroon(95) → Sortino: 1.699
# [I 2025-11-01 14:37:13,134] Trial 200 finished with value: -1.699185111447561 and parameters: {'aroon_length': 95}. Best is trial 23 with value: -1.7299848773673727.
# Trial 202: Aroon(94) → Sortino: 1.595
# [I 2025-11-01 14:37:13,198] Trial 201 finished with value: -1.5951277480474668 and parameters: {'aroon_length': 94}. Best is trial 23 with value: -1.7299848773673727.
# Trial 203: Aroon(100) → Sortino: 1.677
# [I 2025-11-01 14:37:13,237] Trial 202 finished with value: -1.6768791727265755 and parameters: {'aroon_length': 100}. Best is trial 23 with value: -1.7299848773673727.
# Trial 204: Aroon(95) → Sortino: 1.699
# [I 2025-11-01 14:37:13,507] Trial 203 finished with value: -1.699185111447561 and parameters: {'aroon_length': 95}. Best is trial 23 with value: -1.7299848773673727.
# Trial 205: Aroon(91) → Sortino: 1.495
# [I 2025-11-01 14:37:13,614] Trial 204 finished with value: -1.495039146874357 and parameters: {'aroon_length': 91}. Best is trial 23 with value: -1.7299848773673727.
# Trial 206: Aroon(98) → Sortino: 1.667
# [I 2025-11-01 14:37:13,713] Trial 205 finished with value: -1.6669716504447392 and parameters: {'aroon_length': 98}. Best is trial 23 with value: -1.7299848773673727.
# Trial 207: Aroon(103) → Sortino: 1.559
# [I 2025-11-01 14:37:13,761] Trial 206 finished with value: -1.5593678170945622 and parameters: {'aroon_length': 103}. Best is trial 23 with value: -1.7299848773673727.
# Trial 208: Aroon(88) → Sortino: 1.521
# [I 2025-11-01 14:37:13,807] Trial 207 finished with value: -1.521316256183971 and parameters: {'aroon_length': 88}. Best is trial 23 with value: -1.7299848773673727.
# Trial 209: Aroon(94) → Sortino: 1.595
# [I 2025-11-01 14:37:13,861] Trial 208 finished with value: -1.5951277480474668 and parameters: {'aroon_length': 94}. Best is trial 23 with value: -1.7299848773673727.
# Trial 210: Aroon(106) → Sortino: 1.394
# [I 2025-11-01 14:37:13,906] Trial 209 finished with value: -1.3941449759642115 and parameters: {'aroon_length': 106}. Best is trial 23 with value: -1.7299848773673727.
# Trial 211: Aroon(100) → Sortino: 1.677
# [I 2025-11-01 14:37:13,948] Trial 210 finished with value: -1.6768791727265755 and parameters: {'aroon_length': 100}. Best is trial 23 with value: -1.7299848773673727.
# Trial 212: Aroon(95) → Sortino: 1.699
# [I 2025-11-01 14:37:13,999] Trial 211 finished with value: -1.699185111447561 and parameters: {'aroon_length': 95}. Best is trial 23 with value: -1.7299848773673727.
# Trial 213: Aroon(91) → Sortino: 1.495
# [I 2025-11-01 14:37:14,093] Trial 212 finished with value: -1.495039146874357 and parameters: {'aroon_length': 91}. Best is trial 23 with value: -1.7299848773673727.
# Trial 214: Aroon(96) → Sortino: 1.683
# [I 2025-11-01 14:37:14,171] Trial 213 finished with value: -1.6827295923742487 and parameters: {'aroon_length': 96}. Best is trial 23 with value: -1.7299848773673727.
# Trial 215: Aroon(98) → Sortino: 1.667
# [I 2025-11-01 14:37:14,264] Trial 214 finished with value: -1.6669716504447392 and parameters: {'aroon_length': 98}. Best is trial 23 with value: -1.7299848773673727.
# Trial 216: Aroon(103) → Sortino: 1.559
# [I 2025-11-01 14:37:14,315] Trial 215 finished with value: -1.5593678170945622 and parameters: {'aroon_length': 103}. Best is trial 23 with value: -1.7299848773673727.
# Trial 217: Aroon(93) → Sortino: 1.538
# [I 2025-11-01 14:37:14,365] Trial 216 finished with value: -1.538345512221517 and parameters: {'aroon_length': 93}. Best is trial 23 with value: -1.7299848773673727.
# Trial 218: Aroon(88) → Sortino: 1.521
# [I 2025-11-01 14:37:14,413] Trial 217 finished with value: -1.521316256183971 and parameters: {'aroon_length': 88}. Best is trial 23 with value: -1.7299848773673727.
# Trial 219: Aroon(98) → Sortino: 1.667
# [I 2025-11-01 14:37:14,469] Trial 218 finished with value: -1.6669716504447392 and parameters: {'aroon_length': 98}. Best is trial 23 with value: -1.7299848773673727.
# Trial 220: Aroon(82) → Sortino: 1.460
# [I 2025-11-01 14:37:14,534] Trial 219 finished with value: -1.459605179007072 and parameters: {'aroon_length': 82}. Best is trial 23 with value: -1.7299848773673727.
# Trial 221: Aroon(95) → Sortino: 1.699
# [I 2025-11-01 14:37:14,582] Trial 220 finished with value: -1.699185111447561 and parameters: {'aroon_length': 95}. Best is trial 23 with value: -1.7299848773673727.
# [I 2025-11-01 14:37:14,640] Trial 221 finished with value: 999.0 and parameters: {'aroon_length': 159}. Best is trial 23 with value: -1.7299848773673727.
# Trial 223: Aroon(95) → Sortino: 1.699
# [I 2025-11-01 14:37:14,705] Trial 222 finished with value: -1.699185111447561 and parameters: {'aroon_length': 95}. Best is trial 23 with value: -1.7299848773673727.
# Trial 224: Aroon(91) → Sortino: 1.495
# [I 2025-11-01 14:37:14,768] Trial 223 finished with value: -1.495039146874357 and parameters: {'aroon_length': 91}. Best is trial 23 with value: -1.7299848773673727.
# Trial 225: Aroon(100) → Sortino: 1.677
# [I 2025-11-01 14:37:14,806] Trial 224 finished with value: -1.6768791727265755 and parameters: {'aroon_length': 100}. Best is trial 23 with value: -1.7299848773673727.
# Trial 226: Aroon(95) → Sortino: 1.699
# [I 2025-11-01 14:37:14,964] Trial 225 finished with value: -1.699185111447561 and parameters: {'aroon_length': 95}. Best is trial 23 with value: -1.7299848773673727.
# Trial 227: Aroon(102) → Sortino: 1.648
# [I 2025-11-01 14:37:15,016] Trial 226 finished with value: -1.648020078327196 and parameters: {'aroon_length': 102}. Best is trial 23 with value: -1.7299848773673727.
# Trial 228: Aroon(90) → Sortino: 1.520
# [I 2025-11-01 14:37:15,066] Trial 227 finished with value: -1.520037647181133 and parameters: {'aroon_length': 90}. Best is trial 23 with value: -1.7299848773673727.
# Trial 229: Aroon(97) → Sortino: 1.636
# [I 2025-11-01 14:37:15,106] Trial 228 finished with value: -1.6356863447067507 and parameters: {'aroon_length': 97}. Best is trial 23 with value: -1.7299848773673727.
# Trial 230: Aroon(105) → Sortino: 1.455
# [I 2025-11-01 14:37:15,172] Trial 229 finished with value: -1.4552693833113513 and parameters: {'aroon_length': 105}. Best is trial 23 with value: -1.7299848773673727.
# Trial 231: Aroon(47) → Sortino: 0.319
# [I 2025-11-01 14:37:15,279] Trial 230 finished with value: -0.31920350706755724 and parameters: {'aroon_length': 47}. Best is trial 23 with value: -1.7299848773673727.
# Trial 232: Aroon(93) → Sortino: 1.538
# [I 2025-11-01 14:37:15,364] Trial 231 finished with value: -1.538345512221517 and parameters: {'aroon_length': 93}. Best is trial 23 with value: -1.7299848773673727.
# Trial 233: Aroon(95) → Sortino: 1.699
# [I 2025-11-01 14:37:15,562] Trial 232 finished with value: -1.699185111447561 and parameters: {'aroon_length': 95}. Best is trial 23 with value: -1.7299848773673727.
# Trial 234: Aroon(99) → Sortino: 1.730
# [I 2025-11-01 14:37:15,644] Trial 233 finished with value: -1.7299848773673727 and parameters: {'aroon_length': 99}. Best is trial 23 with value: -1.7299848773673727.
# Trial 235: Aroon(100) → Sortino: 1.677
# [I 2025-11-01 14:37:15,762] Trial 234 finished with value: -1.6768791727265755 and parameters: {'aroon_length': 100}. Best is trial 23 with value: -1.7299848773673727.
# Trial 236: Aroon(98) → Sortino: 1.667
# ...
# Trial 924: Aroon(99) → Sortino: 1.730
# [I 2025-11-01 14:37:57,347] Trial 923 finished with value: -1.7299848773673727 and parameters: {'aroon_length': 99}. Best is trial 23 with value: -1.7299848773673727.
# Trial 925: Aroon(90) → Sortino: 1.520
# [I 2025-11-01 14:37:57,426] Trial 924 finished with value: -1.520037647181133 and parameters: {'aroon_length': 90}. Best is trial 23 with value: -1.7299848773673727.
# Trial 926: Aroon(103) → Sortino: 1.559
# [I 2025-11-01 14:37:57,513] Trial 925 finished with value: -1.5593678170945622 and parameters: {'aroon_length': 103}. Best is trial 23 with value: -1.7299848773673727.
# Trial 927: Aroon(95) → Sortino: 1.699
# [I 2025-11-01 14:37:57,566] Trial 926 finished with value: -1.699185111447561 and parameters: {'aroon_length': 95}. Best is trial 23 with value: -1.7299848773673727.
# Trial 928: Aroon(86) → Sortino: 1.522
# [I 2025-11-01 14:37:57,623] Trial 927 finished with value: -1.5223843016472696 and parameters: {'aroon_length': 86}. Best is trial 23 with value: -1.7299848773673727.
# Trial 929: Aroon(99) → Sortino: 1.730
# [I 2025-11-01 14:37:57,704] Trial 928 finished with value: -1.7299848773673727 and parameters: {'aroon_length': 99}. Best is trial 23 with value: -1.7299848773673727.
# Trial 930: Aroon(108) → Sortino: 1.381
# [I 2025-11-01 14:37:57,786] Trial 929 finished with value: -1.3808006726274185 and parameters: {'aroon_length': 108}. Best is trial 23 with value: -1.7299848773673727.
# Trial 931: Aroon(94) → Sortino: 1.595
# [I 2025-11-01 14:37:57,849] Trial 930 finished with value: -1.5951277480474668 and parameters: {'aroon_length': 94}. Best is trial 23 with value: -1.7299848773673727.
# Trial 932: Aroon(104) → Sortino: 1.451
# [I 2025-11-01 14:37:57,907] Trial 931 finished with value: -1.4514133474426052 and parameters: {'aroon_length': 104}. Best is trial 23 with value: -1.7299848773673727.
# Trial 933: Aroon(98) → Sortino: 1.667
# [I 2025-11-01 14:37:57,971] Trial 932 finished with value: -1.6669716504447392 and parameters: {'aroon_length': 98}. Best is trial 23 with value: -1.7299848773673727.
# Trial 934: Aroon(102) → Sortino: 1.648
# [I 2025-11-01 14:37:58,025] Trial 933 finished with value: -1.648020078327196 and parameters: {'aroon_length': 102}. Best is trial 23 with value: -1.7299848773673727.
# Trial 935: Aroon(91) → Sortino: 1.495
# [I 2025-11-01 14:37:58,085] Trial 934 finished with value: -1.495039146874357 and parameters: {'aroon_length': 91}. Best is trial 23 with value: -1.7299848773673727.
# Trial 936: Aroon(96) → Sortino: 1.683
# [I 2025-11-01 14:37:58,143] Trial 935 finished with value: -1.6827295923742487 and parameters: {'aroon_length': 96}. Best is trial 23 with value: -1.7299848773673727.
# Trial 937: Aroon(101) → Sortino: 1.619
# [I 2025-11-01 14:37:58,194] Trial 936 finished with value: -1.61889159817128 and parameters: {'aroon_length': 101}. Best is trial 23 with value: -1.7299848773673727.
# Trial 938: Aroon(27) → Sortino: 0.101
# [I 2025-11-01 14:37:58,248] Trial 937 finished with value: -0.10084830296701974 and parameters: {'aroon_length': 27}. Best is trial 23 with value: -1.7299848773673727.
# Trial 939: Aroon(107) → Sortino: 1.328
# [I 2025-11-01 14:37:58,307] Trial 938 finished with value: -1.3284847137706854 and parameters: {'aroon_length': 107}. Best is trial 23 with value: -1.7299848773673727.
# Trial 940: Aroon(98) → Sortino: 1.667
# [I 2025-11-01 14:37:58,365] Trial 939 finished with value: -1.6669716504447392 and parameters: {'aroon_length': 98}. Best is trial 23 with value: -1.7299848773673727.
# Trial 941: Aroon(92) → Sortino: 1.442
# [I 2025-11-01 14:37:58,429] Trial 940 finished with value: -1.441876538327114 and parameters: {'aroon_length': 92}. Best is trial 23 with value: -1.7299848773673727.
# Trial 942: Aroon(104) → Sortino: 1.451
# [I 2025-11-01 14:37:58,561] Trial 941 finished with value: -1.4514133474426052 and parameters: {'aroon_length': 104}. Best is trial 23 with value: -1.7299848773673727.
# Trial 943: Aroon(96) → Sortino: 1.683
# [I 2025-11-01 14:37:58,614] Trial 942 finished with value: -1.6827295923742487 and parameters: {'aroon_length': 96}. Best is trial 23 with value: -1.7299848773673727.
# Trial 944: Aroon(101) → Sortino: 1.619
# [I 2025-11-01 14:37:58,655] Trial 943 finished with value: -1.61889159817128 and parameters: {'aroon_length': 101}. Best is trial 23 with value: -1.7299848773673727.
# Trial 945: Aroon(114) → Sortino: 1.144
# [I 2025-11-01 14:37:58,714] Trial 944 finished with value: -1.143519154514355 and parameters: {'aroon_length': 114}. Best is trial 23 with value: -1.7299848773673727.
# Trial 946: Aroon(88) → Sortino: 1.521
# [I 2025-11-01 14:37:58,805] Trial 945 finished with value: -1.521316256183971 and parameters: {'aroon_length': 88}. Best is trial 23 with value: -1.7299848773673727.
# Trial 947: Aroon(94) → Sortino: 1.595
# [I 2025-11-01 14:37:58,893] Trial 946 finished with value: -1.5951277480474668 and parameters: {'aroon_length': 94}. Best is trial 23 with value: -1.7299848773673727.
# Trial 948: Aroon(109) → Sortino: 1.321
# [I 2025-11-01 14:37:58,969] Trial 947 finished with value: -1.3206966302260026 and parameters: {'aroon_length': 109}. Best is trial 23 with value: -1.7299848773673727.
# Trial 949: Aroon(83) → Sortino: 1.550
# [I 2025-11-01 14:37:59,036] Trial 948 finished with value: -1.5496976248315664 and parameters: {'aroon_length': 83}. Best is trial 23 with value: -1.7299848773673727.
# Trial 950: Aroon(99) → Sortino: 1.730
# [I 2025-11-01 14:37:59,119] Trial 949 finished with value: -1.7299848773673727 and parameters: {'aroon_length': 99}. Best is trial 23 with value: -1.7299848773673727.
# Trial 951: Aroon(104) → Sortino: 1.451
# [I 2025-11-01 14:37:59,219] Trial 950 finished with value: -1.4514133474426052 and parameters: {'aroon_length': 104}. Best is trial 23 with value: -1.7299848773673727.
# Trial 952: Aroon(96) → Sortino: 1.683
# [I 2025-11-01 14:37:59,291] Trial 951 finished with value: -1.6827295923742487 and parameters: {'aroon_length': 96}. Best is trial 23 with value: -1.7299848773673727.
# Trial 953: Aroon(101) → Sortino: 1.619
# [I 2025-11-01 14:37:59,419] Trial 952 finished with value: -1.61889159817128 and parameters: {'aroon_length': 101}. Best is trial 23 with value: -1.7299848773673727.
# Trial 954: Aroon(91) → Sortino: 1.495
# [I 2025-11-01 14:37:59,515] Trial 953 finished with value: -1.495039146874357 and parameters: {'aroon_length': 91}. Best is trial 23 with value: -1.7299848773673727.
# Trial 955: Aroon(99) → Sortino: 1.730
# [I 2025-11-01 14:37:59,610] Trial 954 finished with value: -1.7299848773673727 and parameters: {'aroon_length': 99}. Best is trial 23 with value: -1.7299848773673727.
# Trial 956: Aroon(106) → Sortino: 1.394
# [I 2025-11-01 14:37:59,770] Trial 955 finished with value: -1.3941449759642115 and parameters: {'aroon_length': 106}. Best is trial 23 with value: -1.7299848773673727.
# Trial 957: Aroon(94) → Sortino: 1.595
# [I 2025-11-01 14:37:59,922] Trial 956 finished with value: -1.5951277480474668 and parameters: {'aroon_length': 94}. Best is trial 23 with value: -1.7299848773673727.
# Trial 958: Aroon(111) → Sortino: 1.192
# [I 2025-11-01 14:38:00,010] Trial 957 finished with value: -1.1916590976916235 and parameters: {'aroon_length': 111}. Best is trial 23 with value: -1.7299848773673727.
# Trial 959: Aroon(103) → Sortino: 1.559
# [I 2025-11-01 14:38:00,168] Trial 958 finished with value: -1.5593678170945622 and parameters: {'aroon_length': 103}. Best is trial 23 with value: -1.7299848773673727.
# Trial 960: Aroon(98) → Sortino: 1.667
# [I 2025-11-01 14:38:00,242] Trial 959 finished with value: -1.6669716504447392 and parameters: {'aroon_length': 98}. Best is trial 23 with value: -1.7299848773673727.
# Trial 961: Aroon(90) → Sortino: 1.520
# [I 2025-11-01 14:38:00,324] Trial 960 finished with value: -1.520037647181133 and parameters: {'aroon_length': 90}. Best is trial 23 with value: -1.7299848773673727.
# Trial 962: Aroon(95) → Sortino: 1.699
# [I 2025-11-01 14:38:00,391] Trial 961 finished with value: -1.699185111447561 and parameters: {'aroon_length': 95}. Best is trial 23 with value: -1.7299848773673727.
# Trial 963: Aroon(102) → Sortino: 1.648
# [I 2025-11-01 14:38:00,438] Trial 962 finished with value: -1.648020078327196 and parameters: {'aroon_length': 102}. Best is trial 23 with value: -1.7299848773673727.
# Trial 964: Aroon(107) → Sortino: 1.328
# [I 2025-11-01 14:38:00,506] Trial 963 finished with value: -1.3284847137706854 and parameters: {'aroon_length': 107}. Best is trial 23 with value: -1.7299848773673727.
# Trial 965: Aroon(99) → Sortino: 1.730
# [I 2025-11-01 14:38:00,556] Trial 964 finished with value: -1.7299848773673727 and parameters: {'aroon_length': 99}. Best is trial 23 with value: -1.7299848773673727.
# Trial 966: Aroon(94) → Sortino: 1.595
# [I 2025-11-01 14:38:00,626] Trial 965 finished with value: -1.5951277480474668 and parameters: {'aroon_length': 94}. Best is trial 23 with value: -1.7299848773673727.
# Trial 967: Aroon(105) → Sortino: 1.455
# [I 2025-11-01 14:38:00,673] Trial 966 finished with value: -1.4552693833113513 and parameters: {'aroon_length': 105}. Best is trial 23 with value: -1.7299848773673727.
# Trial 968: Aroon(87) → Sortino: 1.519
# [I 2025-11-01 14:38:00,732] Trial 967 finished with value: -1.5186831066935462 and parameters: {'aroon_length': 87}. Best is trial 23 with value: -1.7299848773673727.
# Trial 969: Aroon(100) → Sortino: 1.677
# [I 2025-11-01 14:38:00,779] Trial 968 finished with value: -1.6768791727265755 and parameters: {'aroon_length': 100}. Best is trial 23 with value: -1.7299848773673727.
# Trial 970: Aroon(97) → Sortino: 1.636
# [I 2025-11-01 14:38:00,829] Trial 969 finished with value: -1.6356863447067507 and parameters: {'aroon_length': 97}. Best is trial 23 with value: -1.7299848773673727.
# Trial 971: Aroon(104) → Sortino: 1.451
# [I 2025-11-01 14:38:00,884] Trial 970 finished with value: -1.4514133474426052 and parameters: {'aroon_length': 104}. Best is trial 23 with value: -1.7299848773673727.
# Trial 972: Aroon(91) → Sortino: 1.495
# [I 2025-11-01 14:38:00,939] Trial 971 finished with value: -1.495039146874357 and parameters: {'aroon_length': 91}. Best is trial 23 with value: -1.7299848773673727.
# Trial 973: Aroon(110) → Sortino: 1.320
# [I 2025-11-01 14:38:00,985] Trial 972 finished with value: -1.3196792199912324 and parameters: {'aroon_length': 110}. Best is trial 23 with value: -1.7299848773673727.
# Trial 974: Aroon(101) → Sortino: 1.619
# [I 2025-11-01 14:38:01,040] Trial 973 finished with value: -1.61889159817128 and parameters: {'aroon_length': 101}. Best is trial 23 with value: -1.7299848773673727.
# Trial 975: Aroon(95) → Sortino: 1.699
# [I 2025-11-01 14:38:01,091] Trial 974 finished with value: -1.699185111447561 and parameters: {'aroon_length': 95}. Best is trial 23 with value: -1.7299848773673727.
# Trial 976: Aroon(98) → Sortino: 1.667
# [I 2025-11-01 14:38:01,155] Trial 975 finished with value: -1.6669716504447392 and parameters: {'aroon_length': 98}. Best is trial 23 with value: -1.7299848773673727.
# Trial 977: Aroon(103) → Sortino: 1.559
# [I 2025-11-01 14:38:01,207] Trial 976 finished with value: -1.5593678170945622 and parameters: {'aroon_length': 103}. Best is trial 23 with value: -1.7299848773673727.
# Trial 978: Aroon(93) → Sortino: 1.538
# [I 2025-11-01 14:38:01,271] Trial 977 finished with value: -1.538345512221517 and parameters: {'aroon_length': 93}. Best is trial 23 with value: -1.7299848773673727.
# Trial 979: Aroon(107) → Sortino: 1.328
# [I 2025-11-01 14:38:01,320] Trial 978 finished with value: -1.3284847137706854 and parameters: {'aroon_length': 107}. Best is trial 23 with value: -1.7299848773673727.
# Trial 980: Aroon(98) → Sortino: 1.667
# [I 2025-11-01 14:38:01,368] Trial 979 finished with value: -1.6669716504447392 and parameters: {'aroon_length': 98}. Best is trial 23 with value: -1.7299848773673727.
# Trial 981: Aroon(101) → Sortino: 1.619
# [I 2025-11-01 14:38:01,426] Trial 980 finished with value: -1.61889159817128 and parameters: {'aroon_length': 101}. Best is trial 23 with value: -1.7299848773673727.
# Trial 982: Aroon(89) → Sortino: 1.529
# [I 2025-11-01 14:38:01,478] Trial 981 finished with value: -1.5287301373421274 and parameters: {'aroon_length': 89}. Best is trial 23 with value: -1.7299848773673727.
# Trial 983: Aroon(96) → Sortino: 1.683
# [I 2025-11-01 14:38:01,534] Trial 982 finished with value: -1.6827295923742487 and parameters: {'aroon_length': 96}. Best is trial 23 with value: -1.7299848773673727.
# Trial 984: Aroon(105) → Sortino: 1.455
# [I 2025-11-01 14:38:01,597] Trial 983 finished with value: -1.4552693833113513 and parameters: {'aroon_length': 105}. Best is trial 23 with value: -1.7299848773673727.
# Trial 985: Aroon(92) → Sortino: 1.442
# [I 2025-11-01 14:38:01,673] Trial 984 finished with value: -1.441876538327114 and parameters: {'aroon_length': 92}. Best is trial 23 with value: -1.7299848773673727.
# Trial 986: Aroon(101) → Sortino: 1.619
# [I 2025-11-01 14:38:01,820] Trial 985 finished with value: -1.61889159817128 and parameters: {'aroon_length': 101}. Best is trial 23 with value: -1.7299848773673727.
# Trial 987: Aroon(85) → Sortino: 1.624
# [I 2025-11-01 14:38:01,892] Trial 986 finished with value: -1.6241139039092876 and parameters: {'aroon_length': 85}. Best is trial 23 with value: -1.7299848773673727.
# Trial 988: Aroon(78) → Sortino: 1.186
# [I 2025-11-01 14:38:02,048] Trial 987 finished with value: -1.1856798307195446 and parameters: {'aroon_length': 78}. Best is trial 23 with value: -1.7299848773673727.
# Trial 989: Aroon(96) → Sortino: 1.683
# [I 2025-11-01 14:38:02,095] Trial 988 finished with value: -1.6827295923742487 and parameters: {'aroon_length': 96}. Best is trial 23 with value: -1.7299848773673727.
# Trial 990: Aroon(110) → Sortino: 1.320
# [I 2025-11-01 14:38:02,151] Trial 989 finished with value: -1.3196792199912324 and parameters: {'aroon_length': 110}. Best is trial 23 with value: -1.7299848773673727.
# Trial 991: Aroon(100) → Sortino: 1.677
# [I 2025-11-01 14:38:02,197] Trial 990 finished with value: -1.6768791727265755 and parameters: {'aroon_length': 100}. Best is trial 23 with value: -1.7299848773673727.
# Trial 992: Aroon(105) → Sortino: 1.455
# [I 2025-11-01 14:38:02,252] Trial 991 finished with value: -1.4552693833113513 and parameters: {'aroon_length': 105}. Best is trial 23 with value: -1.7299848773673727.
# Trial 993: Aroon(94) → Sortino: 1.595
# [I 2025-11-01 14:38:02,296] Trial 992 finished with value: -1.5951277480474668 and parameters: {'aroon_length': 94}. Best is trial 23 with value: -1.7299848773673727.
# Trial 994: Aroon(98) → Sortino: 1.667
# [I 2025-11-01 14:38:02,348] Trial 993 finished with value: -1.6669716504447392 and parameters: {'aroon_length': 98}. Best is trial 23 with value: -1.7299848773673727.
# Trial 995: Aroon(115) → Sortino: 1.096
# [I 2025-11-01 14:38:02,396] Trial 994 finished with value: -1.0958855432945291 and parameters: {'aroon_length': 115}. Best is trial 23 with value: -1.7299848773673727.
# Trial 996: Aroon(103) → Sortino: 1.559
# [I 2025-11-01 14:38:02,441] Trial 995 finished with value: -1.5593678170945622 and parameters: {'aroon_length': 103}. Best is trial 23 with value: -1.7299848773673727.
# Trial 997: Aroon(90) → Sortino: 1.520
# [I 2025-11-01 14:38:02,490] Trial 996 finished with value: -1.520037647181133 and parameters: {'aroon_length': 90}. Best is trial 23 with value: -1.7299848773673727.
# Trial 998: Aroon(107) → Sortino: 1.328
# [I 2025-11-01 14:38:02,548] Trial 997 finished with value: -1.3284847137706854 and parameters: {'aroon_length': 107}. Best is trial 23 with value: -1.7299848773673727.
# [I 2025-11-01 14:38:02,592] Trial 998 finished with value: 999.0 and parameters: {'aroon_length': 191}. Best is trial 23 with value: -1.7299848773673727.
# Trial 1000: Aroon(97) → Sortino: 1.636
# [I 2025-11-01 14:38:02,640] Trial 999 finished with value: -1.6356863447067507 and parameters: {'aroon_length': 97}. Best is trial 23 with value: -1.7299848773673727.
#
# ✅ Optimization complete!
# Best Parameters: Aroon(99)
# Sortino Ratio: 1.730

# %%
# Display Results

if 'results_df' in globals() and not results_df.empty:
    best = results_df.iloc[0]
    
    print("OPTIMIZATION RESULTS:")
    print("=" * 50)
    print(f"Best Parameters:")
    print(f"  Aroon Length: {int(best['aroon_length'])}")
    
    print("\nPerformance Metrics:")
    print(f"  Total Return: {best['total_return']:.2%}")
    print(f"  Sharpe Ratio: {best['sharpe_ratio']:.3f}")
    print(f"  Sortino Ratio: {best['sortino_ratio']:.3f}")
    print(f"  Max Drawdown: {best['max_drawdown']:.2%}")
    print(f"  Total Trades: {int(best['total_trades'])}")
    print(f"  Win Rate: {best['win_rate']:.1f}%")
    print(f"  Profit Factor: {best['profit_factor']:.2f}")
else:
    print("⚠️ No results found. Run optimization first.")
# Out:
# OPTIMIZATION RESULTS:
# ==================================================
# Best Parameters:
#   Aroon Length: 99
#
# Performance Metrics:
#   Total Return: 403.89%
#   Sharpe Ratio: 1.060
#   Sortino Ratio: 1.730
#   Max Drawdown: -40.61%
#   Total Trades: 11
#   Win Rate: 81.8%
#   Profit Factor: 8.64

# %%
# BENCHMARK ANALYSIS: Best Strategy vs Market (Buy & Hold)

if 'results_df' in globals() and not results_df.empty:
    best = results_df.iloc[0]
    aroon_length = int(best['aroon_length'])

    print(f"BENCHMARK ANALYSIS: Best Aroon({aroon_length}) vs Buy & Hold")
    print("=" * 70)

    # Recreate the BEST strategy portfolio
    close_array = train_close.values
    aroon_up, aroon_down = talib.AROON(close_array, close_array, timeperiod=aroon_length)
    aroon_up_series = pd.Series(aroon_up, index=train_close.index)
    aroon_down_series = pd.Series(aroon_down, index=train_close.index)

    entries = aroon_up_series.vbt.crossed_above(aroon_down_series)
    exits = aroon_up_series.vbt.crossed_below(aroon_down_series)

    best_pf = vbt.Portfolio.from_signals(
        close=train_close,
        entries=entries,
        exits=exits,
        init_cash=100_000,
        fees=0.0005,
        slippage=0.0005,
        freq='D'
    )

    # Create buy & hold benchmark
    benchmark_entries = np.zeros(len(train_close), dtype=bool)
    benchmark_entries[0] = True
    benchmark_exits = np.zeros(len(train_close), dtype=bool)

    benchmark_pf = vbt.Portfolio.from_signals(
        close=train_close,
        entries=benchmark_entries,
        exits=benchmark_exits,
        init_cash=100_000,
        fees=0.0005,
        freq='D'
    )

    # Strategy annualized return
    strategy_annualized_return = best['annualized_return']

    # Benchmark metrics
    bench_total_return = benchmark_pf.total_return()
    bench_annualized_return = benchmark_pf.annualized_return(freq='D')
    bench_sharpe = benchmark_pf.sharpe_ratio(freq='D')
    bench_sortino = benchmark_pf.sortino_ratio(freq='D')
    bench_max_drawdown = benchmark_pf.max_drawdown()
    bench_volatility = benchmark_pf.annualized_volatility(freq='D')

    print("\nPERFORMANCE COMPARISON:")
    print(f"Strategy (Aroon {aroon_length}):")
    print(f"  Total Return:      {best['total_return']:.2%}")
    print(f"  Annualized Return: {strategy_annualized_return:.2%}")
    print(f"  Sharpe Ratio:      {best['sharpe_ratio']:.3f}")
    print(f"  Sortino Ratio:     {best['sortino_ratio']:.3f}")
    print(f"  Max Drawdown:      {best['max_drawdown']:.2%}")
    print(f"  Volatility:        {best['volatility']:.2%}")
    print(f"  Total Trades:      {best['total_trades']}")
    print(f"  Win Rate:          {best['win_rate']:.1f}%")
    print(f"  Profit Factor:     {best['profit_factor']:.2f}")

    print(f"\nBenchmark (Buy & Hold {TICKER}):")
    print(f"  Total Return:      {bench_total_return:.2%}")
    print(f"  Annualized Return: {bench_annualized_return:.2%}")
    print(f"  Sharpe Ratio:      {bench_sharpe:.3f}")
    print(f"  Sortino Ratio:     {bench_sortino:.3f}")
    print(f"  Max Drawdown:      {bench_max_drawdown:.2%}")
    print(f"  Volatility:        {bench_volatility:.2%}")

    # Outperformance metrics
    excess_return = best['total_return'] - bench_total_return
    excess_annualized_return = strategy_annualized_return - bench_annualized_return
    sharpe_diff = best['sharpe_ratio'] - bench_sharpe
    sortino_diff = best['sortino_ratio'] - bench_sortino
    excess_max_drawdown = best['max_drawdown'] - bench_max_drawdown

    print(f"\nOUTPERFORMANCE METRICS:")
    print(f"  Excess Return:           {excess_return:.2%}")
    print(f"  Excess Annualized Return: {excess_annualized_return:.2%}")
    print(f"  Sharpe Difference:       {sharpe_diff:.3f}")
    print(f"  Sortino Difference:      {sortino_diff:.3f}")
    print(f"  Excess Max Drawdown:      {excess_max_drawdown:.2%} ({'Better' if excess_max_drawdown > 0 else '❌ Worse'})")
    
    # Calculate beta
    market_beta = best['volatility'] / bench_volatility if bench_volatility != 0 else np.nan
    print(f"  Market Beta (approx):     {market_beta:.3f} ({'Lower risk' if market_beta < 1 else '⚠️ Higher risk'})")
else:
    print("⚠️ No results available for benchmark analysis.")
# Out:
# BENCHMARK ANALYSIS: Best Aroon(99) vs Buy & Hold
# ======================================================================
#
# PERFORMANCE COMPARISON:
# Strategy (Aroon 99):
#   Total Return:      403.89%
#   Annualized Return: 23.31%
#   Sharpe Ratio:      1.060
#   Sortino Ratio:     1.730
#   Max Drawdown:      -40.61%
#   Volatility:        33.89%
#   Total Trades:      11.0
#   Win Rate:          81.8%
#   Profit Factor:     8.64
#
# Benchmark (Buy & Hold 3GOL.L):
#   Total Return:      -44.29%
#   Annualized Return: -10.37%
#   Sharpe Ratio:      0.075
#   Sortino Ratio:     0.106
#   Max Drawdown:      -83.81%
#   Volatility:        54.68%
#
# OUTPERFORMANCE METRICS:
#   Excess Return:           448.18%
#   Excess Annualized Return: 33.68%
#   Sharpe Difference:       0.985
#   Sortino Difference:      1.624
#   Excess Max Drawdown:      43.20% (Better)
#   Market Beta (approx):     0.620 (Lower risk)

# %%
# IN-SAMPLE vs OUT-OF-SAMPLE COMPARISON

FREQ = "1D"

if 'results_df' in globals() and not results_df.empty:
    best = results_df.iloc[0]
    aroon_length = int(best['aroon_length'])

    # Out-of-sample validation
    close_array_val = val_close.values
    aroon_up_val, aroon_down_val = talib.AROON(close_array_val, close_array_val, timeperiod=aroon_length)
    aroon_up_series_val = pd.Series(aroon_up_val, index=val_close.index)
    aroon_down_series_val = pd.Series(aroon_down_val, index=val_close.index)

    entries_val = aroon_up_series_val.vbt.crossed_above(aroon_down_series_val)
    exits_val = aroon_up_series_val.vbt.crossed_below(aroon_down_series_val)

    pf_val = vbt.Portfolio.from_signals(
        close=val_close,
        entries=entries_val,
        exits=exits_val,
        init_cash=100_000,
        fees=0.0005,
        slippage=0.0005,
        freq=FREQ
    )

    # Out-of-sample metrics
    val_total_return = pf_val.total_return()
    val_annualized_return = pf_val.annualized_return(freq=FREQ)
    val_sharpe = pf_val.sharpe_ratio(freq=FREQ)
    val_sortino = pf_val.sortino_ratio(freq=FREQ)
    val_max_drawdown = pf_val.max_drawdown()
    val_volatility = pf_val.annualized_volatility(freq=FREQ)

    trades_val = pf_val.trades
    val_total_trades = len(trades_val)
    years = max((val_close.index[-1] - val_close.index[0]).days / 365.25, 1e-9)
    val_trades_per_year = val_total_trades / years

    val_win_rate_pct = np.nan
    val_profit_factor = np.nan
    val_expectancy = 0.0
    if val_total_trades > 0:
        tr = trades_val.returns.values if hasattr(trades_val.returns, 'values') else np.array(trades_val.returns)
        if tr.size > 0:
            pos = tr[tr > 0]
            neg = tr[tr < 0]
            val_win_rate_pct = (len(pos) / len(tr)) * 100 if len(tr) > 0 else np.nan
            gains = pos.sum() if len(pos) else 0.0
            losses = abs(neg.sum()) if len(neg) else 0.0
            val_profit_factor = gains / losses if losses > 0 else np.inf
            val_expectancy = tr.mean()

    def chg(before, after):
        if pd.isna(before) or pd.isna(after) or before == 0:
            return "N/A"
        return f"{((after - before) / abs(before)) * 100:+.1f}%"

    print(f"IN-SAMPLE vs OUT-OF-SAMPLE COMPARISON: Best Aroon({aroon_length})")
    print("=" * 80)

    print(f"{'METRIC':<25} {'IN-SAMPLE':<15} {'OUT-OF-SAMPLE':<15} {'DEGRADATION':<15}")

    print("\nRETURN METRICS:")
    print(f"{'Total Return':<25} {best['total_return']:<15.2%} {val_total_return:<15.2%} {chg(best['total_return'], val_total_return)}")
    print(f"{'Annualized Return':<25} {best['annualized_return']:<15.2%} {val_annualized_return:<15.2%} {chg(best['annualized_return'], val_annualized_return)}")

    print("\nRISK-ADJUSTED METRICS:")
    print(f"{'Sharpe Ratio':<25} {best['sharpe_ratio']:<15.3f} {val_sharpe:<15.3f} {chg(best['sharpe_ratio'], val_sharpe)}")
    print(f"{'Sortino Ratio':<25} {best['sortino_ratio']:<15.3f} {val_sortino:<15.3f} {chg(best['sortino_ratio'], val_sortino)}")

    print("\nRISK METRICS:")
    print(f"{'Max Drawdown':<25} {best['max_drawdown']:<15.2%} {val_max_drawdown:<15.2%} {chg(best['max_drawdown'], val_max_drawdown)}")
    print(f"{'Volatility':<25} {best['volatility']:<15.2%} {val_volatility:<15.2%} {chg(best['volatility'], val_volatility)}")

    print("\nTRADE METRICS:")
    print(f"{'Total Trades':<25} {best['total_trades']:<15.0f} {val_total_trades:<15.0f} {chg(best['total_trades'], val_total_trades)}")
    print(f"{'Trades per Year':<25} {best['trades_per_year']:<15.1f} {val_trades_per_year:<15.1f} {chg(best['trades_per_year'], val_trades_per_year)}")
    print(f"{'Win Rate %':<25} {best['win_rate']:<15.1f} {val_win_rate_pct:<15.1f} {chg(best['win_rate'], val_win_rate_pct)}")
    print(f"{'Profit Factor':<25} {best['profit_factor']:<15.2f} {val_profit_factor:<15.2f} {chg(best['profit_factor'], val_profit_factor)}")
    print(f"{'Expectancy':<25} {best['expectancy']:<15.4f} {val_expectancy:<15.4f} {chg(best['expectancy'], val_expectancy)}")
else:
    print("⚠️ No results for comparison.")
# Out:
# IN-SAMPLE vs OUT-OF-SAMPLE COMPARISON: Best Aroon(99)
# ================================================================================
# METRIC                    IN-SAMPLE       OUT-OF-SAMPLE   DEGRADATION
#
# RETURN METRICS:
# Total Return              403.89%         17.61%          -95.6%
# Annualized Return         23.31%          4.66%           -80.0%
#
# RISK-ADJUSTED METRICS:
# Sharpe Ratio              1.060           0.313           -70.5%
# Sortino Ratio             1.730           0.469           -72.9%
#
# RISK METRICS:
# Max Drawdown              -40.61%         -35.03%         +13.7%
# Volatility                33.89%          22.84%          -32.6%
#
# TRADE METRICS:
# Total Trades              11              4               -63.6%
# Trades per Year           1.4             0.8             -45.4%
# Win Rate %                81.8            75.0            -8.3%
# Profit Factor             8.64            10.87           +25.7%
# Expectancy                0.1731          0.0422          -75.6%

# %%
# COMPREHENSIVE VISUALIZATION

if 'results_df' in globals() and not results_df.empty:
    best = results_df.iloc[0]
    aroon_length = int(best['aroon_length'])

    # Calculate Aroon for full sample
    close_array_full = close.values
    aroon_up_full, aroon_down_full = talib.AROON(close_array_full, close_array_full, timeperiod=aroon_length)
    aroon_up_series_full = pd.Series(aroon_up_full, index=close.index)
    aroon_down_series_full = pd.Series(aroon_down_full, index=close.index)

    # Generate signals
    entries_full = aroon_up_series_full.vbt.crossed_above(aroon_down_series_full)
    exits_full = aroon_up_series_full.vbt.crossed_below(aroon_down_series_full)

    # Create portfolio
    pf_full = vbt.Portfolio.from_signals(
        close=close,
        entries=entries_full,
        exits=exits_full,
        init_cash=100_000,
        fees=0.0005,
        slippage=0.0005,
        freq='D'
    )

    # Get returns
    ret = pf_full.returns()

    # Create comprehensive figure
    fig = plt.figure(figsize=(18, 12))
    gs = fig.add_gridspec(4, 2, hspace=0.5, wspace=0.3, 
                          height_ratios=[2.5, 1.5, 1.5, 1],
                          left=0.05, right=0.95, top=0.95, bottom=0.05)

    fig.suptitle(f'Aroon({aroon_length}) Trading Strategy - Comprehensive Analysis', 
                 fontsize=16, fontweight='bold', y=0.98)

    # 1. Price + Aroon lines + Signals
    ax1 = fig.add_subplot(gs[0, :])
    ax1_twin = ax1.twinx()

    ax1.plot(close.index, close.values, label='Close Price', color='black', linewidth=1.5, alpha=0.7)
    ax1_twin.plot(close.index, aroon_up_series_full.values, label='Aroon Up', color='green', linewidth=1.2, alpha=0.8)
    ax1_twin.plot(close.index, aroon_down_series_full.values, label='Aroon Down', color='red', linewidth=1.2, alpha=0.8)
    
    # Mark buy/sell signals
    buy_indices = entries_full[entries_full].index
    sell_indices = exits_full[exits_full].index
    if len(buy_indices) > 0:
        ax1.scatter(buy_indices, close.reindex(buy_indices).values, marker='^', color='green', s=100, label='Buy', zorder=5)
    if len(sell_indices) > 0:
        ax1.scatter(sell_indices, close.reindex(sell_indices).values, marker='v', color='red', s=100, label='Sell', zorder=5)

    ax1.set_title('Price, Aroon Indicator, and Trading Signals', fontsize=13, fontweight='bold')
    ax1.set_ylabel('Price ($)', fontsize=10)
    ax1_twin.set_ylabel('Aroon (0-100)', fontsize=10)
    ax1.legend(loc='upper left', fontsize=9)
    ax1_twin.legend(loc='upper right', fontsize=9)
    ax1.grid(True, alpha=0.3)

    # 2. Equity Curve
    ax2 = fig.add_subplot(gs[1, :])
    equity = (1 + ret).cumprod()
    ax2.plot(close.index, equity.values, color='black', linewidth=2, label='Equity Curve')
    ax2.axvline(x=train_close.index[-1], color='red', linestyle='--', linewidth=2, alpha=0.6, label='Train/Val Split')
    ax2.set_title('Equity Curve', fontsize=13, fontweight='bold')
    ax2.set_ylabel('Cumulative Returns', fontsize=10)
    ax2.legend(loc='best', fontsize=9)
    ax2.grid(True, alpha=0.3)

    # 3. Drawdown
    ax3 = fig.add_subplot(gs[2, :])
    peak = equity.cummax()
    drawdown = (equity - peak) / peak
    ax3.fill_between(close.index, drawdown * 100, 0, color='red', alpha=0.5)
    ax3.plot(close.index, drawdown * 100, color='darkred', linewidth=1.5)
    ax3.set_title('Drawdown Chart', fontsize=13, fontweight='bold')
    ax3.set_ylabel('Drawdown (%)', fontsize=10)
    ax3.set_xlabel('Date', fontsize=10)
    ax3.grid(True, alpha=0.3)

    # 4. Rolling Sharpe
    ax4 = fig.add_subplot(gs[3, :])
    rolling_window = max(20, min(252, max(1, len(ret) // 4)))
    if len(ret) > rolling_window:
        rolling_sharpe = ret.rolling(window=rolling_window).apply(
            lambda x: (x.mean() * 252) / (x.std() * np.sqrt(252)) if x.std() and x.std() != 0 else np.nan,
            raw=False
        )
        ax4.plot(rolling_sharpe.index, rolling_sharpe.values, linewidth=2, color='blue', alpha=0.85)
        ax4.axhline(y=1.0, color='green', linestyle='--', alpha=0.6, label='Sharpe = 1.0')
        ax4.axhline(y=0.5, color='orange', linestyle='--', alpha=0.6, label='Sharpe = 0.5')
        ax4.axvline(x=train_close.index[-1], color='purple', linestyle='--', linewidth=2, alpha=0.6)

    ax4.set_title(f'Rolling Sharpe Ratio (window={rolling_window})', fontsize=12, fontweight='bold')
    ax4.set_ylabel('Sharpe Ratio', fontsize=10)
    ax4.set_xlabel('Date', fontsize=10)
    ax4.legend(loc='upper left', fontsize=9)
    ax4.grid(True, alpha=0.3)
    ax4.xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%Y-%m'))

    plt.savefig('Aroon_Comprehensive_Analysis.png', dpi=300, bbox_inches='tight')
    print("✅ Comprehensive visualization saved as 'Aroon_Comprehensive_Analysis.png'")
    plt.close(fig)

    print(f"\nTraining Period: {train_close.index[0].date()} to {train_close.index[-1].date()} ({len(train_close)} days)")
    print(f"Validation Period: {val_close.index[0].date()} to {val_close.index[-1].date()} ({len(val_close)} days)")
    print(f"\nBest Parameters: Aroon({aroon_length})")
else:
    print("⚠️ No results available for comprehensive visualization.")
# Out:
# ✅ Comprehensive visualization saved as 'Aroon_Comprehensive_Analysis.png'
#
# Training Period: 2012-12-20 to 2020-09-08 (1950 days)
# Validation Period: 2020-09-09 to 2025-10-31 (1300 days)
#
# Best Parameters: Aroon(99)

# %%
# METRICS TABLE - In-Sample vs Out-of-Sample

if 'results_df' in globals() and not results_df.empty:
    best = results_df.iloc[0]
    aroon_length = int(best['aroon_length'])

    # Get train and validation results
    train_result = evaluate_aroon_strategy(aroon_length, data=train_close, return_metrics=True)
    
    val_result = evaluate_aroon_strategy(aroon_length, data=val_close, return_metrics=True)
    
    # Calculate trades per year
    train_trades_per_year = train_result['total_trades'] / (len(train_close) / 252)
    val_trades_per_year = val_result['total_trades'] / (len(val_close) / 252)
    
    # Create separate figure for metrics table
    fig2 = plt.figure(figsize=(14, 10))
    ax = fig2.add_subplot(111)
    ax.axis('off')
    
    # Create metrics table
    table_data = [
        ['Metric', 'In-Sample (Training)', 'Out-of-Sample (Validation)'],
        ['Period', f'{train_close.index[0].date()} to {train_close.index[-1].date()}', 
         f'{val_close.index[0].date()} to {val_close.index[-1].date()}'],
        ['Annualized Return', f"{train_result['annualized_return']:.2%}", f"{val_result['annualized_return']:.2%}"],
        ['Sharpe Ratio', f"{train_result['sharpe_ratio']:.3f}", f"{val_result['sharpe_ratio']:.3f}"],
        ['Sortino Ratio', f"{train_result['sortino_ratio']:.3f}", f"{val_result['sortino_ratio']:.3f}"],
        ['Max Drawdown', f"{train_result['max_drawdown']:.2%}", f"{val_result['max_drawdown']:.2%}"],
        ['Trades per Year', f"{train_trades_per_year:.2f}", f"{val_trades_per_year:.2f}"],
        ['Win Rate', f"{train_result['win_rate']:.1f}%", f"{val_result['win_rate']:.1f}%"],
        ['Profit Factor', f"{train_result['profit_factor']:.2f}", f"{val_result['profit_factor']:.2f}"]
    ]
    
    table = ax.table(cellText=table_data, cellLoc='left', loc='center',
                     colWidths=[0.4, 0.3, 0.3], bbox=[0, 0, 1, 1])
    table.auto_set_font_size(False)
    table.set_fontsize(11)
    table.scale(1, 2.5)
    
    # Style the table
    for i in range(len(table_data)):
        for j in range(len(table_data[0])):
            cell = table[(i, j)]
            if i == 0:
                cell.set_facecolor('#4CAF50')
                cell.set_text_props(weight='bold', color='white')
            else:
                if j == 0:
                    cell.set_facecolor('#F0F0F0')
                else:
                    cell.set_facecolor('#FFFFFF')
    
    fig2.suptitle(f'Performance Metrics Summary - Aroon({aroon_length})', fontsize=16, fontweight='bold', y=0.95)
    plt.savefig('Aroon_Metrics_Table.png', dpi=300, bbox_inches='tight')
    print("✅ Metrics table saved as 'Aroon_Metrics_Table.png'")
    plt.close(fig2)
    
    print(f"\n📊 Metrics Summary:")
    print(f"Training: {train_result['total_return']:.2%} return, {train_result['sharpe_ratio']:.3f} Sharpe")
    print(f"Validation: {val_result['total_return']:.2%} return, {val_result['sharpe_ratio']:.3f} Sharpe")
else:
    print("⚠️ No results available for metrics table.")
# Out:
# ✅ Metrics table saved as 'Aroon_Metrics_Table.png'
#
# 📊 Metrics Summary:
# Training: 403.89% return, 1.060 Sharpe
# Validation: nan% return, nan Sharpe

# %%
# PARAMETER SENSITIVITY ANALYSIS (±15 around best aroon_length)

if 'results_df' in globals() and not results_df.empty:
    best = results_df.iloc[0]
    aroon_length = int(best['aroon_length'])

    print(f"🔬 Parameter Sensitivity Analysis for Best Aroon({aroon_length})")
    print("=" * 80)

    # Create sensitivity ranges (±15 around best length)
    candidates = list(range(max(5, aroon_length - 15), min(101, aroon_length + 16)))

    price_np = train_close.to_numpy(dtype=float)
    idx = train_close.index

    def eval_combo(length: int) -> dict:
        aroon_up, aroon_down = talib.AROON(price_np, price_np, timeperiod=length)
        aroon_up_series = pd.Series(aroon_up, index=idx)
        aroon_down_series = pd.Series(aroon_down, index=idx)

        entries = aroon_up_series.vbt.crossed_above(aroon_down_series)
        exits = aroon_up_series.vbt.crossed_below(aroon_down_series)

        pf = vbt.Portfolio.from_signals(
            close=price_np, entries=entries, exits=exits,
            init_cash=100_000, fees=0.0005, slippage=0.0005, freq='1D'
        )

        total_return = float(pf.total_return())
        sharpe = float(pf.sharpe_ratio(freq='D'))
        sortino = float(pf.sortino_ratio(freq='D'))
        mdd = float(pf.max_drawdown())
        vol = float(pf.annualized_volatility(freq='D'))

        trades = pf.trades
        ntr = len(trades)
        win_rate_pct = np.nan
        profit_factor = np.nan
        expectancy = 0.0
        if ntr > 0:
            tr = trades.returns.values if hasattr(trades.returns, 'values') else np.array(trades.returns)
            if tr.size > 0:
                pos = tr[tr > 0]
                neg = tr[tr < 0]
                win_rate_pct = (len(pos) / len(tr)) * 100 if len(tr) else np.nan
                gains = pos.sum() if len(pos) else 0.0
                losses = abs(neg.sum()) if len(neg) else 0.0
                profit_factor = gains / losses if losses > 0 else np.inf
                expectancy = float(tr.mean())

        return {
            'aroon_length': length,
            'sharpe': sharpe, 'sortino': sortino,
            'total_return': total_return, 'max_drawdown': mdd, 'volatility': vol,
            'total_trades': ntr, 'win_rate_pct': win_rate_pct,
            'profit_factor': profit_factor, 'expectancy': expectancy
        }

    rows = []
    for length in candidates:
        try:
            rows.append(eval_combo(length))
        except Exception:
            pass

    if not rows:
        print("⚠️ No sensitivity results computed.")
    else:
        sens = pd.DataFrame(rows)

        # Show as a table
        cols = ['aroon_length','sharpe','sortino','total_return','max_drawdown','volatility',
                'total_trades','win_rate_pct','profit_factor','expectancy']
        sens_table = sens[cols].sort_values('aroon_length')

        print(f"\n📊 Sensitivity Results ({len(sens_table)} variations tested):\n")
        print(sens_table.to_string())

        # Compact variation summary
        metric_cols = ['sharpe','sortino','total_return','max_drawdown','volatility',
                       'win_rate_pct','profit_factor','expectancy']
        summary = sens_table[metric_cols].agg(['mean','std','min','max']).T

        print("\n📈 Sensitivity Summary (mean / std / min / max):")
        print(summary.round(4).to_string())

        # Highlight best performer in sensitivity test
        best_sens_idx = sens_table['sharpe'].idxmax()
        best_sens = sens_table.loc[best_sens_idx]
        print(f"\n🏆 Best in Sensitivity Test: Aroon({int(best_sens['aroon_length'])}) → Sharpe: {best_sens['sharpe']:.3f}")
else:
    print("⚠️ No results available for sensitivity analysis.")
# Out:
# 🔬 Parameter Sensitivity Analysis for Best Aroon(99)
# ================================================================================
#
# 📊 Sensitivity Results (17 variations tested):
#
#     aroon_length    sharpe   sortino  total_return  max_drawdown  volatility  total_trades  win_rate_pct  profit_factor  expectancy
# 0             84  0.998340  1.625246      3.406018     -0.371804    0.332651            14     85.714286       5.098502    0.132578
# 1             85  0.998185  1.624114      3.419381     -0.371804    0.333580            14     85.714286       5.424213    0.131789
# 2             86  0.942153  1.522384      3.028166     -0.371804    0.335794            13     76.923077       5.567523    0.132748
# 3             87  0.938004  1.518683      2.994734     -0.371804    0.335498            13     76.923077       5.295192    0.131866
# 4             88  0.939577  1.521316      3.006451     -0.371804    0.335532            13     76.923077       5.117583    0.132825
# 5             89  0.943736  1.528730      3.039050     -0.371804    0.335730            13     76.923077       5.279465    0.133090
# 6             90  0.939408  1.520038      3.013261     -0.371804    0.336152            13     76.923077       5.055153    0.132694
# 7             91  0.923152  1.495039      2.905318     -0.371804    0.336748            13     69.230769       4.582978    0.132256
# 8             92  0.892884  1.441877      2.707381     -0.378363    0.337568            12     75.000000       5.981159    0.131861
# 9             93  0.949045  1.538346      3.120350     -0.387945    0.338899            12     75.000000       5.795500    0.142910
# 10            94  0.982958  1.595128      3.377578     -0.381265    0.338667            12     75.000000       6.551104    0.148115
# 11            95  1.041040  1.699185      3.846830     -0.383627    0.337804            12     75.000000       7.751591    0.155795
# 12            96  1.029934  1.682730      3.746881     -0.406058    0.337578            11     81.818182       7.573518    0.168440
# 13            97  1.004441  1.635686      3.548569     -0.406058    0.338506            11     81.818182       7.325512    0.163113
# 14            98  1.022976  1.666972      3.705205     -0.406058    0.338605            11     81.818182       8.341267    0.165728
# 15            99  1.060167  1.729985      4.038911     -0.406058    0.338941            11     81.818182       8.641936    0.173083
# 16           100  1.029576  1.676879      3.770160     -0.406058    0.339089            11     81.818182       8.576341    0.167420
#
# 📈 Sensitivity Summary (mean / std / min / max):
#                   mean     std      min      max
# sharpe          0.9786  0.0486   0.8929   1.0602
# sortino         1.5895  0.0847   1.4419   1.7300
# total_return    3.3338  0.3910   2.7074   4.0389
# max_drawdown   -0.3845  0.0152  -0.4061  -0.3718
# volatility      0.3369  0.0019   0.3327   0.3391
# win_rate_pct   78.4921  4.3767  69.2308  85.7143
# profit_factor   6.3505  1.3848   4.5830   8.6419
# expectancy      0.1457  0.0161   0.1318   0.1731
#
# 🏆 Best in Sensitivity Test: Aroon(99) → Sharpe: 1.060
