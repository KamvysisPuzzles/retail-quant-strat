# %%
# !pip install yfinance
# !pip install TA-Lib
# !pip install numpy
# !pip install pandas
# !pip install vectorbt
# !pip install scipy
# %pip install scikit-optimize
# %pip install optuna

# %%
import yfinance as yf
import talib
import numpy as np
import pandas as pd
import vectorbt as vbt
import warnings
from scipy import stats
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore", message="Degrees of freedom <= 0 for slice", category=RuntimeWarning)
warnings.filterwarnings("ignore", message="invalid value encountered in scalar divide", category=RuntimeWarning)

# %%
# DOWNLOAD STOCK DATA FROM 2018 USING YFINANCE

TICKER = 'SPY'
START_DATE = '2018-01-01'
TRAIN_RATIO = 0.6
# Download data
stock_data = yf.download(TICKER, start=START_DATE, interval='1d')

if not stock_data.empty:
    print(f"Successfully downloaded {len(stock_data)} records for {TICKER}")
    print(f"Data range: {stock_data.index.min().date()} to {stock_data.index.max().date()}")
else:
    print(f"Failed to download {TICKER} data")

stock_data
# Out:
# C:\Users\harka\AppData\Local\Temp\ipykernel_13328\874233762.py:7: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# [*********************100%***********************]  1 of 1 completed
# Successfully downloaded 1970 records for SPY
# Data range: 2018-01-02 to 2025-10-31
# Price            Close        High         Low        Open    Volume
# Ticker             SPY         SPY         SPY         SPY       SPY
# Date
# 2018-01-02  237.909119  237.944533  236.696430  237.085910  86655700
# 2018-01-03  239.414017  239.564509  238.077390  238.077390  90070400
# 2018-01-04  240.423065  240.909929  239.475946  240.060166  80636400
# 2018-01-05  242.025208  242.149118  240.723996  241.219693  83524000
# 2018-01-08  242.467789  242.627114  241.635720  241.927816  57319200
# ...                ...         ...         ...         ...       ...
# 2025-10-27  685.239990  685.539978  682.119995  682.729980  63339800
# 2025-10-28  687.059998  688.909973  684.830017  687.049988  61738100
# 2025-10-29  687.390015  689.700012  682.869995  688.719971  85657100
# 2025-10-30  679.830017  685.940002  679.830017  683.900024  76335800
# 2025-10-31  682.059998  685.080017  679.239990  685.039978  87119400
#
# [1970 rows x 5 columns]

# %%
# PREPARE PRICE SERIES

def select_close_series(df, ticker):
    if isinstance(df.columns, pd.MultiIndex):
        if ('Close', ticker) in df.columns:
            s = df[('Close', ticker)]
        else:
            cols = [c for c in df.columns if 'Close' in str(c)]
            if not cols:
                raise KeyError("Close not found")
            s = df[cols[0]]
    else:
        s = df['Close']
    return s.astype(float).squeeze()

close = select_close_series(stock_data, TICKER)
close.name = 'price'

# Simple split

split_idx = int(len(close) * TRAIN_RATIO)
train_close = close.iloc[:split_idx].copy()
val_close = close.iloc[split_idx:].copy()

print(f"Data ready: train={train_close.index[0].date()} → {train_close.index[-1].date()} | val={val_close.index[0].date()} → {val_close.index[-1].date()}")
# Out:
# Data ready: train=2018-01-02 → 2022-09-12 | val=2022-09-13 → 2025-10-31

# %% [markdown]
# # Triple EMA Strategy - NO RSI FILTER
#
# This notebook optimizes a **pure Triple EMA crossover strategy** without RSI confirmation.
#
# **Strategy Logic**: Buy when any EMA crosses above another. Sell when any EMA crosses below another.
#
# No additional filters - pure trend-following approach.

# %%
# Define Parameter Ranges for Triple EMA Optimization (NO RSI)

param_bounds = {
    'ema1': (1, 30),    # Fast EMA (shortest-term)
    'ema2': (30, 100),   # Medium EMA (medium-term) 
    'ema3': (100, 200), # Slow EMA (longest-term)
}

print("Parameter Bounds for Optimization (Daily Data):")
print(f"  EMA1 (Fast): {param_bounds['ema1'][0]} - {param_bounds['ema1'][1]} periods")
print(f"  EMA2 (Medium): {param_bounds['ema2'][0]} - {param_bounds['ema2'][1]} periods")
print(f"  EMA3 (Slow): {param_bounds['ema3'][0]} - {param_bounds['ema3'][1]} periods")

# Constraint: ema1 < ema2 < ema3
def is_valid_params(ema1, ema2, ema3):
    return ema1 < ema2 < ema3

print(f"\nConstraint: EMA1 < EMA2 < EMA3")
print("✅ Ready for optimization!")
# Out:
# Parameter Bounds for Optimization (Daily Data):
#   EMA1 (Fast): 1 - 30 periods
#   EMA2 (Medium): 30 - 100 periods
#   EMA3 (Slow): 100 - 200 periods
#
# Constraint: EMA1 < EMA2 < EMA3
# ✅ Ready for optimization!

# %%
# Core Optimization Function for Triple EMA Strategy (NO RSI FILTER)

def evaluate_triple_ema_strategy(params, data=train_close, return_metrics=False):
    """
    Evaluate Triple EMA crossover strategy WITHOUT RSI filter.
    
    Args:
        params: tuple of (ema1, ema2, ema3) periods
        data: price data to test on
        return_metrics: if True, return full metrics dict; if False, return negative Sortino ratio
    
    Returns:
        Negative Sortino ratio (for minimization) or full metrics dict
    """
    ema1_period, ema2_period, ema3_period = params
    
    # Validate parameter constraints
    if not is_valid_params(ema1_period, ema2_period, ema3_period):
        return 999.0  # Large penalty for invalid parameters
    
    try:
        # Calculate EMAs
        ema1 = vbt.MA.run(data, ema1_period, ewm=True)
        ema2 = vbt.MA.run(data, ema2_period, ewm=True)
        ema3 = vbt.MA.run(data, ema3_period, ewm=True)
        
        # Generate EMA crossover signals (NO RSI FILTER)
        entries = (
            ema1.ma_crossed_above(ema2.ma) |
            ema1.ma_crossed_above(ema3.ma) |
            ema2.ma_crossed_above(ema3.ma)
        )
        exits = (
            ema1.ma_crossed_below(ema2.ma) |
            ema1.ma_crossed_below(ema3.ma) |
            ema2.ma_crossed_below(ema3.ma)
        )
        
        # Convert to arrays
        entries_array = pd.Series(np.asarray(entries).ravel(), index=data.index, dtype=bool)
        exits_array = pd.Series(np.asarray(exits).ravel(), index=data.index, dtype=bool)
        
        # Backtest
        portfolio = vbt.Portfolio.from_signals(
            close=data,
            entries=entries_array,
            exits=exits_array,
            init_cash=100_000,
            fees=0.0005,
            slippage=0.0005,
            freq='D'
        )
        
        # Calculate key metrics
        sharpe_ratio = float(portfolio.sharpe_ratio(freq='D'))
        sortino_ratio = float(portfolio.sortino_ratio(freq='D'))
        total_return = float(portfolio.total_return())
        max_drawdown = float(portfolio.max_drawdown())
        volatility = float(portfolio.annualized_volatility(freq='D'))
        
        # Trade metrics
        trades = portfolio.trades
        total_trades = len(trades)
        
        # Check for sufficient trading activity
        years = max((data.index[-1] - data.index[0]).days / 365.25, 1e-9)
        trades_per_year = total_trades / years
        
        if trades_per_year < 1:  # Too few trades
            if return_metrics:
                return {
                    'ema1_period': ema1_period,
                    'ema2_period': ema2_period,
                    'ema3_period': ema3_period,
                    'sharpe_ratio': np.nan,
                    'sortino_ratio': np.nan,
                    'total_return': np.nan,
                    'annualized_return': np.nan,
                    'max_drawdown': np.nan,
                    'volatility': np.nan,
                    'total_trades': total_trades,
                    'win_rate': np.nan,
                    'profit_factor': np.nan,
                    'expectancy': np.nan,
                    'trades_per_year': trades_per_year
                }
            return 999.0
        
        if return_metrics:
            # Calculate additional metrics
            win_rate_pct = np.nan
            profit_factor = np.nan
            expectancy = 0.0
            annualized_return = (1.0 + total_return) ** (1.0 / years) - 1.0 if years > 0 else np.nan
            
            if total_trades > 0:
                tr = trades.returns.values if hasattr(trades.returns, 'values') else np.array(trades.returns)
                if tr.size > 0:
                    pos = tr[tr > 0]
                    neg = tr[tr < 0]
                    win_rate_pct = (len(pos) / len(tr)) * 100.0
                    gains = pos.sum() if len(pos) else 0.0
                    losses = abs(neg.sum()) if len(neg) else 0.0
                    profit_factor = (gains / losses) if losses > 0 else np.inf
                    expectancy = float(tr.mean())
            
            return {
                'ema1_period': ema1_period,
                'ema2_period': ema2_period,
                'ema3_period': ema3_period,
                'sharpe_ratio': sharpe_ratio,
                'sortino_ratio': sortino_ratio,
                'total_return': total_return,
                'annualized_return': annualized_return,
                'max_drawdown': max_drawdown,
                'volatility': volatility,
                'total_trades': total_trades,
                'win_rate': win_rate_pct,
                'profit_factor': profit_factor,
                'expectancy': expectancy,
                'trades_per_year': trades_per_year
            }
        else:
            # Return negative Sortino for minimization
            return -sortino_ratio
            
    except Exception as e:
        return 999.0  # Large penalty for errors

print("✅ Core optimization function created - NO RSI FILTER!")
print("Function evaluates Triple EMA strategy without any confirmation filter.")
# Out:
# ✅ Core optimization function created - NO RSI FILTER!
# Function evaluates Triple EMA strategy without any confirmation filter.

# %%
# Import optimization libraries
try:
    from skopt import gp_minimize
    from skopt.space import Real
    from skopt.utils import use_named_args
    SKOPT_AVAILABLE = True
except ImportError:
    SKOPT_AVAILABLE = False

try:
    import optuna
    OPTUNA_AVAILABLE = True
except ImportError:
    OPTUNA_AVAILABLE = False

print(f"scikit-optimize: {'✅' if SKOPT_AVAILABLE else '❌'}")
print(f"Optuna: {'✅' if OPTUNA_AVAILABLE else '❌'}")
# Out:
# scikit-optimize: ✅
# Optuna: ✅

# %%
# OPTUNA OPTIMIZATION - Pure 3EMA Strategy

print("=" * 70)
print("OPTUNA OPTIMIZATION: Triple EMA Strategy (NO RSI FILTER)")
print(f"Training Period: {train_close.index[0].date()} → {train_close.index[-1].date()}")
print("=" * 70)

optimization_results = []
evaluation_count = 0

def objective(trial):
    """Optuna objective function - NO RSI."""
    global evaluation_count
    evaluation_count += 1
    
    # Suggest parameters (NO RSI threshold)
    ema1 = trial.suggest_int('ema1', param_bounds['ema1'][0], param_bounds['ema1'][1])
    ema2 = trial.suggest_int('ema2', param_bounds['ema2'][0], param_bounds['ema2'][1])
    ema3 = trial.suggest_int('ema3', param_bounds['ema3'][0], param_bounds['ema3'][1])
    
    # Validate constraints
    if not is_valid_params(ema1, ema2, ema3):
        return 999.0
    
    # Evaluate strategy (params is now just 3 values, not 4)
    result = evaluate_triple_ema_strategy((ema1, ema2, ema3))
    
    # Debug output
    if result == 999.0 and evaluation_count <= 5:
        print(f"Trial {evaluation_count}: EMA({ema1},{ema2},{ema3}) → No valid trades")
    elif evaluation_count % 10 == 0 or result != 999.0:
        print(f"Trial {evaluation_count}: EMA({ema1},{ema2},{ema3}) → Sortino: {-result:.3f}")
    
    return result

if OPTUNA_AVAILABLE:
    # Create study
    study = optuna.create_study(
        direction='minimize',
        sampler=optuna.samplers.TPESampler(seed=42),
        pruner=optuna.pruners.MedianPruner(n_startup_trials=10, n_warmup_steps=5)
    )
    
    print("\nStarting Optuna optimization...\n")
    
    study.optimize(objective, n_trials=1000, show_progress_bar=True)
    
    # Get best parameters
    best_params = study.best_params
    best_ema1 = best_params['ema1']
    best_ema2 = best_params['ema2']
    best_ema3 = best_params['ema3']
    best_sortino = -study.best_value
    
    # Evaluate best parameters to get full metrics
    best_result = evaluate_triple_ema_strategy(
        (best_ema1, best_ema2, best_ema3), 
        return_metrics=True
    )
    
    # Create results dataframe
    results_df = pd.DataFrame([best_result])
    
    print("\n✅ Optimization complete!")
    print(f"Best Parameters: EMA({best_ema1},{best_ema2},{best_ema3})")
    print(f"Sortino Ratio: {best_sortino:.3f}")
    
else:
    print("❌ Optuna not available")
# Out:
# [I 2025-11-01 18:17:49,562] A new study created in memory with name: no-name-ac171901-e484-434e-a9be-503de180d812
# ======================================================================
# OPTUNA OPTIMIZATION: Triple EMA Strategy (NO RSI FILTER)
# Training Period: 2018-01-02 → 2022-09-12
# ======================================================================
#
# Starting Optuna optimization...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Trial 1: EMA(12,97,173) → No valid trades
# [I 2025-11-01 18:17:49,892] Trial 0 finished with value: 999.0 and parameters: {'ema1': 12, 'ema2': 97, 'ema3': 173}. Best is trial 0 with value: 999.0.
# Trial 2: EMA(18,41,115) → Sortino: 0.783
# [I 2025-11-01 18:17:50,225] Trial 1 finished with value: -0.782947499728137 and parameters: {'ema1': 18, 'ema2': 41, 'ema3': 115}. Best is trial 1 with value: -0.782947499728137.
# Trial 3: EMA(2,91,160) → Sortino: 0.572
# [I 2025-11-01 18:17:50,702] Trial 2 finished with value: -0.57206032489482 and parameters: {'ema1': 2, 'ema2': 91, 'ema3': 160}. Best is trial 1 with value: -0.782947499728137.
# Trial 4: EMA(22,31,197) → Sortino: 0.922
# [I 2025-11-01 18:17:51,128] Trial 3 finished with value: -0.9221923299069639 and parameters: {'ema1': 22, 'ema2': 31, 'ema3': 197}. Best is trial 3 with value: -0.9221923299069639.
# Trial 5: EMA(25,45,118) → Sortino: 1.107
# [I 2025-11-01 18:17:51,464] Trial 4 finished with value: -1.107059672716976 and parameters: {'ema1': 25, 'ema2': 45, 'ema3': 118}. Best is trial 4 with value: -1.107059672716976.
# Trial 6: EMA(6,51,153) → Sortino: 1.083
# [I 2025-11-01 18:17:51,710] Trial 5 finished with value: -1.0827842019257288 and parameters: {'ema1': 6, 'ema2': 51, 'ema3': 153}. Best is trial 4 with value: -1.107059672716976.
# Trial 7: EMA(13,50,161) → Sortino: 1.136
# [I 2025-11-01 18:17:51,966] Trial 6 finished with value: -1.1359442351943467 and parameters: {'ema1': 13, 'ema2': 50, 'ema3': 161}. Best is trial 6 with value: -1.1359442351943467.
# Trial 8: EMA(5,50,137) → Sortino: 1.023
# [I 2025-11-01 18:17:52,380] Trial 7 finished with value: -1.0226735255651758 and parameters: {'ema1': 5, 'ema2': 50, 'ema3': 137}. Best is trial 6 with value: -1.1359442351943467.
# Trial 9: EMA(14,85,120) → Sortino: 1.227
# [I 2025-11-01 18:17:52,938] Trial 8 finished with value: -1.2273846587228148 and parameters: {'ema1': 14, 'ema2': 85, 'ema3': 120}. Best is trial 8 with value: -1.2273846587228148.
# Trial 10: EMA(16,72,104) → Sortino: 1.367
# [I 2025-11-01 18:17:53,356] Trial 9 finished with value: -1.3674615612344296 and parameters: {'ema1': 16, 'ema2': 72, 'ema3': 104}. Best is trial 9 with value: -1.3674615612344296.
# Trial 11: EMA(29,76,100) → Sortino: 0.798
# [I 2025-11-01 18:17:53,724] Trial 10 finished with value: -0.7981184252063712 and parameters: {'ema1': 29, 'ema2': 76, 'ema3': 100}. Best is trial 9 with value: -1.3674615612344296.
# Trial 12: EMA(17,75,128) → Sortino: 1.408
# [I 2025-11-01 18:17:54,227] Trial 11 finished with value: -1.4075264230429194 and parameters: {'ema1': 17, 'ema2': 75, 'ema3': 128}. Best is trial 11 with value: -1.4075264230429194.
# Trial 13: EMA(19,69,133) → Sortino: 1.394
# [I 2025-11-01 18:17:54,664] Trial 12 finished with value: -1.3937129793486687 and parameters: {'ema1': 19, 'ema2': 69, 'ema3': 133}. Best is trial 11 with value: -1.4075264230429194.
# Trial 14: EMA(20,67,135) → Sortino: 1.406
# [I 2025-11-01 18:17:55,221] Trial 13 finished with value: -1.406148205438855 and parameters: {'ema1': 20, 'ema2': 67, 'ema3': 135}. Best is trial 11 with value: -1.4075264230429194.
# Trial 15: EMA(24,61,138) → Sortino: 1.371
# [I 2025-11-01 18:17:55,489] Trial 14 finished with value: -1.3714932671519686 and parameters: {'ema1': 24, 'ema2': 61, 'ema3': 138}. Best is trial 11 with value: -1.4075264230429194.
# Trial 16: EMA(10,82,131) → Sortino: 0.864
# [I 2025-11-01 18:17:55,709] Trial 15 finished with value: -0.8642939768147186 and parameters: {'ema1': 10, 'ema2': 82, 'ema3': 131}. Best is trial 11 with value: -1.4075264230429194.
# Trial 17: EMA(21,63,146) → Sortino: 1.438
# [I 2025-11-01 18:17:56,054] Trial 16 finished with value: -1.4378427919273895 and parameters: {'ema1': 21, 'ema2': 63, 'ema3': 146}. Best is trial 16 with value: -1.4378427919273895.
# Trial 18: EMA(30,60,179) → Sortino: 1.468
# [I 2025-11-01 18:17:56,440] Trial 17 finished with value: -1.4683158914525658 and parameters: {'ema1': 30, 'ema2': 60, 'ema3': 179}. Best is trial 17 with value: -1.4683158914525658.
# Trial 19: EMA(30,60,182) → Sortino: 1.488
# [I 2025-11-01 18:17:56,948] Trial 18 finished with value: -1.4881743811019088 and parameters: {'ema1': 30, 'ema2': 60, 'ema3': 182}. Best is trial 18 with value: -1.4881743811019088.
# Trial 20: EMA(30,58,193) → Sortino: 1.503
# [I 2025-11-01 18:17:57,390] Trial 19 finished with value: -1.5033564834682889 and parameters: {'ema1': 30, 'ema2': 58, 'ema3': 193}. Best is trial 19 with value: -1.5033564834682889.
# Trial 21: EMA(27,58,195) → Sortino: 1.533
# [I 2025-11-01 18:17:57,564] Trial 20 finished with value: -1.5330020217777272 and parameters: {'ema1': 27, 'ema2': 58, 'ema3': 195}. Best is trial 20 with value: -1.5330020217777272.
# Trial 22: EMA(27,56,200) → Sortino: 1.606
# [I 2025-11-01 18:17:57,725] Trial 21 finished with value: -1.6058229838639186 and parameters: {'ema1': 27, 'ema2': 56, 'ema3': 200}. Best is trial 21 with value: -1.6058229838639186.
# Trial 23: EMA(26,54,200) → Sortino: 1.380
# [I 2025-11-01 18:17:57,895] Trial 22 finished with value: -1.3802906685308949 and parameters: {'ema1': 26, 'ema2': 54, 'ema3': 200}. Best is trial 21 with value: -1.6058229838639186.
# Trial 24: EMA(27,39,190) → Sortino: 0.879
# [I 2025-11-01 18:17:58,062] Trial 23 finished with value: -0.8787727353061461 and parameters: {'ema1': 27, 'ema2': 39, 'ema3': 190}. Best is trial 21 with value: -1.6058229838639186.
# Trial 25: EMA(27,57,188) → Sortino: 1.422
# [I 2025-11-01 18:17:58,214] Trial 24 finished with value: -1.4217172850411732 and parameters: {'ema1': 27, 'ema2': 57, 'ema3': 188}. Best is trial 21 with value: -1.6058229838639186.
# Trial 26: EMA(23,43,173) → Sortino: 0.983
# [I 2025-11-01 18:17:58,387] Trial 25 finished with value: -0.9831163065521671 and parameters: {'ema1': 23, 'ema2': 43, 'ema3': 173}. Best is trial 21 with value: -1.6058229838639186.
# Trial 27: EMA(27,34,194) → Sortino: 0.917
# [I 2025-11-01 18:17:58,526] Trial 26 finished with value: -0.9171432035004947 and parameters: {'ema1': 27, 'ema2': 34, 'ema3': 194}. Best is trial 21 with value: -1.6058229838639186.
# Trial 28: EMA(29,66,185) → Sortino: 1.406
# [I 2025-11-01 18:17:58,682] Trial 27 finished with value: -1.4058595800984397 and parameters: {'ema1': 29, 'ema2': 66, 'ema3': 185}. Best is trial 21 with value: -1.6058229838639186.
# Trial 29: EMA(23,54,200) → Sortino: 1.106
# [I 2025-11-01 18:17:58,840] Trial 28 finished with value: -1.1060760205360805 and parameters: {'ema1': 23, 'ema2': 54, 'ema3': 200}. Best is trial 21 with value: -1.6058229838639186.
# Trial 30: EMA(25,47,174) → Sortino: 1.548
# [I 2025-11-01 18:17:58,995] Trial 29 finished with value: -1.5476189192920324 and parameters: {'ema1': 25, 'ema2': 47, 'ema3': 174}. Best is trial 21 with value: -1.6058229838639186.
# Trial 31: EMA(10,45,175) → Sortino: 1.058
# [I 2025-11-01 18:17:59,159] Trial 30 finished with value: -1.0582355887927124 and parameters: {'ema1': 10, 'ema2': 45, 'ema3': 175}. Best is trial 21 with value: -1.6058229838639186.
# Trial 32: EMA(28,50,168) → Sortino: 1.396
# [I 2025-11-01 18:17:59,313] Trial 31 finished with value: -1.3962318611318743 and parameters: {'ema1': 28, 'ema2': 50, 'ema3': 168}. Best is trial 21 with value: -1.6058229838639186.
# Trial 33: EMA(25,56,193) → Sortino: 1.363
# [I 2025-11-01 18:17:59,476] Trial 32 finished with value: -1.3633080330276124 and parameters: {'ema1': 25, 'ema2': 56, 'ema3': 193}. Best is trial 21 with value: -1.6058229838639186.
# Trial 34: EMA(25,48,167) → Sortino: 1.457
# [I 2025-11-01 18:17:59,649] Trial 33 finished with value: -1.4573708103922354 and parameters: {'ema1': 25, 'ema2': 48, 'ema3': 167}. Best is trial 21 with value: -1.6058229838639186.
# [I 2025-11-01 18:17:59,796] Trial 34 finished with value: 999.0 and parameters: {'ema1': 30, 'ema2': 98, 'ema3': 186}. Best is trial 21 with value: -1.6058229838639186.
# Trial 36: EMA(22,38,178) → Sortino: 1.001
# [I 2025-11-01 18:17:59,963] Trial 35 finished with value: -1.0008326986060283 and parameters: {'ema1': 22, 'ema2': 38, 'ema3': 178}. Best is trial 21 with value: -1.6058229838639186.
# Trial 37: EMA(28,46,193) → Sortino: 1.038
# [I 2025-11-01 18:18:00,160] Trial 36 finished with value: -1.037665492926771 and parameters: {'ema1': 28, 'ema2': 46, 'ema3': 193}. Best is trial 21 with value: -1.6058229838639186.
# Trial 38: EMA(26,58,195) → Sortino: 1.458
# [I 2025-11-01 18:18:00,342] Trial 37 finished with value: -1.4582991145633146 and parameters: {'ema1': 26, 'ema2': 58, 'ema3': 195}. Best is trial 21 with value: -1.6058229838639186.
# Trial 39: EMA(24,53,155) → Sortino: 1.189
# [I 2025-11-01 18:18:00,566] Trial 38 finished with value: -1.1889144953907116 and parameters: {'ema1': 24, 'ema2': 53, 'ema3': 155}. Best is trial 21 with value: -1.6058229838639186.
# Trial 40: EMA(21,63,168) → Sortino: 1.348
# [I 2025-11-01 18:18:00,758] Trial 39 finished with value: -1.3484013631030123 and parameters: {'ema1': 21, 'ema2': 63, 'ema3': 168}. Best is trial 21 with value: -1.6058229838639186.
# Trial 41: EMA(28,35,184) → Sortino: 0.897
# [I 2025-11-01 18:18:00,910] Trial 40 finished with value: -0.8969204459398432 and parameters: {'ema1': 28, 'ema2': 35, 'ema3': 184}. Best is trial 21 with value: -1.6058229838639186.
# Trial 42: EMA(29,59,180) → Sortino: 1.367
# [I 2025-11-01 18:18:01,077] Trial 41 finished with value: -1.3666995268717714 and parameters: {'ema1': 29, 'ema2': 59, 'ema3': 180}. Best is trial 21 with value: -1.6058229838639186.
# Trial 43: EMA(30,64,182) → Sortino: 1.370
# [I 2025-11-01 18:18:01,237] Trial 42 finished with value: -1.370082595800524 and parameters: {'ema1': 30, 'ema2': 64, 'ema3': 182}. Best is trial 21 with value: -1.6058229838639186.
# Trial 44: EMA(1,54,191) → Sortino: 0.413
# [I 2025-11-01 18:18:01,390] Trial 43 finished with value: -0.4130884561809322 and parameters: {'ema1': 1, 'ema2': 54, 'ema3': 191}. Best is trial 21 with value: -1.6058229838639186.
# Trial 45: EMA(26,48,198) → Sortino: 1.134
# [I 2025-11-01 18:18:01,531] Trial 44 finished with value: -1.1338550375773995 and parameters: {'ema1': 26, 'ema2': 48, 'ema3': 198}. Best is trial 21 with value: -1.6058229838639186.
# Trial 46: EMA(30,71,188) → Sortino: 0.659
# [I 2025-11-01 18:18:01,878] Trial 45 finished with value: -0.6587406947146561 and parameters: {'ema1': 30, 'ema2': 71, 'ema3': 188}. Best is trial 21 with value: -1.6058229838639186.
# Trial 47: EMA(28,42,172) → Sortino: 1.140
# [I 2025-11-01 18:18:02,197] Trial 46 finished with value: -1.1395032986481213 and parameters: {'ema1': 28, 'ema2': 42, 'ema3': 172}. Best is trial 21 with value: -1.6058229838639186.
# Trial 48: EMA(24,77,160) → Sortino: 1.190
# [I 2025-11-01 18:18:02,367] Trial 47 finished with value: -1.1902532246140862 and parameters: {'ema1': 24, 'ema2': 77, 'ema3': 160}. Best is trial 21 with value: -1.6058229838639186.
# Trial 49: EMA(18,61,197) → Sortino: 1.220
# [I 2025-11-01 18:18:02,534] Trial 48 finished with value: -1.2197020827291989 and parameters: {'ema1': 18, 'ema2': 61, 'ema3': 197}. Best is trial 21 with value: -1.6058229838639186.
# Trial 50: EMA(4,93,189) → Sortino: 0.628
# [I 2025-11-01 18:18:02,693] Trial 49 finished with value: -0.6284140230572338 and parameters: {'ema1': 4, 'ema2': 93, 'ema3': 189}. Best is trial 21 with value: -1.6058229838639186.
# Trial 51: EMA(15,68,182) → Sortino: 0.995
# [I 2025-11-01 18:18:02,859] Trial 50 finished with value: -0.9950279394381557 and parameters: {'ema1': 15, 'ema2': 68, 'ema3': 182}. Best is trial 21 with value: -1.6058229838639186.
# Trial 52: EMA(30,60,177) → Sortino: 1.468
# [I 2025-11-01 18:18:03,006] Trial 51 finished with value: -1.4683158914525658 and parameters: {'ema1': 30, 'ema2': 60, 'ema3': 177}. Best is trial 21 with value: -1.6058229838639186.
# Trial 53: EMA(29,56,164) → Sortino: 1.500
# [I 2025-11-01 18:18:03,174] Trial 52 finished with value: -1.5002799005140928 and parameters: {'ema1': 29, 'ema2': 56, 'ema3': 164}. Best is trial 21 with value: -1.6058229838639186.
# Trial 54: EMA(27,52,164) → Sortino: 1.474
# [I 2025-11-01 18:18:03,330] Trial 53 finished with value: -1.4736868079248195 and parameters: {'ema1': 27, 'ema2': 52, 'ema3': 164}. Best is trial 21 with value: -1.6058229838639186.
# Trial 55: EMA(29,56,153) → Sortino: 1.610
# [I 2025-11-01 18:18:03,493] Trial 54 finished with value: -1.610387644583725 and parameters: {'ema1': 29, 'ema2': 56, 'ema3': 153}. Best is trial 54 with value: -1.610387644583725.
# Trial 56: EMA(26,56,149) → Sortino: 1.430
# [I 2025-11-01 18:18:03,645] Trial 55 finished with value: -1.4299500499896967 and parameters: {'ema1': 26, 'ema2': 56, 'ema3': 149}. Best is trial 54 with value: -1.610387644583725.
# Trial 57: EMA(29,49,159) → Sortino: 1.428
# [I 2025-11-01 18:18:03,811] Trial 56 finished with value: -1.4284137969566137 and parameters: {'ema1': 29, 'ema2': 49, 'ema3': 159}. Best is trial 54 with value: -1.610387644583725.
# Trial 58: EMA(28,63,145) → Sortino: 1.539
# [I 2025-11-01 18:18:03,964] Trial 57 finished with value: -1.5389374663311113 and parameters: {'ema1': 28, 'ema2': 63, 'ema3': 145}. Best is trial 54 with value: -1.610387644583725.
# Trial 59: EMA(25,71,141) → Sortino: 1.403
# [I 2025-11-01 18:18:04,119] Trial 58 finished with value: -1.403139679605127 and parameters: {'ema1': 25, 'ema2': 71, 'ema3': 141}. Best is trial 54 with value: -1.610387644583725.
# Trial 60: EMA(23,65,145) → Sortino: 1.481
# [I 2025-11-01 18:18:04,288] Trial 59 finished with value: -1.4810924176212685 and parameters: {'ema1': 23, 'ema2': 65, 'ema3': 145}. Best is trial 54 with value: -1.610387644583725.
# Trial 61: EMA(27,62,154) → Sortino: 1.489
# [I 2025-11-01 18:18:04,439] Trial 60 finished with value: -1.4887838263293813 and parameters: {'ema1': 27, 'ema2': 62, 'ema3': 154}. Best is trial 54 with value: -1.610387644583725.
# Trial 62: EMA(29,56,157) → Sortino: 1.603
# [I 2025-11-01 18:18:04,593] Trial 61 finished with value: -1.6029324882478546 and parameters: {'ema1': 29, 'ema2': 56, 'ema3': 157}. Best is trial 54 with value: -1.610387644583725.
# Trial 63: EMA(28,52,144) → Sortino: 1.350
# [I 2025-11-01 18:18:04,761] Trial 62 finished with value: -1.350155930477777 and parameters: {'ema1': 28, 'ema2': 52, 'ema3': 144}. Best is trial 54 with value: -1.610387644583725.
# Trial 64: EMA(26,57,123) → Sortino: 1.351
# [I 2025-11-01 18:18:04,902] Trial 63 finished with value: -1.3514306291297902 and parameters: {'ema1': 26, 'ema2': 57, 'ema3': 123}. Best is trial 54 with value: -1.610387644583725.
# Trial 65: EMA(28,46,150) → Sortino: 0.970
# [I 2025-11-01 18:18:05,048] Trial 64 finished with value: -0.9699293197321229 and parameters: {'ema1': 28, 'ema2': 46, 'ema3': 150}. Best is trial 54 with value: -1.610387644583725.
# Trial 66: EMA(29,67,156) → Sortino: 1.334
# [I 2025-11-01 18:18:05,216] Trial 65 finished with value: -1.3336910754851954 and parameters: {'ema1': 29, 'ema2': 67, 'ema3': 156}. Best is trial 54 with value: -1.610387644583725.
# Trial 67: EMA(24,51,142) → Sortino: 1.274
# [I 2025-11-01 18:18:05,369] Trial 66 finished with value: -1.2744303316876844 and parameters: {'ema1': 24, 'ema2': 51, 'ema3': 142}. Best is trial 54 with value: -1.610387644583725.
# Trial 68: EMA(27,55,151) → Sortino: 1.430
# [I 2025-11-01 18:18:05,512] Trial 67 finished with value: -1.4299500499896967 and parameters: {'ema1': 27, 'ema2': 55, 'ema3': 151}. Best is trial 54 with value: -1.610387644583725.
# Trial 69: EMA(25,59,130) → Sortino: 1.282
# [I 2025-11-01 18:18:05,667] Trial 68 finished with value: -1.2816120610350414 and parameters: {'ema1': 25, 'ema2': 59, 'ema3': 130}. Best is trial 54 with value: -1.610387644583725.
# Trial 70: EMA(29,63,110) → Sortino: 1.342
# [I 2025-11-01 18:18:05,855] Trial 69 finished with value: -1.3417913332280833 and parameters: {'ema1': 29, 'ema2': 63, 'ema3': 110}. Best is trial 54 with value: -1.610387644583725.
# Trial 71: EMA(11,58,200) → Sortino: 1.183
# [I 2025-11-01 18:18:06,001] Trial 70 finished with value: -1.1831254056279186 and parameters: {'ema1': 11, 'ema2': 58, 'ema3': 200}. Best is trial 54 with value: -1.610387644583725.
# Trial 72: EMA(29,56,158) → Sortino: 1.603
# [I 2025-11-01 18:18:06,156] Trial 71 finished with value: -1.6029324882478546 and parameters: {'ema1': 29, 'ema2': 56, 'ema3': 158}. Best is trial 54 with value: -1.610387644583725.
# Trial 73: EMA(27,54,163) → Sortino: 1.339
# [I 2025-11-01 18:18:06,493] Trial 72 finished with value: -1.3387072323046867 and parameters: {'ema1': 27, 'ema2': 54, 'ema3': 163}. Best is trial 54 with value: -1.610387644583725.
# Trial 74: EMA(30,65,137) → Sortino: 1.370
# [I 2025-11-01 18:18:06,803] Trial 73 finished with value: -1.370082595800524 and parameters: {'ema1': 30, 'ema2': 65, 'ema3': 137}. Best is trial 54 with value: -1.610387644583725.
# Trial 75: EMA(8,50,148) → Sortino: 1.019
# [I 2025-11-01 18:18:06,962] Trial 74 finished with value: -1.0192059297027576 and parameters: {'ema1': 8, 'ema2': 50, 'ema3': 148}. Best is trial 54 with value: -1.610387644583725.
# Trial 76: EMA(28,44,157) → Sortino: 1.215
# [I 2025-11-01 18:18:07,123] Trial 75 finished with value: -1.214557632451928 and parameters: {'ema1': 28, 'ema2': 44, 'ema3': 157}. Best is trial 54 with value: -1.610387644583725.
# Trial 77: EMA(26,61,152) → Sortino: 1.491
# [I 2025-11-01 18:18:07,292] Trial 76 finished with value: -1.4908185261032831 and parameters: {'ema1': 26, 'ema2': 61, 'ema3': 152}. Best is trial 54 with value: -1.610387644583725.
# Trial 78: EMA(28,40,196) → Sortino: 1.159
# [I 2025-11-01 18:18:07,449] Trial 77 finished with value: -1.1588582321072827 and parameters: {'ema1': 28, 'ema2': 40, 'ema3': 196}. Best is trial 54 with value: -1.610387644583725.
# [I 2025-11-01 18:18:07,468] Trial 78 finished with value: 999.0 and parameters: {'ema1': 30, 'ema2': 30, 'ema3': 173}. Best is trial 54 with value: -1.610387644583725.
# Trial 80: EMA(29,47,191) → Sortino: 1.208
# [I 2025-11-01 18:18:07,612] Trial 79 finished with value: -1.2080747364002995 and parameters: {'ema1': 29, 'ema2': 47, 'ema3': 191}. Best is trial 54 with value: -1.610387644583725.
# Trial 81: EMA(22,58,140) → Sortino: 1.126
# [I 2025-11-01 18:18:07,784] Trial 80 finished with value: -1.1262721914595344 and parameters: {'ema1': 22, 'ema2': 58, 'ema3': 140}. Best is trial 54 with value: -1.610387644583725.
# Trial 82: EMA(29,56,165) → Sortino: 1.436
# [I 2025-11-01 18:18:07,954] Trial 81 finished with value: -1.4355820696530712 and parameters: {'ema1': 29, 'ema2': 56, 'ema3': 165}. Best is trial 54 with value: -1.610387644583725.
# Trial 83: EMA(29,53,170) → Sortino: 1.400
# [I 2025-11-01 18:18:08,103] Trial 82 finished with value: -1.3998281706743414 and parameters: {'ema1': 29, 'ema2': 53, 'ema3': 170}. Best is trial 54 with value: -1.610387644583725.
# Trial 84: EMA(27,57,158) → Sortino: 1.490
# [I 2025-11-01 18:18:08,267] Trial 83 finished with value: -1.4895714891295544 and parameters: {'ema1': 27, 'ema2': 57, 'ema3': 158}. Best is trial 54 with value: -1.610387644583725.
# Trial 85: EMA(28,62,162) → Sortino: 1.435
# [I 2025-11-01 18:18:08,418] Trial 84 finished with value: -1.4353264620680217 and parameters: {'ema1': 28, 'ema2': 62, 'ema3': 162}. Best is trial 54 with value: -1.610387644583725.
# Trial 86: EMA(30,60,147) → Sortino: 1.544
# [I 2025-11-01 18:18:08,569] Trial 85 finished with value: -1.5438935786717378 and parameters: {'ema1': 30, 'ema2': 60, 'ema3': 147}. Best is trial 54 with value: -1.610387644583725.
# Trial 87: EMA(30,69,148) → Sortino: 1.000
# [I 2025-11-01 18:18:08,731] Trial 86 finished with value: -1.0003175021969073 and parameters: {'ema1': 30, 'ema2': 69, 'ema3': 148}. Best is trial 54 with value: -1.610387644583725.
# Trial 88: EMA(26,61,133) → Sortino: 1.435
# [I 2025-11-01 18:18:08,895] Trial 87 finished with value: -1.4351537015422045 and parameters: {'ema1': 26, 'ema2': 61, 'ema3': 133}. Best is trial 54 with value: -1.610387644583725.
# Trial 89: EMA(25,59,153) → Sortino: 1.393
# [I 2025-11-01 18:18:09,055] Trial 88 finished with value: -1.393084000780314 and parameters: {'ema1': 25, 'ema2': 59, 'ema3': 153}. Best is trial 54 with value: -1.610387644583725.
# Trial 90: EMA(30,52,143) → Sortino: 1.497
# [I 2025-11-01 18:18:09,215] Trial 89 finished with value: -1.496859818263333 and parameters: {'ema1': 30, 'ema2': 52, 'ema3': 143}. Best is trial 54 with value: -1.610387644583725.
# Trial 91: EMA(13,64,146) → Sortino: 1.121
# [I 2025-11-01 18:18:09,380] Trial 90 finished with value: -1.1206943787545727 and parameters: {'ema1': 13, 'ema2': 64, 'ema3': 146}. Best is trial 54 with value: -1.610387644583725.
# Trial 92: EMA(29,55,161) → Sortino: 1.593
# [I 2025-11-01 18:18:09,535] Trial 91 finished with value: -1.592520834825432 and parameters: {'ema1': 29, 'ema2': 55, 'ema3': 161}. Best is trial 54 with value: -1.610387644583725.
# Trial 93: EMA(27,54,198) → Sortino: 1.450
# [I 2025-11-01 18:18:09,697] Trial 92 finished with value: -1.4499889135545319 and parameters: {'ema1': 27, 'ema2': 54, 'ema3': 198}. Best is trial 54 with value: -1.610387644583725.
# Trial 94: EMA(28,55,160) → Sortino: 1.494
# [I 2025-11-01 18:18:09,853] Trial 93 finished with value: -1.4944600955898828 and parameters: {'ema1': 28, 'ema2': 55, 'ema3': 160}. Best is trial 54 with value: -1.610387644583725.
# Trial 95: EMA(29,59,186) → Sortino: 1.490
# [I 2025-11-01 18:18:10,018] Trial 94 finished with value: -1.4897225418983409 and parameters: {'ema1': 29, 'ema2': 59, 'ema3': 186}. Best is trial 54 with value: -1.610387644583725.
# Trial 96: EMA(28,49,155) → Sortino: 1.267
# [I 2025-11-01 18:18:10,161] Trial 95 finished with value: -1.266791924050683 and parameters: {'ema1': 28, 'ema2': 49, 'ema3': 155}. Best is trial 54 with value: -1.610387644583725.
# Trial 97: EMA(30,51,194) → Sortino: 1.488
# [I 2025-11-01 18:18:10,333] Trial 96 finished with value: -1.4875348871922158 and parameters: {'ema1': 30, 'ema2': 51, 'ema3': 194}. Best is trial 54 with value: -1.610387644583725.
# Trial 98: EMA(29,66,167) → Sortino: 1.259
# [I 2025-11-01 18:18:10,480] Trial 97 finished with value: -1.2593749862953336 and parameters: {'ema1': 29, 'ema2': 66, 'ema3': 167}. Best is trial 54 with value: -1.610387644583725.
# Trial 99: EMA(27,57,176) → Sortino: 1.412
# [I 2025-11-01 18:18:10,831] Trial 98 finished with value: -1.4116812056102566 and parameters: {'ema1': 27, 'ema2': 57, 'ema3': 176}. Best is trial 54 with value: -1.610387644583725.
# Trial 100: EMA(26,63,147) → Sortino: 1.463
# [I 2025-11-01 18:18:11,163] Trial 99 finished with value: -1.462836272433593 and parameters: {'ema1': 26, 'ema2': 63, 'ema3': 147}. Best is trial 54 with value: -1.610387644583725.
# Trial 101: EMA(24,74,192) → Sortino: 1.296
# [I 2025-11-01 18:18:11,329] Trial 100 finished with value: -1.2958198260086544 and parameters: {'ema1': 24, 'ema2': 74, 'ema3': 192}. Best is trial 54 with value: -1.610387644583725.
# Trial 102: EMA(29,55,158) → Sortino: 1.697
# [I 2025-11-01 18:18:11,479] Trial 101 finished with value: -1.69709978144451 and parameters: {'ema1': 29, 'ema2': 55, 'ema3': 158}. Best is trial 101 with value: -1.69709978144451.
# Trial 103: EMA(29,55,151) → Sortino: 1.648
# [I 2025-11-01 18:18:11,639] Trial 102 finished with value: -1.647625507796022 and parameters: {'ema1': 29, 'ema2': 55, 'ema3': 151}. Best is trial 101 with value: -1.69709978144451.
# Trial 104: EMA(28,55,151) → Sortino: 1.549
# [I 2025-11-01 18:18:11,796] Trial 103 finished with value: -1.5494724853664297 and parameters: {'ema1': 28, 'ema2': 55, 'ema3': 151}. Best is trial 101 with value: -1.69709978144451.
# Trial 105: EMA(29,55,150) → Sortino: 1.648
# [I 2025-11-01 18:18:11,946] Trial 104 finished with value: -1.647625507796022 and parameters: {'ema1': 29, 'ema2': 55, 'ema3': 150}. Best is trial 101 with value: -1.69709978144451.
# Trial 106: EMA(29,53,151) → Sortino: 1.529
# [I 2025-11-01 18:18:12,100] Trial 105 finished with value: -1.5293889981671511 and parameters: {'ema1': 29, 'ema2': 53, 'ema3': 151}. Best is trial 101 with value: -1.69709978144451.
# Trial 107: EMA(30,55,154) → Sortino: 1.536
# [I 2025-11-01 18:18:12,296] Trial 106 finished with value: -1.5362106685695807 and parameters: {'ema1': 30, 'ema2': 55, 'ema3': 154}. Best is trial 101 with value: -1.69709978144451.
# Trial 108: EMA(29,48,158) → Sortino: 1.299
# [I 2025-11-01 18:18:12,468] Trial 107 finished with value: -1.2987277018927343 and parameters: {'ema1': 29, 'ema2': 48, 'ema3': 158}. Best is trial 101 with value: -1.69709978144451.
# Trial 109: EMA(28,56,161) → Sortino: 1.550
# [I 2025-11-01 18:18:12,914] Trial 108 finished with value: -1.5495742359118223 and parameters: {'ema1': 28, 'ema2': 56, 'ema3': 161}. Best is trial 101 with value: -1.69709978144451.
# Trial 110: EMA(28,50,161) → Sortino: 1.361
# [I 2025-11-01 18:18:13,264] Trial 109 finished with value: -1.3608226535431585 and parameters: {'ema1': 28, 'ema2': 50, 'ema3': 161}. Best is trial 101 with value: -1.69709978144451.
# Trial 111: EMA(27,52,156) → Sortino: 1.425
# [I 2025-11-01 18:18:13,473] Trial 110 finished with value: -1.4246611407161696 and parameters: {'ema1': 27, 'ema2': 52, 'ema3': 156}. Best is trial 101 with value: -1.69709978144451.
# Trial 112: EMA(30,55,152) → Sortino: 1.536
# [I 2025-11-01 18:18:13,647] Trial 111 finished with value: -1.5362106685695807 and parameters: {'ema1': 30, 'ema2': 55, 'ema3': 152}. Best is trial 101 with value: -1.69709978144451.
# Trial 113: EMA(29,60,150) → Sortino: 1.539
# [I 2025-11-01 18:18:13,821] Trial 112 finished with value: -1.5389374663311113 and parameters: {'ema1': 29, 'ema2': 60, 'ema3': 150}. Best is trial 101 with value: -1.69709978144451.
# Trial 114: EMA(28,56,166) → Sortino: 1.550
# [I 2025-11-01 18:18:13,969] Trial 113 finished with value: -1.5495742359118223 and parameters: {'ema1': 28, 'ema2': 56, 'ema3': 166}. Best is trial 101 with value: -1.69709978144451.
# Trial 115: EMA(27,56,166) → Sortino: 1.494
# [I 2025-11-01 18:18:14,136] Trial 114 finished with value: -1.4944600955898828 and parameters: {'ema1': 27, 'ema2': 56, 'ema3': 166}. Best is trial 101 with value: -1.69709978144451.
# Trial 116: EMA(28,53,162) → Sortino: 1.480
# [I 2025-11-01 18:18:14,307] Trial 115 finished with value: -1.4797782458021376 and parameters: {'ema1': 28, 'ema2': 53, 'ema3': 162}. Best is trial 101 with value: -1.69709978144451.
# Trial 117: EMA(26,57,158) → Sortino: 1.375
# [I 2025-11-01 18:18:14,463] Trial 116 finished with value: -1.3749777758435597 and parameters: {'ema1': 26, 'ema2': 57, 'ema3': 158}. Best is trial 101 with value: -1.69709978144451.
# Trial 118: EMA(27,51,170) → Sortino: 1.264
# [I 2025-11-01 18:18:14,634] Trial 117 finished with value: -1.263816492600226 and parameters: {'ema1': 27, 'ema2': 51, 'ema3': 170}. Best is trial 101 with value: -1.69709978144451.
# Trial 119: EMA(29,45,160) → Sortino: 1.004
# [I 2025-11-01 18:18:14,798] Trial 118 finished with value: -1.0043177285856173 and parameters: {'ema1': 29, 'ema2': 45, 'ema3': 160}. Best is trial 101 with value: -1.69709978144451.
# Trial 120: EMA(17,54,169) → Sortino: 1.148
# [I 2025-11-01 18:18:14,953] Trial 119 finished with value: -1.1481105376518048 and parameters: {'ema1': 17, 'ema2': 54, 'ema3': 169}. Best is trial 101 with value: -1.69709978144451.
# Trial 121: EMA(28,37,164) → Sortino: 0.893
# [I 2025-11-01 18:18:15,130] Trial 120 finished with value: -0.8933370635215014 and parameters: {'ema1': 28, 'ema2': 37, 'ema3': 164}. Best is trial 101 with value: -1.69709978144451.
# Trial 122: EMA(30,60,154) → Sortino: 1.452
# [I 2025-11-01 18:18:15,298] Trial 121 finished with value: -1.4517158588114716 and parameters: {'ema1': 30, 'ema2': 60, 'ema3': 154}. Best is trial 101 with value: -1.69709978144451.
# Trial 123: EMA(29,58,156) → Sortino: 1.459
# [I 2025-11-01 18:18:15,454] Trial 122 finished with value: -1.4585685404008093 and parameters: {'ema1': 29, 'ema2': 58, 'ema3': 156}. Best is trial 101 with value: -1.69709978144451.
# Trial 124: EMA(30,56,150) → Sortino: 1.495
# [I 2025-11-01 18:18:15,640] Trial 123 finished with value: -1.4950237644977358 and parameters: {'ema1': 30, 'ema2': 56, 'ema3': 150}. Best is trial 101 with value: -1.69709978144451.
# Trial 125: EMA(29,59,153) → Sortino: 1.453
# [I 2025-11-01 18:18:15,817] Trial 124 finished with value: -1.453264765096016 and parameters: {'ema1': 29, 'ema2': 59, 'ema3': 153}. Best is trial 101 with value: -1.69709978144451.
# Trial 126: EMA(28,53,148) → Sortino: 1.410
# [I 2025-11-01 18:18:15,972] Trial 125 finished with value: -1.4098812078867866 and parameters: {'ema1': 28, 'ema2': 53, 'ema3': 148}. Best is trial 101 with value: -1.69709978144451.
# Trial 127: EMA(27,55,139) → Sortino: 1.375
# [I 2025-11-01 18:18:16,132] Trial 126 finished with value: -1.3749777758435597 and parameters: {'ema1': 27, 'ema2': 55, 'ema3': 139}. Best is trial 101 with value: -1.69709978144451.
# Trial 128: EMA(28,85,157) → Sortino: 0.680
# [I 2025-11-01 18:18:16,305] Trial 127 finished with value: -0.6800006415671931 and parameters: {'ema1': 28, 'ema2': 85, 'ema3': 157}. Best is trial 101 with value: -1.69709978144451.
# Trial 129: EMA(26,49,162) → Sortino: 1.213
# [I 2025-11-01 18:18:16,461] Trial 128 finished with value: -1.2125203094463657 and parameters: {'ema1': 26, 'ema2': 49, 'ema3': 162}. Best is trial 101 with value: -1.69709978144451.
# Trial 130: EMA(29,57,145) → Sortino: 1.544
# [I 2025-11-01 18:18:16,614] Trial 129 finished with value: -1.5439968934413877 and parameters: {'ema1': 29, 'ema2': 57, 'ema3': 145}. Best is trial 101 with value: -1.69709978144451.
# Trial 131: EMA(29,51,159) → Sortino: 1.407
# [I 2025-11-01 18:18:16,998] Trial 130 finished with value: -1.4074578665093687 and parameters: {'ema1': 29, 'ema2': 51, 'ema3': 159}. Best is trial 101 with value: -1.69709978144451.
# Trial 132: EMA(30,58,143) → Sortino: 1.470
# [I 2025-11-01 18:18:17,263] Trial 131 finished with value: -1.4698640522489974 and parameters: {'ema1': 30, 'ema2': 58, 'ema3': 143}. Best is trial 101 with value: -1.69709978144451.
# Trial 133: EMA(29,56,146) → Sortino: 1.535
# [I 2025-11-01 18:18:17,419] Trial 132 finished with value: -1.5348151278705076 and parameters: {'ema1': 29, 'ema2': 56, 'ema3': 146}. Best is trial 101 with value: -1.69709978144451.
# Trial 134: EMA(28,61,149) → Sortino: 1.538
# [I 2025-11-01 18:18:17,570] Trial 133 finished with value: -1.5381214326633288 and parameters: {'ema1': 28, 'ema2': 61, 'ema3': 149}. Best is trial 101 with value: -1.69709978144451.
# Trial 135: EMA(19,57,153) → Sortino: 1.269
# [I 2025-11-01 18:18:17,792] Trial 134 finished with value: -1.269295356175985 and parameters: {'ema1': 19, 'ema2': 57, 'ema3': 153}. Best is trial 101 with value: -1.69709978144451.
# Trial 136: EMA(30,54,155) → Sortino: 1.568
# [I 2025-11-01 18:18:17,939] Trial 135 finished with value: -1.5683052677678289 and parameters: {'ema1': 30, 'ema2': 54, 'ema3': 155}. Best is trial 101 with value: -1.69709978144451.
# Trial 137: EMA(27,54,155) → Sortino: 1.407
# [I 2025-11-01 18:18:18,102] Trial 136 finished with value: -1.4074578665093687 and parameters: {'ema1': 27, 'ema2': 54, 'ema3': 155}. Best is trial 101 with value: -1.69709978144451.
# Trial 138: EMA(28,52,165) → Sortino: 1.454
# [I 2025-11-01 18:18:18,249] Trial 137 finished with value: -1.45421615551464 and parameters: {'ema1': 28, 'ema2': 52, 'ema3': 165}. Best is trial 101 with value: -1.69709978144451.
# Trial 139: EMA(29,55,159) → Sortino: 1.696
# [I 2025-11-01 18:18:18,409] Trial 138 finished with value: -1.6962729668855894 and parameters: {'ema1': 29, 'ema2': 55, 'ema3': 159}. Best is trial 101 with value: -1.69709978144451.
# Trial 140: EMA(30,54,159) → Sortino: 1.571
# [I 2025-11-01 18:18:18,573] Trial 139 finished with value: -1.5711506755412652 and parameters: {'ema1': 30, 'ema2': 54, 'ema3': 159}. Best is trial 101 with value: -1.69709978144451.
# Trial 141: EMA(30,54,160) → Sortino: 1.539
# [I 2025-11-01 18:18:18,887] Trial 140 finished with value: -1.5386989739913945 and parameters: {'ema1': 30, 'ema2': 54, 'ema3': 160}. Best is trial 101 with value: -1.69709978144451.
# Trial 142: EMA(29,55,157) → Sortino: 1.664
# [I 2025-11-01 18:18:19,064] Trial 141 finished with value: -1.6640768386726488 and parameters: {'ema1': 29, 'ema2': 55, 'ema3': 157}. Best is trial 101 with value: -1.69709978144451.
# Trial 143: EMA(30,55,157) → Sortino: 1.539
# [I 2025-11-01 18:18:19,352] Trial 142 finished with value: -1.539123067887827 and parameters: {'ema1': 30, 'ema2': 55, 'ema3': 157}. Best is trial 101 with value: -1.69709978144451.
# Trial 144: EMA(28,53,159) → Sortino: 1.447
# [I 2025-11-01 18:18:19,626] Trial 143 finished with value: -1.446834308358061 and parameters: {'ema1': 28, 'ema2': 53, 'ema3': 159}. Best is trial 101 with value: -1.69709978144451.
# Trial 145: EMA(29,52,155) → Sortino: 1.549
# [I 2025-11-01 18:18:19,871] Trial 144 finished with value: -1.5494724853664297 and parameters: {'ema1': 29, 'ema2': 52, 'ema3': 155}. Best is trial 101 with value: -1.69709978144451.
# Trial 146: EMA(30,55,163) → Sortino: 1.375
# [I 2025-11-01 18:18:20,073] Trial 145 finished with value: -1.374885885958037 and parameters: {'ema1': 30, 'ema2': 55, 'ema3': 163}. Best is trial 101 with value: -1.69709978144451.
# Trial 147: EMA(28,50,152) → Sortino: 1.327
# [I 2025-11-01 18:18:20,240] Trial 146 finished with value: -1.3269679094835776 and parameters: {'ema1': 28, 'ema2': 50, 'ema3': 152}. Best is trial 101 with value: -1.69709978144451.
# Trial 148: EMA(29,58,157) → Sortino: 1.459
# [I 2025-11-01 18:18:20,568] Trial 147 finished with value: -1.4585685404008093 and parameters: {'ema1': 29, 'ema2': 58, 'ema3': 157}. Best is trial 101 with value: -1.69709978144451.
# Trial 149: EMA(3,56,161) → Sortino: 0.625
# [I 2025-11-01 18:18:21,153] Trial 148 finished with value: -0.6248784664982342 and parameters: {'ema1': 3, 'ema2': 56, 'ema3': 161}. Best is trial 101 with value: -1.69709978144451.
# Trial 150: EMA(30,53,158) → Sortino: 1.646
# [I 2025-11-01 18:18:21,647] Trial 149 finished with value: -1.6459711451243502 and parameters: {'ema1': 30, 'ema2': 53, 'ema3': 158}. Best is trial 101 with value: -1.69709978144451.
# Trial 151: EMA(30,53,159) → Sortino: 1.606
# [I 2025-11-01 18:18:21,897] Trial 150 finished with value: -1.6061143898608565 and parameters: {'ema1': 30, 'ema2': 53, 'ema3': 159}. Best is trial 101 with value: -1.69709978144451.
# Trial 152: EMA(30,53,159) → Sortino: 1.606
# [I 2025-11-01 18:18:22,142] Trial 151 finished with value: -1.6061143898608565 and parameters: {'ema1': 30, 'ema2': 53, 'ema3': 159}. Best is trial 101 with value: -1.69709978144451.
# Trial 153: EMA(30,53,159) → Sortino: 1.606
# [I 2025-11-01 18:18:22,457] Trial 152 finished with value: -1.6061143898608565 and parameters: {'ema1': 30, 'ema2': 53, 'ema3': 159}. Best is trial 101 with value: -1.69709978144451.
# Trial 154: EMA(30,52,158) → Sortino: 1.566
# [I 2025-11-01 18:18:22,973] Trial 153 finished with value: -1.5656612569329607 and parameters: {'ema1': 30, 'ema2': 52, 'ema3': 158}. Best is trial 101 with value: -1.69709978144451.
# Trial 155: EMA(30,49,155) → Sortino: 1.385
# [I 2025-11-01 18:18:23,284] Trial 154 finished with value: -1.3850702545043607 and parameters: {'ema1': 30, 'ema2': 49, 'ema3': 155}. Best is trial 101 with value: -1.69709978144451.
# Trial 156: EMA(30,51,114) → Sortino: 1.488
# [I 2025-11-01 18:18:23,558] Trial 155 finished with value: -1.4882927413129896 and parameters: {'ema1': 30, 'ema2': 51, 'ema3': 114}. Best is trial 101 with value: -1.69709978144451.
# Trial 157: EMA(29,53,163) → Sortino: 1.598
# [I 2025-11-01 18:18:23,827] Trial 156 finished with value: -1.5982542793965833 and parameters: {'ema1': 29, 'ema2': 53, 'ema3': 163}. Best is trial 101 with value: -1.69709978144451.
# Trial 158: EMA(29,48,163) → Sortino: 1.333
# [I 2025-11-01 18:18:24,167] Trial 157 finished with value: -1.3325824459523157 and parameters: {'ema1': 29, 'ema2': 48, 'ema3': 163}. Best is trial 101 with value: -1.69709978144451.
# Trial 159: EMA(7,53,159) → Sortino: 1.308
# [I 2025-11-01 18:18:24,379] Trial 158 finished with value: -1.3078799182938612 and parameters: {'ema1': 7, 'ema2': 53, 'ema3': 159}. Best is trial 101 with value: -1.69709978144451.
# Trial 160: EMA(29,51,161) → Sortino: 1.450
# [I 2025-11-01 18:18:24,670] Trial 159 finished with value: -1.4499889135545319 and parameters: {'ema1': 29, 'ema2': 51, 'ema3': 161}. Best is trial 101 with value: -1.69709978144451.
# Trial 161: EMA(29,53,157) → Sortino: 1.563
# [I 2025-11-01 18:18:24,922] Trial 160 finished with value: -1.563260900086318 and parameters: {'ema1': 29, 'ema2': 53, 'ema3': 157}. Best is trial 101 with value: -1.69709978144451.
# Trial 162: EMA(30,54,154) → Sortino: 1.568
# [I 2025-11-01 18:18:25,145] Trial 161 finished with value: -1.5683052677678289 and parameters: {'ema1': 30, 'ema2': 54, 'ema3': 154}. Best is trial 101 with value: -1.69709978144451.
# Trial 163: EMA(30,54,156) → Sortino: 1.610
# [I 2025-11-01 18:18:25,311] Trial 162 finished with value: -1.610387644583725 and parameters: {'ema1': 30, 'ema2': 54, 'ema3': 156}. Best is trial 101 with value: -1.69709978144451.
# Trial 164: EMA(30,58,158) → Sortino: 1.453
# [I 2025-11-01 18:18:25,572] Trial 163 finished with value: -1.453264765096016 and parameters: {'ema1': 30, 'ema2': 58, 'ema3': 158}. Best is trial 101 with value: -1.69709978144451.
# Trial 165: EMA(29,50,152) → Sortino: 1.383
# [I 2025-11-01 18:18:25,845] Trial 164 finished with value: -1.383343803076406 and parameters: {'ema1': 29, 'ema2': 50, 'ema3': 152}. Best is trial 101 with value: -1.69709978144451.
# Trial 166: EMA(30,52,164) → Sortino: 1.506
# [I 2025-11-01 18:18:26,162] Trial 165 finished with value: -1.5055826630173983 and parameters: {'ema1': 30, 'ema2': 52, 'ema3': 164}. Best is trial 101 with value: -1.69709978144451.
# Trial 167: EMA(29,55,160) → Sortino: 1.593
# [I 2025-11-01 18:18:26,379] Trial 166 finished with value: -1.592520834825432 and parameters: {'ema1': 29, 'ema2': 55, 'ema3': 160}. Best is trial 101 with value: -1.69709978144451.
# Trial 168: EMA(29,57,101) → Sortino: 1.470
# [I 2025-11-01 18:18:26,570] Trial 167 finished with value: -1.4699002260830614 and parameters: {'ema1': 29, 'ema2': 57, 'ema3': 101}. Best is trial 101 with value: -1.69709978144451.
# Trial 169: EMA(29,59,162) → Sortino: 1.435
# [I 2025-11-01 18:18:26,769] Trial 168 finished with value: -1.4353264620680217 and parameters: {'ema1': 29, 'ema2': 59, 'ema3': 162}. Best is trial 101 with value: -1.69709978144451.
# Trial 170: EMA(29,55,156) → Sortino: 1.664
# [I 2025-11-01 18:18:27,004] Trial 169 finished with value: -1.6640768386726488 and parameters: {'ema1': 29, 'ema2': 55, 'ema3': 156}. Best is trial 101 with value: -1.69709978144451.
# Trial 171: EMA(28,56,156) → Sortino: 1.654
# [I 2025-11-01 18:18:27,177] Trial 170 finished with value: -1.654170480959406 and parameters: {'ema1': 28, 'ema2': 56, 'ema3': 156}. Best is trial 101 with value: -1.69709978144451.
# Trial 172: EMA(28,56,156) → Sortino: 1.654
# [I 2025-11-01 18:18:27,340] Trial 171 finished with value: -1.654170480959406 and parameters: {'ema1': 28, 'ema2': 56, 'ema3': 156}. Best is trial 101 with value: -1.69709978144451.
# Trial 173: EMA(28,57,156) → Sortino: 1.578
# [I 2025-11-01 18:18:27,478] Trial 172 finished with value: -1.5777814591211603 and parameters: {'ema1': 28, 'ema2': 57, 'ema3': 156}. Best is trial 101 with value: -1.69709978144451.
# Trial 174: EMA(29,53,152) → Sortino: 1.549
# [I 2025-11-01 18:18:27,663] Trial 173 finished with value: -1.5494724853664297 and parameters: {'ema1': 29, 'ema2': 53, 'ema3': 152}. Best is trial 101 with value: -1.69709978144451.
# Trial 175: EMA(27,56,154) → Sortino: 1.566
# [I 2025-11-01 18:18:27,894] Trial 174 finished with value: -1.5661117288561723 and parameters: {'ema1': 27, 'ema2': 56, 'ema3': 154}. Best is trial 101 with value: -1.69709978144451.
# [I 2025-11-01 18:18:28,084] Trial 175 finished with value: 999.0 and parameters: {'ema1': 28, 'ema2': 100, 'ema3': 156}. Best is trial 101 with value: -1.69709978144451.
# Trial 177: EMA(30,52,150) → Sortino: 1.532
# [I 2025-11-01 18:18:28,359] Trial 176 finished with value: -1.531789042798661 and parameters: {'ema1': 30, 'ema2': 52, 'ema3': 150}. Best is trial 101 with value: -1.69709978144451.
# Trial 178: EMA(29,59,157) → Sortino: 1.453
# [I 2025-11-01 18:18:28,523] Trial 177 finished with value: -1.453264765096016 and parameters: {'ema1': 29, 'ema2': 59, 'ema3': 157}. Best is trial 101 with value: -1.69709978144451.
# Trial 179: EMA(28,54,154) → Sortino: 1.563
# [I 2025-11-01 18:18:28,673] Trial 178 finished with value: -1.563260900086318 and parameters: {'ema1': 28, 'ema2': 54, 'ema3': 154}. Best is trial 101 with value: -1.69709978144451.
# Trial 180: EMA(30,57,159) → Sortino: 1.453
# [I 2025-11-01 18:18:28,842] Trial 179 finished with value: -1.453264765096016 and parameters: {'ema1': 30, 'ema2': 57, 'ema3': 159}. Best is trial 101 with value: -1.69709978144451.
# Trial 181: EMA(29,55,151) → Sortino: 1.648
# [I 2025-11-01 18:18:29,090] Trial 180 finished with value: -1.647625507796022 and parameters: {'ema1': 29, 'ema2': 55, 'ema3': 151}. Best is trial 101 with value: -1.69709978144451.
# Trial 182: EMA(29,56,149) → Sortino: 1.555
# [I 2025-11-01 18:18:29,321] Trial 181 finished with value: -1.5546722589384665 and parameters: {'ema1': 29, 'ema2': 56, 'ema3': 149}. Best is trial 101 with value: -1.69709978144451.
# Trial 183: EMA(30,55,152) → Sortino: 1.536
# [I 2025-11-01 18:18:29,494] Trial 182 finished with value: -1.5362106685695807 and parameters: {'ema1': 30, 'ema2': 55, 'ema3': 152}. Best is trial 101 with value: -1.69709978144451.
# Trial 184: EMA(28,53,156) → Sortino: 1.444
# [I 2025-11-01 18:18:29,709] Trial 183 finished with value: -1.4437284100482422 and parameters: {'ema1': 28, 'ema2': 53, 'ema3': 156}. Best is trial 101 with value: -1.69709978144451.
# Trial 185: EMA(29,51,123) → Sortino: 1.378
# [I 2025-11-01 18:18:29,872] Trial 184 finished with value: -1.3781473513727465 and parameters: {'ema1': 29, 'ema2': 51, 'ema3': 123}. Best is trial 101 with value: -1.69709978144451.
# Trial 186: EMA(29,55,154) → Sortino: 1.661
# [I 2025-11-01 18:18:30,113] Trial 185 finished with value: -1.6614370525590911 and parameters: {'ema1': 29, 'ema2': 55, 'ema3': 154}. Best is trial 101 with value: -1.69709978144451.
# Trial 187: EMA(27,58,153) → Sortino: 1.695
# [I 2025-11-01 18:18:30,360] Trial 186 finished with value: -1.694699364768923 and parameters: {'ema1': 27, 'ema2': 58, 'ema3': 153}. Best is trial 101 with value: -1.69709978144451.
# Trial 188: EMA(27,58,150) → Sortino: 1.702
# [I 2025-11-01 18:18:30,579] Trial 187 finished with value: -1.7016648688028575 and parameters: {'ema1': 27, 'ema2': 58, 'ema3': 150}. Best is trial 187 with value: -1.7016648688028575.
# Trial 189: EMA(27,58,151) → Sortino: 1.662
# [I 2025-11-01 18:18:31,004] Trial 188 finished with value: -1.6616767260940941 and parameters: {'ema1': 27, 'ema2': 58, 'ema3': 151}. Best is trial 187 with value: -1.7016648688028575.
# Trial 190: EMA(26,61,151) → Sortino: 1.491
# [I 2025-11-01 18:18:31,257] Trial 189 finished with value: -1.4908185261032831 and parameters: {'ema1': 26, 'ema2': 61, 'ema3': 151}. Best is trial 187 with value: -1.7016648688028575.
# Trial 191: EMA(27,58,149) → Sortino: 1.659
# [I 2025-11-01 18:18:31,476] Trial 190 finished with value: -1.6590317814830344 and parameters: {'ema1': 27, 'ema2': 58, 'ema3': 149}. Best is trial 187 with value: -1.7016648688028575.
# Trial 192: EMA(27,60,148) → Sortino: 1.574
# [I 2025-11-01 18:18:31,805] Trial 191 finished with value: -1.5741516231405188 and parameters: {'ema1': 27, 'ema2': 60, 'ema3': 148}. Best is trial 187 with value: -1.7016648688028575.
# Trial 193: EMA(27,58,150) → Sortino: 1.702
# [I 2025-11-01 18:18:31,988] Trial 192 finished with value: -1.7016648688028575 and parameters: {'ema1': 27, 'ema2': 58, 'ema3': 150}. Best is trial 187 with value: -1.7016648688028575.
# Trial 194: EMA(27,58,150) → Sortino: 1.702
# [I 2025-11-01 18:18:32,205] Trial 193 finished with value: -1.7016648688028575 and parameters: {'ema1': 27, 'ema2': 58, 'ema3': 150}. Best is trial 187 with value: -1.7016648688028575.
# Trial 195: EMA(27,59,149) → Sortino: 1.544
# [I 2025-11-01 18:18:32,408] Trial 194 finished with value: -1.54369698340812 and parameters: {'ema1': 27, 'ema2': 59, 'ema3': 149}. Best is trial 187 with value: -1.7016648688028575.
# Trial 196: EMA(25,58,147) → Sortino: 1.430
# [I 2025-11-01 18:18:32,664] Trial 195 finished with value: -1.4299500499896967 and parameters: {'ema1': 25, 'ema2': 58, 'ema3': 147}. Best is trial 187 with value: -1.7016648688028575.
# Trial 197: EMA(26,62,150) → Sortino: 1.519
# [I 2025-11-01 18:18:32,978] Trial 196 finished with value: -1.5189988757837953 and parameters: {'ema1': 26, 'ema2': 62, 'ema3': 150}. Best is trial 187 with value: -1.7016648688028575.
# Trial 198: EMA(27,58,153) → Sortino: 1.695
# [I 2025-11-01 18:18:33,330] Trial 197 finished with value: -1.694699364768923 and parameters: {'ema1': 27, 'ema2': 58, 'ema3': 153}. Best is trial 187 with value: -1.7016648688028575.
# Trial 199: EMA(27,60,153) → Sortino: 1.521
# [I 2025-11-01 18:18:33,601] Trial 198 finished with value: -1.5213673482612162 and parameters: {'ema1': 27, 'ema2': 60, 'ema3': 153}. Best is trial 187 with value: -1.7016648688028575.
# Trial 200: EMA(26,58,150) → Sortino: 1.606
# [I 2025-11-01 18:18:33,787] Trial 199 finished with value: -1.6058229838639186 and parameters: {'ema1': 26, 'ema2': 58, 'ema3': 150}. Best is trial 187 with value: -1.7016648688028575.
# Trial 201: EMA(27,57,145) → Sortino: 1.506
# [I 2025-11-01 18:18:34,105] Trial 200 finished with value: -1.5063230755610766 and parameters: {'ema1': 27, 'ema2': 57, 'ema3': 145}. Best is trial 187 with value: -1.7016648688028575.
# Trial 202: EMA(27,59,153) → Sortino: 1.491
# [I 2025-11-01 18:18:34,381] Trial 201 finished with value: -1.4908185261032831 and parameters: {'ema1': 27, 'ema2': 59, 'ema3': 153}. Best is trial 187 with value: -1.7016648688028575.
# Trial 203: EMA(28,55,151) → Sortino: 1.549
# [I 2025-11-01 18:18:34,709] Trial 202 finished with value: -1.5494724853664297 and parameters: {'ema1': 28, 'ema2': 55, 'ema3': 151}. Best is trial 187 with value: -1.7016648688028575.
# Trial 204: EMA(28,57,147) → Sortino: 1.530
# [I 2025-11-01 18:18:35,043] Trial 203 finished with value: -1.5295550822622732 and parameters: {'ema1': 28, 'ema2': 57, 'ema3': 147}. Best is trial 187 with value: -1.7016648688028575.
# Trial 205: EMA(26,58,154) → Sortino: 1.598
# [I 2025-11-01 18:18:35,463] Trial 204 finished with value: -1.5982542793965833 and parameters: {'ema1': 26, 'ema2': 58, 'ema3': 154}. Best is trial 187 with value: -1.7016648688028575.
# Trial 206: EMA(27,55,152) → Sortino: 1.444
# [I 2025-11-01 18:18:35,710] Trial 205 finished with value: -1.4437284100482422 and parameters: {'ema1': 27, 'ema2': 55, 'ema3': 152}. Best is trial 187 with value: -1.7016648688028575.
# Trial 207: EMA(28,56,155) → Sortino: 1.621
# [I 2025-11-01 18:18:36,083] Trial 206 finished with value: -1.6211718641757273 and parameters: {'ema1': 28, 'ema2': 56, 'ema3': 155}. Best is trial 187 with value: -1.7016648688028575.
# Trial 208: EMA(28,60,148) → Sortino: 1.506
# [I 2025-11-01 18:18:36,529] Trial 207 finished with value: -1.506337385098257 and parameters: {'ema1': 28, 'ema2': 60, 'ema3': 148}. Best is trial 187 with value: -1.7016648688028575.
# Trial 209: EMA(25,57,154) → Sortino: 1.461
# [I 2025-11-01 18:18:36,952] Trial 208 finished with value: -1.4609467067251336 and parameters: {'ema1': 25, 'ema2': 57, 'ema3': 154}. Best is trial 187 with value: -1.7016648688028575.
# Trial 210: EMA(27,58,150) → Sortino: 1.702
# [I 2025-11-01 18:18:37,162] Trial 209 finished with value: -1.7016648688028575 and parameters: {'ema1': 27, 'ema2': 58, 'ema3': 150}. Best is trial 187 with value: -1.7016648688028575.
# Trial 211: EMA(27,62,150) → Sortino: 1.489
# [I 2025-11-01 18:18:37,451] Trial 210 finished with value: -1.4887838263293813 and parameters: {'ema1': 27, 'ema2': 62, 'ema3': 150}. Best is trial 187 with value: -1.7016648688028575.
# Trial 212: EMA(28,56,152) → Sortino: 1.618
# [I 2025-11-01 18:18:37,626] Trial 211 finished with value: -1.618439469414206 and parameters: {'ema1': 28, 'ema2': 56, 'ema3': 152}. Best is trial 187 with value: -1.7016648688028575.
# Trial 213: EMA(27,58,151) → Sortino: 1.662
# ...
# Trial 931: EMA(29,58,153) → Sortino: 1.544
# [I 2025-11-01 18:20:56,147] Trial 930 finished with value: -1.544227627295763 and parameters: {'ema1': 29, 'ema2': 58, 'ema3': 153}. Best is trial 276 with value: -1.704070534162746.
# Trial 932: EMA(28,52,149) → Sortino: 1.385
# [I 2025-11-01 18:20:56,274] Trial 931 finished with value: -1.3850702545043607 and parameters: {'ema1': 28, 'ema2': 52, 'ema3': 149}. Best is trial 276 with value: -1.704070534162746.
# Trial 933: EMA(29,57,156) → Sortino: 1.612
# [I 2025-11-01 18:20:56,384] Trial 932 finished with value: -1.6120890769691902 and parameters: {'ema1': 29, 'ema2': 57, 'ema3': 156}. Best is trial 276 with value: -1.704070534162746.
# Trial 934: EMA(27,60,161) → Sortino: 1.503
# [I 2025-11-01 18:20:56,491] Trial 933 finished with value: -1.5034397875753795 and parameters: {'ema1': 27, 'ema2': 60, 'ema3': 161}. Best is trial 276 with value: -1.704070534162746.
# Trial 935: EMA(30,54,144) → Sortino: 1.500
# [I 2025-11-01 18:20:56,613] Trial 934 finished with value: -1.5002799005140928 and parameters: {'ema1': 30, 'ema2': 54, 'ema3': 144}. Best is trial 276 with value: -1.704070534162746.
# Trial 936: EMA(3,55,159) → Sortino: 0.579
# [I 2025-11-01 18:20:56,720] Trial 935 finished with value: -0.5786367493084548 and parameters: {'ema1': 3, 'ema2': 55, 'ema3': 159}. Best is trial 276 with value: -1.704070534162746.
# Trial 937: EMA(28,56,154) → Sortino: 1.621
# [I 2025-11-01 18:20:56,833] Trial 936 finished with value: -1.6211718641757273 and parameters: {'ema1': 28, 'ema2': 56, 'ema3': 154}. Best is trial 276 with value: -1.704070534162746.
# Trial 938: EMA(9,59,157) → Sortino: 0.974
# [I 2025-11-01 18:20:56,969] Trial 937 finished with value: -0.9738532266394202 and parameters: {'ema1': 9, 'ema2': 59, 'ema3': 157}. Best is trial 276 with value: -1.704070534162746.
# Trial 939: EMA(25,53,151) → Sortino: 1.160
# [I 2025-11-01 18:20:57,448] Trial 938 finished with value: -1.1604238980070989 and parameters: {'ema1': 25, 'ema2': 53, 'ema3': 151}. Best is trial 276 with value: -1.704070534162746.
# Trial 940: EMA(26,57,147) → Sortino: 1.430
# [I 2025-11-01 18:20:57,694] Trial 939 finished with value: -1.4299500499896967 and parameters: {'ema1': 26, 'ema2': 57, 'ema3': 147}. Best is trial 276 with value: -1.704070534162746.
# Trial 941: EMA(29,61,156) → Sortino: 1.453
# [I 2025-11-01 18:20:57,806] Trial 940 finished with value: -1.453264765096016 and parameters: {'ema1': 29, 'ema2': 61, 'ema3': 156}. Best is trial 276 with value: -1.704070534162746.
# Trial 942: EMA(29,55,173) → Sortino: 1.522
# [I 2025-11-01 18:20:57,919] Trial 941 finished with value: -1.5219802731397825 and parameters: {'ema1': 29, 'ema2': 55, 'ema3': 173}. Best is trial 276 with value: -1.704070534162746.
# Trial 943: EMA(15,72,160) → Sortino: 1.384
# [I 2025-11-01 18:20:58,039] Trial 942 finished with value: -1.383982566923168 and parameters: {'ema1': 15, 'ema2': 72, 'ema3': 160}. Best is trial 276 with value: -1.704070534162746.
# Trial 944: EMA(27,49,154) → Sortino: 1.127
# [I 2025-11-01 18:20:58,154] Trial 943 finished with value: -1.1267141072437614 and parameters: {'ema1': 27, 'ema2': 49, 'ema3': 154}. Best is trial 276 with value: -1.704070534162746.
# Trial 945: EMA(28,58,162) → Sortino: 1.462
# [I 2025-11-01 18:20:58,274] Trial 944 finished with value: -1.462256903321304 and parameters: {'ema1': 28, 'ema2': 58, 'ema3': 162}. Best is trial 276 with value: -1.704070534162746.
# Trial 946: EMA(30,53,152) → Sortino: 1.590
# [I 2025-11-01 18:20:58,384] Trial 945 finished with value: -1.589542498089486 and parameters: {'ema1': 30, 'ema2': 53, 'ema3': 152}. Best is trial 276 with value: -1.704070534162746.
# Trial 947: EMA(29,56,157) → Sortino: 1.603
# [I 2025-11-01 18:20:58,495] Trial 946 finished with value: -1.6029324882478546 and parameters: {'ema1': 29, 'ema2': 56, 'ema3': 157}. Best is trial 276 with value: -1.704070534162746.
# Trial 948: EMA(26,54,159) → Sortino: 1.466
# [I 2025-11-01 18:20:58,607] Trial 947 finished with value: -1.4655445217632999 and parameters: {'ema1': 26, 'ema2': 54, 'ema3': 159}. Best is trial 276 with value: -1.704070534162746.
# Trial 949: EMA(30,58,150) → Sortino: 1.545
# [I 2025-11-01 18:20:58,722] Trial 948 finished with value: -1.545441739468168 and parameters: {'ema1': 30, 'ema2': 58, 'ema3': 150}. Best is trial 276 with value: -1.704070534162746.
# Trial 950: EMA(28,56,155) → Sortino: 1.621
# [I 2025-11-01 18:20:58,839] Trial 949 finished with value: -1.6211718641757273 and parameters: {'ema1': 28, 'ema2': 56, 'ema3': 155}. Best is trial 276 with value: -1.704070534162746.
# Trial 951: EMA(27,51,153) → Sortino: 1.299
# [I 2025-11-01 18:20:58,946] Trial 950 finished with value: -1.2987277018927343 and parameters: {'ema1': 27, 'ema2': 51, 'ema3': 153}. Best is trial 276 with value: -1.704070534162746.
# Trial 952: EMA(29,59,158) → Sortino: 1.453
# [I 2025-11-01 18:20:59,060] Trial 951 finished with value: -1.453264765096016 and parameters: {'ema1': 29, 'ema2': 59, 'ema3': 158}. Best is trial 276 with value: -1.704070534162746.
# Trial 953: EMA(29,55,163) → Sortino: 1.593
# [I 2025-11-01 18:20:59,171] Trial 952 finished with value: -1.592520834825432 and parameters: {'ema1': 29, 'ema2': 55, 'ema3': 163}. Best is trial 276 with value: -1.704070534162746.
# Trial 954: EMA(30,53,156) → Sortino: 1.603
# [I 2025-11-01 18:20:59,524] Trial 953 finished with value: -1.6033500349905756 and parameters: {'ema1': 30, 'ema2': 53, 'ema3': 156}. Best is trial 276 with value: -1.704070534162746.
# Trial 955: EMA(26,57,149) → Sortino: 1.444
# [I 2025-11-01 18:20:59,634] Trial 954 finished with value: -1.4437284100482422 and parameters: {'ema1': 26, 'ema2': 57, 'ema3': 149}. Best is trial 276 with value: -1.704070534162746.
# Trial 956: EMA(28,54,160) → Sortino: 1.599
# [I 2025-11-01 18:20:59,747] Trial 955 finished with value: -1.59907960444739 and parameters: {'ema1': 28, 'ema2': 54, 'ema3': 160}. Best is trial 276 with value: -1.704070534162746.
# Trial 957: EMA(28,60,153) → Sortino: 1.453
# [I 2025-11-01 18:20:59,856] Trial 956 finished with value: -1.453264765096016 and parameters: {'ema1': 28, 'ema2': 60, 'ema3': 153}. Best is trial 276 with value: -1.704070534162746.
# Trial 958: EMA(30,57,155) → Sortino: 1.539
# [I 2025-11-01 18:20:59,963] Trial 957 finished with value: -1.5389374663311113 and parameters: {'ema1': 30, 'ema2': 57, 'ema3': 155}. Best is trial 276 with value: -1.704070534162746.
# Trial 959: EMA(2,55,158) → Sortino: 0.472
# [I 2025-11-01 18:21:00,078] Trial 958 finished with value: -0.472202630843858 and parameters: {'ema1': 2, 'ema2': 55, 'ema3': 158}. Best is trial 276 with value: -1.704070534162746.
# Trial 960: EMA(27,52,152) → Sortino: 1.405
# [I 2025-11-01 18:21:00,188] Trial 959 finished with value: -1.4045875683740379 and parameters: {'ema1': 27, 'ema2': 52, 'ema3': 152}. Best is trial 276 with value: -1.704070534162746.
# Trial 961: EMA(29,56,161) → Sortino: 1.500
# [I 2025-11-01 18:21:00,303] Trial 960 finished with value: -1.5002799005140928 and parameters: {'ema1': 29, 'ema2': 56, 'ema3': 161}. Best is trial 276 with value: -1.704070534162746.
# Trial 962: EMA(28,62,157) → Sortino: 1.453
# [I 2025-11-01 18:21:00,412] Trial 961 finished with value: -1.453264765096016 and parameters: {'ema1': 28, 'ema2': 62, 'ema3': 157}. Best is trial 276 with value: -1.704070534162746.
# Trial 963: EMA(29,58,155) → Sortino: 1.459
# [I 2025-11-01 18:21:00,522] Trial 962 finished with value: -1.4585685404008093 and parameters: {'ema1': 29, 'ema2': 58, 'ema3': 155}. Best is trial 276 with value: -1.704070534162746.
# Trial 964: EMA(29,54,165) → Sortino: 1.471
# [I 2025-11-01 18:21:00,684] Trial 963 finished with value: -1.4713083550419557 and parameters: {'ema1': 29, 'ema2': 54, 'ema3': 165}. Best is trial 276 with value: -1.704070534162746.
# Trial 965: EMA(27,56,103) → Sortino: 1.432
# [I 2025-11-01 18:21:00,813] Trial 964 finished with value: -1.4319251709681553 and parameters: {'ema1': 27, 'ema2': 56, 'ema3': 103}. Best is trial 276 with value: -1.704070534162746.
# Trial 966: EMA(28,59,147) → Sortino: 1.551
# [I 2025-11-01 18:21:00,926] Trial 965 finished with value: -1.5509470646298547 and parameters: {'ema1': 28, 'ema2': 59, 'ema3': 147}. Best is trial 276 with value: -1.704070534162746.
# Trial 967: EMA(30,55,151) → Sortino: 1.523
# [I 2025-11-01 18:21:01,042] Trial 966 finished with value: -1.5225790999925382 and parameters: {'ema1': 30, 'ema2': 55, 'ema3': 151}. Best is trial 276 with value: -1.704070534162746.
# Trial 968: EMA(24,53,160) → Sortino: 1.193
# [I 2025-11-01 18:21:01,163] Trial 967 finished with value: -1.1925600187200962 and parameters: {'ema1': 24, 'ema2': 53, 'ema3': 160}. Best is trial 276 with value: -1.704070534162746.
# Trial 969: EMA(29,50,154) → Sortino: 1.383
# [I 2025-11-01 18:21:01,281] Trial 968 finished with value: -1.383343803076406 and parameters: {'ema1': 29, 'ema2': 50, 'ema3': 154}. Best is trial 276 with value: -1.704070534162746.
# Trial 970: EMA(28,57,157) → Sortino: 1.493
# [I 2025-11-01 18:21:01,399] Trial 969 finished with value: -1.4931875542794224 and parameters: {'ema1': 28, 'ema2': 57, 'ema3': 157}. Best is trial 276 with value: -1.704070534162746.
# Trial 971: EMA(30,52,150) → Sortino: 1.532
# [I 2025-11-01 18:21:01,507] Trial 970 finished with value: -1.531789042798661 and parameters: {'ema1': 30, 'ema2': 52, 'ema3': 150}. Best is trial 276 with value: -1.704070534162746.
# Trial 972: EMA(27,55,158) → Sortino: 1.480
# [I 2025-11-01 18:21:01,626] Trial 971 finished with value: -1.4797782458021376 and parameters: {'ema1': 27, 'ema2': 55, 'ema3': 158}. Best is trial 276 with value: -1.704070534162746.
# Trial 973: EMA(28,60,153) → Sortino: 1.453
# [I 2025-11-01 18:21:01,739] Trial 972 finished with value: -1.453264765096016 and parameters: {'ema1': 28, 'ema2': 60, 'ema3': 153}. Best is trial 276 with value: -1.704070534162746.
# Trial 974: EMA(29,64,155) → Sortino: 1.249
# [I 2025-11-01 18:21:01,853] Trial 973 finished with value: -1.2494143462302658 and parameters: {'ema1': 29, 'ema2': 64, 'ema3': 155}. Best is trial 276 with value: -1.704070534162746.
# Trial 975: EMA(28,57,162) → Sortino: 1.475
# [I 2025-11-01 18:21:01,970] Trial 974 finished with value: -1.4752671733502065 and parameters: {'ema1': 28, 'ema2': 57, 'ema3': 162}. Best is trial 276 with value: -1.704070534162746.
# Trial 976: EMA(26,54,159) → Sortino: 1.466
# [I 2025-11-01 18:21:02,076] Trial 975 finished with value: -1.4655445217632999 and parameters: {'ema1': 26, 'ema2': 54, 'ema3': 159}. Best is trial 276 with value: -1.704070534162746.
# Trial 977: EMA(29,58,148) → Sortino: 1.509
# [I 2025-11-01 18:21:02,184] Trial 976 finished with value: -1.5086577060676836 and parameters: {'ema1': 29, 'ema2': 58, 'ema3': 148}. Best is trial 276 with value: -1.704070534162746.
# Trial 978: EMA(30,56,151) → Sortino: 1.509
# [I 2025-11-01 18:21:02,296] Trial 977 finished with value: -1.5086577060676836 and parameters: {'ema1': 30, 'ema2': 56, 'ema3': 151}. Best is trial 276 with value: -1.704070534162746.
# Trial 979: EMA(27,51,156) → Sortino: 1.319
# [I 2025-11-01 18:21:02,406] Trial 978 finished with value: -1.3188010157733088 and parameters: {'ema1': 27, 'ema2': 51, 'ema3': 156}. Best is trial 276 with value: -1.704070534162746.
# Trial 980: EMA(29,59,153) → Sortino: 1.453
# [I 2025-11-01 18:21:02,519] Trial 979 finished with value: -1.453264765096016 and parameters: {'ema1': 29, 'ema2': 59, 'ema3': 153}. Best is trial 276 with value: -1.704070534162746.
# Trial 981: EMA(27,54,160) → Sortino: 1.444
# [I 2025-11-01 18:21:02,636] Trial 980 finished with value: -1.4435849917834038 and parameters: {'ema1': 27, 'ema2': 54, 'ema3': 160}. Best is trial 276 with value: -1.704070534162746.
# Trial 982: EMA(29,61,157) → Sortino: 1.453
# [I 2025-11-01 18:21:02,744] Trial 981 finished with value: -1.453264765096016 and parameters: {'ema1': 29, 'ema2': 61, 'ema3': 157}. Best is trial 276 with value: -1.704070534162746.
# Trial 983: EMA(30,56,155) → Sortino: 1.512
# [I 2025-11-01 18:21:02,854] Trial 982 finished with value: -1.5116275460629103 and parameters: {'ema1': 30, 'ema2': 56, 'ema3': 155}. Best is trial 276 with value: -1.704070534162746.
# Trial 984: EMA(28,58,163) → Sortino: 1.462
# [I 2025-11-01 18:21:02,964] Trial 983 finished with value: -1.462256903321304 and parameters: {'ema1': 28, 'ema2': 58, 'ema3': 163}. Best is trial 276 with value: -1.704070534162746.
# Trial 985: EMA(12,55,169) → Sortino: 1.154
# [I 2025-11-01 18:21:03,072] Trial 984 finished with value: -1.1540445230176324 and parameters: {'ema1': 12, 'ema2': 55, 'ema3': 169}. Best is trial 276 with value: -1.704070534162746.
# Trial 986: EMA(28,53,158) → Sortino: 1.486
# [I 2025-11-01 18:21:03,182] Trial 985 finished with value: -1.4862594570934047 and parameters: {'ema1': 28, 'ema2': 53, 'ema3': 158}. Best is trial 276 with value: -1.704070534162746.
# Trial 987: EMA(26,57,149) → Sortino: 1.444
# [I 2025-11-01 18:21:03,298] Trial 986 finished with value: -1.4437284100482422 and parameters: {'ema1': 26, 'ema2': 57, 'ema3': 149}. Best is trial 276 with value: -1.704070534162746.
# Trial 988: EMA(29,52,152) → Sortino: 1.529
# [I 2025-11-01 18:21:03,411] Trial 987 finished with value: -1.5293889981671511 and parameters: {'ema1': 29, 'ema2': 52, 'ema3': 152}. Best is trial 276 with value: -1.704070534162746.
# Trial 989: EMA(7,55,161) → Sortino: 1.197
# [I 2025-11-01 18:21:03,520] Trial 988 finished with value: -1.1972993782071437 and parameters: {'ema1': 7, 'ema2': 55, 'ema3': 161}. Best is trial 276 with value: -1.704070534162746.
# Trial 990: EMA(30,59,156) → Sortino: 1.453
# [I 2025-11-01 18:21:03,631] Trial 989 finished with value: -1.453264765096016 and parameters: {'ema1': 30, 'ema2': 59, 'ema3': 156}. Best is trial 276 with value: -1.704070534162746.
# Trial 991: EMA(29,57,154) → Sortino: 1.580
# [I 2025-11-01 18:21:03,743] Trial 990 finished with value: -1.5803102188565614 and parameters: {'ema1': 29, 'ema2': 57, 'ema3': 154}. Best is trial 276 with value: -1.704070534162746.
# Trial 992: EMA(25,44,145) → Sortino: 1.089
# [I 2025-11-01 18:21:03,852] Trial 991 finished with value: -1.0886160369273545 and parameters: {'ema1': 25, 'ema2': 44, 'ema3': 145}. Best is trial 276 with value: -1.704070534162746.
# Trial 993: EMA(19,54,159) → Sortino: 1.127
# [I 2025-11-01 18:21:03,963] Trial 992 finished with value: -1.1271532742872568 and parameters: {'ema1': 19, 'ema2': 54, 'ema3': 159}. Best is trial 276 with value: -1.704070534162746.
# Trial 994: EMA(27,55,151) → Sortino: 1.430
# [I 2025-11-01 18:21:04,081] Trial 993 finished with value: -1.4299500499896967 and parameters: {'ema1': 27, 'ema2': 55, 'ema3': 151}. Best is trial 276 with value: -1.704070534162746.
# Trial 995: EMA(30,67,118) → Sortino: 1.260
# [I 2025-11-01 18:21:04,195] Trial 994 finished with value: -1.2595005206057617 and parameters: {'ema1': 30, 'ema2': 67, 'ema3': 118}. Best is trial 276 with value: -1.704070534162746.
# Trial 996: EMA(28,57,157) → Sortino: 1.493
# [I 2025-11-01 18:21:04,308] Trial 995 finished with value: -1.4931875542794224 and parameters: {'ema1': 28, 'ema2': 57, 'ema3': 157}. Best is trial 276 with value: -1.704070534162746.
# Trial 997: EMA(29,56,154) → Sortino: 1.571
# [I 2025-11-01 18:21:04,419] Trial 996 finished with value: -1.5711506755412652 and parameters: {'ema1': 29, 'ema2': 56, 'ema3': 154}. Best is trial 276 with value: -1.704070534162746.
# Trial 998: EMA(28,62,160) → Sortino: 1.321
# [I 2025-11-01 18:21:04,665] Trial 997 finished with value: -1.3209229748333442 and parameters: {'ema1': 28, 'ema2': 62, 'ema3': 160}. Best is trial 276 with value: -1.704070534162746.
# Trial 999: EMA(27,53,156) → Sortino: 1.466
# [I 2025-11-01 18:21:04,835] Trial 998 finished with value: -1.4662321455559324 and parameters: {'ema1': 27, 'ema2': 53, 'ema3': 156}. Best is trial 276 with value: -1.704070534162746.
# Trial 1000: EMA(29,59,152) → Sortino: 1.538
# [I 2025-11-01 18:21:04,944] Trial 999 finished with value: -1.5381214326633288 and parameters: {'ema1': 29, 'ema2': 59, 'ema3': 152}. Best is trial 276 with value: -1.704070534162746.
#
# ✅ Optimization complete!
# Best Parameters: EMA(29,55,155)
# Sortino Ratio: 1.704

# %%
# Display Results

if 'results_df' in globals() and not results_df.empty:
    best = results_df.iloc[0]
    
    print("OPTIMIZATION RESULTS:")
    print("=" * 50)
    print(f"Best Parameters:")
    print(f"  EMA1 (Fast): {int(best['ema1_period'])}")
    print(f"  EMA2 (Medium): {int(best['ema2_period'])}")
    print(f"  EMA3 (Slow): {int(best['ema3_period'])}")
    
    print("\nPerformance Metrics:")
    print(f"  Total Return: {best['total_return']:.2%}")
    print(f"  Sharpe Ratio: {best['sharpe_ratio']:.3f}")
    print(f"  Sortino Ratio: {best['sortino_ratio']:.3f}")
    print(f"  Max Drawdown: {best['max_drawdown']:.2%}")
    print(f"  Total Trades: {int(best['total_trades'])}")
    print(f"  Win Rate: {best['win_rate']:.1f}%")
    print(f"  Profit Factor: {best['profit_factor']:.2f}")
else:
    print("⚠️ No results found. Run optimization first.")
# Out:
# OPTIMIZATION RESULTS:
# ==================================================
# Best Parameters:
#   EMA1 (Fast): 29
#   EMA2 (Medium): 55
#   EMA3 (Slow): 155
#
# Performance Metrics:
#   Total Return: 76.06%
#   Sharpe Ratio: 1.238
#   Sortino Ratio: 1.704
#   Max Drawdown: -15.11%
#   Total Trades: 6
#   Win Rate: 66.7%
#   Profit Factor: 39.39

# %%
# BENCHMARK ANALYSIS: Best Strategy vs Market (Buy & Hold) - ENHANCED

if 'results_df' in globals() and not results_df.empty:
    best = results_df.iloc[0]
    ema1, ema2, ema3 = int(best['ema1_period']), int(best['ema2_period']), int(best['ema3_period'])

    print(f"BENCHMARK ANALYSIS: Best EMA({ema1},{ema2},{ema3}) vs Buy & Hold")
    print("=" * 70)

    # Recreate the BEST strategy portfolio to get returns
    ema1_ma = vbt.MA.run(train_close, ema1, ewm=True)
    ema2_ma = vbt.MA.run(train_close, ema2, ewm=True)
    ema3_ma = vbt.MA.run(train_close, ema3, ewm=True)

    # Triple EMA crossover signals
    entries = (
        ema1_ma.ma_crossed_above(ema2_ma.ma) |
        ema1_ma.ma_crossed_above(ema3_ma.ma) |
        ema2_ma.ma_crossed_above(ema3_ma.ma)
    )
    exits = (
        ema1_ma.ma_crossed_below(ema2_ma.ma) |
        ema1_ma.ma_crossed_below(ema3_ma.ma) |
        ema2_ma.ma_crossed_below(ema3_ma.ma)
    )

    best_pf = vbt.Portfolio.from_signals(
        close=train_close,
        entries=entries,
        exits=exits,
        init_cash=100_000,
        fees=0.0005,
        slippage=0.0005,
        freq='D'
    )

    # Create buy & hold benchmark
    benchmark_entries = np.zeros(len(train_close), dtype=bool)
    benchmark_entries[0] = True
    benchmark_exits = np.zeros(len(train_close), dtype=bool)

    benchmark_pf = vbt.Portfolio.from_signals(
        close=train_close,
        entries=benchmark_entries,
        exits=benchmark_exits,
        init_cash=100_000,
        fees=0.0005,
        freq='D'
    )

    # Get returns for comparison
    strategy_returns = best_pf.returns().dropna()
    benchmark_returns = benchmark_pf.returns().dropna()

    # Benchmark metrics
    bench_total_return = benchmark_pf.total_return()
    bench_annualized_return = benchmark_pf.annualized_return(freq='D')
    bench_sharpe = benchmark_pf.sharpe_ratio(freq='D')
    bench_sortino = benchmark_pf.sortino_ratio(freq='D')
    bench_max_drawdown = benchmark_pf.max_drawdown()
    bench_volatility = benchmark_pf.annualized_volatility(freq='D')

    # Strategy annualized return
    strategy_annualized_return = best['annualized_return']

    # Performance comparison
    print("\nPERFORMANCE COMPARISON:")
    print(f"Strategy (EMA {ema1},{ema2},{ema3}):")
    print(f"  Total Return:      {best['total_return']:.2%}")
    print(f"  Annualized Return: {strategy_annualized_return:.2%}")
    print(f"  Sharpe Ratio:      {best['sharpe_ratio']:.3f}")
    print(f"  Sortino Ratio:     {best['sortino_ratio']:.3f}")
    print(f"  Max Drawdown:      {best['max_drawdown']:.2%}")
    print(f"  Volatility:        {best['volatility']:.2%}")
    print(f"  Total Trades:      {best['total_trades']}")
    print(f"  Win Rate:          {best['win_rate']:.1f}%")
    print(f"  Profit Factor:     {best['profit_factor']:.2f}")

    print(f"\nBenchmark (Buy & Hold {TICKER}):")
    print(f"  Total Return:      {bench_total_return:.2%}")
    print(f"  Annualized Return: {bench_annualized_return:.2%}")
    print(f"  Sharpe Ratio:      {bench_sharpe:.3f}")
    print(f"  Sortino Ratio:     {bench_sortino:.3f}")
    print(f"  Max Drawdown:      {bench_max_drawdown:.2%}")
    print(f"  Volatility:        {bench_volatility:.2%}")

    # Outperformance metrics
    excess_return = best['total_return'] - bench_total_return
    excess_annualized_return = strategy_annualized_return - bench_annualized_return
    sharpe_diff = best['sharpe_ratio'] - bench_sharpe
    sortino_diff = best['sortino_ratio'] - bench_sortino
    excess_max_drawdown = best['max_drawdown'] - bench_max_drawdown

    print(f"\nOUTPERFORMANCE METRICS:")
    print(f"  Excess Return:           {excess_return:.2%}")
    print(f"  Excess Annualized Return: {excess_annualized_return:.2%}")
    print(f"  Sharpe Difference:       {sharpe_diff:.3f}")
    print(f"  Sortino Difference:      {sortino_diff:.3f}")
    print(f"  Excess Max Drawdown:      {excess_max_drawdown:.2%} ({'Better' if excess_max_drawdown > 0 else '❌ Worse'})")
    
    # Calculate beta
    market_beta = best['volatility'] / bench_volatility if bench_volatility != 0 else np.nan
    print(f"  Market Beta (approx):     {market_beta:.3f} ({'Lower risk' if market_beta < 1 else '⚠️ Higher risk'})")
else:
    print("⚠️ No results available for benchmark analysis.")
# Out:
# BENCHMARK ANALYSIS: Best EMA(29,55,155) vs Buy & Hold
# ======================================================================
#
# PERFORMANCE COMPARISON:
# Strategy (EMA 29,55,155):
#   Total Return:      76.06%
#   Annualized Return: 12.81%
#   Sharpe Ratio:      1.238
#   Sortino Ratio:     1.704
#   Max Drawdown:      -15.11%
#   Volatility:        15.03%
#   Total Trades:      6.0
#   Win Rate:          66.7%
#   Profit Factor:     39.39
#
# Benchmark (Buy & Hold SPY):
#   Total Return:      65.02%
#   Annualized Return: 16.73%
#   Sharpe Ratio:      0.733
#   Sortino Ratio:     1.004
#   Max Drawdown:      -33.72%
#   Volatility:        25.59%
#
# OUTPERFORMANCE METRICS:
#   Excess Return:           11.04%
#   Excess Annualized Return: -3.92%
#   Sharpe Difference:       0.504
#   Sortino Difference:      0.700
#   Excess Max Drawdown:      18.60% (Better)
#   Market Beta (approx):     0.587 (Lower risk)

# %%
# IN-SAMPLE vs OUT-OF-SAMPLE COMPARISON

FREQ = "1D"

if 'results_df' in globals() and not results_df.empty:
    best = results_df.iloc[0]
    ema1, ema2, ema3 = int(best['ema1_period']), int(best['ema2_period']), int(best['ema3_period'])

    # Out-of-sample validation
    ema1_val = vbt.MA.run(val_close, ema1, ewm=True).ma
    ema2_val = vbt.MA.run(val_close, ema2, ewm=True).ma
    ema3_val = vbt.MA.run(val_close, ema3, ewm=True).ma

    # Triple EMA crossover signals
    entries_val = (
        ema1_val.vbt.crossed_above(ema2_val) |
        ema1_val.vbt.crossed_above(ema3_val) |
        ema2_val.vbt.crossed_above(ema3_val)
    )
    exits_val = (
        ema1_val.vbt.crossed_below(ema2_val) |
        ema1_val.vbt.crossed_below(ema3_val) |
        ema2_val.vbt.crossed_below(ema3_val)
    )

    pf_val = vbt.Portfolio.from_signals(
        close=val_close,
        entries=entries_val,
        exits=exits_val,
        init_cash=100_000,
        fees=0.0005,
        slippage=0.0005,
        freq=FREQ
    )

    # Out-of-sample metrics
    val_total_return = pf_val.total_return()
    val_annualized_return = pf_val.annualized_return(freq=FREQ)
    val_sharpe = pf_val.sharpe_ratio(freq=FREQ)
    val_sortino = pf_val.sortino_ratio(freq=FREQ)
    val_max_drawdown = pf_val.max_drawdown()
    val_volatility = pf_val.annualized_volatility(freq=FREQ)

    trades_val = pf_val.trades
    val_total_trades = len(trades_val)
    years = max((val_close.index[-1] - val_close.index[0]).days / 365.25, 1e-9)
    val_trades_per_year = val_total_trades / years

    val_win_rate_pct = np.nan
    val_profit_factor = np.nan
    val_expectancy = 0.0
    if val_total_trades > 0:
        tr = trades_val.returns.values if hasattr(trades_val.returns, 'values') else np.array(trades_val.returns)
        if tr.size > 0:
            pos = tr[tr > 0]
            neg = tr[tr < 0]
            val_win_rate_pct = (len(pos) / len(tr)) * 100 if len(tr) > 0 else np.nan
            gains = pos.sum() if len(pos) else 0.0
            losses = abs(neg.sum()) if len(neg) else 0.0
            val_profit_factor = gains / losses if losses > 0 else np.inf
            val_expectancy = tr.mean()

    def chg(before, after):
        if pd.isna(before) or pd.isna(after) or before == 0:
            return "N/A"
        return f"{((after - before) / abs(before)) * 100:+.1f}%"

    print(f"IN-SAMPLE vs OUT-OF-SAMPLE COMPARISON: Best EMA({ema1},{ema2},{ema3})")
    print("=" * 80)

    print(f"{'METRIC':<25} {'IN-SAMPLE':<15} {'OUT-OF-SAMPLE':<15} {'DEGRADATION':<15}")

    print("\nRETURN METRICS:")
    print(f"{'Total Return':<25} {best['total_return']:<15.2%} {val_total_return:<15.2%} {chg(best['total_return'], val_total_return)}")
    print(f"{'Annualized Return':<25} {best['annualized_return']:<15.2%} {val_annualized_return:<15.2%} {chg(best['annualized_return'], val_annualized_return)}")

    print("\nRISK-ADJUSTED METRICS:")
    print(f"{'Sharpe Ratio':<25} {best['sharpe_ratio']:<15.3f} {val_sharpe:<15.3f} {chg(best['sharpe_ratio'], val_sharpe)}")
    print(f"{'Sortino Ratio':<25} {best['sortino_ratio']:<15.3f} {val_sortino:<15.3f} {chg(best['sortino_ratio'], val_sortino)}")

    print("\nRISK METRICS:")
    print(f"{'Max Drawdown':<25} {best['max_drawdown']:<15.2%} {val_max_drawdown:<15.2%} {chg(best['max_drawdown'], val_max_drawdown)}")
    print(f"{'Volatility':<25} {best['volatility']:<15.2%} {val_volatility:<15.2%} {chg(best['volatility'], val_volatility)}")

    print("\nTRADE METRICS:")
    print(f"{'Total Trades':<25} {best['total_trades']:<15.0f} {val_total_trades:<15.0f} {chg(best['total_trades'], val_total_trades)}")
    print(f"{'Trades per Year':<25} {best['trades_per_year']:<15.1f} {val_trades_per_year:<15.1f} {chg(best['trades_per_year'], val_trades_per_year)}")
    print(f"{'Win Rate %':<25} {best['win_rate']:<15.1f} {val_win_rate_pct:<15.1f} {chg(best['win_rate'], val_win_rate_pct)}")
    print(f"{'Profit Factor':<25} {best['profit_factor']:<15.2f} {val_profit_factor:<15.2f} {chg(best['profit_factor'], val_profit_factor)}")
    print(f"{'Expectancy':<25} {best['expectancy']:<15.4f} {val_expectancy:<15.4f} {chg(best['expectancy'], val_expectancy)}")
else:
    print("⚠️ No results for comparison.")
# Out:
# IN-SAMPLE vs OUT-OF-SAMPLE COMPARISON: Best EMA(29,55,155)
# ================================================================================
# METRIC                    IN-SAMPLE       OUT-OF-SAMPLE   DEGRADATION
#
# RETURN METRICS:
# Total Return              76.06%          49.72%          -34.6%
# Annualized Return         12.81%          20.56%          +60.5%
#
# RISK-ADJUSTED METRICS:
# Sharpe Ratio              1.238           1.770           +43.0%
# Sortino Ratio             1.704           2.575           +51.1%
#
# RISK METRICS:
# Max Drawdown              -15.11%         -8.61%          +43.1%
# Volatility                15.03%          10.90%          -27.5%
#
# TRADE METRICS:
# Total Trades              6               2               -66.7%
# Trades per Year           1.3             0.6             -50.1%
# Win Rate %                66.7            100.0           +50.0%
# Profit Factor             39.39           inf             +inf%
# Expectancy                0.1116          0.2259          +102.4%

# %%
# OUT-OF-SAMPLE BENCHMARK COMPARISON

if 'results_df' in globals() and not results_df.empty:
    best = results_df.iloc[0]
    ema1, ema2, ema3 = int(best['ema1_period']), int(best['ema2_period']), int(best['ema3_period'])

    print(f"OUT-OF-SAMPLE BENCHMARK: Best EMA({ema1},{ema2},{ema3}) vs Buy & Hold")
    print("=" * 70)

    # Use validation data
    close_data = val_close
    
    # Recreate the BEST strategy portfolio
    ema1_ma = vbt.MA.run(close_data, ema1, ewm=True)
    ema2_ma = vbt.MA.run(close_data, ema2, ewm=True)
    ema3_ma = vbt.MA.run(close_data, ema3, ewm=True)

    entries_raw = (
        ema1_ma.ma_crossed_above(ema2_ma.ma) |
        ema1_ma.ma_crossed_above(ema3_ma.ma) |
        ema2_ma.ma_crossed_above(ema3_ma.ma)
    )
    exits_raw = (
        ema1_ma.ma_crossed_below(ema2_ma.ma) |
        ema1_ma.ma_crossed_below(ema3_ma.ma) |
        ema2_ma.ma_crossed_below(ema3_ma.ma)
    )
    
    entries = pd.Series(np.asarray(entries_raw).ravel(), index=close_data.index, dtype=bool)
    exits = pd.Series(np.asarray(exits_raw).ravel(), index=close_data.index, dtype=bool)

    strategy_pf = vbt.Portfolio.from_signals(
        close=close_data,
        entries=entries,
        exits=exits,
        init_cash=100_000,
        fees=0.0005,
        slippage=0.0005,
        freq='D'
    )

    # Buy & hold benchmark
    benchmark_entries = np.zeros(len(close_data), dtype=bool)
    benchmark_entries[0] = True
    benchmark_exits = np.zeros(len(close_data), dtype=bool)

    benchmark_pf = vbt.Portfolio.from_signals(
        close=close_data,
        entries=benchmark_entries,
        exits=benchmark_exits,
        init_cash=100_000,
        fees=0.0005,
        freq='D'
    )

    # Benchmark metrics
    bench_total_return = benchmark_pf.total_return()
    bench_annualized_return = benchmark_pf.annualized_return(freq='D')
    bench_sharpe = benchmark_pf.sharpe_ratio(freq='D')
    bench_sortino = benchmark_pf.sortino_ratio(freq='D')
    bench_max_drawdown = benchmark_pf.max_drawdown()
    bench_volatility = benchmark_pf.annualized_volatility(freq='D')

    # Strategy metrics
    trades_val = strategy_pf.trades
    val_total_trades = len(trades_val)
    years = max((close_data.index[-1] - close_data.index[0]).days / 365.25, 1e-9)
    
    val_win_rate_pct = np.nan
    val_profit_factor = np.nan
    val_expectancy = 0.0
    
    if val_total_trades > 0:
        tr = trades_val.returns.values if hasattr(trades_val.returns, 'values') else np.array(trades_val.returns)
        if tr.size > 0:
            pos = tr[tr > 0]
            neg = tr[tr < 0]
            val_win_rate_pct = (len(pos) / len(tr)) * 100 if len(tr) > 0 else np.nan
            gains = pos.sum() if len(pos) else 0.0
            losses = abs(neg.sum()) if len(neg) else 0.0
            val_profit_factor = gains / losses if losses > 0 else np.inf
            val_expectancy = tr.mean()

    strategy_total_return = strategy_pf.total_return()
    strategy_annualized_return = strategy_pf.annualized_return(freq='D')
    strategy_sharpe = strategy_pf.sharpe_ratio(freq='D')
    strategy_sortino = strategy_pf.sortino_ratio(freq='D')
    strategy_max_drawdown = strategy_pf.max_drawdown()
    strategy_volatility = strategy_pf.annualized_volatility(freq='D')

    # Performance comparison
    print(f"\n{'METRIC':<30} {'STRATEGY':<20} {'BUY & HOLD':<15} {'OUTPERFORMANCE':<15}")
    print("=" * 80)
    
    print(f"\nRETURN METRICS:")
    excess_return = strategy_total_return - bench_total_return
    print(f"{'Total Return':<30} {strategy_total_return:>20.2%} {bench_total_return:>15.2%} {excess_return:>+15.2%}")
    
    excess_annual = strategy_annualized_return - bench_annualized_return
    print(f"{'Annualized Return':<30} {strategy_annualized_return:>20.2%} {bench_annualized_return:>15.2%} {excess_annual:>+15.2%}")

    print(f"\nRISK-ADJUSTED METRICS:")
    excess_sharpe = strategy_sharpe - bench_sharpe
    print(f"{'Sharpe Ratio':<30} {strategy_sharpe:>20.3f} {bench_sharpe:>15.3f} {excess_sharpe:>+15.3f}")
    
    excess_sortino = strategy_sortino - bench_sortino
    print(f"{'Sortino Ratio':<30} {strategy_sortino:>20.3f} {bench_sortino:>15.3f} {excess_sortino:>+15.3f}")

    print(f"\nRISK METRICS:")
    excess_dd = strategy_max_drawdown - bench_max_drawdown
    print(f"{'Max Drawdown':<30} {strategy_max_drawdown:>20.2%} {bench_max_drawdown:>15.2%} {excess_dd:>+15.2%}")
    
    excess_vol = strategy_volatility - bench_volatility
    print(f"{'Volatility':<30} {strategy_volatility:>20.2%} {bench_volatility:>15.2%} {excess_vol:>+15.2%}")

    print(f"\nTRADE METRICS:")
    print(f"{'Total Trades':<30} {val_total_trades:>20.0f}")
    print(f"{'Win Rate %':<30} {val_win_rate_pct:>20.1f}")
    print(f"{'Profit Factor':<30} {val_profit_factor:>20.2f}")
    print(f"{'Expectancy':<30} {val_expectancy:>20.4f}")

    print(f"\n✅ Out-of-sample evaluation complete!")
    print(f"📊 Period: {close_data.index[0].date()} → {close_data.index[-1].date()}")
    
    # Summary verdict
    if strategy_total_return > bench_total_return and strategy_sharpe > bench_sharpe:
        print(f"🏆 Strategy OUTPERFORMS Buy & Hold on validation set!")
    elif strategy_total_return > bench_total_return:
        print(f"📈 Strategy has higher returns but Buy & Hold has better Sharpe")
    elif strategy_sharpe > bench_sharpe:
        print(f"💪 Strategy has better risk-adjusted returns despite lower total return")
    else:
        print(f"⚠️ Strategy underperforms Buy & Hold on validation set")
else:
    print("⚠️ No results available.")
# Out:
# OUT-OF-SAMPLE BENCHMARK: Best EMA(29,55,155) vs Buy & Hold
# ======================================================================
#
# METRIC                         STRATEGY             BUY & HOLD      OUTPERFORMANCE
# ================================================================================
#
# RETURN METRICS:
# Total Return                                 49.72%          81.45%         -31.72%
# Annualized Return                            20.56%          31.78%         -11.22%
#
# RISK-ADJUSTED METRICS:
# Sharpe Ratio                                  1.770           1.484          +0.286
# Sortino Ratio                                 2.575           2.269          +0.306
#
# RISK METRICS:
# Max Drawdown                                 -8.61%         -18.76%         +10.15%
# Volatility                                   10.90%          19.93%          -9.03%
#
# TRADE METRICS:
# Total Trades                                      2
# Win Rate %                                    100.0
# Profit Factor                                   inf
# Expectancy                                   0.2259
#
# ✅ Out-of-sample evaluation complete!
# 📊 Period: 2022-09-13 → 2025-10-31
# 💪 Strategy has better risk-adjusted returns despite lower total return

# %%
# ROLLING SHARPE + DRAWDOWNS - BEST STRATEGY (FULL SAMPLE)

if 'results_df' in globals() and not results_df.empty:
    best = results_df.iloc[0]
    ema1, ema2, ema3 = int(best['ema1_period']), int(best['ema2_period']), int(best['ema3_period'])

    # Build full-sample Triple EMA signals
    ema1_full = vbt.MA.run(close, ema1, ewm=True).ma
    ema2_full = vbt.MA.run(close, ema2, ewm=True).ma
    ema3_full = vbt.MA.run(close, ema3, ewm=True).ma

    # Triple EMA crossover signals
    entries_full = (
        ema1_full.vbt.crossed_above(ema2_full) |
        ema1_full.vbt.crossed_above(ema3_full) |
        ema2_full.vbt.crossed_above(ema3_full)
    )
    exits_full = (
        ema1_full.vbt.crossed_below(ema2_full) |
        ema1_full.vbt.crossed_below(ema3_full) |
        ema2_full.vbt.crossed_below(ema3_full)
    )

    entries_full = entries_full.reindex(close.index).fillna(False).to_numpy(dtype=bool)
    exits_full = exits_full.reindex(close.index).fillna(False).to_numpy(dtype=bool)

    pf_full = vbt.Portfolio.from_signals(
        close=close.to_numpy(dtype=float),
        entries=entries_full,
        exits=exits_full,
        init_cash=100_000,
        fees=0.0005,
        slippage=0.0005,
        freq=FREQ
    )

    # Compute returns
    ret = pf_full.returns()

    # 1) Rolling Sharpe (252-day window)
    rolling_window = max(20, min(252, max(1, len(ret) // 4)))
    if len(ret) > rolling_window:
        rolling_sharpe = ret.rolling(window=rolling_window).apply(
            lambda x: (x.mean() * 252) / (x.std() * np.sqrt(252)) if x.std() and x.std() != 0 else np.nan,
            raw=False
        )

        plt.figure(figsize=(12, 5))
        plt.plot(rolling_sharpe.index, rolling_sharpe.values, linewidth=2, color='blue', alpha=0.85)
        plt.axhline(y=1.0, color='green', linestyle='--', alpha=0.6, label='Sharpe = 1.0')
        plt.axhline(y=0.5, color='orange', linestyle='--', alpha=0.6, label='Sharpe = 0.5')
        plt.axhline(y=0.0, color='red', linestyle='--', alpha=0.6, label='Sharpe = 0.0')
        plt.title(f'Rolling Sharpe (window={rolling_window}) - Best EMA({ema1},{ema2},{ema3}) Full Sample', fontsize=14, fontweight='bold')
        plt.xlabel('Date', fontsize=12)
        plt.ylabel('Rolling Sharpe Ratio', fontsize=12)
        plt.grid(True, alpha=0.3)
        plt.legend()
        plt.tight_layout()
        plt.show()
    else:
        print("⚠️ Not enough data for rolling Sharpe calculation.")

    # 2) Drawdowns (underwater)
    eq = (1 + ret).cumprod()
    peak = eq.cummax()
    dd = (eq - peak) / peak

    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 8), sharex=True)

    ax1.plot(eq.index, (eq - 1) * 100, color='black', linewidth=1.5, label='Cumulative Return %')
    ax1.plot(peak.index, (peak - 1) * 100, color='green', linewidth=1.0, alpha=0.7, label='Peak %')
    ax1.fill_between(eq.index, (eq - 1) * 100, (peak - 1) * 100, color='red', alpha=0.25, label='Drawdown Area')
    ax1.set_title(f'Cumulative Returns & Drawdowns - Best EMA({ema1},{ema2},{ema3}) Full Sample', fontsize=14, fontweight='bold')
    ax1.set_ylabel('Return (%)', fontsize=12)
    ax1.grid(True, alpha=0.3)
    ax1.legend()

    ax2.fill_between(dd.index, dd * 100, 0, color='red', alpha=0.7, label='Drawdown %')
    ax2.plot(dd.index, dd * 100, color='darkred', linewidth=1)
    ax2.set_title('Underwater Chart (Drawdown from Peak)', fontsize=13)
    ax2.set_xlabel('Date', fontsize=12)
    ax2.set_ylabel('Drawdown (%)', fontsize=12)
    ax2.grid(True, alpha=0.3)
    ax2.legend()

    plt.tight_layout()
    plt.show()

    print(f"✅ Rolling Sharpe and Drawdown analysis complete for best strategy: EMA({ema1},{ema2},{ema3})")
else:
    print("⚠️ No results to visualize.")
# Out:
# ✅ Rolling Sharpe and Drawdown analysis complete for best strategy: EMA(29,55,155)

# %%
# VISUALS: Signals + Equity Curves - BEST STRATEGY

if 'results_df' in globals() and not results_df.empty:
    best = results_df.iloc[0]
    ema1, ema2, ema3 = int(best['ema1_period']), int(best['ema2_period']), int(best['ema3_period'])

    # Build full sample EMAs and signals
    ema1_full = vbt.MA.run(close, ema1, ewm=True).ma
    ema2_full = vbt.MA.run(close, ema2, ewm=True).ma
    ema3_full = vbt.MA.run(close, ema3, ewm=True).ma

    # Triple EMA crossover signals
    entries_1 = ema1_full.vbt.crossed_above(ema2_full)
    entries_2 = ema1_full.vbt.crossed_above(ema3_full)
    entries_3 = ema2_full.vbt.crossed_above(ema3_full)
    entries_full = (entries_1 | entries_2 | entries_3)
    
    exits_1 = ema1_full.vbt.crossed_below(ema2_full)
    exits_2 = ema1_full.vbt.crossed_below(ema3_full)
    exits_3 = ema2_full.vbt.crossed_below(ema3_full)
    exits_full = (exits_1 | exits_2 | exits_3)

    entries_full = entries_full.reindex(close.index).fillna(False).to_numpy(dtype=bool)
    exits_full = exits_full.reindex(close.index).fillna(False).to_numpy(dtype=bool)

    # 1) Price + Triple EMAs + signals (full sample)
    fig, ax = plt.subplots(figsize=(14, 7))
    ax.plot(close.index, close.values, label='Close', color='black', linewidth=1.5, alpha=0.7)
    ax.plot(close.index, ema1_full.values, label=f'Fast EMA ({ema1})', color='blue', alpha=0.8, linewidth=1.2)
    ax.plot(close.index, ema2_full.values, label=f'Medium EMA ({ema2})', color='orange', alpha=0.8, linewidth=1.2)
    ax.plot(close.index, ema3_full.values, label=f'Slow EMA ({ema3})', color='purple', alpha=0.8, linewidth=1.2)

    buy_idx = close.index[entries_full]
    sell_idx = close.index[exits_full]
    ax.scatter(buy_idx, close.reindex(buy_idx).values, marker='^', color='green', s=80, label='Buy', zorder=5)
    ax.scatter(sell_idx, close.reindex(sell_idx).values, marker='v', color='red', s=80, label='Sell', zorder=5)

    ax.set_title(f'Best Triple EMA({ema1},{ema2},{ema3}) - Full Sample Signals', fontsize=14, fontweight='bold')
    ax.set_xlabel('Date', fontsize=12)
    ax.set_ylabel('Price', fontsize=12)
    ax.grid(True, alpha=0.3)
    ax.legend(loc='best')
    plt.tight_layout()
    plt.show()

    # 2) Equity curves: train / val / full
    price_full = close.to_numpy(dtype=float)
    entries_train = entries_full[:split_idx]
    exits_train = exits_full[:split_idx]
    entries_val = entries_full[split_idx:]
    exits_val = exits_full[split_idx:]

    pf_full = vbt.Portfolio.from_signals(
        close=price_full,
        entries=entries_full,
        exits=exits_full,
        init_cash=100_000,
        fees=0.0005,
        slippage=0.0005,
        freq=FREQ
    )

    pf_train = vbt.Portfolio.from_signals(
        close=train_close.to_numpy(dtype=float),
        entries=entries_train,
        exits=exits_train,
        init_cash=100_000,
        fees=0.0005,
        slippage=0.0005,
        freq=FREQ
    )

    pf_val2 = vbt.Portfolio.from_signals(
        close=val_close.to_numpy(dtype=float),
        entries=entries_val,
        exits=exits_val,
        init_cash=100_000,
        fees=0.0005,
        slippage=0.0005,
        freq=FREQ
    )

    eq_full = (1 + pf_full.returns()).cumprod()
    eq_train = (1 + pf_train.returns()).cumprod()
    eq_val = (1 + pf_val2.returns()).cumprod()

    fig, ax = plt.subplots(figsize=(14, 7))
    ax.plot(close.index, eq_full.values, label='Full Sample', color='black', linewidth=2)
    ax.plot(train_close.index, eq_train.values, label='Train (In-Sample)', color='blue', linewidth=1.5, alpha=0.8)
    ax.plot(val_close.index, eq_val.values, label='Validation (Out-of-Sample)', color='orange', linewidth=1.5, alpha=0.8)

    # Add vertical line to show train/val split
    ax.axvline(x=train_close.index[-1], color='red', linestyle='--', alpha=0.5, label='Train/Val Split')

    ax.set_title(f'Best Triple EMA({ema1},{ema2},{ema3}) - Equity Curves', fontsize=14, fontweight='bold')
    ax.set_xlabel('Date', fontsize=12)
    ax.set_ylabel('Cumulative Returns (normalized to 1)', fontsize=12)
    ax.grid(True, alpha=0.3)
    ax.legend(loc='best')
    plt.tight_layout()
    plt.show()

    print(f"✅ Visualizations complete for best strategy: EMA({ema1},{ema2},{ema3})")
else:
    print("⚠️ No results to visualize.")
# Out:
# ✅ Visualizations complete for best strategy: EMA(29,55,155)

# %%
# TRADE-BY-TRADE RETURNS (BAR) + CUMULATIVE PER-TRADE EQUITY

if 'results_df' not in globals() or results_df.empty:
    print("⚠️ No results available.")
else:
    best = results_df.iloc[0]
    ema1, ema2, ema3 = int(best['ema1_period']), int(best['ema2_period']), int(best['ema3_period'])

    # Resolve full close series
    full_close = close.astype(float)

    # Indicators
    ema1_full = vbt.MA.run(full_close, ema1, ewm=True)
    ema2_full = vbt.MA.run(full_close, ema2, ewm=True)
    ema3_full = vbt.MA.run(full_close, ema3, ewm=True)

    # Signals
    entries_raw = (
        ema1_full.ma_crossed_above(ema2_full.ma) |
        ema1_full.ma_crossed_above(ema3_full.ma) |
        ema2_full.ma_crossed_above(ema3_full.ma)
    )
    exits_raw = (
        ema1_full.ma_crossed_below(ema2_full.ma) |
        ema1_full.ma_crossed_below(ema3_full.ma) |
        ema2_full.ma_crossed_below(ema3_full.ma)
    )

    entries_full = pd.Series(np.asarray(entries_raw).ravel(), index=full_close.index, dtype=bool)
    exits_full = pd.Series(np.asarray(exits_raw).ravel(), index=full_close.index, dtype=bool)

    # Backtest
    pf_full = vbt.Portfolio.from_signals(
        close=full_close.to_numpy(dtype=float),
        entries=entries_full,
        exits=exits_full,
        init_cash=100_000,
        fees=0.0005,
        slippage=0.0005,
        freq='1D'
    )

    # Trade-by-trade returns
    trades = pf_full.trades
    trade_returns = trades.returns.values if hasattr(trades.returns, 'values') else np.asarray(trades.returns)
    trade_returns = np.asarray(trade_returns).ravel()

    if trade_returns.size == 0:
        print("No trades to plot.")
    else:
        # Calculate statistics
        winning_trades = trade_returns[trade_returns > 0]
        losing_trades = trade_returns[trade_returns < 0]

        total_trades = len(trade_returns)
        win_count = len(winning_trades)
        loss_count = len(losing_trades)
        win_rate = (win_count / total_trades * 100) if total_trades > 0 else 0

        avg_win_pct = (winning_trades.mean() * 100) if len(winning_trades) > 0 else 0
        avg_loss_pct = (losing_trades.mean() * 100) if len(losing_trades) > 0 else 0
        max_win_pct = (winning_trades.max() * 100) if len(winning_trades) > 0 else 0
        max_loss_pct = (losing_trades.min() * 100) if len(losing_trades) > 0 else 0

        print(f"Total trades plotted: {total_trades}")
        print(f"Win Rate: {win_rate:.1f}% ({win_count}W / {loss_count}L)")
        print(f"Avg Win: {avg_win_pct:.2f}% | Avg Loss: {avg_loss_pct:.2f}%")
        print(f"Max Win: {max_win_pct:.2f}% | Max Loss: {max_loss_pct:.2f}%")

        equity_per_trade = np.cumprod(1.0 + trade_returns)

        fig, axes = plt.subplots(2, 1, figsize=(14, 9), sharex=False)

        # Per-trade returns (%)
        x = np.arange(1, trade_returns.size + 1)
        colors = np.where(trade_returns >= 0, 'green', 'red')
        axes[0].bar(x, trade_returns * 100.0, color=colors, alpha=0.85, width=0.8)
        axes[0].axhline(0, color='black', linewidth=1, alpha=0.6)

        # Add statistics text box
        stats_text = (
            f'Win Rate: {win_rate:.1f}% ({win_count}W/{loss_count}L)\n'
            f'Avg Win: {avg_win_pct:.2f}% | Avg Loss: {avg_loss_pct:.2f}%\n'
            f'Max Win: {max_win_pct:.2f}% | Max Loss: {max_loss_pct:.2f}%'
        )
        axes[0].text(0.02, 0.98, stats_text, transform=axes[0].transAxes,
                    fontsize=10, verticalalignment='top',
                    bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.8))

        axes[0].set_title(f'Per-Trade Returns (%) - Triple EMA({ema1},{ema2},{ema3}) Full Sample',
                         fontsize=13, fontweight='bold')
        axes[0].set_ylabel('Return (%)')
        axes[0].grid(True, alpha=0.3)

        # Cumulative equity per trade
        axes[1].plot(x, equity_per_trade, color='black', linewidth=2)
        axes[1].set_title('Cumulative Equity per Trade (Trade Domain)', fontsize=13)
        axes[1].set_xlabel('Trade #')
        axes[1].set_ylabel('Equity (x)')
        axes[1].grid(True, alpha=0.3)

        plt.tight_layout()
        plt.show()
# Out:
# Total trades plotted: 11
# Win Rate: 63.6% (7W / 4L)
# Avg Win: 18.34% | Avg Loss: -2.46%
# Max Win: 50.92% | Max Loss: -4.27%

# %%
# PARAMETER SENSITIVITY TABLE (±15 lookbacks around BEST ema1, ema2, ema3)

if 'results_df' in globals() and not results_df.empty:
    best = results_df.iloc[0]
    ema1, ema2, ema3 = int(best['ema1_period']), int(best['ema2_period']), int(best['ema3_period'])

    print(f"🔬 Parameter Sensitivity Analysis for Best EMA({ema1},{ema2},{ema3})")
    print("=" * 80)

    # Create sensitivity ranges (±15 around each parameter)
    fast_candidates = list(range(max(2, ema1 - 15), ema1 + 16))
    medium_candidates = list(range(max(3, ema2 - 15), ema2 + 16))
    slow_candidates = list(range(max(4, ema3 - 15), ema3 + 16))

    # Test variations: vary one parameter at a time
    combos = ([(f, ema2, ema3) for f in fast_candidates] +
              [(ema1, m, ema3) for m in medium_candidates if m != ema2] +
              [(ema1, ema2, s) for s in slow_candidates if s != ema3])

    price_np = train_close.to_numpy(dtype=float)
    idx = train_close.index

    def series_to_np_bool(s: pd.Series) -> np.ndarray:
        return s.reindex(idx).fillna(False).astype(bool).to_numpy(dtype=bool)

    def eval_combo(e1: int, e2: int, e3: int) -> dict:
        fma = vbt.MA.run(train_close, e1, ewm=True).ma
        mma = vbt.MA.run(train_close, e2, ewm=True).ma
        sma = vbt.MA.run(train_close, e3, ewm=True).ma

        # Triple EMA crossover
        e = series_to_np_bool(
            (fma.vbt.crossed_above(mma) & (fma > sma)) |
            (mma.vbt.crossed_above(sma) & (fma > mma))
        )
        x = series_to_np_bool(
            (fma.vbt.crossed_below(mma) & (fma < sma)) |
            (mma.vbt.crossed_below(sma) & (fma < mma))
        )

        pf = vbt.Portfolio.from_signals(
            close=price_np, entries=e, exits=x,
            init_cash=100_000, fees=0.0005, slippage=0.0005, freq='1D'
        )

        total_return = float(pf.total_return())
        sharpe = float(pf.sharpe_ratio(freq='1D'))
        sortino = float(pf.sortino_ratio(freq='1D'))
        mdd = float(pf.max_drawdown())
        vol = float(pf.annualized_volatility(freq='1D'))

        trades = pf.trades
        ntr = len(trades)
        win_rate_pct = np.nan
        profit_factor = np.nan
        expectancy = 0.0
        if ntr > 0:
            tr = trades.returns.values if hasattr(trades.returns, 'values') else np.array(trades.returns)
            if tr.size > 0:
                pos = tr[tr > 0]
                neg = tr[tr < 0]
                win_rate_pct = (len(pos) / len(tr)) * 100 if len(tr) else np.nan
                gains = pos.sum() if len(pos) else 0.0
                losses = abs(neg.sum()) if len(neg) else 0.0
                profit_factor = gains / losses if losses > 0 else np.inf
                expectancy = float(tr.mean())

        return {
            'ema1': e1, 'ema2': e2, 'ema3': e3,
            'sharpe': sharpe, 'sortino': sortino,
            'total_return': total_return, 'max_drawdown': mdd, 'volatility': vol,
            'total_trades': ntr, 'win_rate_pct': win_rate_pct,
            'profit_factor': profit_factor, 'expectancy': expectancy
        }

    rows = []
    for combo in combos:
        try:
            rows.append(eval_combo(*combo))
        except Exception:
            pass

    if not rows:
        print("⚠️ No sensitivity results computed.")
    else:
        sens = pd.DataFrame(rows)

        # Show as a table
        cols = ['ema1','ema2','ema3','sharpe','sortino','total_return','max_drawdown','volatility',
                'total_trades','win_rate_pct','profit_factor','expectancy']
        sens_table = sens[cols].sort_values(['ema1','ema2','ema3'])

        print(f"\n📊 Sensitivity Results ({len(sens_table)} variations tested):\n")
        print(sens_table.to_string())

        # Compact variation summary
        metric_cols = ['sharpe','sortino','total_return','max_drawdown','volatility',
                       'win_rate_pct','profit_factor','expectancy']
        summary = sens_table[metric_cols].agg(['mean','std','min','max']).T

        print("\n📈 Sensitivity Summary (mean / std / min / max):")
        print(summary.round(4).to_string())

        # Highlight best performer in sensitivity test
        best_sens_idx = sens_table['sharpe'].idxmax()
        best_sens = sens_table.loc[best_sens_idx]
        print(f"\n🏆 Best in Sensitivity Test: EMA({int(best_sens['ema1'])},{int(best_sens['ema2'])},{int(best_sens['ema3'])}) → Sharpe: {best_sens['sharpe']:.3f}")
else:
    print("⚠️ No results available for sensitivity analysis.")
# Out:
# 🔬 Parameter Sensitivity Analysis for Best EMA(29,55,155)
# ================================================================================
#
# 📊 Sensitivity Results (91 variations tested):
#
#     ema1  ema2  ema3    sharpe   sortino  total_return  max_drawdown  volatility  total_trades  win_rate_pct  profit_factor  expectancy
# 0     14    55   155  0.238567  0.305130      0.091682     -0.332883    0.191684             3     33.333333       1.728184    0.051747
# 1     15    55   155  0.218775  0.279640      0.078342     -0.332883    0.191563             3     33.333333       1.642163    0.048024
# 2     16    55   155  0.218775  0.279640      0.078342     -0.332883    0.191563             3     33.333333       1.642163    0.048024
# 3     17    55   155  0.218775  0.279640      0.078342     -0.332883    0.191563             3     33.333333       1.642163    0.048024
# 4     18    55   155  0.218775  0.279640      0.078342     -0.332883    0.191563             3     33.333333       1.642163    0.048024
# 5     19    55   155  0.228767  0.292440      0.085042     -0.332883    0.191531             3     33.333333       1.684268    0.049894
# 6     20    55   155  0.228767  0.292440      0.085042     -0.332883    0.191531             3     33.333333       1.684268    0.049894
# 7     21    55   155  0.228767  0.292440      0.085042     -0.332883    0.191531             3     33.333333       1.684268    0.049894
# 8     22    55   155  0.253840  0.324691      0.102004     -0.332883    0.191336             3     33.333333       1.801182    0.054627
# 9     23    55   155  0.253840  0.324691      0.102004     -0.332883    0.191336             3     33.333333       1.801182    0.054627
# 10    24    55   155  0.249274  0.318841      0.098889     -0.332883    0.191330             3     33.333333       1.778514    0.053758
# 11    25    55   155  0.249274  0.318841      0.098889     -0.332883    0.191330             3     33.333333       1.778514    0.053758
# 12    26    55   155  0.235518  0.301156      0.089555     -0.332883    0.191273             3     33.333333       1.713870    0.051153
# 13    27    55   155  0.235518  0.301156      0.089555     -0.332883    0.191273             3     33.333333       1.713870    0.051153
# 14    28    55   155  0.235518  0.301156      0.089555     -0.332883    0.191273             3     33.333333       1.713870    0.051153
# 31    29    40   155  0.222276  0.281475      0.080017     -0.334009    0.186075             3     33.333333       1.664864    0.045971
# 32    29    41   155  0.189705  0.240067      0.059027     -0.341963    0.185970             3     33.333333       1.538770    0.037253
# 33    29    42   155  0.190419  0.240970      0.059482     -0.341963    0.185969             3     33.333333       1.541560    0.037378
# 34    29    43   155  0.185719  0.235015      0.056488     -0.341963    0.185963             3     33.333333       1.522445    0.036511
# 35    29    44   155  0.271969  0.348613      0.113530     -0.306435    0.188106             3     33.333333       1.964658    0.052241
# 36    29    45   155  0.318100  0.408934      0.145518     -0.306435    0.188629             3     33.333333       2.205779    0.064608
# 37    29    46   155  0.318100  0.408934      0.145518     -0.306435    0.188629             3     33.333333       2.205779    0.064608
# 38    29    47   155  0.322927  0.415264      0.148913     -0.301224    0.188651             3     33.333333       2.230757    0.065947
# 39    29    48   155  0.298824  0.384090      0.132086     -0.301224    0.188563             3     33.333333       2.057709    0.061440
# 40    29    49   155  0.277796  0.356887      0.117691     -0.301224    0.188712             3     33.333333       1.958543    0.055680
# 41    29    50   155  0.192797  0.246024      0.061099     -0.336605    0.190980             3     33.333333       1.546428    0.040200
# 42    29    51   155  0.197337  0.251859      0.064082     -0.336605    0.190935             3     33.333333       1.564557    0.041052
# 43    29    52   155  0.185474  0.236694      0.056306     -0.336605    0.190971             3     33.333333       1.519606    0.037784
# 44    29    53   155  0.191367  0.244221      0.060162     -0.336605    0.190960             3     33.333333       1.542076    0.038843
# 45    29    54   155  0.200418  0.255792      0.066111     -0.332883    0.190934             3     33.333333       1.576847    0.041335
# 61    29    55   140  0.276358  0.353682      0.117093     -0.332883    0.190054             3     33.333333       1.923385    0.058604
# 62    29    55   141  0.276358  0.353682      0.117093     -0.332883    0.190054             3     33.333333       1.923385    0.058604
# 63    29    55   142  0.228467  0.291709      0.084741     -0.332883    0.190796             3     33.333333       1.683531    0.049562
# 64    29    55   143  0.228467  0.291709      0.084741     -0.332883    0.190796             3     33.333333       1.683531    0.049562
# 65    29    55   144  0.207742  0.265124      0.070948     -0.332883    0.190942             3     33.333333       1.603641    0.043769
# 66    29    55   145  0.207742  0.265124      0.070948     -0.332883    0.190942             3     33.333333       1.603641    0.043769
# 67    29    55   146  0.207742  0.265124      0.070948     -0.332883    0.190942             3     33.333333       1.603641    0.043769
# 68    29    55   147  0.207742  0.265124      0.070948     -0.332883    0.190942             3     33.333333       1.603641    0.043769
# 69    29    55   148  0.207742  0.265124      0.070948     -0.332883    0.190942             3     33.333333       1.603641    0.043769
# 70    29    55   149  0.195877  0.249956      0.063122     -0.332883    0.190978             3     33.333333       1.558309    0.040482
# 71    29    55   150  0.195877  0.249956      0.063122     -0.332883    0.190978             3     33.333333       1.558309    0.040482
# 72    29    55   151  0.200418  0.255792      0.066111     -0.332883    0.190934             3     33.333333       1.576847    0.041335
# 73    29    55   152  0.200418  0.255792      0.066111     -0.332883    0.190934             3     33.333333       1.576847    0.041335
# 74    29    55   153  0.200418  0.255792      0.066111     -0.332883    0.190934             3     33.333333       1.576847    0.041335
# 75    29    55   154  0.200418  0.255792      0.066111     -0.332883    0.190934             3     33.333333       1.576847    0.041335
# 15    29    55   155  0.235518  0.301156      0.089555     -0.332883    0.191273             3     33.333333       1.713870    0.051153
# 76    29    55   156  0.235518  0.301156      0.089555     -0.332883    0.191273             3     33.333333       1.713870    0.051153
# 77    29    55   157  0.235518  0.301156      0.089555     -0.332883    0.191273             3     33.333333       1.713870    0.051153
# 78    29    55   158  0.235518  0.301156      0.089555     -0.332883    0.191273             3     33.333333       1.713870    0.051153
# 79    29    55   159  0.310660  0.399030      0.141847     -0.332883    0.192135             3     33.333333       2.077756    0.068951
# 80    29    55   160  0.393985  0.507506      0.203488     -0.332883    0.193269             2     50.000000       2.986384    0.125701
# 81    29    55   161  0.393985  0.507506      0.203488     -0.332883    0.193269             2     50.000000       2.986384    0.125701
# 82    29    55   162  0.393985  0.507506      0.203488     -0.332883    0.193269             2     50.000000       2.986384    0.125701
# 83    29    55   163  0.393985  0.507506      0.203488     -0.332883    0.193269             2     50.000000       2.986384    0.125701
# 84    29    55   164  0.336398  0.431886      0.161476     -0.331465    0.194390             2     50.000000       2.622362    0.101159
# 85    29    55   165  0.336398  0.431886      0.161476     -0.331465    0.194390             2     50.000000       2.622362    0.101159
# 86    29    55   166  0.336398  0.431886      0.161476     -0.331465    0.194390             2     50.000000       2.622362    0.101159
# 87    29    55   167  0.336398  0.431886      0.161476     -0.331465    0.194390             2     50.000000       2.622362    0.101159
# 88    29    55   168  0.336398  0.431886      0.161476     -0.331465    0.194390             2     50.000000       2.622362    0.101159
# 89    29    55   169  0.336398  0.431886      0.161476     -0.331465    0.194390             2     50.000000       2.622362    0.101159
# 90    29    55   170  0.336398  0.431886      0.161476     -0.331465    0.194390             2     50.000000       2.622362    0.101159
# 46    29    56   155  0.256087  0.327592      0.103494     -0.332883    0.191141             3     33.333333       1.812235    0.055043
# 47    29    57   155  0.293509  0.376234      0.129499     -0.332883    0.191531             3     33.333333       1.973098    0.065558
# 48    29    58   155  0.360163  0.462943      0.177935     -0.331465    0.192724             2     50.000000       2.785167    0.110246
# 49    29    59   155  0.399633  0.514920      0.207689     -0.331465    0.193190             2     50.000000       3.060130    0.127226
# 50    29    60   155  0.399633  0.514920      0.207689     -0.331465    0.193190             2     50.000000       3.060130    0.127226
# 51    29    61   155  0.508653  0.661571      0.289379     -0.291098    0.190458             2     50.000000       3.912148    0.172062
# 52    29    62   155  0.445982  0.577819      0.241729     -0.291098    0.191677             2     50.000000       3.454680    0.145033
# 53    29    63   155  0.426937  0.552823      0.227035     -0.297189    0.191566             2     50.000000       3.313605    0.136698
# 54    29    64   155  0.426937  0.552823      0.227035     -0.297189    0.191566             2     50.000000       3.313605    0.136698
# 55    29    65   155  0.440559  0.570567      0.237386     -0.297189    0.191507             2     50.000000       3.536366    0.140420
# 56    29    66   155  0.368113  0.474213      0.184062     -0.327476    0.193083             2     50.000000       2.626729    0.121248
# 57    29    67   155  0.353305  0.454979      0.173110     -0.333697    0.193016             2     50.000000       2.540355    0.114810
# 58    29    68   155  0.356511  0.459112      0.175461     -0.333697    0.193013             2     50.000000       2.569768    0.115663
# 59    29    69   155  0.366148  0.471660      0.182537     -0.333697    0.192973             2     50.000000       2.626105    0.119814
# 60    29    70   155  0.366148  0.471660      0.182537     -0.333697    0.192973             2     50.000000       2.626105    0.119814
# 16    30    55   155  0.256087  0.327592      0.103494     -0.332883    0.191141             3     33.333333       1.812235    0.055043
# 17    31    55   155  0.256087  0.327592      0.103494     -0.332883    0.191141             3     33.333333       1.812235    0.055043
# 18    32    55   155  0.264243  0.338078      0.109051     -0.332883    0.191039             3     33.333333       1.854678    0.056593
# 19    33    55   155  0.264243  0.338078      0.109051     -0.332883    0.191039             3     33.333333       1.854678    0.056593
# 20    34    55   155  0.268573  0.343625      0.112025     -0.332883    0.191032             3     33.333333       1.878211    0.057423
# 21    35    55   155  0.387412  0.497822      0.195162     -0.332883    0.188811             2     50.000000       2.911032    0.120933
# 22    36    55   155  0.387412  0.497822      0.195162     -0.332883    0.188811             2     50.000000       2.911032    0.120933
# 23    37    55   155  0.387412  0.497822      0.195162     -0.332883    0.188811             2     50.000000       2.911032    0.120933
# 24    38    55   155  0.387412  0.497822      0.195162     -0.332883    0.188811             2     50.000000       2.911032    0.120933
# 25    39    55   155  0.387412  0.497822      0.195162     -0.332883    0.188811             2     50.000000       2.911032    0.120933
# 26    40    55   155  0.387412  0.497822      0.195162     -0.332883    0.188811             2     50.000000       2.911032    0.120933
# 27    41    55   155  0.387412  0.497822      0.195162     -0.332883    0.188811             2     50.000000       2.911032    0.120933
# 28    42    55   155  0.387412  0.497822      0.195162     -0.332883    0.188811             2     50.000000       2.911032    0.120933
# 29    43    55   155  0.387412  0.497822      0.195162     -0.332883    0.188811             2     50.000000       2.911032    0.120933
# 30    44    55   155  0.387412  0.497822      0.195162     -0.332883    0.188811             2     50.000000       2.911032    0.120933
#
# 📈 Sensitivity Summary (mean / std / min / max):
#                   mean     std      min      max
# sharpe          0.2907  0.0806   0.1855   0.5087
# sortino         0.3730  0.1051   0.2350   0.6616
# total_return    0.1289  0.0570   0.0563   0.2894
# max_drawdown   -0.3292  0.0113  -0.3420  -0.2911
# volatility      0.1910  0.0019   0.1860   0.1944
# win_rate_pct   39.5604  8.1074  33.3333  50.0000
# profit_factor   2.1727  0.6170   1.5196   3.9121
# expectancy      0.0764  0.0362   0.0365   0.1721
#
# 🏆 Best in Sensitivity Test: EMA(29,61,155) → Sharpe: 0.509
