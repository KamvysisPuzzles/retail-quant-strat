# %%
# !pip install yfinance
# !pip install TA-Lib
# !pip install numpy
# !pip install pandas
# !pip install vectorbt
# !pip install scipy
# %pip install scikit-optimize
# %pip install optuna

# %%
import yfinance as yf
import talib
import numpy as np
import pandas as pd
import vectorbt as vbt
import warnings
from scipy import stats
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore", message="Degrees of freedom <= 0 for slice", category=RuntimeWarning)
warnings.filterwarnings("ignore", message="invalid value encountered in scalar divide", category=RuntimeWarning)

# %%
# DOWNLOAD STOCK DATA FROM 2018 USING YFINANCE

TICKER = 'XOP'
START_DATE = '2018-01-01'
TRAIN_RATIO = 0.6
# Download data
stock_data = yf.download(TICKER, start=START_DATE, interval='1d')

if not stock_data.empty:
    print(f"Successfully downloaded {len(stock_data)} records for {TICKER}")
    print(f"Data range: {stock_data.index.min().date()} to {stock_data.index.max().date()}")
else:
    print(f"Failed to download {TICKER} data")

stock_data
# Out:
# C:\Users\harka\AppData\Local\Temp\ipykernel_3596\1366748794.py:7: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# [*********************100%***********************]  1 of 1 completed
# Successfully downloaded 1999 records for XOP
# Data range: 2018-01-02 to 2025-12-15
# Price            Close        High         Low        Open   Volume
# Ticker             XOP         XOP         XOP         XOP      XOP
# Date
# 2018-01-02  129.838013  129.871978  127.358115  127.731788  4282625
# 2018-01-03  131.128876  132.080078  130.279595  130.279595  4604550
# 2018-01-04  131.774384  132.114091  129.736102  131.740405  3927200
# 2018-01-05  130.925079  131.332730  129.770057  130.925079  3039400
# 2018-01-08  131.706421  131.842309  129.736084  130.789196  1949050
# ...                ...         ...         ...         ...      ...
# 2025-12-08  134.130005  136.750000  133.979996  135.550003  2754400
# 2025-12-09  134.550003  135.460007  133.830002  133.919998  2100100
# 2025-12-10  135.220001  135.639999  132.440002  134.309998  2696800
# 2025-12-11  133.009995  134.169998  132.429993  133.380005  2219400
# 2025-12-15  129.740005  131.919998  129.279999  131.990005   843578
#
# [1999 rows x 5 columns]

# %%
# PREPARE PRICE SERIES

def select_close_series(df, ticker):
    if isinstance(df.columns, pd.MultiIndex):
        if ('Close', ticker) in df.columns:
            s = df[('Close', ticker)]
        else:
            cols = [c for c in df.columns if 'Close' in str(c)]
            if not cols:
                raise KeyError("Close not found")
            s = df[cols[0]]
    else:
        s = df['Close']
    return s.astype(float).squeeze()

close = select_close_series(stock_data, TICKER)
close.name = 'price'

# Simple split

split_idx = int(len(close) * TRAIN_RATIO)
train_close = close.iloc[:split_idx].copy()
val_close = close.iloc[split_idx:].copy()

print(f"Data ready: train={train_close.index[0].date()} → {train_close.index[-1].date()} | val={val_close.index[0].date()} → {val_close.index[-1].date()}")
# Out:
# Data ready: train=2018-01-02 → 2022-10-05 | val=2022-10-06 → 2025-12-15

# %% [markdown]
# # Triple EMA Strategy - NO RSI FILTER
#
# This notebook optimizes a **pure Triple EMA crossover strategy** without RSI confirmation.
#
# **Strategy Logic**: Buy when any EMA crosses above another. Sell when any EMA crosses below another.
#
# No additional filters - pure trend-following approach.

# %%
# Define Parameter Ranges for Triple EMA Optimization (NO RSI)

param_bounds = {
    'ema1': (1, 30),    # Fast EMA (shortest-term)
    'ema2': (30, 100),   # Medium EMA (medium-term) 
    'ema3': (100, 200), # Slow EMA (longest-term)
}

print("Parameter Bounds for Optimization (Daily Data):")
print(f"  EMA1 (Fast): {param_bounds['ema1'][0]} - {param_bounds['ema1'][1]} periods")
print(f"  EMA2 (Medium): {param_bounds['ema2'][0]} - {param_bounds['ema2'][1]} periods")
print(f"  EMA3 (Slow): {param_bounds['ema3'][0]} - {param_bounds['ema3'][1]} periods")

# Constraint: ema1 < ema2 < ema3
def is_valid_params(ema1, ema2, ema3):
    return ema1 < ema2 < ema3

print(f"\nConstraint: EMA1 < EMA2 < EMA3")
print("✅ Ready for optimization!")
# Out:
# Parameter Bounds for Optimization (Daily Data):
#   EMA1 (Fast): 1 - 30 periods
#   EMA2 (Medium): 30 - 100 periods
#   EMA3 (Slow): 100 - 200 periods
#
# Constraint: EMA1 < EMA2 < EMA3
# ✅ Ready for optimization!

# %%
# Core Optimization Function for Triple EMA Strategy (NO RSI FILTER)

def evaluate_triple_ema_strategy(params, data=train_close, return_metrics=False):
    """
    Evaluate Triple EMA crossover strategy WITHOUT RSI filter.
    
    Args:
        params: tuple of (ema1, ema2, ema3) periods
        data: price data to test on
        return_metrics: if True, return full metrics dict; if False, return negative Sortino ratio
    
    Returns:
        Negative Sortino ratio (for minimization) or full metrics dict
    """
    ema1_period, ema2_period, ema3_period = params
    
    # Validate parameter constraints
    if not is_valid_params(ema1_period, ema2_period, ema3_period):
        return 999.0  # Large penalty for invalid parameters
    
    try:
        # Calculate EMAs
        ema1 = vbt.MA.run(data, ema1_period, ewm=True)
        ema2 = vbt.MA.run(data, ema2_period, ewm=True)
        ema3 = vbt.MA.run(data, ema3_period, ewm=True)
        
        # Generate EMA crossover signals (NO RSI FILTER)
        entries = (
            ema1.ma_crossed_above(ema2.ma) |
            ema1.ma_crossed_above(ema3.ma) |
            ema2.ma_crossed_above(ema3.ma)
        )
        exits = (
            ema1.ma_crossed_below(ema2.ma) |
            ema1.ma_crossed_below(ema3.ma) |
            ema2.ma_crossed_below(ema3.ma)
        )
        
        # Convert to arrays
        entries_array = pd.Series(np.asarray(entries).ravel(), index=data.index, dtype=bool)
        exits_array = pd.Series(np.asarray(exits).ravel(), index=data.index, dtype=bool)
        
        # Backtest
        portfolio = vbt.Portfolio.from_signals(
            close=data,
            entries=entries_array,
            exits=exits_array,
            init_cash=100_000,
            fees=0.0005,
            slippage=0.0005,
            freq='D'
        )
        
        # Calculate key metrics
        sharpe_ratio = float(portfolio.sharpe_ratio(freq='D'))
        sortino_ratio = float(portfolio.sortino_ratio(freq='D'))
        total_return = float(portfolio.total_return())
        max_drawdown = float(portfolio.max_drawdown())
        volatility = float(portfolio.annualized_volatility(freq='D'))
        
        # Trade metrics
        trades = portfolio.trades
        total_trades = len(trades)
        
        # Check for sufficient trading activity
        years = max((data.index[-1] - data.index[0]).days / 365.25, 1e-9)
        trades_per_year = total_trades / years
        
        if trades_per_year < 1:  # Too few trades
            if return_metrics:
                return {
                    'ema1_period': ema1_period,
                    'ema2_period': ema2_period,
                    'ema3_period': ema3_period,
                    'sharpe_ratio': np.nan,
                    'sortino_ratio': np.nan,
                    'total_return': np.nan,
                    'annualized_return': np.nan,
                    'max_drawdown': np.nan,
                    'volatility': np.nan,
                    'total_trades': total_trades,
                    'win_rate': np.nan,
                    'profit_factor': np.nan,
                    'expectancy': np.nan,
                    'trades_per_year': trades_per_year
                }
            return 999.0
        
        if return_metrics:
            # Calculate additional metrics
            win_rate_pct = np.nan
            profit_factor = np.nan
            expectancy = 0.0
            annualized_return = (1.0 + total_return) ** (1.0 / years) - 1.0 if years > 0 else np.nan
            
            if total_trades > 0:
                tr = trades.returns.values if hasattr(trades.returns, 'values') else np.array(trades.returns)
                if tr.size > 0:
                    pos = tr[tr > 0]
                    neg = tr[tr < 0]
                    win_rate_pct = (len(pos) / len(tr)) * 100.0
                    gains = pos.sum() if len(pos) else 0.0
                    losses = abs(neg.sum()) if len(neg) else 0.0
                    profit_factor = (gains / losses) if losses > 0 else np.inf
                    expectancy = float(tr.mean())
            
            return {
                'ema1_period': ema1_period,
                'ema2_period': ema2_period,
                'ema3_period': ema3_period,
                'sharpe_ratio': sharpe_ratio,
                'sortino_ratio': sortino_ratio,
                'total_return': total_return,
                'annualized_return': annualized_return,
                'max_drawdown': max_drawdown,
                'volatility': volatility,
                'total_trades': total_trades,
                'win_rate': win_rate_pct,
                'profit_factor': profit_factor,
                'expectancy': expectancy,
                'trades_per_year': trades_per_year
            }
        else:
            # Return negative Sortino for minimization
            return -sortino_ratio
            
    except Exception as e:
        return 999.0  # Large penalty for errors

print("✅ Core optimization function created - NO RSI FILTER!")
print("Function evaluates Triple EMA strategy without any confirmation filter.")
# Out:
# ✅ Core optimization function created - NO RSI FILTER!
# Function evaluates Triple EMA strategy without any confirmation filter.

# %%
# Import optimization libraries
try:
    from skopt import gp_minimize
    from skopt.space import Real
    from skopt.utils import use_named_args
    SKOPT_AVAILABLE = True
except ImportError:
    SKOPT_AVAILABLE = False

try:
    import optuna
    OPTUNA_AVAILABLE = True
except ImportError:
    OPTUNA_AVAILABLE = False

print(f"scikit-optimize: {'✅' if SKOPT_AVAILABLE else '❌'}")
print(f"Optuna: {'✅' if OPTUNA_AVAILABLE else '❌'}")
# Out:
# scikit-optimize: ✅
# Optuna: ✅

# %%
# OPTUNA OPTIMIZATION - Pure 3EMA Strategy

print("=" * 70)
print("OPTUNA OPTIMIZATION: Triple EMA Strategy (NO RSI FILTER)")
print(f"Training Period: {train_close.index[0].date()} → {train_close.index[-1].date()}")
print("=" * 70)

optimization_results = []
evaluation_count = 0

def objective(trial):
    """Optuna objective function - NO RSI."""
    global evaluation_count
    evaluation_count += 1
    
    # Suggest parameters (NO RSI threshold)
    ema1 = trial.suggest_int('ema1', param_bounds['ema1'][0], param_bounds['ema1'][1])
    ema2 = trial.suggest_int('ema2', param_bounds['ema2'][0], param_bounds['ema2'][1])
    ema3 = trial.suggest_int('ema3', param_bounds['ema3'][0], param_bounds['ema3'][1])
    
    # Validate constraints
    if not is_valid_params(ema1, ema2, ema3):
        return 999.0
    
    # Evaluate strategy (params is now just 3 values, not 4)
    result = evaluate_triple_ema_strategy((ema1, ema2, ema3))
    
    # Debug output
    if result == 999.0 and evaluation_count <= 5:
        print(f"Trial {evaluation_count}: EMA({ema1},{ema2},{ema3}) → No valid trades")
    elif evaluation_count % 10 == 0 or result != 999.0:
        print(f"Trial {evaluation_count}: EMA({ema1},{ema2},{ema3}) → Sortino: {-result:.3f}")
    
    return result

if OPTUNA_AVAILABLE:
    # Create study
    study = optuna.create_study(
        direction='minimize',
        sampler=optuna.samplers.TPESampler(seed=42),
        pruner=optuna.pruners.MedianPruner(n_startup_trials=10, n_warmup_steps=5)
    )
    
    print("\nStarting Optuna optimization...\n")
    
    study.optimize(objective, n_trials=1000, show_progress_bar=True)
    
    # Get best parameters
    best_params = study.best_params
    best_ema1 = best_params['ema1']
    best_ema2 = best_params['ema2']
    best_ema3 = best_params['ema3']
    best_sortino = -study.best_value
    
    # Evaluate best parameters to get full metrics
    best_result = evaluate_triple_ema_strategy(
        (best_ema1, best_ema2, best_ema3), 
        return_metrics=True
    )
    
    # Create results dataframe
    results_df = pd.DataFrame([best_result])
    
    print("\n✅ Optimization complete!")
    print(f"Best Parameters: EMA({best_ema1},{best_ema2},{best_ema3})")
    print(f"Sortino Ratio: {best_sortino:.3f}")
    
else:
    print("❌ Optuna not available")
# Out:
# [I 2025-12-15 16:19:39,383] A new study created in memory with name: no-name-47067631-011a-436f-9fcf-174b29321bca
# ======================================================================
# OPTUNA OPTIMIZATION: Triple EMA Strategy (NO RSI FILTER)
# Training Period: 2018-01-02 → 2022-10-05
# ======================================================================
#
# Starting Optuna optimization...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Trial 1: EMA(12,97,173) → Sortino: 0.275
# [I 2025-12-15 16:19:39,596] Trial 0 finished with value: -0.2748105911449179 and parameters: {'ema1': 12, 'ema2': 97, 'ema3': 173}. Best is trial 0 with value: -0.2748105911449179.
# Trial 2: EMA(18,41,115) → Sortino: 0.616
# [I 2025-12-15 16:19:39,707] Trial 1 finished with value: -0.6161618404551314 and parameters: {'ema1': 18, 'ema2': 41, 'ema3': 115}. Best is trial 1 with value: -0.6161618404551314.
# Trial 3: EMA(2,91,160) → Sortino: 1.135
# [I 2025-12-15 16:19:39,830] Trial 2 finished with value: -1.1347951606646824 and parameters: {'ema1': 2, 'ema2': 91, 'ema3': 160}. Best is trial 2 with value: -1.1347951606646824.
# Trial 4: EMA(22,31,197) → Sortino: 0.290
# [I 2025-12-15 16:19:40,239] Trial 3 finished with value: -0.29040485119635967 and parameters: {'ema1': 22, 'ema2': 31, 'ema3': 197}. Best is trial 2 with value: -1.1347951606646824.
# Trial 5: EMA(25,45,118) → Sortino: 0.685
# [I 2025-12-15 16:19:40,394] Trial 4 finished with value: -0.6846416870634139 and parameters: {'ema1': 25, 'ema2': 45, 'ema3': 118}. Best is trial 2 with value: -1.1347951606646824.
# Trial 6: EMA(6,51,153) → Sortino: 1.215
# [I 2025-12-15 16:19:40,620] Trial 5 finished with value: -1.2149972262628739 and parameters: {'ema1': 6, 'ema2': 51, 'ema3': 153}. Best is trial 5 with value: -1.2149972262628739.
# Trial 7: EMA(13,50,161) → Sortino: 0.836
# [I 2025-12-15 16:19:40,748] Trial 6 finished with value: -0.8362976604919689 and parameters: {'ema1': 13, 'ema2': 50, 'ema3': 161}. Best is trial 5 with value: -1.2149972262628739.
# Trial 8: EMA(5,50,137) → Sortino: 1.110
# [I 2025-12-15 16:19:40,894] Trial 7 finished with value: -1.1099761927442284 and parameters: {'ema1': 5, 'ema2': 50, 'ema3': 137}. Best is trial 5 with value: -1.2149972262628739.
# Trial 9: EMA(14,85,120) → Sortino: 0.229
# [I 2025-12-15 16:19:41,030] Trial 8 finished with value: -0.22903640893739083 and parameters: {'ema1': 14, 'ema2': 85, 'ema3': 120}. Best is trial 5 with value: -1.2149972262628739.
# Trial 10: EMA(16,72,104) → Sortino: 0.541
# [I 2025-12-15 16:19:41,200] Trial 9 finished with value: -0.5414020809085458 and parameters: {'ema1': 16, 'ema2': 72, 'ema3': 104}. Best is trial 5 with value: -1.2149972262628739.
# Trial 11: EMA(7,63,186) → Sortino: 0.770
# [I 2025-12-15 16:19:41,424] Trial 10 finished with value: -0.7695865264114318 and parameters: {'ema1': 7, 'ema2': 63, 'ema3': 186}. Best is trial 5 with value: -1.2149972262628739.
# Trial 12: EMA(1,66,145) → Sortino: 1.098
# [I 2025-12-15 16:19:41,605] Trial 11 finished with value: -1.0979801764048651 and parameters: {'ema1': 1, 'ema2': 66, 'ema3': 145}. Best is trial 5 with value: -1.2149972262628739.
# Trial 13: EMA(1,99,163) → Sortino: 0.936
# [I 2025-12-15 16:19:41,766] Trial 12 finished with value: -0.9355172597388342 and parameters: {'ema1': 1, 'ema2': 99, 'ema3': 163}. Best is trial 5 with value: -1.2149972262628739.
# Trial 14: EMA(7,81,139) → Sortino: 0.780
# [I 2025-12-15 16:19:41,889] Trial 13 finished with value: -0.7804100233507181 and parameters: {'ema1': 7, 'ema2': 81, 'ema3': 139}. Best is trial 5 with value: -1.2149972262628739.
# Trial 15: EMA(9,59,158) → Sortino: 0.855
# [I 2025-12-15 16:19:42,008] Trial 14 finished with value: -0.8547507867917659 and parameters: {'ema1': 9, 'ema2': 59, 'ema3': 158}. Best is trial 5 with value: -1.2149972262628739.
# Trial 16: EMA(4,88,177) → Sortino: 1.001
# [I 2025-12-15 16:19:42,132] Trial 15 finished with value: -1.0011551220605213 and parameters: {'ema1': 4, 'ema2': 88, 'ema3': 177}. Best is trial 5 with value: -1.2149972262628739.
# Trial 17: EMA(9,75,131) → Sortino: 0.448
# [I 2025-12-15 16:19:42,262] Trial 16 finished with value: -0.44800311317347413 and parameters: {'ema1': 9, 'ema2': 75, 'ema3': 131}. Best is trial 5 with value: -1.2149972262628739.
# Trial 18: EMA(3,58,152) → Sortino: 0.829
# [I 2025-12-15 16:19:42,379] Trial 17 finished with value: -0.8287978004765452 and parameters: {'ema1': 3, 'ema2': 58, 'ema3': 152}. Best is trial 5 with value: -1.2149972262628739.
# Trial 19: EMA(19,32,170) → Sortino: 0.483
# [I 2025-12-15 16:19:42,497] Trial 18 finished with value: -0.4829075352067573 and parameters: {'ema1': 19, 'ema2': 32, 'ema3': 170}. Best is trial 5 with value: -1.2149972262628739.
# Trial 20: EMA(30,90,150) → Sortino: 0.819
# [I 2025-12-15 16:19:42,674] Trial 19 finished with value: -0.818552815218352 and parameters: {'ema1': 30, 'ema2': 90, 'ema3': 150}. Best is trial 5 with value: -1.2149972262628739.
# Trial 21: EMA(11,79,182) → Sortino: 0.466
# [I 2025-12-15 16:19:43,082] Trial 20 finished with value: -0.4660584699197099 and parameters: {'ema1': 11, 'ema2': 79, 'ema3': 182}. Best is trial 5 with value: -1.2149972262628739.
# Trial 22: EMA(5,52,136) → Sortino: 1.196
# [I 2025-12-15 16:19:43,214] Trial 21 finished with value: -1.196147468713869 and parameters: {'ema1': 5, 'ema2': 52, 'ema3': 136}. Best is trial 5 with value: -1.2149972262628739.
# Trial 23: EMA(5,55,135) → Sortino: 1.079
# [I 2025-12-15 16:19:43,332] Trial 22 finished with value: -1.0793257355243666 and parameters: {'ema1': 5, 'ema2': 55, 'ema3': 135}. Best is trial 5 with value: -1.2149972262628739.
# Trial 24: EMA(1,39,129) → Sortino: 1.125
# [I 2025-12-15 16:19:43,475] Trial 23 finished with value: -1.124794201025196 and parameters: {'ema1': 1, 'ema2': 39, 'ema3': 129}. Best is trial 5 with value: -1.2149972262628739.
# Trial 25: EMA(8,67,146) → Sortino: 0.866
# [I 2025-12-15 16:19:43,595] Trial 24 finished with value: -0.8663365613986034 and parameters: {'ema1': 8, 'ema2': 67, 'ema3': 146}. Best is trial 5 with value: -1.2149972262628739.
# Trial 26: EMA(4,48,154) → Sortino: 1.255
# [I 2025-12-15 16:19:43,700] Trial 25 finished with value: -1.2551427626903386 and parameters: {'ema1': 4, 'ema2': 48, 'ema3': 154}. Best is trial 25 with value: -1.2551427626903386.
# Trial 27: EMA(6,50,126) → Sortino: 1.462
# [I 2025-12-15 16:19:43,816] Trial 26 finished with value: -1.4621536871190486 and parameters: {'ema1': 6, 'ema2': 50, 'ema3': 126}. Best is trial 26 with value: -1.4621536871190486.
# Trial 28: EMA(10,45,124) → Sortino: 1.105
# [I 2025-12-15 16:19:43,927] Trial 27 finished with value: -1.1046341165011906 and parameters: {'ema1': 10, 'ema2': 45, 'ema3': 124}. Best is trial 26 with value: -1.4621536871190486.
# Trial 29: EMA(7,38,100) → Sortino: 1.198
# [I 2025-12-15 16:19:44,032] Trial 28 finished with value: -1.1984678584685433 and parameters: {'ema1': 7, 'ema2': 38, 'ema3': 100}. Best is trial 26 with value: -1.4621536871190486.
# Trial 30: EMA(12,47,153) → Sortino: 0.659
# [I 2025-12-15 16:19:44,140] Trial 29 finished with value: -0.6587182964139733 and parameters: {'ema1': 12, 'ema2': 47, 'ema3': 153}. Best is trial 26 with value: -1.4621536871190486.
# Trial 31: EMA(4,60,169) → Sortino: 0.877
# [I 2025-12-15 16:19:44,246] Trial 30 finished with value: -0.8766548337268304 and parameters: {'ema1': 4, 'ema2': 60, 'ema3': 169}. Best is trial 26 with value: -1.4621536871190486.
# Trial 32: EMA(7,36,100) → Sortino: 1.187
# [I 2025-12-15 16:19:44,358] Trial 31 finished with value: -1.1871930303830651 and parameters: {'ema1': 7, 'ema2': 36, 'ema3': 100}. Best is trial 26 with value: -1.4621536871190486.
# Trial 33: EMA(6,40,110) → Sortino: 1.260
# [I 2025-12-15 16:19:44,477] Trial 32 finished with value: -1.2602784656199537 and parameters: {'ema1': 6, 'ema2': 40, 'ema3': 110}. Best is trial 26 with value: -1.4621536871190486.
# Trial 34: EMA(3,44,142) → Sortino: 1.339
# [I 2025-12-15 16:19:44,587] Trial 33 finished with value: -1.338795280032701 and parameters: {'ema1': 3, 'ema2': 44, 'ema3': 142}. Best is trial 26 with value: -1.4621536871190486.
# Trial 35: EMA(3,42,115) → Sortino: 1.581
# [I 2025-12-15 16:19:44,694] Trial 34 finished with value: -1.5812092815227645 and parameters: {'ema1': 3, 'ema2': 42, 'ema3': 115}. Best is trial 34 with value: -1.5812092815227645.
# Trial 36: EMA(3,42,109) → Sortino: 1.571
# [I 2025-12-15 16:19:44,802] Trial 35 finished with value: -1.5707889578774021 and parameters: {'ema1': 3, 'ema2': 42, 'ema3': 109}. Best is trial 34 with value: -1.5812092815227645.
# Trial 37: EMA(3,43,116) → Sortino: 1.417
# [I 2025-12-15 16:19:45,310] Trial 36 finished with value: -1.41719262691239 and parameters: {'ema1': 3, 'ema2': 43, 'ema3': 116}. Best is trial 34 with value: -1.5812092815227645.
# Trial 38: EMA(2,30,112) → Sortino: 1.403
# [I 2025-12-15 16:19:45,419] Trial 37 finished with value: -1.402576249535976 and parameters: {'ema1': 2, 'ema2': 30, 'ema3': 112}. Best is trial 34 with value: -1.5812092815227645.
# Trial 39: EMA(3,35,110) → Sortino: 1.473
# [I 2025-12-15 16:19:45,524] Trial 38 finished with value: -1.4729692692687362 and parameters: {'ema1': 3, 'ema2': 35, 'ema3': 110}. Best is trial 34 with value: -1.5812092815227645.
# Trial 40: EMA(25,33,110) → Sortino: 0.496
# [I 2025-12-15 16:19:45,691] Trial 39 finished with value: -0.4959835792040142 and parameters: {'ema1': 25, 'ema2': 33, 'ema3': 110}. Best is trial 34 with value: -1.5812092815227645.
# Trial 41: EMA(15,35,122) → Sortino: 0.653
# [I 2025-12-15 16:19:45,854] Trial 40 finished with value: -0.6532516473493662 and parameters: {'ema1': 15, 'ema2': 35, 'ema3': 122}. Best is trial 34 with value: -1.5812092815227645.
# Trial 42: EMA(3,42,116) → Sortino: 1.581
# [I 2025-12-15 16:19:45,988] Trial 41 finished with value: -1.5812092815227645 and parameters: {'ema1': 3, 'ema2': 42, 'ema3': 116}. Best is trial 34 with value: -1.5812092815227645.
# Trial 43: EMA(2,41,106) → Sortino: 1.092
# [I 2025-12-15 16:19:46,110] Trial 42 finished with value: -1.0917588663090374 and parameters: {'ema1': 2, 'ema2': 41, 'ema3': 106}. Best is trial 34 with value: -1.5812092815227645.
# Trial 44: EMA(5,53,116) → Sortino: 1.331
# [I 2025-12-15 16:19:46,224] Trial 43 finished with value: -1.3309445928084915 and parameters: {'ema1': 5, 'ema2': 53, 'ema3': 116}. Best is trial 34 with value: -1.5812092815227645.
# Trial 45: EMA(1,36,126) → Sortino: 1.113
# [I 2025-12-15 16:19:46,330] Trial 44 finished with value: -1.1128754507379992 and parameters: {'ema1': 1, 'ema2': 36, 'ema3': 126}. Best is trial 34 with value: -1.5812092815227645.
# Trial 46: EMA(3,41,106) → Sortino: 1.450
# [I 2025-12-15 16:19:46,439] Trial 45 finished with value: -1.4502116991324827 and parameters: {'ema1': 3, 'ema2': 41, 'ema3': 106}. Best is trial 34 with value: -1.5812092815227645.
# Trial 47: EMA(6,47,118) → Sortino: 1.265
# [I 2025-12-15 16:19:46,544] Trial 46 finished with value: -1.2652083805368766 and parameters: {'ema1': 6, 'ema2': 47, 'ema3': 118}. Best is trial 34 with value: -1.5812092815227645.
# Trial 48: EMA(17,55,113) → Sortino: 0.588
# [I 2025-12-15 16:19:46,653] Trial 47 finished with value: -0.5877916823013204 and parameters: {'ema1': 17, 'ema2': 55, 'ema3': 113}. Best is trial 34 with value: -1.5812092815227645.
# Trial 49: EMA(9,34,120) → Sortino: 1.274
# [I 2025-12-15 16:19:46,756] Trial 48 finished with value: -1.2735123419908176 and parameters: {'ema1': 9, 'ema2': 34, 'ema3': 120}. Best is trial 34 with value: -1.5812092815227645.
# Trial 50: EMA(2,38,104) → Sortino: 1.139
# [I 2025-12-15 16:19:46,895] Trial 49 finished with value: -1.1394495113612635 and parameters: {'ema1': 2, 'ema2': 38, 'ema3': 104}. Best is trial 34 with value: -1.5812092815227645.
# Trial 51: EMA(4,49,130) → Sortino: 0.861
# [I 2025-12-15 16:19:47,025] Trial 50 finished with value: -0.861013043618321 and parameters: {'ema1': 4, 'ema2': 49, 'ema3': 130}. Best is trial 34 with value: -1.5812092815227645.
# Trial 52: EMA(3,42,106) → Sortino: 1.457
# [I 2025-12-15 16:19:47,151] Trial 51 finished with value: -1.456720866064709 and parameters: {'ema1': 3, 'ema2': 42, 'ema3': 106}. Best is trial 34 with value: -1.5812092815227645.
# Trial 53: EMA(1,43,108) → Sortino: 0.767
# [I 2025-12-15 16:19:47,277] Trial 52 finished with value: -0.7665565424881773 and parameters: {'ema1': 1, 'ema2': 43, 'ema3': 108}. Best is trial 34 with value: -1.5812092815227645.
# Trial 54: EMA(6,46,114) → Sortino: 1.360
# [I 2025-12-15 16:19:47,391] Trial 53 finished with value: -1.3602767651963903 and parameters: {'ema1': 6, 'ema2': 46, 'ema3': 114}. Best is trial 34 with value: -1.5812092815227645.
# Trial 55: EMA(3,30,103) → Sortino: 1.406
# [I 2025-12-15 16:19:47,498] Trial 54 finished with value: -1.4056461683403658 and parameters: {'ema1': 3, 'ema2': 30, 'ema3': 103}. Best is trial 34 with value: -1.5812092815227645.
# Trial 56: EMA(20,42,126) → Sortino: 0.789
# [I 2025-12-15 16:19:47,612] Trial 55 finished with value: -0.7891078327972799 and parameters: {'ema1': 20, 'ema2': 42, 'ema3': 126}. Best is trial 34 with value: -1.5812092815227645.
# Trial 57: EMA(8,95,110) → Sortino: 0.517
# [I 2025-12-15 16:19:47,741] Trial 56 finished with value: -0.516629008213485 and parameters: {'ema1': 8, 'ema2': 95, 'ema3': 110}. Best is trial 34 with value: -1.5812092815227645.
# Trial 58: EMA(2,37,121) → Sortino: 1.100
# [I 2025-12-15 16:19:47,883] Trial 57 finished with value: -1.100484020291003 and parameters: {'ema1': 2, 'ema2': 37, 'ema3': 121}. Best is trial 34 with value: -1.5812092815227645.
# Trial 59: EMA(5,51,117) → Sortino: 1.138
# [I 2025-12-15 16:19:47,996] Trial 58 finished with value: -1.1384296074192763 and parameters: {'ema1': 5, 'ema2': 51, 'ema3': 117}. Best is trial 34 with value: -1.5812092815227645.
# Trial 60: EMA(8,40,200) → Sortino: 1.071
# [I 2025-12-15 16:19:48,125] Trial 59 finished with value: -1.0713499127942567 and parameters: {'ema1': 8, 'ema2': 40, 'ema3': 200}. Best is trial 34 with value: -1.5812092815227645.
# Trial 61: EMA(4,33,107) → Sortino: 1.439
# [I 2025-12-15 16:19:48,257] Trial 60 finished with value: -1.4388863952967574 and parameters: {'ema1': 4, 'ema2': 33, 'ema3': 107}. Best is trial 34 with value: -1.5812092815227645.
# Trial 62: EMA(3,41,104) → Sortino: 1.371
# [I 2025-12-15 16:19:48,391] Trial 61 finished with value: -1.3713630913214458 and parameters: {'ema1': 3, 'ema2': 41, 'ema3': 104}. Best is trial 34 with value: -1.5812092815227645.
# Trial 63: EMA(2,46,113) → Sortino: 1.373
# [I 2025-12-15 16:19:48,534] Trial 62 finished with value: -1.3730447337024307 and parameters: {'ema1': 2, 'ema2': 46, 'ema3': 113}. Best is trial 34 with value: -1.5812092815227645.
# Trial 64: EMA(6,44,100) → Sortino: 1.406
# [I 2025-12-15 16:19:48,655] Trial 63 finished with value: -1.4055808841618846 and parameters: {'ema1': 6, 'ema2': 44, 'ema3': 100}. Best is trial 34 with value: -1.5812092815227645.
# Trial 65: EMA(1,49,108) → Sortino: 0.847
# [I 2025-12-15 16:19:48,763] Trial 64 finished with value: -0.8473975615028844 and parameters: {'ema1': 1, 'ema2': 49, 'ema3': 108}. Best is trial 34 with value: -1.5812092815227645.
# Trial 66: EMA(5,38,133) → Sortino: 1.374
# [I 2025-12-15 16:19:48,889] Trial 65 finished with value: -1.3743089587831963 and parameters: {'ema1': 5, 'ema2': 38, 'ema3': 133}. Best is trial 34 with value: -1.5812092815227645.
# Trial 67: EMA(4,55,124) → Sortino: 0.948
# [I 2025-12-15 16:19:49,004] Trial 66 finished with value: -0.9477195915260518 and parameters: {'ema1': 4, 'ema2': 55, 'ema3': 124}. Best is trial 34 with value: -1.5812092815227645.
# Trial 68: EMA(3,41,103) → Sortino: 1.371
# [I 2025-12-15 16:19:49,137] Trial 67 finished with value: -1.3713630913214458 and parameters: {'ema1': 3, 'ema2': 41, 'ema3': 103}. Best is trial 34 with value: -1.5812092815227645.
# Trial 69: EMA(7,35,111) → Sortino: 1.244
# [I 2025-12-15 16:19:49,277] Trial 68 finished with value: -1.244454795990061 and parameters: {'ema1': 7, 'ema2': 35, 'ema3': 111}. Best is trial 34 with value: -1.5812092815227645.
# Trial 70: EMA(2,63,119) → Sortino: 0.809
# [I 2025-12-15 16:19:49,399] Trial 69 finished with value: -0.8094046506578979 and parameters: {'ema1': 2, 'ema2': 63, 'ema3': 119}. Best is trial 34 with value: -1.5812092815227645.
# Trial 71: EMA(4,43,106) → Sortino: 1.353
# [I 2025-12-15 16:19:49,545] Trial 70 finished with value: -1.3525506078512979 and parameters: {'ema1': 4, 'ema2': 43, 'ema3': 106}. Best is trial 34 with value: -1.5812092815227645.
# Trial 72: EMA(4,33,115) → Sortino: 1.502
# [I 2025-12-15 16:19:49,690] Trial 71 finished with value: -1.5024585838344553 and parameters: {'ema1': 4, 'ema2': 33, 'ema3': 115}. Best is trial 34 with value: -1.5812092815227645.
# Trial 73: EMA(5,32,115) → Sortino: 1.427
# [I 2025-12-15 16:19:49,810] Trial 72 finished with value: -1.4271240338456073 and parameters: {'ema1': 5, 'ema2': 32, 'ema3': 115}. Best is trial 34 with value: -1.5812092815227645.
# Trial 74: EMA(3,39,111) → Sortino: 1.562
# [I 2025-12-15 16:19:49,955] Trial 73 finished with value: -1.5616094885825194 and parameters: {'ema1': 3, 'ema2': 39, 'ema3': 111}. Best is trial 34 with value: -1.5812092815227645.
# Trial 75: EMA(1,38,123) → Sortino: 1.092
# [I 2025-12-15 16:19:50,070] Trial 74 finished with value: -1.0924846098487622 and parameters: {'ema1': 1, 'ema2': 38, 'ema3': 123}. Best is trial 34 with value: -1.5812092815227645.
# Trial 76: EMA(3,36,128) → Sortino: 1.542
# [I 2025-12-15 16:19:50,178] Trial 75 finished with value: -1.5424944150103612 and parameters: {'ema1': 3, 'ema2': 36, 'ema3': 128}. Best is trial 34 with value: -1.5812092815227645.
# Trial 77: EMA(6,31,138) → Sortino: 1.308
# [I 2025-12-15 16:19:50,301] Trial 76 finished with value: -1.3080223527534327 and parameters: {'ema1': 6, 'ema2': 31, 'ema3': 138}. Best is trial 34 with value: -1.5812092815227645.
# Trial 78: EMA(24,35,125) → Sortino: 0.381
# [I 2025-12-15 16:19:50,434] Trial 77 finished with value: -0.38091330450436256 and parameters: {'ema1': 24, 'ema2': 35, 'ema3': 125}. Best is trial 34 with value: -1.5812092815227645.
# Trial 79: EMA(4,33,129) → Sortino: 1.362
# [I 2025-12-15 16:19:50,615] Trial 78 finished with value: -1.3622731002718216 and parameters: {'ema1': 4, 'ema2': 33, 'ema3': 129}. Best is trial 34 with value: -1.5812092815227645.
# Trial 80: EMA(11,36,118) → Sortino: 1.032
# [I 2025-12-15 16:19:50,725] Trial 79 finished with value: -1.0324815570449206 and parameters: {'ema1': 11, 'ema2': 36, 'ema3': 118}. Best is trial 34 with value: -1.5812092815227645.
# Trial 81: EMA(1,70,121) → Sortino: 0.607
# [I 2025-12-15 16:19:50,866] Trial 80 finished with value: -0.6065925548637621 and parameters: {'ema1': 1, 'ema2': 70, 'ema3': 121}. Best is trial 34 with value: -1.5812092815227645.
# Trial 82: EMA(3,39,110) → Sortino: 1.562
# [I 2025-12-15 16:19:50,997] Trial 81 finished with value: -1.5616094885825194 and parameters: {'ema1': 3, 'ema2': 39, 'ema3': 110}. Best is trial 34 with value: -1.5812092815227645.
# Trial 83: EMA(5,39,115) → Sortino: 1.362
# [I 2025-12-15 16:19:51,131] Trial 82 finished with value: -1.3624459704631726 and parameters: {'ema1': 5, 'ema2': 39, 'ema3': 115}. Best is trial 34 with value: -1.5812092815227645.
# Trial 84: EMA(3,45,110) → Sortino: 1.277
# [I 2025-12-15 16:19:51,301] Trial 83 finished with value: -1.277431694868743 and parameters: {'ema1': 3, 'ema2': 45, 'ema3': 110}. Best is trial 34 with value: -1.5812092815227645.
# Trial 85: EMA(2,37,113) → Sortino: 1.181
# [I 2025-12-15 16:19:51,442] Trial 84 finished with value: -1.1809158873362162 and parameters: {'ema1': 2, 'ema2': 37, 'ema3': 113}. Best is trial 34 with value: -1.5812092815227645.
# Trial 86: EMA(4,39,127) → Sortino: 1.293
# [I 2025-12-15 16:19:51,559] Trial 85 finished with value: -1.2932187440327392 and parameters: {'ema1': 4, 'ema2': 39, 'ema3': 127}. Best is trial 34 with value: -1.5812092815227645.
# Trial 87: EMA(29,31,133) → Sortino: 0.426
# [I 2025-12-15 16:19:51,677] Trial 86 finished with value: -0.42562210199168604 and parameters: {'ema1': 29, 'ema2': 31, 'ema3': 133}. Best is trial 34 with value: -1.5812092815227645.
# Trial 88: EMA(3,35,191) → Sortino: 1.373
# [I 2025-12-15 16:19:51,828] Trial 87 finished with value: -1.3725110600822417 and parameters: {'ema1': 3, 'ema2': 35, 'ema3': 191}. Best is trial 34 with value: -1.5812092815227645.
# Trial 89: EMA(6,33,117) → Sortino: 1.425
# [I 2025-12-15 16:19:51,945] Trial 88 finished with value: -1.4250698544994915 and parameters: {'ema1': 6, 'ema2': 33, 'ema3': 117}. Best is trial 34 with value: -1.5812092815227645.
# Trial 90: EMA(1,48,111) → Sortino: 0.822
# [I 2025-12-15 16:19:52,071] Trial 89 finished with value: -0.8224827375165937 and parameters: {'ema1': 1, 'ema2': 48, 'ema3': 111}. Best is trial 34 with value: -1.5812092815227645.
# Trial 91: EMA(13,40,109) → Sortino: 0.908
# [I 2025-12-15 16:19:52,197] Trial 90 finished with value: -0.9084618111359335 and parameters: {'ema1': 13, 'ema2': 40, 'ema3': 109}. Best is trial 34 with value: -1.5812092815227645.
# Trial 92: EMA(2,43,105) → Sortino: 1.146
# [I 2025-12-15 16:19:52,310] Trial 91 finished with value: -1.1459948820274373 and parameters: {'ema1': 2, 'ema2': 43, 'ema3': 105}. Best is trial 34 with value: -1.5812092815227645.
# Trial 93: EMA(4,37,141) → Sortino: 1.442
# [I 2025-12-15 16:19:52,427] Trial 92 finished with value: -1.4415331476313926 and parameters: {'ema1': 4, 'ema2': 37, 'ema3': 141}. Best is trial 34 with value: -1.5812092815227645.
# Trial 94: EMA(7,45,102) → Sortino: 1.238
# [I 2025-12-15 16:19:52,581] Trial 93 finished with value: -1.2381613311521928 and parameters: {'ema1': 7, 'ema2': 45, 'ema3': 102}. Best is trial 34 with value: -1.5812092815227645.
# Trial 95: EMA(5,41,113) → Sortino: 1.372
# [I 2025-12-15 16:19:52,716] Trial 94 finished with value: -1.3720614815296763 and parameters: {'ema1': 5, 'ema2': 41, 'ema3': 113}. Best is trial 34 with value: -1.5812092815227645.
# Trial 96: EMA(3,39,108) → Sortino: 1.540
# [I 2025-12-15 16:19:52,828] Trial 95 finished with value: -1.5395270429157646 and parameters: {'ema1': 3, 'ema2': 39, 'ema3': 108}. Best is trial 34 with value: -1.5812092815227645.
# Trial 97: EMA(3,34,119) → Sortino: 1.323
# [I 2025-12-15 16:19:52,937] Trial 96 finished with value: -1.3232608976004743 and parameters: {'ema1': 3, 'ema2': 34, 'ema3': 119}. Best is trial 34 with value: -1.5812092815227645.
# Trial 98: EMA(2,39,108) → Sortino: 1.271
# [I 2025-12-15 16:19:53,056] Trial 97 finished with value: -1.27100818754821 and parameters: {'ema1': 2, 'ema2': 39, 'ema3': 108}. Best is trial 34 with value: -1.5812092815227645.
# Trial 99: EMA(5,36,115) → Sortino: 1.320
# [I 2025-12-15 16:19:53,172] Trial 98 finished with value: -1.320400689260642 and parameters: {'ema1': 5, 'ema2': 36, 'ema3': 115}. Best is trial 34 with value: -1.5812092815227645.
# Trial 100: EMA(3,30,122) → Sortino: 1.525
# [I 2025-12-15 16:19:53,302] Trial 99 finished with value: -1.5247527882160374 and parameters: {'ema1': 3, 'ema2': 30, 'ema3': 122}. Best is trial 34 with value: -1.5812092815227645.
# Trial 101: EMA(3,30,122) → Sortino: 1.525
# [I 2025-12-15 16:19:53,450] Trial 100 finished with value: -1.5247527882160374 and parameters: {'ema1': 3, 'ema2': 30, 'ema3': 122}. Best is trial 34 with value: -1.5812092815227645.
# Trial 102: EMA(2,30,122) → Sortino: 1.252
# [I 2025-12-15 16:19:53,565] Trial 101 finished with value: -1.2515939910974305 and parameters: {'ema1': 2, 'ema2': 30, 'ema3': 122}. Best is trial 34 with value: -1.5812092815227645.
# Trial 103: EMA(4,32,117) → Sortino: 1.630
# [I 2025-12-15 16:19:53,684] Trial 102 finished with value: -1.6295666551291588 and parameters: {'ema1': 4, 'ema2': 32, 'ema3': 117}. Best is trial 102 with value: -1.6295666551291588.
# Trial 104: EMA(4,31,120) → Sortino: 1.479
# [I 2025-12-15 16:19:53,811] Trial 103 finished with value: -1.4791553610096604 and parameters: {'ema1': 4, 'ema2': 31, 'ema3': 120}. Best is trial 102 with value: -1.6295666551291588.
# Trial 105: EMA(4,32,117) → Sortino: 1.630
# [I 2025-12-15 16:19:53,948] Trial 104 finished with value: -1.6295666551291588 and parameters: {'ema1': 4, 'ema2': 32, 'ema3': 117}. Best is trial 102 with value: -1.6295666551291588.
# Trial 106: EMA(3,30,117) → Sortino: 1.557
# [I 2025-12-15 16:19:54,059] Trial 105 finished with value: -1.5567611018768803 and parameters: {'ema1': 3, 'ema2': 30, 'ema3': 117}. Best is trial 102 with value: -1.6295666551291588.
# Trial 107: EMA(1,81,128) → Sortino: 0.764
# [I 2025-12-15 16:19:54,168] Trial 106 finished with value: -0.7641845148601453 and parameters: {'ema1': 1, 'ema2': 81, 'ema3': 128}. Best is trial 102 with value: -1.6295666551291588.
# Trial 108: EMA(2,34,118) → Sortino: 1.200
# [I 2025-12-15 16:19:54,367] Trial 107 finished with value: -1.2004680300851016 and parameters: {'ema1': 2, 'ema2': 34, 'ema3': 118}. Best is trial 102 with value: -1.6295666551291588.
# Trial 109: EMA(3,37,112) → Sortino: 1.449
# [I 2025-12-15 16:19:54,512] Trial 108 finished with value: -1.4492726639850844 and parameters: {'ema1': 3, 'ema2': 37, 'ema3': 112}. Best is trial 102 with value: -1.6295666551291588.
# Trial 110: EMA(5,32,117) → Sortino: 1.340
# [I 2025-12-15 16:19:54,635] Trial 109 finished with value: -1.3404853233029488 and parameters: {'ema1': 5, 'ema2': 32, 'ema3': 117}. Best is trial 102 with value: -1.6295666551291588.
# Trial 111: EMA(4,32,112) → Sortino: 1.522
# [I 2025-12-15 16:19:54,758] Trial 110 finished with value: -1.5218065469402662 and parameters: {'ema1': 4, 'ema2': 32, 'ema3': 112}. Best is trial 102 with value: -1.6295666551291588.
# Trial 112: EMA(3,30,123) → Sortino: 1.457
# [I 2025-12-15 16:19:54,871] Trial 111 finished with value: -1.4570218360291822 and parameters: {'ema1': 3, 'ema2': 30, 'ema3': 123}. Best is trial 102 with value: -1.6295666551291588.
# Trial 113: EMA(2,30,121) → Sortino: 1.186
# [I 2025-12-15 16:19:54,988] Trial 112 finished with value: -1.1861098586855754 and parameters: {'ema1': 2, 'ema2': 30, 'ema3': 121}. Best is trial 102 with value: -1.6295666551291588.
# Trial 114: EMA(3,34,115) → Sortino: 1.490
# [I 2025-12-15 16:19:55,097] Trial 113 finished with value: -1.4895110695879845 and parameters: {'ema1': 3, 'ema2': 34, 'ema3': 115}. Best is trial 102 with value: -1.6295666551291588.
# Trial 115: EMA(1,31,131) → Sortino: 1.334
# [I 2025-12-15 16:19:55,205] Trial 114 finished with value: -1.3339378801006843 and parameters: {'ema1': 1, 'ema2': 31, 'ema3': 131}. Best is trial 102 with value: -1.6295666551291588.
# Trial 116: EMA(5,32,119) → Sortino: 1.286
# [I 2025-12-15 16:19:55,310] Trial 115 finished with value: -1.2859279965216333 and parameters: {'ema1': 5, 'ema2': 32, 'ema3': 119}. Best is trial 102 with value: -1.6295666551291588.
# Trial 117: EMA(6,36,124) → Sortino: 1.456
# [I 2025-12-15 16:19:55,421] Trial 116 finished with value: -1.4561896784732784 and parameters: {'ema1': 6, 'ema2': 36, 'ema3': 124}. Best is trial 102 with value: -1.6295666551291588.
# Trial 118: EMA(3,38,108) → Sortino: 1.463
# [I 2025-12-15 16:19:55,585] Trial 117 finished with value: -1.4626335669230195 and parameters: {'ema1': 3, 'ema2': 38, 'ema3': 108}. Best is trial 102 with value: -1.6295666551291588.
# Trial 119: EMA(4,34,116) → Sortino: 1.609
# [I 2025-12-15 16:19:55,727] Trial 118 finished with value: -1.608907229513998 and parameters: {'ema1': 4, 'ema2': 34, 'ema3': 116}. Best is trial 102 with value: -1.6295666551291588.
# Trial 120: EMA(4,40,163) → Sortino: 1.272
# [I 2025-12-15 16:19:55,835] Trial 119 finished with value: -1.2724295407671375 and parameters: {'ema1': 4, 'ema2': 40, 'ema3': 163}. Best is trial 102 with value: -1.6295666551291588.
# Trial 121: EMA(2,42,114) → Sortino: 1.289
# [I 2025-12-15 16:19:55,988] Trial 120 finished with value: -1.2893567330944562 and parameters: {'ema1': 2, 'ema2': 42, 'ema3': 114}. Best is trial 102 with value: -1.6295666551291588.
# Trial 122: EMA(3,34,117) → Sortino: 1.396
# [I 2025-12-15 16:19:56,129] Trial 121 finished with value: -1.396407207186365 and parameters: {'ema1': 3, 'ema2': 34, 'ema3': 117}. Best is trial 102 with value: -1.6295666551291588.
# Trial 123: EMA(4,35,112) → Sortino: 1.245
# [I 2025-12-15 16:19:56,263] Trial 122 finished with value: -1.2448631109124604 and parameters: {'ema1': 4, 'ema2': 35, 'ema3': 112}. Best is trial 102 with value: -1.6295666551291588.
# Trial 124: EMA(5,32,110) → Sortino: 1.379
# [I 2025-12-15 16:19:56,369] Trial 123 finished with value: -1.3793582045215118 and parameters: {'ema1': 5, 'ema2': 32, 'ema3': 110}. Best is trial 102 with value: -1.6295666551291588.
# Trial 125: EMA(4,37,116) → Sortino: 1.591
# [I 2025-12-15 16:19:56,479] Trial 124 finished with value: -1.5908711951431629 and parameters: {'ema1': 4, 'ema2': 37, 'ema3': 116}. Best is trial 102 with value: -1.6295666551291588.
# Trial 126: EMA(6,36,116) → Sortino: 1.308
# [I 2025-12-15 16:19:56,589] Trial 125 finished with value: -1.3084049939326263 and parameters: {'ema1': 6, 'ema2': 36, 'ema3': 116}. Best is trial 102 with value: -1.6295666551291588.
# Trial 127: EMA(4,38,158) → Sortino: 1.438
# [I 2025-12-15 16:19:56,699] Trial 126 finished with value: -1.4380241080837943 and parameters: {'ema1': 4, 'ema2': 38, 'ema3': 158}. Best is trial 102 with value: -1.6295666551291588.
# Trial 128: EMA(1,44,102) → Sortino: 0.919
# [I 2025-12-15 16:19:56,803] Trial 127 finished with value: -0.9190718783967033 and parameters: {'ema1': 1, 'ema2': 44, 'ema3': 102}. Best is trial 102 with value: -1.6295666551291588.
# Trial 129: EMA(2,76,120) → Sortino: 0.688
# [I 2025-12-15 16:19:56,917] Trial 128 finished with value: -0.6876584322062245 and parameters: {'ema1': 2, 'ema2': 76, 'ema3': 120}. Best is trial 102 with value: -1.6295666551291588.
# Trial 130: EMA(4,40,114) → Sortino: 1.364
# [I 2025-12-15 16:19:57,022] Trial 129 finished with value: -1.3637246733507213 and parameters: {'ema1': 4, 'ema2': 40, 'ema3': 114}. Best is trial 102 with value: -1.6295666551291588.
# Trial 131: EMA(3,37,107) → Sortino: 1.440
# [I 2025-12-15 16:19:57,131] Trial 130 finished with value: -1.4404120287067996 and parameters: {'ema1': 3, 'ema2': 37, 'ema3': 107}. Best is trial 102 with value: -1.6295666551291588.
# Trial 132: EMA(3,33,125) → Sortino: 1.218
# [I 2025-12-15 16:19:57,241] Trial 131 finished with value: -1.2182695753863622 and parameters: {'ema1': 3, 'ema2': 33, 'ema3': 125}. Best is trial 102 with value: -1.6295666551291588.
# Trial 133: EMA(4,42,122) → Sortino: 1.193
# [I 2025-12-15 16:19:57,353] Trial 132 finished with value: -1.193262314939948 and parameters: {'ema1': 4, 'ema2': 42, 'ema3': 122}. Best is trial 102 with value: -1.6295666551291588.
# Trial 134: EMA(5,30,117) → Sortino: 1.223
# [I 2025-12-15 16:19:57,465] Trial 133 finished with value: -1.222654934237793 and parameters: {'ema1': 5, 'ema2': 30, 'ema3': 117}. Best is trial 102 with value: -1.6295666551291588.
# Trial 135: EMA(2,34,110) → Sortino: 1.344
# [I 2025-12-15 16:19:57,574] Trial 134 finished with value: -1.344161863958958 and parameters: {'ema1': 2, 'ema2': 34, 'ema3': 110}. Best is trial 102 with value: -1.6295666551291588.
# Trial 136: EMA(20,39,119) → Sortino: 0.647
# [I 2025-12-15 16:19:57,685] Trial 135 finished with value: -0.6471033612508988 and parameters: {'ema1': 20, 'ema2': 39, 'ema3': 119}. Best is trial 102 with value: -1.6295666551291588.
# Trial 137: EMA(3,33,113) → Sortino: 1.358
# [I 2025-12-15 16:19:57,795] Trial 136 finished with value: -1.3578720918512583 and parameters: {'ema1': 3, 'ema2': 33, 'ema3': 113}. Best is trial 102 with value: -1.6295666551291588.
# Trial 138: EMA(1,36,127) → Sortino: 1.154
# [I 2025-12-15 16:19:57,905] Trial 137 finished with value: -1.1542387410029737 and parameters: {'ema1': 1, 'ema2': 36, 'ema3': 127}. Best is trial 102 with value: -1.6295666551291588.
# Trial 139: EMA(2,30,115) → Sortino: 1.400
# [I 2025-12-15 16:19:58,016] Trial 138 finished with value: -1.4001512474231852 and parameters: {'ema1': 2, 'ema2': 30, 'ema3': 115}. Best is trial 102 with value: -1.6295666551291588.
# Trial 140: EMA(4,35,105) → Sortino: 1.198
# [I 2025-12-15 16:19:58,126] Trial 139 finished with value: -1.1980474760329871 and parameters: {'ema1': 4, 'ema2': 35, 'ema3': 105}. Best is trial 102 with value: -1.6295666551291588.
# Trial 141: EMA(5,46,109) → Sortino: 1.566
# [I 2025-12-15 16:19:58,234] Trial 140 finished with value: -1.565729397541904 and parameters: {'ema1': 5, 'ema2': 46, 'ema3': 109}. Best is trial 102 with value: -1.6295666551291588.
# Trial 142: EMA(4,47,109) → Sortino: 1.495
# [I 2025-12-15 16:19:58,351] Trial 141 finished with value: -1.4946439417490018 and parameters: {'ema1': 4, 'ema2': 47, 'ema3': 109}. Best is trial 102 with value: -1.6295666551291588.
# Trial 143: EMA(3,41,117) → Sortino: 1.481
# [I 2025-12-15 16:19:58,462] Trial 142 finished with value: -1.480599284561222 and parameters: {'ema1': 3, 'ema2': 41, 'ema3': 117}. Best is trial 102 with value: -1.6295666551291588.
# Trial 144: EMA(5,43,112) → Sortino: 1.496
# [I 2025-12-15 16:19:58,570] Trial 143 finished with value: -1.4961728314735392 and parameters: {'ema1': 5, 'ema2': 43, 'ema3': 112}. Best is trial 102 with value: -1.6295666551291588.
# Trial 145: EMA(15,38,107) → Sortino: 0.740
# [I 2025-12-15 16:19:58,680] Trial 144 finished with value: -0.73952896922977 and parameters: {'ema1': 15, 'ema2': 38, 'ema3': 107}. Best is trial 102 with value: -1.6295666551291588.
# Trial 146: EMA(2,32,121) → Sortino: 1.171
# [I 2025-12-15 16:19:58,788] Trial 145 finished with value: -1.1709940423374972 and parameters: {'ema1': 2, 'ema2': 32, 'ema3': 121}. Best is trial 102 with value: -1.6295666551291588.
# Trial 147: EMA(5,39,114) → Sortino: 1.362
# [I 2025-12-15 16:19:58,896] Trial 146 finished with value: -1.3624459704631726 and parameters: {'ema1': 5, 'ema2': 39, 'ema3': 114}. Best is trial 102 with value: -1.6295666551291588.
# Trial 148: EMA(6,44,148) → Sortino: 1.610
# [I 2025-12-15 16:19:59,003] Trial 147 finished with value: -1.6098737267495815 and parameters: {'ema1': 6, 'ema2': 44, 'ema3': 148}. Best is trial 102 with value: -1.6295666551291588.
# Trial 149: EMA(6,45,147) → Sortino: 1.458
# [I 2025-12-15 16:19:59,120] Trial 148 finished with value: -1.4584417235713811 and parameters: {'ema1': 6, 'ema2': 45, 'ema3': 147}. Best is trial 102 with value: -1.6295666551291588.
# Trial 150: EMA(4,46,111) → Sortino: 1.409
# [I 2025-12-15 16:19:59,258] Trial 149 finished with value: -1.4094368353142797 and parameters: {'ema1': 4, 'ema2': 46, 'ema3': 111}. Best is trial 102 with value: -1.6295666551291588.
# Trial 151: EMA(5,44,149) → Sortino: 1.429
# [I 2025-12-15 16:19:59,375] Trial 150 finished with value: -1.4293578520631294 and parameters: {'ema1': 5, 'ema2': 44, 'ema3': 149}. Best is trial 102 with value: -1.6295666551291588.
# Trial 152: EMA(7,42,175) → Sortino: 1.149
# [I 2025-12-15 16:19:59,481] Trial 151 finished with value: -1.1489735350949963 and parameters: {'ema1': 7, 'ema2': 42, 'ema3': 175}. Best is trial 102 with value: -1.6295666551291588.
# Trial 153: EMA(3,40,119) → Sortino: 1.374
# [I 2025-12-15 16:19:59,587] Trial 152 finished with value: -1.3737034660065341 and parameters: {'ema1': 3, 'ema2': 40, 'ema3': 119}. Best is trial 102 with value: -1.6295666551291588.
# Trial 154: EMA(3,37,116) → Sortino: 1.510
# [I 2025-12-15 16:19:59,697] Trial 153 finished with value: -1.5103579871693709 and parameters: {'ema1': 3, 'ema2': 37, 'ema3': 116}. Best is trial 102 with value: -1.6295666551291588.
# Trial 155: EMA(4,32,123) → Sortino: 1.440
# [I 2025-12-15 16:19:59,803] Trial 154 finished with value: -1.4400865217990138 and parameters: {'ema1': 4, 'ema2': 32, 'ema3': 123}. Best is trial 102 with value: -1.6295666551291588.
# Trial 156: EMA(2,43,108) → Sortino: 1.203
# [I 2025-12-15 16:19:59,915] Trial 155 finished with value: -1.2030218863228843 and parameters: {'ema1': 2, 'ema2': 43, 'ema3': 108}. Best is trial 102 with value: -1.6295666551291588.
# Trial 157: EMA(4,35,113) → Sortino: 1.285
# [I 2025-12-15 16:20:00,025] Trial 156 finished with value: -1.2847500061474055 and parameters: {'ema1': 4, 'ema2': 35, 'ema3': 113}. Best is trial 102 with value: -1.6295666551291588.
# Trial 158: EMA(3,31,166) → Sortino: 1.862
# [I 2025-12-15 16:20:00,131] Trial 157 finished with value: -1.8622682689177488 and parameters: {'ema1': 3, 'ema2': 31, 'ema3': 166}. Best is trial 157 with value: -1.8622682689177488.
# Trial 159: EMA(6,40,165) → Sortino: 1.104
# [I 2025-12-15 16:20:00,242] Trial 158 finished with value: -1.1042425688885644 and parameters: {'ema1': 6, 'ema2': 40, 'ema3': 165}. Best is trial 157 with value: -1.8622682689177488.
# Trial 160: EMA(3,34,104) → Sortino: 1.289
# [I 2025-12-15 16:20:00,353] Trial 159 finished with value: -1.2887739886618197 and parameters: {'ema1': 3, 'ema2': 34, 'ema3': 104}. Best is trial 157 with value: -1.8622682689177488.
# Trial 161: EMA(5,37,181) → Sortino: 1.084
# [I 2025-12-15 16:20:00,462] Trial 160 finished with value: -1.0838005487227078 and parameters: {'ema1': 5, 'ema2': 37, 'ema3': 181}. Best is trial 157 with value: -1.8622682689177488.
# Trial 162: EMA(3,31,111) → Sortino: 1.690
# [I 2025-12-15 16:20:00,652] Trial 161 finished with value: -1.69022248638063 and parameters: {'ema1': 3, 'ema2': 31, 'ema3': 111}. Best is trial 157 with value: -1.8622682689177488.
# Trial 163: EMA(2,31,111) → Sortino: 1.592
# [I 2025-12-15 16:20:00,794] Trial 162 finished with value: -1.592052221259312 and parameters: {'ema1': 2, 'ema2': 31, 'ema3': 111}. Best is trial 157 with value: -1.8622682689177488.
# Trial 164: EMA(2,32,110) → Sortino: 1.414
# [I 2025-12-15 16:20:00,900] Trial 163 finished with value: -1.4136771406475868 and parameters: {'ema1': 2, 'ema2': 32, 'ema3': 110}. Best is trial 157 with value: -1.8622682689177488.
# Trial 165: EMA(1,31,111) → Sortino: 1.002
# [I 2025-12-15 16:20:01,007] Trial 164 finished with value: -1.0019444592190418 and parameters: {'ema1': 1, 'ema2': 31, 'ema3': 111}. Best is trial 157 with value: -1.8622682689177488.
# Trial 166: EMA(3,34,107) → Sortino: 1.420
# [I 2025-12-15 16:20:01,113] Trial 165 finished with value: -1.4199657942529353 and parameters: {'ema1': 3, 'ema2': 34, 'ema3': 107}. Best is trial 157 with value: -1.8622682689177488.
# Trial 167: EMA(4,33,168) → Sortino: 1.278
# [I 2025-12-15 16:20:01,223] Trial 166 finished with value: -1.2779346781781618 and parameters: {'ema1': 4, 'ema2': 33, 'ema3': 168}. Best is trial 157 with value: -1.8622682689177488.
# Trial 168: EMA(2,60,159) → Sortino: 1.147
# [I 2025-12-15 16:20:01,333] Trial 167 finished with value: -1.146518477348577 and parameters: {'ema1': 2, 'ema2': 60, 'ema3': 159}. Best is trial 157 with value: -1.8622682689177488.
# Trial 169: EMA(4,36,172) → Sortino: 1.261
# [I 2025-12-15 16:20:01,437] Trial 168 finished with value: -1.2614628967869446 and parameters: {'ema1': 4, 'ema2': 36, 'ema3': 172}. Best is trial 157 with value: -1.8622682689177488.
# Trial 170: EMA(3,41,153) → Sortino: 1.286
# [I 2025-12-15 16:20:01,549] Trial 169 finished with value: -1.2857931754050176 and parameters: {'ema1': 3, 'ema2': 41, 'ema3': 153}. Best is trial 157 with value: -1.8622682689177488.
# Trial 171: EMA(2,39,109) → Sortino: 1.336
# [I 2025-12-15 16:20:01,660] Trial 170 finished with value: -1.3362889006093102 and parameters: {'ema1': 2, 'ema2': 39, 'ema3': 109}. Best is trial 157 with value: -1.8622682689177488.
# Trial 172: EMA(3,31,114) → Sortino: 1.739
# [I 2025-12-15 16:20:01,766] Trial 171 finished with value: -1.7392390279303864 and parameters: {'ema1': 3, 'ema2': 31, 'ema3': 114}. Best is trial 157 with value: -1.8622682689177488.
# Trial 173: EMA(3,31,114) → Sortino: 1.739
# [I 2025-12-15 16:20:01,871] Trial 172 finished with value: -1.7392390279303864 and parameters: {'ema1': 3, 'ema2': 31, 'ema3': 114}. Best is trial 157 with value: -1.8622682689177488.
# Trial 174: EMA(3,31,114) → Sortino: 1.739
# [I 2025-12-15 16:20:01,977] Trial 173 finished with value: -1.7392390279303864 and parameters: {'ema1': 3, 'ema2': 31, 'ema3': 114}. Best is trial 157 with value: -1.8622682689177488.
# Trial 175: EMA(4,31,114) → Sortino: 1.663
# [I 2025-12-15 16:20:02,090] Trial 174 finished with value: -1.6633497001474362 and parameters: {'ema1': 4, 'ema2': 31, 'ema3': 114}. Best is trial 157 with value: -1.8622682689177488.
# Trial 176: EMA(4,31,113) → Sortino: 1.648
# [I 2025-12-15 16:20:02,195] Trial 175 finished with value: -1.6478657972476456 and parameters: {'ema1': 4, 'ema2': 31, 'ema3': 113}. Best is trial 157 with value: -1.8622682689177488.
# Trial 177: EMA(5,31,114) → Sortino: 1.371
# [I 2025-12-15 16:20:02,299] Trial 176 finished with value: -1.3707149787263155 and parameters: {'ema1': 5, 'ema2': 31, 'ema3': 114}. Best is trial 157 with value: -1.8622682689177488.
# Trial 178: EMA(4,32,112) → Sortino: 1.522
# [I 2025-12-15 16:20:02,402] Trial 177 finished with value: -1.5218065469402662 and parameters: {'ema1': 4, 'ema2': 32, 'ema3': 112}. Best is trial 157 with value: -1.8622682689177488.
# Trial 179: EMA(4,33,115) → Sortino: 1.502
# [I 2025-12-15 16:20:02,506] Trial 178 finished with value: -1.5024585838344553 and parameters: {'ema1': 4, 'ema2': 33, 'ema3': 115}. Best is trial 157 with value: -1.8622682689177488.
# Trial 180: EMA(5,31,113) → Sortino: 1.371
# [I 2025-12-15 16:20:02,614] Trial 179 finished with value: -1.3707149787263155 and parameters: {'ema1': 5, 'ema2': 31, 'ema3': 113}. Best is trial 157 with value: -1.8622682689177488.
# Trial 181: EMA(6,30,116) → Sortino: 1.421
# [I 2025-12-15 16:20:02,724] Trial 180 finished with value: -1.4210959823246634 and parameters: {'ema1': 6, 'ema2': 30, 'ema3': 116}. Best is trial 157 with value: -1.8622682689177488.
# Trial 182: EMA(3,33,111) → Sortino: 1.402
# [I 2025-12-15 16:20:02,833] Trial 181 finished with value: -1.402211903078121 and parameters: {'ema1': 3, 'ema2': 33, 'ema3': 111}. Best is trial 157 with value: -1.8622682689177488.
# Trial 183: EMA(28,31,114) → Sortino: 0.363
# [I 2025-12-15 16:20:02,939] Trial 182 finished with value: -0.3632000702980753 and parameters: {'ema1': 28, 'ema2': 31, 'ema3': 114}. Best is trial 157 with value: -1.8622682689177488.
# Trial 184: EMA(4,34,156) → Sortino: 1.537
# [I 2025-12-15 16:20:03,049] Trial 183 finished with value: -1.5370084781733895 and parameters: {'ema1': 4, 'ema2': 34, 'ema3': 156}. Best is trial 157 with value: -1.8622682689177488.
# Trial 185: EMA(2,30,118) → Sortino: 1.335
# [I 2025-12-15 16:20:03,163] Trial 184 finished with value: -1.3351222106759861 and parameters: {'ema1': 2, 'ema2': 30, 'ema3': 118}. Best is trial 157 with value: -1.8622682689177488.
# Trial 186: EMA(4,32,110) → Sortino: 1.554
# [I 2025-12-15 16:20:03,274] Trial 185 finished with value: -1.5535582677091262 and parameters: {'ema1': 4, 'ema2': 32, 'ema3': 110}. Best is trial 157 with value: -1.8622682689177488.
# Trial 187: EMA(3,35,112) → Sortino: 1.423
# [I 2025-12-15 16:20:03,396] Trial 186 finished with value: -1.4225634799959572 and parameters: {'ema1': 3, 'ema2': 35, 'ema3': 112}. Best is trial 157 with value: -1.8622682689177488.
# Trial 188: EMA(5,33,106) → Sortino: 1.355
# [I 2025-12-15 16:20:03,509] Trial 187 finished with value: -1.3554398376167685 and parameters: {'ema1': 5, 'ema2': 33, 'ema3': 106}. Best is trial 157 with value: -1.8622682689177488.
# Trial 189: EMA(1,31,115) → Sortino: 1.102
# [I 2025-12-15 16:20:03,622] Trial 188 finished with value: -1.102270030657466 and parameters: {'ema1': 1, 'ema2': 31, 'ema3': 115}. Best is trial 157 with value: -1.8622682689177488.
# Trial 190: EMA(2,32,109) → Sortino: 1.368
# [I 2025-12-15 16:20:03,735] Trial 189 finished with value: -1.3675432422141658 and parameters: {'ema1': 2, 'ema2': 32, 'ema3': 109}. Best is trial 157 with value: -1.8622682689177488.
# Trial 191: EMA(4,30,117) → Sortino: 1.646
# [I 2025-12-15 16:20:03,850] Trial 190 finished with value: -1.646365833939872 and parameters: {'ema1': 4, 'ema2': 30, 'ema3': 117}. Best is trial 157 with value: -1.8622682689177488.
# Trial 192: EMA(4,30,117) → Sortino: 1.646
# [I 2025-12-15 16:20:03,967] Trial 191 finished with value: -1.646365833939872 and parameters: {'ema1': 4, 'ema2': 30, 'ema3': 117}. Best is trial 157 with value: -1.8622682689177488.
# Trial 193: EMA(18,30,117) → Sortino: 0.417
# [I 2025-12-15 16:20:04,075] Trial 192 finished with value: -0.4174264420254543 and parameters: {'ema1': 18, 'ema2': 30, 'ema3': 117}. Best is trial 157 with value: -1.8622682689177488.
# Trial 194: EMA(4,30,119) → Sortino: 1.418
# [I 2025-12-15 16:20:04,362] Trial 193 finished with value: -1.4175726471006451 and parameters: {'ema1': 4, 'ema2': 30, 'ema3': 119}. Best is trial 157 with value: -1.8622682689177488.
# Trial 195: EMA(4,32,187) → Sortino: 1.363
# [I 2025-12-15 16:20:04,496] Trial 194 finished with value: -1.363208460528062 and parameters: {'ema1': 4, 'ema2': 32, 'ema3': 187}. Best is trial 157 with value: -1.8622682689177488.
# Trial 196: EMA(5,34,116) → Sortino: 1.387
# [I 2025-12-15 16:20:04,630] Trial 195 finished with value: -1.386637944120059 and parameters: {'ema1': 5, 'ema2': 34, 'ema3': 116}. Best is trial 157 with value: -1.8622682689177488.
# Trial 197: EMA(3,32,113) → Sortino: 1.534
# [I 2025-12-15 16:20:04,748] Trial 196 finished with value: -1.5338450382205675 and parameters: {'ema1': 3, 'ema2': 32, 'ema3': 113}. Best is trial 157 with value: -1.8622682689177488.
# Trial 198: EMA(4,31,118) → Sortino: 1.486
# [I 2025-12-15 16:20:04,864] Trial 197 finished with value: -1.4858078770593501 and parameters: {'ema1': 4, 'ema2': 31, 'ema3': 118}. Best is trial 157 with value: -1.8622682689177488.
# Trial 199: EMA(3,30,115) → Sortino: 1.652
# [I 2025-12-15 16:20:05,015] Trial 198 finished with value: -1.6517354859600901 and parameters: {'ema1': 3, 'ema2': 30, 'ema3': 115}. Best is trial 157 with value: -1.8622682689177488.
# Trial 200: EMA(5,30,120) → Sortino: 1.162
# [I 2025-12-15 16:20:05,129] Trial 199 finished with value: -1.1622339067590026 and parameters: {'ema1': 5, 'ema2': 30, 'ema3': 120}. Best is trial 157 with value: -1.8622682689177488.
# Trial 201: EMA(10,33,115) → Sortino: 1.257
# [I 2025-12-15 16:20:05,248] Trial 200 finished with value: -1.257133276204507 and parameters: {'ema1': 10, 'ema2': 33, 'ema3': 115}. Best is trial 157 with value: -1.8622682689177488.
# Trial 202: EMA(3,30,113) → Sortino: 1.638
# [I 2025-12-15 16:20:05,354] Trial 201 finished with value: -1.6380744749240788 and parameters: {'ema1': 3, 'ema2': 30, 'ema3': 113}. Best is trial 157 with value: -1.8622682689177488.
# Trial 203: EMA(3,30,114) → Sortino: 1.690
# [I 2025-12-15 16:20:05,466] Trial 202 finished with value: -1.6901922822839135 and parameters: {'ema1': 3, 'ema2': 30, 'ema3': 114}. Best is trial 157 with value: -1.8622682689177488.
# Trial 204: EMA(3,30,116) → Sortino: 1.652
# [I 2025-12-15 16:20:05,573] Trial 203 finished with value: -1.6517354859600901 and parameters: {'ema1': 3, 'ema2': 30, 'ema3': 116}. Best is trial 157 with value: -1.8622682689177488.
# Trial 205: EMA(3,31,117) → Sortino: 1.606
# [I 2025-12-15 16:20:05,682] Trial 204 finished with value: -1.6057037605383337 and parameters: {'ema1': 3, 'ema2': 31, 'ema3': 117}. Best is trial 157 with value: -1.8622682689177488.
# Trial 206: EMA(2,30,117) → Sortino: 1.337
# [I 2025-12-15 16:20:05,808] Trial 205 finished with value: -1.3369519037089095 and parameters: {'ema1': 2, 'ema2': 30, 'ema3': 117}. Best is trial 157 with value: -1.8622682689177488.
# Trial 207: EMA(3,30,114) → Sortino: 1.690
# [I 2025-12-15 16:20:05,934] Trial 206 finished with value: -1.6901922822839135 and parameters: {'ema1': 3, 'ema2': 30, 'ema3': 114}. Best is trial 157 with value: -1.8622682689177488.
# Trial 208: EMA(3,30,114) → Sortino: 1.690
# [I 2025-12-15 16:20:06,038] Trial 207 finished with value: -1.6901922822839135 and parameters: {'ema1': 3, 'ema2': 30, 'ema3': 114}. Best is trial 157 with value: -1.8622682689177488.
# Trial 209: EMA(3,30,114) → Sortino: 1.690
# [I 2025-12-15 16:20:06,144] Trial 208 finished with value: -1.6901922822839135 and parameters: {'ema1': 3, 'ema2': 30, 'ema3': 114}. Best is trial 157 with value: -1.8622682689177488.
# Trial 210: EMA(3,30,114) → Sortino: 1.690
# [I 2025-12-15 16:20:06,258] Trial 209 finished with value: -1.6901922822839135 and parameters: {'ema1': 3, 'ema2': 30, 'ema3': 114}. Best is trial 157 with value: -1.8622682689177488.
# Trial 211: EMA(3,30,114) → Sortino: 1.690
# [I 2025-12-15 16:20:06,366] Trial 210 finished with value: -1.6901922822839135 and parameters: {'ema1': 3, 'ema2': 30, 'ema3': 114}. Best is trial 157 with value: -1.8622682689177488.
# Trial 212: EMA(3,30,114) → Sortino: 1.690
# ...
# Trial 931: EMA(4,30,182) → Sortino: 1.380
# [I 2025-12-15 16:21:36,878] Trial 930 finished with value: -1.3802134754964153 and parameters: {'ema1': 4, 'ema2': 30, 'ema3': 182}. Best is trial 533 with value: -1.9515508795482708.
# Trial 932: EMA(1,33,129) → Sortino: 1.188
# [I 2025-12-15 16:21:36,993] Trial 931 finished with value: -1.18812612740581 and parameters: {'ema1': 1, 'ema2': 33, 'ema3': 129}. Best is trial 533 with value: -1.9515508795482708.
# Trial 933: EMA(16,31,184) → Sortino: 0.599
# [I 2025-12-15 16:21:37,117] Trial 932 finished with value: -0.5985283873790385 and parameters: {'ema1': 16, 'ema2': 31, 'ema3': 184}. Best is trial 533 with value: -1.9515508795482708.
# Trial 934: EMA(2,32,187) → Sortino: 1.860
# [I 2025-12-15 16:21:37,242] Trial 933 finished with value: -1.8602959268699495 and parameters: {'ema1': 2, 'ema2': 32, 'ema3': 187}. Best is trial 533 with value: -1.9515508795482708.
# Trial 935: EMA(2,30,185) → Sortino: 1.950
# [I 2025-12-15 16:21:37,363] Trial 934 finished with value: -1.9503651912913074 and parameters: {'ema1': 2, 'ema2': 30, 'ema3': 185}. Best is trial 533 with value: -1.9515508795482708.
# Trial 936: EMA(3,31,188) → Sortino: 1.573
# [I 2025-12-15 16:21:37,487] Trial 935 finished with value: -1.5731020521767272 and parameters: {'ema1': 3, 'ema2': 31, 'ema3': 188}. Best is trial 533 with value: -1.9515508795482708.
# Trial 937: EMA(2,44,186) → Sortino: 1.854
# [I 2025-12-15 16:21:37,615] Trial 936 finished with value: -1.8542572187631017 and parameters: {'ema1': 2, 'ema2': 44, 'ema3': 186}. Best is trial 533 with value: -1.9515508795482708.
# Trial 938: EMA(3,30,186) → Sortino: 1.547
# [I 2025-12-15 16:21:37,744] Trial 937 finished with value: -1.5467545233186668 and parameters: {'ema1': 3, 'ema2': 30, 'ema3': 186}. Best is trial 533 with value: -1.9515508795482708.
# Trial 939: EMA(1,30,182) → Sortino: 1.763
# [I 2025-12-15 16:21:37,868] Trial 938 finished with value: -1.7633624168147553 and parameters: {'ema1': 1, 'ema2': 30, 'ema3': 182}. Best is trial 533 with value: -1.9515508795482708.
# Trial 940: EMA(2,30,142) → Sortino: 1.413
# [I 2025-12-15 16:21:37,991] Trial 939 finished with value: -1.4128273709890127 and parameters: {'ema1': 2, 'ema2': 30, 'ema3': 142}. Best is trial 533 with value: -1.9515508795482708.
# Trial 941: EMA(3,30,188) → Sortino: 1.547
# [I 2025-12-15 16:21:38,115] Trial 940 finished with value: -1.5467545233186668 and parameters: {'ema1': 3, 'ema2': 30, 'ema3': 188}. Best is trial 533 with value: -1.9515508795482708.
# Trial 942: EMA(1,31,148) → Sortino: 1.622
# [I 2025-12-15 16:21:38,243] Trial 941 finished with value: -1.62191836298366 and parameters: {'ema1': 1, 'ema2': 31, 'ema3': 148}. Best is trial 533 with value: -1.9515508795482708.
# Trial 943: EMA(2,30,185) → Sortino: 1.950
# [I 2025-12-15 16:21:38,389] Trial 942 finished with value: -1.9503651912913074 and parameters: {'ema1': 2, 'ema2': 30, 'ema3': 185}. Best is trial 533 with value: -1.9515508795482708.
# Trial 944: EMA(2,30,188) → Sortino: 1.902
# [I 2025-12-15 16:21:38,515] Trial 943 finished with value: -1.9017692720037536 and parameters: {'ema1': 2, 'ema2': 30, 'ema3': 188}. Best is trial 533 with value: -1.9515508795482708.
# Trial 945: EMA(5,30,186) → Sortino: 1.023
# [I 2025-12-15 16:21:38,645] Trial 944 finished with value: -1.0231331627650049 and parameters: {'ema1': 5, 'ema2': 30, 'ema3': 186}. Best is trial 533 with value: -1.9515508795482708.
# Trial 946: EMA(3,30,155) → Sortino: 1.533
# [I 2025-12-15 16:21:38,769] Trial 945 finished with value: -1.5331514798418997 and parameters: {'ema1': 3, 'ema2': 30, 'ema3': 155}. Best is trial 533 with value: -1.9515508795482708.
# Trial 947: EMA(1,30,185) → Sortino: 1.674
# [I 2025-12-15 16:21:38,899] Trial 946 finished with value: -1.674362610793465 and parameters: {'ema1': 1, 'ema2': 30, 'ema3': 185}. Best is trial 533 with value: -1.9515508795482708.
# Trial 948: EMA(2,31,183) → Sortino: 1.826
# [I 2025-12-15 16:21:39,023] Trial 947 finished with value: -1.8261523908332242 and parameters: {'ema1': 2, 'ema2': 31, 'ema3': 183}. Best is trial 533 with value: -1.9515508795482708.
# Trial 949: EMA(2,30,188) → Sortino: 1.902
# [I 2025-12-15 16:21:39,146] Trial 948 finished with value: -1.9017692720037536 and parameters: {'ema1': 2, 'ema2': 30, 'ema3': 188}. Best is trial 533 with value: -1.9515508795482708.
# Trial 950: EMA(3,32,179) → Sortino: 1.421
# [I 2025-12-15 16:21:39,277] Trial 949 finished with value: -1.4213871762239452 and parameters: {'ema1': 3, 'ema2': 32, 'ema3': 179}. Best is trial 533 with value: -1.9515508795482708.
# Trial 951: EMA(1,32,185) → Sortino: 1.708
# [I 2025-12-15 16:21:39,398] Trial 950 finished with value: -1.7082382912339917 and parameters: {'ema1': 1, 'ema2': 32, 'ema3': 185}. Best is trial 533 with value: -1.9515508795482708.
# Trial 952: EMA(2,30,182) → Sortino: 1.825
# [I 2025-12-15 16:21:39,528] Trial 951 finished with value: -1.825035821384372 and parameters: {'ema1': 2, 'ema2': 30, 'ema3': 182}. Best is trial 533 with value: -1.9515508795482708.
# Trial 953: EMA(3,31,187) → Sortino: 1.573
# [I 2025-12-15 16:21:39,723] Trial 952 finished with value: -1.5731020521767272 and parameters: {'ema1': 3, 'ema2': 31, 'ema3': 187}. Best is trial 533 with value: -1.9515508795482708.
# Trial 954: EMA(1,32,185) → Sortino: 1.708
# [I 2025-12-15 16:21:39,896] Trial 953 finished with value: -1.7082382912339917 and parameters: {'ema1': 1, 'ema2': 32, 'ema3': 185}. Best is trial 533 with value: -1.9515508795482708.
# Trial 955: EMA(29,30,181) → Sortino: 0.279
# [I 2025-12-15 16:21:40,018] Trial 954 finished with value: -0.2787859462915221 and parameters: {'ema1': 29, 'ema2': 30, 'ema3': 181}. Best is trial 533 with value: -1.9515508795482708.
# Trial 956: EMA(2,33,183) → Sortino: 1.753
# [I 2025-12-15 16:21:40,142] Trial 955 finished with value: -1.753262417932232 and parameters: {'ema1': 2, 'ema2': 33, 'ema3': 183}. Best is trial 533 with value: -1.9515508795482708.
# Trial 957: EMA(2,31,187) → Sortino: 1.903
# [I 2025-12-15 16:21:40,290] Trial 956 finished with value: -1.9029362661133482 and parameters: {'ema1': 2, 'ema2': 31, 'ema3': 187}. Best is trial 533 with value: -1.9515508795482708.
# Trial 958: EMA(1,30,184) → Sortino: 1.763
# [I 2025-12-15 16:21:40,414] Trial 957 finished with value: -1.7633624168147553 and parameters: {'ema1': 1, 'ema2': 30, 'ema3': 184}. Best is trial 533 with value: -1.9515508795482708.
# Trial 959: EMA(3,32,188) → Sortino: 1.434
# [I 2025-12-15 16:21:40,543] Trial 958 finished with value: -1.4342787465141527 and parameters: {'ema1': 3, 'ema2': 32, 'ema3': 188}. Best is trial 533 with value: -1.9515508795482708.
# Trial 960: EMA(2,31,180) → Sortino: 1.826
# [I 2025-12-15 16:21:40,666] Trial 959 finished with value: -1.8261523908332242 and parameters: {'ema1': 2, 'ema2': 31, 'ema3': 180}. Best is trial 533 with value: -1.9515508795482708.
# Trial 961: EMA(4,30,186) → Sortino: 1.380
# [I 2025-12-15 16:21:40,789] Trial 960 finished with value: -1.3802134754964153 and parameters: {'ema1': 4, 'ema2': 30, 'ema3': 186}. Best is trial 533 with value: -1.9515508795482708.
# Trial 962: EMA(3,33,138) → Sortino: 1.276
# [I 2025-12-15 16:21:40,919] Trial 961 finished with value: -1.2759355501090273 and parameters: {'ema1': 3, 'ema2': 33, 'ema3': 138}. Best is trial 533 with value: -1.9515508795482708.
# Trial 963: EMA(1,32,183) → Sortino: 1.798
# [I 2025-12-15 16:21:41,044] Trial 962 finished with value: -1.7977199101221042 and parameters: {'ema1': 1, 'ema2': 32, 'ema3': 183}. Best is trial 533 with value: -1.9515508795482708.
# Trial 964: EMA(2,30,185) → Sortino: 1.950
# [I 2025-12-15 16:21:41,169] Trial 963 finished with value: -1.9503651912913074 and parameters: {'ema1': 2, 'ema2': 30, 'ema3': 185}. Best is trial 533 with value: -1.9515508795482708.
# Trial 965: EMA(2,30,178) → Sortino: 1.825
# [I 2025-12-15 16:21:41,296] Trial 964 finished with value: -1.825035821384372 and parameters: {'ema1': 2, 'ema2': 30, 'ema3': 178}. Best is trial 533 with value: -1.9515508795482708.
# Trial 966: EMA(11,30,181) → Sortino: 1.069
# [I 2025-12-15 16:21:41,426] Trial 965 finished with value: -1.069470764401608 and parameters: {'ema1': 11, 'ema2': 30, 'ema3': 181}. Best is trial 533 with value: -1.9515508795482708.
# Trial 967: EMA(1,30,184) → Sortino: 1.763
# [I 2025-12-15 16:21:41,558] Trial 966 finished with value: -1.7633624168147553 and parameters: {'ema1': 1, 'ema2': 30, 'ema3': 184}. Best is trial 533 with value: -1.9515508795482708.
# Trial 968: EMA(2,30,182) → Sortino: 1.825
# [I 2025-12-15 16:21:41,685] Trial 967 finished with value: -1.825035821384372 and parameters: {'ema1': 2, 'ema2': 30, 'ema3': 182}. Best is trial 533 with value: -1.9515508795482708.
# Trial 969: EMA(3,31,185) → Sortino: 1.573
# [I 2025-12-15 16:21:41,812] Trial 968 finished with value: -1.5731020521767272 and parameters: {'ema1': 3, 'ema2': 31, 'ema3': 185}. Best is trial 533 with value: -1.9515508795482708.
# Trial 970: EMA(4,59,188) → Sortino: 0.887
# [I 2025-12-15 16:21:41,935] Trial 969 finished with value: -0.8874103797438256 and parameters: {'ema1': 4, 'ema2': 59, 'ema3': 188}. Best is trial 533 with value: -1.9515508795482708.
# Trial 971: EMA(1,31,183) → Sortino: 1.814
# [I 2025-12-15 16:21:42,086] Trial 970 finished with value: -1.8143317873283338 and parameters: {'ema1': 1, 'ema2': 31, 'ema3': 183}. Best is trial 533 with value: -1.9515508795482708.
# Trial 972: EMA(2,30,186) → Sortino: 1.950
# [I 2025-12-15 16:21:42,211] Trial 971 finished with value: -1.9503651912913074 and parameters: {'ema1': 2, 'ema2': 30, 'ema3': 186}. Best is trial 533 with value: -1.9515508795482708.
# Trial 973: EMA(3,30,188) → Sortino: 1.547
# [I 2025-12-15 16:21:42,332] Trial 972 finished with value: -1.5467545233186668 and parameters: {'ema1': 3, 'ema2': 30, 'ema3': 188}. Best is trial 533 with value: -1.9515508795482708.
# Trial 974: EMA(3,30,186) → Sortino: 1.547
# [I 2025-12-15 16:21:42,459] Trial 973 finished with value: -1.5467545233186668 and parameters: {'ema1': 3, 'ema2': 30, 'ema3': 186}. Best is trial 533 with value: -1.9515508795482708.
# Trial 975: EMA(2,30,188) → Sortino: 1.902
# [I 2025-12-15 16:21:42,586] Trial 974 finished with value: -1.9017692720037536 and parameters: {'ema1': 2, 'ema2': 30, 'ema3': 188}. Best is trial 533 with value: -1.9515508795482708.
# Trial 976: EMA(1,31,186) → Sortino: 1.771
# [I 2025-12-15 16:21:42,718] Trial 975 finished with value: -1.7707634933226943 and parameters: {'ema1': 1, 'ema2': 31, 'ema3': 186}. Best is trial 533 with value: -1.9515508795482708.
# Trial 977: EMA(2,32,185) → Sortino: 1.909
# [I 2025-12-15 16:21:42,849] Trial 976 finished with value: -1.9089511786785216 and parameters: {'ema1': 2, 'ema2': 32, 'ema3': 185}. Best is trial 533 with value: -1.9515508795482708.
# Trial 978: EMA(2,30,188) → Sortino: 1.902
# [I 2025-12-15 16:21:42,974] Trial 977 finished with value: -1.9017692720037536 and parameters: {'ema1': 2, 'ema2': 30, 'ema3': 188}. Best is trial 533 with value: -1.9515508795482708.
# Trial 979: EMA(1,32,184) → Sortino: 1.798
# [I 2025-12-15 16:21:43,098] Trial 978 finished with value: -1.7977199101221042 and parameters: {'ema1': 1, 'ema2': 32, 'ema3': 184}. Best is trial 533 with value: -1.9515508795482708.
# Trial 980: EMA(3,30,181) → Sortino: 1.579
# [I 2025-12-15 16:21:43,220] Trial 979 finished with value: -1.5789508626547861 and parameters: {'ema1': 3, 'ema2': 30, 'ema3': 181}. Best is trial 533 with value: -1.9515508795482708.
# Trial 981: EMA(2,33,186) → Sortino: 1.877
# [I 2025-12-15 16:21:43,348] Trial 980 finished with value: -1.8774387021335386 and parameters: {'ema1': 2, 'ema2': 33, 'ema3': 186}. Best is trial 533 with value: -1.9515508795482708.
# Trial 982: EMA(4,31,183) → Sortino: 1.394
# [I 2025-12-15 16:21:43,473] Trial 981 finished with value: -1.3937155568055306 and parameters: {'ema1': 4, 'ema2': 31, 'ema3': 183}. Best is trial 533 with value: -1.9515508795482708.
# Trial 983: EMA(3,30,188) → Sortino: 1.547
# [I 2025-12-15 16:21:43,624] Trial 982 finished with value: -1.5467545233186668 and parameters: {'ema1': 3, 'ema2': 30, 'ema3': 188}. Best is trial 533 with value: -1.9515508795482708.
# Trial 984: EMA(1,32,186) → Sortino: 1.754
# [I 2025-12-15 16:21:43,746] Trial 983 finished with value: -1.754088997808458 and parameters: {'ema1': 1, 'ema2': 32, 'ema3': 186}. Best is trial 533 with value: -1.9515508795482708.
# Trial 985: EMA(2,33,180) → Sortino: 1.753
# [I 2025-12-15 16:21:43,867] Trial 984 finished with value: -1.753262417932232 and parameters: {'ema1': 2, 'ema2': 33, 'ema3': 180}. Best is trial 533 with value: -1.9515508795482708.
# Trial 986: EMA(26,31,184) → Sortino: 0.391
# [I 2025-12-15 16:21:43,990] Trial 985 finished with value: -0.39053579834059465 and parameters: {'ema1': 26, 'ema2': 31, 'ema3': 184}. Best is trial 533 with value: -1.9515508795482708.
# Trial 987: EMA(2,30,182) → Sortino: 1.825
# [I 2025-12-15 16:21:44,115] Trial 986 finished with value: -1.825035821384372 and parameters: {'ema1': 2, 'ema2': 30, 'ema3': 182}. Best is trial 533 with value: -1.9515508795482708.
# Trial 988: EMA(1,32,188) → Sortino: 1.754
# [I 2025-12-15 16:21:44,246] Trial 987 finished with value: -1.754088997808458 and parameters: {'ema1': 1, 'ema2': 32, 'ema3': 188}. Best is trial 533 with value: -1.9515508795482708.
# Trial 989: EMA(21,30,186) → Sortino: 0.346
# [I 2025-12-15 16:21:44,370] Trial 988 finished with value: -0.34553326872263984 and parameters: {'ema1': 21, 'ema2': 30, 'ema3': 186}. Best is trial 533 with value: -1.9515508795482708.
# Trial 990: EMA(3,32,177) → Sortino: 1.421
# [I 2025-12-15 16:21:44,502] Trial 989 finished with value: -1.4213871762239452 and parameters: {'ema1': 3, 'ema2': 32, 'ema3': 177}. Best is trial 533 with value: -1.9515508795482708.
# Trial 991: EMA(2,30,184) → Sortino: 1.950
# [I 2025-12-15 16:21:44,635] Trial 990 finished with value: -1.9503651912913074 and parameters: {'ema1': 2, 'ema2': 30, 'ema3': 184}. Best is trial 533 with value: -1.9515508795482708.
# Trial 992: EMA(3,33,186) → Sortino: 1.304
# [I 2025-12-15 16:21:44,760] Trial 991 finished with value: -1.304052957313339 and parameters: {'ema1': 3, 'ema2': 33, 'ema3': 186}. Best is trial 533 with value: -1.9515508795482708.
# Trial 993: EMA(2,84,182) → Sortino: 1.402
# [I 2025-12-15 16:21:44,890] Trial 992 finished with value: -1.4023242733657564 and parameters: {'ema1': 2, 'ema2': 84, 'ema3': 182}. Best is trial 533 with value: -1.9515508795482708.
# Trial 994: EMA(4,31,188) → Sortino: 1.460
# [I 2025-12-15 16:21:45,014] Trial 993 finished with value: -1.4596447758815325 and parameters: {'ema1': 4, 'ema2': 31, 'ema3': 188}. Best is trial 533 with value: -1.9515508795482708.
# Trial 995: EMA(1,30,184) → Sortino: 1.763
# [I 2025-12-15 16:21:45,142] Trial 994 finished with value: -1.7633624168147553 and parameters: {'ema1': 1, 'ema2': 30, 'ema3': 184}. Best is trial 533 with value: -1.9515508795482708.
# Trial 996: EMA(20,33,180) → Sortino: 0.426
# [I 2025-12-15 16:21:45,264] Trial 995 finished with value: -0.42602752974890895 and parameters: {'ema1': 20, 'ema2': 33, 'ema3': 180}. Best is trial 533 with value: -1.9515508795482708.
# Trial 997: EMA(1,32,186) → Sortino: 1.754
# [I 2025-12-15 16:21:45,390] Trial 996 finished with value: -1.754088997808458 and parameters: {'ema1': 1, 'ema2': 32, 'ema3': 186}. Best is trial 533 with value: -1.9515508795482708.
# Trial 998: EMA(2,31,183) → Sortino: 1.826
# [I 2025-12-15 16:21:45,526] Trial 997 finished with value: -1.8261523908332242 and parameters: {'ema1': 2, 'ema2': 31, 'ema3': 183}. Best is trial 533 with value: -1.9515508795482708.
# Trial 999: EMA(3,30,188) → Sortino: 1.547
# [I 2025-12-15 16:21:45,655] Trial 998 finished with value: -1.5467545233186668 and parameters: {'ema1': 3, 'ema2': 30, 'ema3': 188}. Best is trial 533 with value: -1.9515508795482708.
# Trial 1000: EMA(2,32,185) → Sortino: 1.909
# [I 2025-12-15 16:21:45,781] Trial 999 finished with value: -1.9089511786785216 and parameters: {'ema1': 2, 'ema2': 32, 'ema3': 185}. Best is trial 533 with value: -1.9515508795482708.
#
# ✅ Optimization complete!
# Best Parameters: EMA(2,31,185)
# Sortino Ratio: 1.952

# %%
# Display Results

if 'results_df' in globals() and not results_df.empty:
    best = results_df.iloc[0]
    
    print("OPTIMIZATION RESULTS:")
    print("=" * 50)
    print(f"Best Parameters:")
    print(f"  EMA1 (Fast): {int(best['ema1_period'])}")
    print(f"  EMA2 (Medium): {int(best['ema2_period'])}")
    print(f"  EMA3 (Slow): {int(best['ema3_period'])}")
    
    print("\nPerformance Metrics:")
    print(f"  Total Return: {best['total_return']:.2%}")
    print(f"  Sharpe Ratio: {best['sharpe_ratio']:.3f}")
    print(f"  Sortino Ratio: {best['sortino_ratio']:.3f}")
    print(f"  Max Drawdown: {best['max_drawdown']:.2%}")
    print(f"  Total Trades: {int(best['total_trades'])}")
    print(f"  Win Rate: {best['win_rate']:.1f}%")
    print(f"  Profit Factor: {best['profit_factor']:.2f}")
else:
    print("⚠️ No results found. Run optimization first.")
# Out:
# OPTIMIZATION RESULTS:
# ==================================================
# Best Parameters:
#   EMA1 (Fast): 2
#   EMA2 (Medium): 31
#   EMA3 (Slow): 185
#
# Performance Metrics:
#   Total Return: 246.49%
#   Sharpe Ratio: 1.209
#   Sortino Ratio: 1.952
#   Max Drawdown: -27.53%
#   Total Trades: 39
#   Win Rate: 35.9%
#   Profit Factor: 3.43

# %%
# BENCHMARK ANALYSIS: Best Strategy vs Market (Buy & Hold) - ENHANCED

if 'results_df' in globals() and not results_df.empty:
    best = results_df.iloc[0]
    ema1, ema2, ema3 = int(best['ema1_period']), int(best['ema2_period']), int(best['ema3_period'])

    print(f"BENCHMARK ANALYSIS: Best EMA({ema1},{ema2},{ema3}) vs Buy & Hold")
    print("=" * 70)

    # Recreate the BEST strategy portfolio to get returns
    ema1_ma = vbt.MA.run(train_close, ema1, ewm=True)
    ema2_ma = vbt.MA.run(train_close, ema2, ewm=True)
    ema3_ma = vbt.MA.run(train_close, ema3, ewm=True)

    # Triple EMA crossover signals
    entries = (
        ema1_ma.ma_crossed_above(ema2_ma.ma) |
        ema1_ma.ma_crossed_above(ema3_ma.ma) |
        ema2_ma.ma_crossed_above(ema3_ma.ma)
    )
    exits = (
        ema1_ma.ma_crossed_below(ema2_ma.ma) |
        ema1_ma.ma_crossed_below(ema3_ma.ma) |
        ema2_ma.ma_crossed_below(ema3_ma.ma)
    )

    best_pf = vbt.Portfolio.from_signals(
        close=train_close,
        entries=entries,
        exits=exits,
        init_cash=100_000,
        fees=0.0005,
        slippage=0.0005,
        freq='D'
    )

    # Create buy & hold benchmark
    benchmark_entries = np.zeros(len(train_close), dtype=bool)
    benchmark_entries[0] = True
    benchmark_exits = np.zeros(len(train_close), dtype=bool)

    benchmark_pf = vbt.Portfolio.from_signals(
        close=train_close,
        entries=benchmark_entries,
        exits=benchmark_exits,
        init_cash=100_000,
        fees=0.0005,
        freq='D'
    )

    # Get returns for comparison
    strategy_returns = best_pf.returns().dropna()
    benchmark_returns = benchmark_pf.returns().dropna()

    # Benchmark metrics
    bench_total_return = benchmark_pf.total_return()
    bench_annualized_return = benchmark_pf.annualized_return(freq='D')
    bench_sharpe = benchmark_pf.sharpe_ratio(freq='D')
    bench_sortino = benchmark_pf.sortino_ratio(freq='D')
    bench_max_drawdown = benchmark_pf.max_drawdown()
    bench_volatility = benchmark_pf.annualized_volatility(freq='D')

    # Strategy annualized return
    strategy_annualized_return = best['annualized_return']

    # Performance comparison
    print("\nPERFORMANCE COMPARISON:")
    print(f"Strategy (EMA {ema1},{ema2},{ema3}):")
    print(f"  Total Return:      {best['total_return']:.2%}")
    print(f"  Annualized Return: {strategy_annualized_return:.2%}")
    print(f"  Sharpe Ratio:      {best['sharpe_ratio']:.3f}")
    print(f"  Sortino Ratio:     {best['sortino_ratio']:.3f}")
    print(f"  Max Drawdown:      {best['max_drawdown']:.2%}")
    print(f"  Volatility:        {best['volatility']:.2%}")
    print(f"  Total Trades:      {best['total_trades']}")
    print(f"  Win Rate:          {best['win_rate']:.1f}%")
    print(f"  Profit Factor:     {best['profit_factor']:.2f}")

    print(f"\nBenchmark (Buy & Hold {TICKER}):")
    print(f"  Total Return:      {bench_total_return:.2%}")
    print(f"  Annualized Return: {bench_annualized_return:.2%}")
    print(f"  Sharpe Ratio:      {bench_sharpe:.3f}")
    print(f"  Sortino Ratio:     {bench_sortino:.3f}")
    print(f"  Max Drawdown:      {bench_max_drawdown:.2%}")
    print(f"  Volatility:        {bench_volatility:.2%}")

    # Outperformance metrics
    excess_return = best['total_return'] - bench_total_return
    excess_annualized_return = strategy_annualized_return - bench_annualized_return
    sharpe_diff = best['sharpe_ratio'] - bench_sharpe
    sortino_diff = best['sortino_ratio'] - bench_sortino
    excess_max_drawdown = best['max_drawdown'] - bench_max_drawdown

    print(f"\nOUTPERFORMANCE METRICS:")
    print(f"  Excess Return:           {excess_return:.2%}")
    print(f"  Excess Annualized Return: {excess_annualized_return:.2%}")
    print(f"  Sharpe Difference:       {sharpe_diff:.3f}")
    print(f"  Sortino Difference:      {sortino_diff:.3f}")
    print(f"  Excess Max Drawdown:      {excess_max_drawdown:.2%} ({'Better' if excess_max_drawdown > 0 else '❌ Worse'})")
    
    # Calculate beta
    market_beta = best['volatility'] / bench_volatility if bench_volatility != 0 else np.nan
    print(f"  Market Beta (approx):     {market_beta:.3f} ({'Lower risk' if market_beta < 1 else '⚠️ Higher risk'})")
else:
    print("⚠️ No results available for benchmark analysis.")
# Out:
# BENCHMARK ANALYSIS: Best EMA(2,31,185) vs Buy & Hold
# ======================================================================
#
# PERFORMANCE COMPARISON:
# Strategy (EMA 2,31,185):
#   Total Return:      246.49%
#   Annualized Return: 29.86%
#   Sharpe Ratio:      1.209
#   Sortino Ratio:     1.952
#   Max Drawdown:      -27.53%
#   Volatility:        36.88%
#   Total Trades:      39.0
#   Win Rate:          35.9%
#   Profit Factor:     3.43
#
# Benchmark (Buy & Hold XOP):
#   Total Return:      1.48%
#   Annualized Return: 0.45%
#   Sharpe Ratio:      0.314
#   Sortino Ratio:     0.446
#   Max Drawdown:      -82.61%
#   Volatility:        59.69%
#
# OUTPERFORMANCE METRICS:
#   Excess Return:           245.01%
#   Excess Annualized Return: 29.42%
#   Sharpe Difference:       0.894
#   Sortino Difference:      1.506
#   Excess Max Drawdown:      55.07% (Better)
#   Market Beta (approx):     0.618 (Lower risk)

# %%
# IN-SAMPLE vs OUT-OF-SAMPLE COMPARISON

FREQ = "1D"

if 'results_df' in globals() and not results_df.empty:
    best = results_df.iloc[0]
    ema1, ema2, ema3 = int(best['ema1_period']), int(best['ema2_period']), int(best['ema3_period'])

    # Out-of-sample validation
    ema1_val = vbt.MA.run(val_close, ema1, ewm=True).ma
    ema2_val = vbt.MA.run(val_close, ema2, ewm=True).ma
    ema3_val = vbt.MA.run(val_close, ema3, ewm=True).ma

    # Triple EMA crossover signals
    entries_val = (
        ema1_val.vbt.crossed_above(ema2_val) |
        ema1_val.vbt.crossed_above(ema3_val) |
        ema2_val.vbt.crossed_above(ema3_val)
    )
    exits_val = (
        ema1_val.vbt.crossed_below(ema2_val) |
        ema1_val.vbt.crossed_below(ema3_val) |
        ema2_val.vbt.crossed_below(ema3_val)
    )

    pf_val = vbt.Portfolio.from_signals(
        close=val_close,
        entries=entries_val,
        exits=exits_val,
        init_cash=100_000,
        fees=0.0005,
        slippage=0.0005,
        freq=FREQ
    )

    # Out-of-sample metrics
    val_total_return = pf_val.total_return()
    val_annualized_return = pf_val.annualized_return(freq=FREQ)
    val_sharpe = pf_val.sharpe_ratio(freq=FREQ)
    val_sortino = pf_val.sortino_ratio(freq=FREQ)
    val_max_drawdown = pf_val.max_drawdown()
    val_volatility = pf_val.annualized_volatility(freq=FREQ)

    trades_val = pf_val.trades
    val_total_trades = len(trades_val)
    years = max((val_close.index[-1] - val_close.index[0]).days / 365.25, 1e-9)
    val_trades_per_year = val_total_trades / years

    val_win_rate_pct = np.nan
    val_profit_factor = np.nan
    val_expectancy = 0.0
    if val_total_trades > 0:
        tr = trades_val.returns.values if hasattr(trades_val.returns, 'values') else np.array(trades_val.returns)
        if tr.size > 0:
            pos = tr[tr > 0]
            neg = tr[tr < 0]
            val_win_rate_pct = (len(pos) / len(tr)) * 100 if len(tr) > 0 else np.nan
            gains = pos.sum() if len(pos) else 0.0
            losses = abs(neg.sum()) if len(neg) else 0.0
            val_profit_factor = gains / losses if losses > 0 else np.inf
            val_expectancy = tr.mean()

    def chg(before, after):
        if pd.isna(before) or pd.isna(after) or before == 0:
            return "N/A"
        return f"{((after - before) / abs(before)) * 100:+.1f}%"

    print(f"IN-SAMPLE vs OUT-OF-SAMPLE COMPARISON: Best EMA({ema1},{ema2},{ema3})")
    print("=" * 80)

    print(f"{'METRIC':<25} {'IN-SAMPLE':<15} {'OUT-OF-SAMPLE':<15} {'DEGRADATION':<15}")

    print("\nRETURN METRICS:")
    print(f"{'Total Return':<25} {best['total_return']:<15.2%} {val_total_return:<15.2%} {chg(best['total_return'], val_total_return)}")
    print(f"{'Annualized Return':<25} {best['annualized_return']:<15.2%} {val_annualized_return:<15.2%} {chg(best['annualized_return'], val_annualized_return)}")

    print("\nRISK-ADJUSTED METRICS:")
    print(f"{'Sharpe Ratio':<25} {best['sharpe_ratio']:<15.3f} {val_sharpe:<15.3f} {chg(best['sharpe_ratio'], val_sharpe)}")
    print(f"{'Sortino Ratio':<25} {best['sortino_ratio']:<15.3f} {val_sortino:<15.3f} {chg(best['sortino_ratio'], val_sortino)}")

    print("\nRISK METRICS:")
    print(f"{'Max Drawdown':<25} {best['max_drawdown']:<15.2%} {val_max_drawdown:<15.2%} {chg(best['max_drawdown'], val_max_drawdown)}")
    print(f"{'Volatility':<25} {best['volatility']:<15.2%} {val_volatility:<15.2%} {chg(best['volatility'], val_volatility)}")

    print("\nTRADE METRICS:")
    print(f"{'Total Trades':<25} {best['total_trades']:<15.0f} {val_total_trades:<15.0f} {chg(best['total_trades'], val_total_trades)}")
    print(f"{'Trades per Year':<25} {best['trades_per_year']:<15.1f} {val_trades_per_year:<15.1f} {chg(best['trades_per_year'], val_trades_per_year)}")
    print(f"{'Win Rate %':<25} {best['win_rate']:<15.1f} {val_win_rate_pct:<15.1f} {chg(best['win_rate'], val_win_rate_pct)}")
    print(f"{'Profit Factor':<25} {best['profit_factor']:<15.2f} {val_profit_factor:<15.2f} {chg(best['profit_factor'], val_profit_factor)}")
    print(f"{'Expectancy':<25} {best['expectancy']:<15.4f} {val_expectancy:<15.4f} {chg(best['expectancy'], val_expectancy)}")
else:
    print("⚠️ No results for comparison.")
# Out:
# IN-SAMPLE vs OUT-OF-SAMPLE COMPARISON: Best EMA(2,31,185)
# ================================================================================
# METRIC                    IN-SAMPLE       OUT-OF-SAMPLE   DEGRADATION
#
# RETURN METRICS:
# Total Return              246.49%         -34.91%         -114.2%
# Annualized Return         29.86%          -17.79%         -159.6%
#
# RISK-ADJUSTED METRICS:
# Sharpe Ratio              1.209           -0.835          -169.1%
# Sortino Ratio             1.952           -1.057          -154.2%
#
# RISK METRICS:
# Max Drawdown              -27.53%         -38.53%         -39.9%
# Volatility                36.88%          20.84%          -43.5%
#
# TRADE METRICS:
# Total Trades              39              38              -2.6%
# Trades per Year           8.2             11.9            +45.2%
# Win Rate %                35.9            21.1            -41.4%
# Profit Factor             3.43            0.46            -86.6%
# Expectancy                0.0411          -0.0106         -125.8%

# %%
# OUT-OF-SAMPLE BENCHMARK COMPARISON

if 'results_df' in globals() and not results_df.empty:
    best = results_df.iloc[0]
    ema1, ema2, ema3 = int(best['ema1_period']), int(best['ema2_period']), int(best['ema3_period'])

    print(f"OUT-OF-SAMPLE BENCHMARK: Best EMA({ema1},{ema2},{ema3}) vs Buy & Hold")
    print("=" * 70)

    # Use validation data
    close_data = val_close
    
    # Recreate the BEST strategy portfolio
    ema1_ma = vbt.MA.run(close_data, ema1, ewm=True)
    ema2_ma = vbt.MA.run(close_data, ema2, ewm=True)
    ema3_ma = vbt.MA.run(close_data, ema3, ewm=True)

    entries_raw = (
        ema1_ma.ma_crossed_above(ema2_ma.ma) |
        ema1_ma.ma_crossed_above(ema3_ma.ma) |
        ema2_ma.ma_crossed_above(ema3_ma.ma)
    )
    exits_raw = (
        ema1_ma.ma_crossed_below(ema2_ma.ma) |
        ema1_ma.ma_crossed_below(ema3_ma.ma) |
        ema2_ma.ma_crossed_below(ema3_ma.ma)
    )
    
    entries = pd.Series(np.asarray(entries_raw).ravel(), index=close_data.index, dtype=bool)
    exits = pd.Series(np.asarray(exits_raw).ravel(), index=close_data.index, dtype=bool)

    strategy_pf = vbt.Portfolio.from_signals(
        close=close_data,
        entries=entries,
        exits=exits,
        init_cash=100_000,
        fees=0.0005,
        slippage=0.0005,
        freq='D'
    )

    # Buy & hold benchmark
    benchmark_entries = np.zeros(len(close_data), dtype=bool)
    benchmark_entries[0] = True
    benchmark_exits = np.zeros(len(close_data), dtype=bool)

    benchmark_pf = vbt.Portfolio.from_signals(
        close=close_data,
        entries=benchmark_entries,
        exits=benchmark_exits,
        init_cash=100_000,
        fees=0.0005,
        freq='D'
    )

    # Benchmark metrics
    bench_total_return = benchmark_pf.total_return()
    bench_annualized_return = benchmark_pf.annualized_return(freq='D')
    bench_sharpe = benchmark_pf.sharpe_ratio(freq='D')
    bench_sortino = benchmark_pf.sortino_ratio(freq='D')
    bench_max_drawdown = benchmark_pf.max_drawdown()
    bench_volatility = benchmark_pf.annualized_volatility(freq='D')

    # Strategy metrics
    trades_val = strategy_pf.trades
    val_total_trades = len(trades_val)
    years = max((close_data.index[-1] - close_data.index[0]).days / 365.25, 1e-9)
    
    val_win_rate_pct = np.nan
    val_profit_factor = np.nan
    val_expectancy = 0.0
    
    if val_total_trades > 0:
        tr = trades_val.returns.values if hasattr(trades_val.returns, 'values') else np.array(trades_val.returns)
        if tr.size > 0:
            pos = tr[tr > 0]
            neg = tr[tr < 0]
            val_win_rate_pct = (len(pos) / len(tr)) * 100 if len(tr) > 0 else np.nan
            gains = pos.sum() if len(pos) else 0.0
            losses = abs(neg.sum()) if len(neg) else 0.0
            val_profit_factor = gains / losses if losses > 0 else np.inf
            val_expectancy = tr.mean()

    strategy_total_return = strategy_pf.total_return()
    strategy_annualized_return = strategy_pf.annualized_return(freq='D')
    strategy_sharpe = strategy_pf.sharpe_ratio(freq='D')
    strategy_sortino = strategy_pf.sortino_ratio(freq='D')
    strategy_max_drawdown = strategy_pf.max_drawdown()
    strategy_volatility = strategy_pf.annualized_volatility(freq='D')

    # Performance comparison
    print(f"\n{'METRIC':<30} {'STRATEGY':<20} {'BUY & HOLD':<15} {'OUTPERFORMANCE':<15}")
    print("=" * 80)
    
    print(f"\nRETURN METRICS:")
    excess_return = strategy_total_return - bench_total_return
    print(f"{'Total Return':<30} {strategy_total_return:>20.2%} {bench_total_return:>15.2%} {excess_return:>+15.2%}")
    
    excess_annual = strategy_annualized_return - bench_annualized_return
    print(f"{'Annualized Return':<30} {strategy_annualized_return:>20.2%} {bench_annualized_return:>15.2%} {excess_annual:>+15.2%}")

    print(f"\nRISK-ADJUSTED METRICS:")
    excess_sharpe = strategy_sharpe - bench_sharpe
    print(f"{'Sharpe Ratio':<30} {strategy_sharpe:>20.3f} {bench_sharpe:>15.3f} {excess_sharpe:>+15.3f}")
    
    excess_sortino = strategy_sortino - bench_sortino
    print(f"{'Sortino Ratio':<30} {strategy_sortino:>20.3f} {bench_sortino:>15.3f} {excess_sortino:>+15.3f}")

    print(f"\nRISK METRICS:")
    excess_dd = strategy_max_drawdown - bench_max_drawdown
    print(f"{'Max Drawdown':<30} {strategy_max_drawdown:>20.2%} {bench_max_drawdown:>15.2%} {excess_dd:>+15.2%}")
    
    excess_vol = strategy_volatility - bench_volatility
    print(f"{'Volatility':<30} {strategy_volatility:>20.2%} {bench_volatility:>15.2%} {excess_vol:>+15.2%}")

    print(f"\nTRADE METRICS:")
    print(f"{'Total Trades':<30} {val_total_trades:>20.0f}")
    print(f"{'Win Rate %':<30} {val_win_rate_pct:>20.1f}")
    print(f"{'Profit Factor':<30} {val_profit_factor:>20.2f}")
    print(f"{'Expectancy':<30} {val_expectancy:>20.4f}")

    print(f"\n✅ Out-of-sample evaluation complete!")
    print(f"📊 Period: {close_data.index[0].date()} → {close_data.index[-1].date()}")
    
    # Summary verdict
    if strategy_total_return > bench_total_return and strategy_sharpe > bench_sharpe:
        print(f"🏆 Strategy OUTPERFORMS Buy & Hold on validation set!")
    elif strategy_total_return > bench_total_return:
        print(f"📈 Strategy has higher returns but Buy & Hold has better Sharpe")
    elif strategy_sharpe > bench_sharpe:
        print(f"💪 Strategy has better risk-adjusted returns despite lower total return")
    else:
        print(f"⚠️ Strategy underperforms Buy & Hold on validation set")
else:
    print("⚠️ No results available.")
# Out:
# OUT-OF-SAMPLE BENCHMARK: Best EMA(2,31,185) vs Buy & Hold
# ======================================================================
#
# METRIC                         STRATEGY             BUY & HOLD      OUTPERFORMANCE
# ================================================================================
#
# RETURN METRICS:
# Total Return                                -34.91%          -3.04%         -31.88%
# Annualized Return                           -17.79%          -1.40%         -16.40%
#
# RISK-ADJUSTED METRICS:
# Sharpe Ratio                                 -0.835           0.136          -0.971
# Sortino Ratio                                -1.057           0.185          -1.242
#
# RISK METRICS:
# Max Drawdown                                -38.53%         -34.98%          -3.55%
# Volatility                                   20.84%          35.06%         -14.22%
#
# TRADE METRICS:
# Total Trades                                     38
# Win Rate %                                     21.1
# Profit Factor                                  0.46
# Expectancy                                  -0.0106
#
# ✅ Out-of-sample evaluation complete!
# 📊 Period: 2022-10-06 → 2025-12-15
# ⚠️ Strategy underperforms Buy & Hold on validation set

# %%
# ROLLING SHARPE + DRAWDOWNS - BEST STRATEGY (FULL SAMPLE)

if 'results_df' in globals() and not results_df.empty:
    best = results_df.iloc[0]
    ema1, ema2, ema3 = int(best['ema1_period']), int(best['ema2_period']), int(best['ema3_period'])

    # Build full-sample Triple EMA signals
    ema1_full = vbt.MA.run(close, ema1, ewm=True).ma
    ema2_full = vbt.MA.run(close, ema2, ewm=True).ma
    ema3_full = vbt.MA.run(close, ema3, ewm=True).ma

    # Triple EMA crossover signals
    entries_full = (
        ema1_full.vbt.crossed_above(ema2_full) |
        ema1_full.vbt.crossed_above(ema3_full) |
        ema2_full.vbt.crossed_above(ema3_full)
    )
    exits_full = (
        ema1_full.vbt.crossed_below(ema2_full) |
        ema1_full.vbt.crossed_below(ema3_full) |
        ema2_full.vbt.crossed_below(ema3_full)
    )

    entries_full = entries_full.reindex(close.index).fillna(False).to_numpy(dtype=bool)
    exits_full = exits_full.reindex(close.index).fillna(False).to_numpy(dtype=bool)

    pf_full = vbt.Portfolio.from_signals(
        close=close.to_numpy(dtype=float),
        entries=entries_full,
        exits=exits_full,
        init_cash=100_000,
        fees=0.0005,
        slippage=0.0005,
        freq=FREQ
    )

    # Compute returns
    ret = pf_full.returns()

    # 1) Rolling Sharpe (252-day window)
    rolling_window = max(20, min(252, max(1, len(ret) // 4)))
    if len(ret) > rolling_window:
        rolling_sharpe = ret.rolling(window=rolling_window).apply(
            lambda x: (x.mean() * 252) / (x.std() * np.sqrt(252)) if x.std() and x.std() != 0 else np.nan,
            raw=False
        )

        plt.figure(figsize=(12, 5))
        plt.plot(rolling_sharpe.index, rolling_sharpe.values, linewidth=2, color='blue', alpha=0.85)
        plt.axhline(y=1.0, color='green', linestyle='--', alpha=0.6, label='Sharpe = 1.0')
        plt.axhline(y=0.5, color='orange', linestyle='--', alpha=0.6, label='Sharpe = 0.5')
        plt.axhline(y=0.0, color='red', linestyle='--', alpha=0.6, label='Sharpe = 0.0')
        plt.title(f'Rolling Sharpe (window={rolling_window}) - Best EMA({ema1},{ema2},{ema3}) Full Sample', fontsize=14, fontweight='bold')
        plt.xlabel('Date', fontsize=12)
        plt.ylabel('Rolling Sharpe Ratio', fontsize=12)
        plt.grid(True, alpha=0.3)
        plt.legend()
        plt.tight_layout()
        plt.show()
    else:
        print("⚠️ Not enough data for rolling Sharpe calculation.")

    # 2) Drawdowns (underwater)
    eq = (1 + ret).cumprod()
    peak = eq.cummax()
    dd = (eq - peak) / peak

    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 8), sharex=True)

    ax1.plot(eq.index, (eq - 1) * 100, color='black', linewidth=1.5, label='Cumulative Return %')
    ax1.plot(peak.index, (peak - 1) * 100, color='green', linewidth=1.0, alpha=0.7, label='Peak %')
    ax1.fill_between(eq.index, (eq - 1) * 100, (peak - 1) * 100, color='red', alpha=0.25, label='Drawdown Area')
    ax1.set_title(f'Cumulative Returns & Drawdowns - Best EMA({ema1},{ema2},{ema3}) Full Sample', fontsize=14, fontweight='bold')
    ax1.set_ylabel('Return (%)', fontsize=12)
    ax1.grid(True, alpha=0.3)
    ax1.legend()

    ax2.fill_between(dd.index, dd * 100, 0, color='red', alpha=0.7, label='Drawdown %')
    ax2.plot(dd.index, dd * 100, color='darkred', linewidth=1)
    ax2.set_title('Underwater Chart (Drawdown from Peak)', fontsize=13)
    ax2.set_xlabel('Date', fontsize=12)
    ax2.set_ylabel('Drawdown (%)', fontsize=12)
    ax2.grid(True, alpha=0.3)
    ax2.legend()

    plt.tight_layout()
    plt.show()

    print(f"✅ Rolling Sharpe and Drawdown analysis complete for best strategy: EMA({ema1},{ema2},{ema3})")
else:
    print("⚠️ No results to visualize.")
# Out:
# ✅ Rolling Sharpe and Drawdown analysis complete for best strategy: EMA(2,31,185)

# %%
# VISUALS: Signals + Equity Curves - BEST STRATEGY

if 'results_df' in globals() and not results_df.empty:
    best = results_df.iloc[0]
    ema1, ema2, ema3 = int(best['ema1_period']), int(best['ema2_period']), int(best['ema3_period'])

    # Build full sample EMAs and signals
    ema1_full = vbt.MA.run(close, ema1, ewm=True).ma
    ema2_full = vbt.MA.run(close, ema2, ewm=True).ma
    ema3_full = vbt.MA.run(close, ema3, ewm=True).ma

    # Triple EMA crossover signals
    entries_1 = ema1_full.vbt.crossed_above(ema2_full)
    entries_2 = ema1_full.vbt.crossed_above(ema3_full)
    entries_3 = ema2_full.vbt.crossed_above(ema3_full)
    entries_full = (entries_1 | entries_2 | entries_3)
    
    exits_1 = ema1_full.vbt.crossed_below(ema2_full)
    exits_2 = ema1_full.vbt.crossed_below(ema3_full)
    exits_3 = ema2_full.vbt.crossed_below(ema3_full)
    exits_full = (exits_1 | exits_2 | exits_3)

    entries_full = entries_full.reindex(close.index).fillna(False).to_numpy(dtype=bool)
    exits_full = exits_full.reindex(close.index).fillna(False).to_numpy(dtype=bool)

    # 1) Price + Triple EMAs + signals (full sample)
    fig, ax = plt.subplots(figsize=(14, 7))
    ax.plot(close.index, close.values, label='Close', color='black', linewidth=1.5, alpha=0.7)
    ax.plot(close.index, ema1_full.values, label=f'Fast EMA ({ema1})', color='blue', alpha=0.8, linewidth=1.2)
    ax.plot(close.index, ema2_full.values, label=f'Medium EMA ({ema2})', color='orange', alpha=0.8, linewidth=1.2)
    ax.plot(close.index, ema3_full.values, label=f'Slow EMA ({ema3})', color='purple', alpha=0.8, linewidth=1.2)

    buy_idx = close.index[entries_full]
    sell_idx = close.index[exits_full]
    ax.scatter(buy_idx, close.reindex(buy_idx).values, marker='^', color='green', s=80, label='Buy', zorder=5)
    ax.scatter(sell_idx, close.reindex(sell_idx).values, marker='v', color='red', s=80, label='Sell', zorder=5)

    ax.set_title(f'Best Triple EMA({ema1},{ema2},{ema3}) - Full Sample Signals', fontsize=14, fontweight='bold')
    ax.set_xlabel('Date', fontsize=12)
    ax.set_ylabel('Price', fontsize=12)
    ax.grid(True, alpha=0.3)
    ax.legend(loc='best')
    plt.tight_layout()
    plt.show()

    # 2) Equity curves: train / val / full
    price_full = close.to_numpy(dtype=float)
    entries_train = entries_full[:split_idx]
    exits_train = exits_full[:split_idx]
    entries_val = entries_full[split_idx:]
    exits_val = exits_full[split_idx:]

    pf_full = vbt.Portfolio.from_signals(
        close=price_full,
        entries=entries_full,
        exits=exits_full,
        init_cash=100_000,
        fees=0.0005,
        slippage=0.0005,
        freq=FREQ
    )

    pf_train = vbt.Portfolio.from_signals(
        close=train_close.to_numpy(dtype=float),
        entries=entries_train,
        exits=exits_train,
        init_cash=100_000,
        fees=0.0005,
        slippage=0.0005,
        freq=FREQ
    )

    pf_val2 = vbt.Portfolio.from_signals(
        close=val_close.to_numpy(dtype=float),
        entries=entries_val,
        exits=exits_val,
        init_cash=100_000,
        fees=0.0005,
        slippage=0.0005,
        freq=FREQ
    )

    eq_full = (1 + pf_full.returns()).cumprod()
    eq_train = (1 + pf_train.returns()).cumprod()
    eq_val = (1 + pf_val2.returns()).cumprod()

    fig, ax = plt.subplots(figsize=(14, 7))
    ax.plot(close.index, eq_full.values, label='Full Sample', color='black', linewidth=2)
    ax.plot(train_close.index, eq_train.values, label='Train (In-Sample)', color='blue', linewidth=1.5, alpha=0.8)
    ax.plot(val_close.index, eq_val.values, label='Validation (Out-of-Sample)', color='orange', linewidth=1.5, alpha=0.8)

    # Add vertical line to show train/val split
    ax.axvline(x=train_close.index[-1], color='red', linestyle='--', alpha=0.5, label='Train/Val Split')

    ax.set_title(f'Best Triple EMA({ema1},{ema2},{ema3}) - Equity Curves', fontsize=14, fontweight='bold')
    ax.set_xlabel('Date', fontsize=12)
    ax.set_ylabel('Cumulative Returns (normalized to 1)', fontsize=12)
    ax.grid(True, alpha=0.3)
    ax.legend(loc='best')
    plt.tight_layout()
    plt.show()

    print(f"✅ Visualizations complete for best strategy: EMA({ema1},{ema2},{ema3})")
else:
    print("⚠️ No results to visualize.")
# Out:
# ✅ Visualizations complete for best strategy: EMA(2,31,185)

# %%
# TRADE-BY-TRADE RETURNS (BAR) + CUMULATIVE PER-TRADE EQUITY

if 'results_df' not in globals() or results_df.empty:
    print("⚠️ No results available.")
else:
    best = results_df.iloc[0]
    ema1, ema2, ema3 = int(best['ema1_period']), int(best['ema2_period']), int(best['ema3_period'])

    # Resolve full close series
    full_close = close.astype(float)

    # Indicators
    ema1_full = vbt.MA.run(full_close, ema1, ewm=True)
    ema2_full = vbt.MA.run(full_close, ema2, ewm=True)
    ema3_full = vbt.MA.run(full_close, ema3, ewm=True)

    # Signals
    entries_raw = (
        ema1_full.ma_crossed_above(ema2_full.ma) |
        ema1_full.ma_crossed_above(ema3_full.ma) |
        ema2_full.ma_crossed_above(ema3_full.ma)
    )
    exits_raw = (
        ema1_full.ma_crossed_below(ema2_full.ma) |
        ema1_full.ma_crossed_below(ema3_full.ma) |
        ema2_full.ma_crossed_below(ema3_full.ma)
    )

    entries_full = pd.Series(np.asarray(entries_raw).ravel(), index=full_close.index, dtype=bool)
    exits_full = pd.Series(np.asarray(exits_raw).ravel(), index=full_close.index, dtype=bool)

    # Backtest
    pf_full = vbt.Portfolio.from_signals(
        close=full_close.to_numpy(dtype=float),
        entries=entries_full,
        exits=exits_full,
        init_cash=100_000,
        fees=0.0005,
        slippage=0.0005,
        freq='1D'
    )

    # Trade-by-trade returns
    trades = pf_full.trades
    trade_returns = trades.returns.values if hasattr(trades.returns, 'values') else np.asarray(trades.returns)
    trade_returns = np.asarray(trade_returns).ravel()

    if trade_returns.size == 0:
        print("No trades to plot.")
    else:
        # Calculate statistics
        winning_trades = trade_returns[trade_returns > 0]
        losing_trades = trade_returns[trade_returns < 0]

        total_trades = len(trade_returns)
        win_count = len(winning_trades)
        loss_count = len(losing_trades)
        win_rate = (win_count / total_trades * 100) if total_trades > 0 else 0

        avg_win_pct = (winning_trades.mean() * 100) if len(winning_trades) > 0 else 0
        avg_loss_pct = (losing_trades.mean() * 100) if len(losing_trades) > 0 else 0
        max_win_pct = (winning_trades.max() * 100) if len(winning_trades) > 0 else 0
        max_loss_pct = (losing_trades.min() * 100) if len(losing_trades) > 0 else 0

        print(f"Total trades plotted: {total_trades}")
        print(f"Win Rate: {win_rate:.1f}% ({win_count}W / {loss_count}L)")
        print(f"Avg Win: {avg_win_pct:.2f}% | Avg Loss: {avg_loss_pct:.2f}%")
        print(f"Max Win: {max_win_pct:.2f}% | Max Loss: {max_loss_pct:.2f}%")

        equity_per_trade = np.cumprod(1.0 + trade_returns)

        fig, axes = plt.subplots(2, 1, figsize=(14, 9), sharex=False)

        # Per-trade returns (%)
        x = np.arange(1, trade_returns.size + 1)
        colors = np.where(trade_returns >= 0, 'green', 'red')
        axes[0].bar(x, trade_returns * 100.0, color=colors, alpha=0.85, width=0.8)
        axes[0].axhline(0, color='black', linewidth=1, alpha=0.6)

        # Add statistics text box
        stats_text = (
            f'Win Rate: {win_rate:.1f}% ({win_count}W/{loss_count}L)\n'
            f'Avg Win: {avg_win_pct:.2f}% | Avg Loss: {avg_loss_pct:.2f}%\n'
            f'Max Win: {max_win_pct:.2f}% | Max Loss: {max_loss_pct:.2f}%'
        )
        axes[0].text(0.02, 0.98, stats_text, transform=axes[0].transAxes,
                    fontsize=10, verticalalignment='top',
                    bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.8))

        axes[0].set_title(f'Per-Trade Returns (%) - Triple EMA({ema1},{ema2},{ema3}) Full Sample',
                         fontsize=13, fontweight='bold')
        axes[0].set_ylabel('Return (%)')
        axes[0].grid(True, alpha=0.3)

        # Cumulative equity per trade
        axes[1].plot(x, equity_per_trade, color='black', linewidth=2)
        axes[1].set_title('Cumulative Equity per Trade (Trade Domain)', fontsize=13)
        axes[1].set_xlabel('Trade #')
        axes[1].set_ylabel('Equity (x)')
        axes[1].grid(True, alpha=0.3)

        plt.tight_layout()
        plt.show()
# Out:
# Total trades plotted: 82
# Win Rate: 28.0% (23W / 59L)
# Avg Win: 11.61% | Avg Loss: -2.71%
# Max Win: 67.27% | Max Loss: -10.09%

# %%
# PARAMETER SENSITIVITY TABLE (±15 lookbacks around BEST ema1, ema2, ema3)

if 'results_df' in globals() and not results_df.empty:
    best = results_df.iloc[0]
    ema1, ema2, ema3 = int(best['ema1_period']), int(best['ema2_period']), int(best['ema3_period'])

    print(f"🔬 Parameter Sensitivity Analysis for Best EMA({ema1},{ema2},{ema3})")
    print("=" * 80)

    # Create sensitivity ranges (±15 around each parameter)
    fast_candidates = list(range(max(2, ema1 - 15), ema1 + 16))
    medium_candidates = list(range(max(3, ema2 - 15), ema2 + 16))
    slow_candidates = list(range(max(4, ema3 - 15), ema3 + 16))

    # Test variations: vary one parameter at a time
    combos = ([(f, ema2, ema3) for f in fast_candidates] +
              [(ema1, m, ema3) for m in medium_candidates if m != ema2] +
              [(ema1, ema2, s) for s in slow_candidates if s != ema3])

    price_np = train_close.to_numpy(dtype=float)
    idx = train_close.index

    def series_to_np_bool(s: pd.Series) -> np.ndarray:
        return s.reindex(idx).fillna(False).astype(bool).to_numpy(dtype=bool)

    def eval_combo(e1: int, e2: int, e3: int) -> dict:
        fma = vbt.MA.run(train_close, e1, ewm=True).ma
        mma = vbt.MA.run(train_close, e2, ewm=True).ma
        sma = vbt.MA.run(train_close, e3, ewm=True).ma

        # Triple EMA crossover
        e = series_to_np_bool(
            (fma.vbt.crossed_above(mma) & (fma > sma)) |
            (mma.vbt.crossed_above(sma) & (fma > mma))
        )
        x = series_to_np_bool(
            (fma.vbt.crossed_below(mma) & (fma < sma)) |
            (mma.vbt.crossed_below(sma) & (fma < mma))
        )

        pf = vbt.Portfolio.from_signals(
            close=price_np, entries=e, exits=x,
            init_cash=100_000, fees=0.0005, slippage=0.0005, freq='1D'
        )

        total_return = float(pf.total_return())
        sharpe = float(pf.sharpe_ratio(freq='1D'))
        sortino = float(pf.sortino_ratio(freq='1D'))
        mdd = float(pf.max_drawdown())
        vol = float(pf.annualized_volatility(freq='1D'))

        trades = pf.trades
        ntr = len(trades)
        win_rate_pct = np.nan
        profit_factor = np.nan
        expectancy = 0.0
        if ntr > 0:
            tr = trades.returns.values if hasattr(trades.returns, 'values') else np.array(trades.returns)
            if tr.size > 0:
                pos = tr[tr > 0]
                neg = tr[tr < 0]
                win_rate_pct = (len(pos) / len(tr)) * 100 if len(tr) else np.nan
                gains = pos.sum() if len(pos) else 0.0
                losses = abs(neg.sum()) if len(neg) else 0.0
                profit_factor = gains / losses if losses > 0 else np.inf
                expectancy = float(tr.mean())

        return {
            'ema1': e1, 'ema2': e2, 'ema3': e3,
            'sharpe': sharpe, 'sortino': sortino,
            'total_return': total_return, 'max_drawdown': mdd, 'volatility': vol,
            'total_trades': ntr, 'win_rate_pct': win_rate_pct,
            'profit_factor': profit_factor, 'expectancy': expectancy
        }

    rows = []
    for combo in combos:
        try:
            rows.append(eval_combo(*combo))
        except Exception:
            pass

    if not rows:
        print("⚠️ No sensitivity results computed.")
    else:
        sens = pd.DataFrame(rows)

        # Show as a table
        cols = ['ema1','ema2','ema3','sharpe','sortino','total_return','max_drawdown','volatility',
                'total_trades','win_rate_pct','profit_factor','expectancy']
        sens_table = sens[cols].sort_values(['ema1','ema2','ema3'])

        print(f"\n📊 Sensitivity Results ({len(sens_table)} variations tested):\n")
        print(sens_table.to_string())

        # Compact variation summary
        metric_cols = ['sharpe','sortino','total_return','max_drawdown','volatility',
                       'win_rate_pct','profit_factor','expectancy']
        summary = sens_table[metric_cols].agg(['mean','std','min','max']).T

        print("\n📈 Sensitivity Summary (mean / std / min / max):")
        print(summary.round(4).to_string())

        # Highlight best performer in sensitivity test
        best_sens_idx = sens_table['sharpe'].idxmax()
        best_sens = sens_table.loc[best_sens_idx]
        print(f"\n🏆 Best in Sensitivity Test: EMA({int(best_sens['ema1'])},{int(best_sens['ema2'])},{int(best_sens['ema3'])}) → Sharpe: {best_sens['sharpe']:.3f}")
else:
    print("⚠️ No results available for sensitivity analysis.")
# Out:
# 🔬 Parameter Sensitivity Analysis for Best EMA(2,31,185)
# ================================================================================
#
# 📊 Sensitivity Results (76 variations tested):
#
#     ema1  ema2  ema3    sharpe   sortino  total_return  max_drawdown  volatility  total_trades  win_rate_pct  profit_factor  expectancy
# 16     2    16   185  0.988215  1.483010      1.426706     -0.331661    0.327380             1         100.0            inf    1.427419
# 17     2    17   185  0.988215  1.483010      1.426706     -0.331661    0.327380             1         100.0            inf    1.427419
# 18     2    18   185  0.988215  1.483010      1.426706     -0.331661    0.327380             1         100.0            inf    1.427419
# 19     2    19   185  1.020855  1.534895      1.510244     -0.331661    0.326836             1         100.0            inf    1.510999
# 20     2    20   185  1.020855  1.534895      1.510244     -0.331661    0.326836             1         100.0            inf    1.510999
# 21     2    21   185  1.006935  1.513522      1.472509     -0.331661    0.326740             1         100.0            inf    1.473245
# 22     2    22   185  1.006935  1.513522      1.472509     -0.331661    0.326740             1         100.0            inf    1.473245
# 23     2    23   185  1.006935  1.513522      1.472509     -0.331661    0.326740             1         100.0            inf    1.473245
# 24     2    24   185  1.000298  1.503464      1.454877     -0.331661    0.326722             1         100.0            inf    1.455605
# 25     2    25   185  1.000298  1.503464      1.454877     -0.331661    0.326722             1         100.0            inf    1.455605
# 26     2    26   185  0.951957  1.424501      1.323847     -0.331661    0.325282             1         100.0            inf    1.324509
# 27     2    27   185  0.951957  1.424501      1.323847     -0.331661    0.325282             1         100.0            inf    1.324509
# 28     2    28   185  0.951957  1.424501      1.323847     -0.331661    0.325282             1         100.0            inf    1.324509
# 29     2    29   185  0.970440  1.453040      1.369224     -0.331661    0.325095             1         100.0            inf    1.369908
# 30     2    30   185  0.970440  1.453040      1.369224     -0.331661    0.325095             1         100.0            inf    1.369908
# 46     2    31   170  0.766256  1.129446      0.923064     -0.331661    0.331627             2          50.0       7.676009    0.575979
# 47     2    31   171  0.766256  1.129446      0.923064     -0.331661    0.331627             2          50.0       7.676009    0.575979
# 48     2    31   172  0.766256  1.129446      0.923064     -0.331661    0.331627             2          50.0       7.676009    0.575979
# 49     2    31   173  0.766256  1.129446      0.923064     -0.331661    0.331627             2          50.0       7.676009    0.575979
# 50     2    31   174  0.766256  1.129446      0.923064     -0.331661    0.331627             2          50.0       7.676009    0.575979
# 51     2    31   175  0.766256  1.129446      0.923064     -0.331661    0.331627             2          50.0       7.676009    0.575979
# 52     2    31   176  0.766256  1.129446      0.923064     -0.331661    0.331627             2          50.0       7.676009    0.575979
# 53     2    31   177  0.766256  1.129446      0.923064     -0.331661    0.331627             2          50.0       7.676009    0.575979
# 54     2    31   178  0.766256  1.129446      0.923064     -0.331661    0.331627             2          50.0       7.676009    0.575979
# 55     2    31   179  0.784265  1.156637      0.960614     -0.331661    0.331446             2          50.0       7.939113    0.598678
# 56     2    31   180  0.784265  1.156637      0.960614     -0.331661    0.331446             2          50.0       7.939113    0.598678
# 57     2    31   181  0.970440  1.453040      1.369224     -0.331661    0.325095             1         100.0            inf    1.369908
# 58     2    31   182  0.970440  1.453040      1.369224     -0.331661    0.325095             1         100.0            inf    1.369908
# 59     2    31   183  0.970440  1.453040      1.369224     -0.331661    0.325095             1         100.0            inf    1.369908
# 60     2    31   184  0.970440  1.453040      1.369224     -0.331661    0.325095             1         100.0            inf    1.369908
# 0      2    31   185  0.970440  1.453040      1.369224     -0.331661    0.325095             1         100.0            inf    1.369908
# 61     2    31   186  0.970440  1.453040      1.369224     -0.331661    0.325095             1         100.0            inf    1.369908
# 62     2    31   187  1.010853  1.517872      1.469209     -0.331661    0.324292             1         100.0            inf    1.469943
# 63     2    31   188  1.010853  1.517872      1.469209     -0.331661    0.324292             1         100.0            inf    1.469943
# 64     2    31   189  1.010853  1.517872      1.469209     -0.331661    0.324292             1         100.0            inf    1.469943
# 65     2    31   190  1.010853  1.517872      1.469209     -0.331661    0.324292             1         100.0            inf    1.469943
# 66     2    31   191  1.010853  1.517872      1.469209     -0.331661    0.324292             1         100.0            inf    1.469943
# 67     2    31   192  0.991411  1.487776      1.417591     -0.331661    0.324096             1         100.0            inf    1.418300
# 68     2    31   193  0.991411  1.487776      1.417591     -0.331661    0.324096             1         100.0            inf    1.418300
# 69     2    31   194  0.991411  1.487776      1.417591     -0.331661    0.324096             1         100.0            inf    1.418300
# 70     2    31   195  0.991411  1.487776      1.417591     -0.331661    0.324096             1         100.0            inf    1.418300
# 71     2    31   196  0.991411  1.487776      1.417591     -0.331661    0.324096             1         100.0            inf    1.418300
# 72     2    31   197  0.991411  1.487776      1.417591     -0.331661    0.324096             1         100.0            inf    1.418300
# 73     2    31   198  1.004286  1.507536      1.450407     -0.331661    0.324001             1         100.0            inf    1.451132
# 74     2    31   199  1.004286  1.507536      1.450407     -0.331661    0.324001             1         100.0            inf    1.451132
# 75     2    31   200  1.004286  1.507536      1.450407     -0.331661    0.324001             1         100.0            inf    1.451132
# 31     2    32   185  1.010853  1.517872      1.469209     -0.331661    0.324292             1         100.0            inf    1.469943
# 32     2    33   185  1.010853  1.517872      1.469209     -0.331661    0.324292             1         100.0            inf    1.469943
# 33     2    34   185  0.991411  1.487776      1.417591     -0.331661    0.324096             1         100.0            inf    1.418300
# 34     2    35   185  0.991411  1.487776      1.417591     -0.331661    0.324096             1         100.0            inf    1.418300
# 35     2    36   185  1.004286  1.507536      1.450407     -0.331661    0.324001             1         100.0            inf    1.451132
# 36     2    37   185  1.004286  1.507536      1.450407     -0.331661    0.324001             1         100.0            inf    1.451132
# 37     2    38   185  1.004286  1.507536      1.450407     -0.331661    0.324001             1         100.0            inf    1.451132
# 38     2    39   185  1.004286  1.507536      1.450407     -0.331661    0.324001             1         100.0            inf    1.451132
# 39     2    40   185  1.016860  1.526833      1.482877     -0.331661    0.323909             1         100.0            inf    1.483618
# 40     2    41   185  1.016860  1.526833      1.482877     -0.331661    0.323909             1         100.0            inf    1.483618
# 41     2    42   185  1.033662  1.552842      1.526707     -0.331661    0.323753             1         100.0            inf    1.527470
# 42     2    43   185  1.050291  1.578599      1.570811     -0.331661    0.323599             1         100.0            inf    1.571596
# 43     2    44   185  1.010792  1.514924      1.460026     -0.331661    0.322682             1         100.0            inf    1.460756
# 44     2    45   185  1.010792  1.514924      1.460026     -0.331661    0.322682             1         100.0            inf    1.460756
# 45     2    46   185  1.024857  1.536536      1.496300     -0.331661    0.322570             1         100.0            inf    1.497048
# 1      3    31   185  0.970440  1.453040      1.369224     -0.331661    0.325095             1         100.0            inf    1.369908
# 2      4    31   185  0.970440  1.453040      1.369224     -0.331661    0.325095             1         100.0            inf    1.369908
# 3      5    31   185  0.970440  1.453040      1.369224     -0.331661    0.325095             1         100.0            inf    1.369908
# 4      6    31   185  0.970440  1.453040      1.369224     -0.331661    0.325095             1         100.0            inf    1.369908
# 5      7    31   185  0.970440  1.453040      1.369224     -0.331661    0.325095             1         100.0            inf    1.369908
# 6      8    31   185  0.970440  1.453040      1.369224     -0.331661    0.325095             1         100.0            inf    1.369908
# 7      9    31   185  0.970440  1.453040      1.369224     -0.331661    0.325095             1         100.0            inf    1.369908
# 8     10    31   185  0.970440  1.453040      1.369224     -0.331661    0.325095             1         100.0            inf    1.369908
# 9     11    31   185  0.970440  1.453040      1.369224     -0.331661    0.325095             1         100.0            inf    1.369908
# 10    12    31   185  0.970440  1.453040      1.369224     -0.331661    0.325095             1         100.0            inf    1.369908
# 11    13    31   185  0.970440  1.453040      1.369224     -0.331661    0.325095             1         100.0            inf    1.369908
# 12    14    31   185  0.970440  1.453040      1.369224     -0.331661    0.325095             1         100.0            inf    1.369908
# 13    15    31   185  0.970440  1.453040      1.369224     -0.331661    0.325095             1         100.0            inf    1.369908
# 14    16    31   185  0.970440  1.453040      1.369224     -0.331661    0.325095             1         100.0            inf    1.369908
# 15    17    31   185  0.970440  1.453040      1.369224     -0.331661    0.325095             1         100.0            inf    1.369908
#
# 📈 Sensitivity Summary (mean / std / min / max):
#                   mean      std      min       max
# sharpe          0.9588   0.0809   0.7663    1.0503
# sortino         1.4351   0.1286   1.1294    1.5786
# total_return    1.3497   0.1810   0.9231    1.5708
# max_drawdown   -0.3317   0.0000  -0.3317   -0.3317
# volatility      0.3258   0.0026   0.3226    0.3316
# win_rate_pct   92.7632  17.7087  50.0000  100.0000
# profit_factor      inf      NaN   7.6760       inf
# expectancy      1.2997   0.3022   0.5760    1.5716
#
# 🏆 Best in Sensitivity Test: EMA(2,43,185) → Sharpe: 1.050
# c:\Users\harka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning:
#
# invalid value encountered in subtract
