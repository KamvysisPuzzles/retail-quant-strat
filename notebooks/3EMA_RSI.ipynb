# %%
# Out:
# C:\Users\harka\AppData\Local\Temp\ipykernel_12348\1833448086.py:8: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# [*********************100%***********************]  1 of 1 completed
# Successfully downloaded 1970 records for GLD
# Data range: 2018-01-02 to 2025-10-31
# Price            Close        High         Low        Open    Volume
# Ticker             GLD         GLD         GLD         GLD       GLD
# Date
# 2018-01-02  125.150002  125.180000  124.389999  124.660004  11762500
# 2018-01-03  124.820000  125.089996  124.099998  125.050003   7904300
# 2018-01-04  125.459999  125.849998  124.739998  124.889999   7329700
# 2018-01-05  125.330002  125.480003  124.830002  124.930000   5739900
# 2018-01-08  125.309998  125.320000  124.900002  125.199997   3566700
# ...                ...         ...         ...         ...       ...
# 2025-10-27  367.010010  371.589996  365.339996  371.130005  23657600
# ...

# %%
# Out:
# ...
# DATA SPLIT INFORMATION
# ...
# Training Period (In-Sample):   2018-01-02 to 2022-09-12
#   Duration: 1182 days (~4.7 years)
#
# Validation Period (Out-of-Sample): 2022-09-13 to 2025-10-31
#   Duration: 788 days (~3.1 years)
#
# Split Ratio: 60% / 40%
# ...

# %%
# Out:
# ...
# HARDCODED ENSEMBLE STRATEGY PARAMETERS
# ...
# Triple EMA:
#   EMA1 (Fast):   38
#   EMA2 (Medium):   101
#   EMA3 (Slow):     210
#
# RSI:
#   RSI Period:       18
#   Oversold Threshold: 72
#   Overbought Threshold: 126
# ...
#
# Strategy Logic: 3EMA OR RSI (any indicator triggers signal)
# ...

# %%
# Out:
# ✅ Ensemble strategy evaluation function created!
# Function combines 3EMA + RSI with OR logic.

# %%
# Out:
# ✅ Ensemble Strategy Evaluation Complete!
# Total Return: 38.05%
# Sharpe Ratio: 0.766
# Sortino Ratio: 1.065
# Total Trades: 5

# %%
# Out:
# ...
# ENSEMBLE STRATEGY EVALUATION RESULTS
# ...
#
# Strategy Parameters:
#   EMA1: 38, EMA2: 101, EMA3: 210
#   RSI: Period=18, Oversold=72, Overbought=126
#
# 📊 Performance Metrics (Training Set):
#   Total Return:      38.05%
#   Annualized Return: 7.11%
#   Sharpe Ratio:      0.766
#   Sortino Ratio:     1.065
#   Max Drawdown:      -19.66%
#   Volatility:        14.35%
#   Total Trades:     5
#   Win Rate:          40.0%
#   Profit Factor:     6.03
#   Trades per Year:   1.1
# ...

# %%
# Out:
# 📊 Performance Metrics (Validation Set):
#   Total Return:      nan%
#   Annualized Return: nan%
#   Sharpe Ratio:      nan
#   Sortino Ratio:     nan
#   Max Drawdown:      nan%
#   Total Trades:      1
#   Win Rate:          nan%
#   Profit Factor:     nan
#
# ...
# IN-SAMPLE vs OUT-OF-SAMPLE COMPARISON
# ...
# METRIC                    IN-SAMPLE       OUT-OF-SAMPLE   CHANGE
#
# RETURN METRICS:
# Total Return              38.05%          nan%            N/A
# Annualized Return         7.11%           nan%            N/A
#
# RISK-ADJUSTED METRICS:
# Sharpe Ratio              0.766           nan             N/A
# Sortino Ratio             1.065           nan             N/A
#
# TRADE METRICS:
# Total Trades              5               1               -80.0%
# Win Rate %                40.0            nan             N/A
# Profit Factor             6.03            nan             N/A
